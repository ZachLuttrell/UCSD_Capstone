# %% [markdown]
# # Training The Baseline:
#
# **ITERATION 2:**
# Training the U-Net without the VGG16 backbone, and only training on 20% of the dataset to reduce training times.

# %% [markdown]
# Mount the Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# Install and import any libraries necessary.

# %%
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load in the images and their corresponding masks

# %%
# A quick check on total contents of the image and mask directories

import os

def count_files(directory, extension=".tif"):
    # List all files in the directory and count those with the specified extension
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")
# Out:
# Number of image files: 5632
# Number of mask files: 5632

# %%
import os
import numpy as np
import tifffile as tiff

# Set the image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/images'
mask_directory = '/gdrive/My Drive/Dataset/patches/masks'

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage (e.g., 20%)
percentage_to_load = 10 / 100.0  # size of dataset
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
count = 0
print(f'Preparing to load {number_of_files_to_load} image/mask pairs...')
for image_name in image_files[:number_of_files_to_load]:
    img_path = os.path.join(image_directory, image_name)
    mask_name = image_to_mask[image_name]
    mask_path = os.path.join(mask_directory, mask_name)

    if os.path.exists(mask_path):
        img = tiff.imread(img_path)
        mask = tiff.imread(mask_path)

        images.append(img)
        masks.append(mask)
    else:
        print(f'Mask not found for image: {image_name}')

    # update the count
    count += 1
    print(f'Processed: {count}')

# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))  # Adjust as per your channel needs
# Out:
# Preparing to load 563 image/mask pairs...
# Processed: 1
# Processed: 2
# Processed: 3
# Processed: 4
# Processed: 5
# Processed: 6
# Processed: 7
# Processed: 8
# Processed: 9
# Processed: 10
# Processed: 11
# Processed: 12
# Processed: 13
# Processed: 14
# Processed: 15
# Processed: 16
# Processed: 17
# Processed: 18
# Processed: 19
# Processed: 20
# Processed: 21
# Processed: 22
# Processed: 23
# Processed: 24
# Processed: 25
# Processed: 26
# Processed: 27
# Processed: 28
# Processed: 29
# Processed: 30
# Processed: 31
# Processed: 32
# Processed: 33
# Processed: 34
# Processed: 35
# Processed: 36
# Processed: 37
# Processed: 38
# Processed: 39
# Processed: 40
# Processed: 41
# Processed: 42
# Processed: 43
# Processed: 44
# Processed: 45
# Processed: 46
# Processed: 47
# Processed: 48
# Processed: 49
# Processed: 50
# Processed: 51
# Processed: 52
# Processed: 53
# Processed: 54
# Processed: 55
# Processed: 56
# Processed: 57
# Processed: 58
# Processed: 59
# Processed: 60
# Processed: 61
# Processed: 62
# Processed: 63
# Processed: 64
# Processed: 65
# Processed: 66
# Processed: 67
# Processed: 68
# Processed: 69
# Processed: 70
# Processed: 71
# Processed: 72
# Processed: 73
# Processed: 74
# Processed: 75
# Processed: 76
# Processed: 77
# Processed: 78
# Processed: 79
# Processed: 80
# Processed: 81
# Processed: 82
# Processed: 83
# Processed: 84
# Processed: 85
# Processed: 86
# Processed: 87
# Processed: 88
# Processed: 89
# Processed: 90
# Processed: 91
# Processed: 92
# Processed: 93
# Processed: 94
# Processed: 95
# Processed: 96
# Processed: 97
# Processed: 98
# Processed: 99
# Processed: 100
# Processed: 101
# Processed: 102
# Processed: 103
# Processed: 104
# Processed: 105
# Processed: 106
# Processed: 107
# Processed: 108
# Processed: 109
# Processed: 110
# Processed: 111
# Processed: 112
# Processed: 113
# Processed: 114
# Processed: 115
# Processed: 116
# Processed: 117
# Processed: 118
# Processed: 119
# Processed: 120
# Processed: 121
# Processed: 122
# Processed: 123
# Processed: 521
# Processed: 522
# Processed: 523
# Processed: 524
# Processed: 525
# Processed: 526
# Processed: 527
# Processed: 528
# Processed: 529
# Processed: 530
# Processed: 531
# Processed: 532
# Processed: 533
# Processed: 534
# Processed: 535
# Processed: 536
# Processed: 537
# Processed: 538
# Processed: 539
# Processed: 540
# Processed: 541
# Processed: 542
# Processed: 543
# Processed: 544
# Processed: 545
# Processed: 546
# Processed: 547
# Processed: 548
# Processed: 549
# Processed: 550
# Processed: 551
# Processed: 552
# Processed: 553
# Processed: 554
# Processed: 555
# Processed: 556
# Processed: 557
# Processed: 558
# Processed: 559
# Processed: 560
# Processed: 561
# Processed: 562
# Processed: 563

# %% [markdown]
# Perform the Train/Test/Val Split

# %%
# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# Show the shapes
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}')
print(f'y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}')
print(f'y_val:   {y_val.shape}')
print(f'X_test:  {X_test.shape}')
print(f'y_test:  {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (405, 1, 256, 256, 3)
# y_train: (405, 256, 256, 1)
# X_val:   (45, 1, 256, 256, 3)
# y_val:   (45, 256, 256, 1)
# X_test:  (113, 1, 256, 256, 3)
# y_test:  (113, 256, 256, 1)

# %%
# If X_train, X_test, X_val have an extra unnecessary dimension at axis=1, you can remove it:
X_train = X_train.squeeze(axis=1)
X_test = X_test.squeeze(axis=1)
X_val = X_val.squeeze(axis=1)

# %% [markdown]
# Define the Model

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.backend import epsilon

def dice_coefficient(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + epsilon())

def jaccard_index(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + epsilon()) / (union + epsilon())

def simple_unet_model(input_size=(256, 256, 3)):
    inputs = Input(input_size)

    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    # Bottleneck
    c5 = Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    # Decoder
    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = UpSampling2D((2, 2))(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = UpSampling2D((2, 2))(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %% [markdown]
# Compile the Model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Create the model
model = simple_unet_model(input_size=(256, 256, 3))

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=BinaryCrossentropy(),
    metrics=['accuracy', dice_coefficient, jaccard_index]
)

# Print a summary
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_57 (Conv2D)          (None, 256, 256, 64)         1792      ['input_4[0][0]']
#
#  dropout_27 (Dropout)        (None, 256, 256, 64)         0         ['conv2d_57[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 256, 256, 64)         36928     ['dropout_27[0][0]']
#
#  max_pooling2d_12 (MaxPooli  (None, 128, 128, 64)         0         ['conv2d_58[0][0]']
#  ng2D)
#
#  conv2d_59 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_12[0][0]']
#
#  dropout_28 (Dropout)        (None, 128, 128, 128)        0         ['conv2d_59[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 128, 128, 128)        147584    ['dropout_28[0][0]']
#
#  max_pooling2d_13 (MaxPooli  (None, 64, 64, 128)          0         ['conv2d_60[0][0]']
#  ng2D)
#
#  conv2d_61 (Conv2D)          (None, 64, 64, 256)          295168    ['max_pooling2d_13[0][0]']
#
#  dropout_29 (Dropout)        (None, 64, 64, 256)          0         ['conv2d_61[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 64, 64, 256)          590080    ['dropout_29[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 32, 32, 256)          0         ['conv2d_62[0][0]']
#  ng2D)
#
#  conv2d_63 (Conv2D)          (None, 32, 32, 512)          1180160   ['max_pooling2d_14[0][0]']
#
#  dropout_30 (Dropout)        (None, 32, 32, 512)          0         ['conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 32, 32, 512)          2359808   ['dropout_30[0][0]']
#
#  max_pooling2d_15 (MaxPooli  (None, 16, 16, 512)          0         ['conv2d_64[0][0]']
#  ng2D)
#
#  conv2d_65 (Conv2D)          (None, 16, 16, 1024)         4719616   ['max_pooling2d_15[0][0]']
#
#  dropout_31 (Dropout)        (None, 16, 16, 1024)         0         ['conv2d_65[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 16, 16, 1024)         9438208   ['dropout_31[0][0]']
#
#  up_sampling2d_12 (UpSampli  (None, 32, 32, 1024)         0         ['conv2d_66[0][0]']
#  ng2D)
#
#  concatenate_12 (Concatenat  (None, 32, 32, 1536)         0         ['up_sampling2d_12[0][0]',
#  e)                                                                  'conv2d_64[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 32, 32, 512)          7078400   ['concatenate_12[0][0]']
#
#  dropout_32 (Dropout)        (None, 32, 32, 512)          0         ['conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 32, 32, 512)          2359808   ['dropout_32[0][0]']
#
#  up_sampling2d_13 (UpSampli  (None, 64, 64, 512)          0         ['conv2d_68[0][0]']
#  ng2D)
#
#  concatenate_13 (Concatenat  (None, 64, 64, 768)          0         ['up_sampling2d_13[0][0]',
#  e)                                                                  'conv2d_62[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 64, 64, 256)          1769728   ['concatenate_13[0][0]']
#
#  dropout_33 (Dropout)        (None, 64, 64, 256)          0         ['conv2d_69[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 64, 64, 256)          590080    ['dropout_33[0][0]']
#
#  up_sampling2d_14 (UpSampli  (None, 128, 128, 256)        0         ['conv2d_70[0][0]']
#  ng2D)
#
#  concatenate_14 (Concatenat  (None, 128, 128, 384)        0         ['up_sampling2d_14[0][0]',
#  e)                                                                  'conv2d_60[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 128, 128, 128)        442496    ['concatenate_14[0][0]']
#
#  dropout_34 (Dropout)        (None, 128, 128, 128)        0         ['conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 128, 128, 128)        147584    ['dropout_34[0][0]']
#
#  up_sampling2d_15 (UpSampli  (None, 256, 256, 128)        0         ['conv2d_72[0][0]']
#  ng2D)
#
#  concatenate_15 (Concatenat  (None, 256, 256, 192)        0         ['up_sampling2d_15[0][0]',
#  e)                                                                  'conv2d_58[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 256, 256, 64)         110656    ['concatenate_15[0][0]']
#
#  dropout_35 (Dropout)        (None, 256, 256, 64)         0         ['conv2d_73[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 256, 256, 64)         36928     ['dropout_35[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 256, 256, 1)          65        ['conv2d_74[0][0]']
#
# ==================================================================================================
# Total params: 31378945 (119.70 MB)
# Trainable params: 31378945 (119.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# Train the Model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf


# Early Stopping to prevent overfitting
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True
)

# Model Checkpoint to save the best model during training
model_checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=16,
    callbacks=[early_stopping, model_checkpoint],
    verbose=1  # Set to 2 for one line per epoch, 1 for a progress bar
)

# Save the Model
model_save_path = '/content/drive/My Drive/Dataset/Models/unet_1.h5'  # Change 'my_model' to your preferred model name
model.save(model_save_path)

print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/50
# 51/51 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.9036 - dice_coefficient: 0.0634 - jaccard_index: 0.0329
# Epoch 1: val_loss improved from inf to 0.30313, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 51/51 [==============================] - 1077s 21s/step - loss: 0.3508 - accuracy: 0.9036 - dice_coefficient: 0.0634 - jaccard_index: 0.0329 - val_loss: 0.3031 - val_accuracy: 0.9427 - val_dice_coefficient: 0.0857 - val_jaccard_index: 0.0448
# Epoch 2/50
# 51/51 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9367 - dice_coefficient: 0.0747 - jaccard_index: 0.0390
# Epoch 2: val_loss improved from 0.30313 to 0.22221, saving model to best_model.h5
# 51/51 [==============================] - 1070s 21s/step - loss: 0.2492 - accuracy: 0.9367 - dice_coefficient: 0.0747 - jaccard_index: 0.0390 - val_loss: 0.2222 - val_accuracy: 0.9427 - val_dice_coefficient: 0.1014 - val_jaccard_index: 0.0534
# Epoch 3/50
# 51/51 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9367 - dice_coefficient: 0.0916 - jaccard_index: 0.0482
# Epoch 3: val_loss improved from 0.22221 to 0.20655, saving model to best_model.h5
# 51/51 [==============================] - 1067s 21s/step - loss: 0.2391 - accuracy: 0.9367 - dice_coefficient: 0.0916 - jaccard_index: 0.0482 - val_loss: 0.2066 - val_accuracy: 0.9427 - val_dice_coefficient: 0.1015 - val_jaccard_index: 0.0535
# Epoch 4/50
# 51/51 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9368 - dice_coefficient: 0.1251 - jaccard_index: 0.0670
# Epoch 4: val_loss improved from 0.20655 to 0.20158, saving model to best_model.h5
# 51/51 [==============================] - 1065s 21s/step - loss: 0.2122 - accuracy: 0.9368 - dice_coefficient: 0.1251 - jaccard_index: 0.0670 - val_loss: 0.2016 - val_accuracy: 0.9430 - val_dice_coefficient: 0.1269 - val_jaccard_index: 0.0679
# Epoch 5/50
# 51/51 [==============================] - ETA: 0s - loss: 0.2009 - accuracy: 0.9376 - dice_coefficient: 0.1550 - jaccard_index: 0.0843
# Epoch 5: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1065s 21s/step - loss: 0.2009 - accuracy: 0.9376 - dice_coefficient: 0.1550 - jaccard_index: 0.0843 - val_loss: 0.2197 - val_accuracy: 0.9430 - val_dice_coefficient: 0.1069 - val_jaccard_index: 0.0566
# Epoch 6/50
# 51/51 [==============================] - ETA: 0s - loss: 0.2014 - accuracy: 0.9379 - dice_coefficient: 0.1551 - jaccard_index: 0.0842
# Epoch 6: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1065s 21s/step - loss: 0.2014 - accuracy: 0.9379 - dice_coefficient: 0.1551 - jaccard_index: 0.0842 - val_loss: 0.2261 - val_accuracy: 0.9433 - val_dice_coefficient: 0.1352 - val_jaccard_index: 0.0727
# Epoch 7/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9387 - dice_coefficient: 0.1760 - jaccard_index: 0.0968
# Epoch 7: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1065s 21s/step - loss: 0.1926 - accuracy: 0.9387 - dice_coefficient: 0.1760 - jaccard_index: 0.0968 - val_loss: 0.3446 - val_accuracy: 0.9431 - val_dice_coefficient: 0.0706 - val_jaccard_index: 0.0368
# Epoch 8/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9384 - dice_coefficient: 0.1737 - jaccard_index: 0.0953
# Epoch 8: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1065s 21s/step - loss: 0.1941 - accuracy: 0.9384 - dice_coefficient: 0.1737 - jaccard_index: 0.0953 - val_loss: 0.2579 - val_accuracy: 0.9433 - val_dice_coefficient: 0.1243 - val_jaccard_index: 0.0666
# Epoch 9/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9389 - dice_coefficient: 0.1857 - jaccard_index: 0.1027
# Epoch 9: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1066s 21s/step - loss: 0.1891 - accuracy: 0.9389 - dice_coefficient: 0.1857 - jaccard_index: 0.1027 - val_loss: 0.2919 - val_accuracy: 0.9433 - val_dice_coefficient: 0.1146 - val_jaccard_index: 0.0611
# Epoch 10/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9390 - dice_coefficient: 0.1937 - jaccard_index: 0.1075
# Epoch 10: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1066s 21s/step - loss: 0.1857 - accuracy: 0.9390 - dice_coefficient: 0.1937 - jaccard_index: 0.1075 - val_loss: 0.3470 - val_accuracy: 0.9432 - val_dice_coefficient: 0.0949 - val_jaccard_index: 0.0502
# Epoch 11/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9388 - dice_coefficient: 0.1906 - jaccard_index: 0.1058
# Epoch 11: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1064s 21s/step - loss: 0.1880 - accuracy: 0.9388 - dice_coefficient: 0.1906 - jaccard_index: 0.1058 - val_loss: 0.2190 - val_accuracy: 0.9434 - val_dice_coefficient: 0.1641 - val_jaccard_index: 0.0897
# Epoch 12/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1833 - accuracy: 0.9398 - dice_coefficient: 0.2018 - jaccard_index: 0.1125
# Epoch 12: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1072s 21s/step - loss: 0.1833 - accuracy: 0.9398 - dice_coefficient: 0.2018 - jaccard_index: 0.1125 - val_loss: 0.2918 - val_accuracy: 0.9436 - val_dice_coefficient: 0.1180 - val_jaccard_index: 0.0631
# Epoch 13/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1826 - accuracy: 0.9398 - dice_coefficient: 0.2071 - jaccard_index: 0.1159
# Epoch 13: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1066s 21s/step - loss: 0.1826 - accuracy: 0.9398 - dice_coefficient: 0.2071 - jaccard_index: 0.1159 - val_loss: 0.3253 - val_accuracy: 0.9436 - val_dice_coefficient: 0.1100 - val_jaccard_index: 0.0586
# Epoch 14/50
# 51/51 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.9400 - dice_coefficient: 0.2122 - jaccard_index: 0.1190 Restoring model weights from the end of the best epoch: 4.
#
# Epoch 14: val_loss did not improve from 0.20158
# 51/51 [==============================] - 1067s 21s/step - loss: 0.1791 - accuracy: 0.9400 - dice_coefficient: 0.2122 - jaccard_index: 0.1190 - val_loss: 0.2623 - val_accuracy: 0.9436 - val_dice_coefficient: 0.1586 - val_jaccard_index: 0.0866
# Epoch 14: early stopping
# Model saved to /content/drive/My Drive/Dataset/Models/unet_1.h5

# %% [markdown]
# Evaluate The Model

# %%
# Save the Model
model_save_path = '/gdrive/My Drive/Dataset/Models/unet_1.h5'  # Change 'my_model' to your preferred model name
model.save(model_save_path)

print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /gdrive/My Drive/Dataset/Models/unet_1.h5

# %% [markdown]
# # Evaluation

# %%
# LOAD THE MODEL
model_name = 'unet_1' # SET THIS

from tensorflow.keras.models import load_model
import tensorflow as tf

def dice_coefficient(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + epsilon())

def jaccard_index(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + epsilon()) / (union + epsilon())

# Path to your saved model
model_save_path = f'/gdrive/My Drive/Dataset/Models/{model_name}.h5'

# Load the model with the custom object
model = load_model(model_save_path, custom_objects={'dice_coefficient': dice_coefficient, 'jaccard_index': jaccard_index})

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import tensorflow as tf

# Function to make predictions
def make_prediction(model, image):
    image = np.expand_dims(image, axis=0)  # Expand dims to add the batch size
    pred_mask = model.predict(image)[0]    # Make prediction
    return pred_mask

# Select a random example
index = np.random.randint(0, len(X_test))  # Choose a random index from the test set
sample_image = X_test[index]
sample_mask = y_test[index]

# Get the model prediction
predicted_mask = make_prediction(model, sample_image)

# Post-process the predicted mask
predicted_mask = (predicted_mask > 0.5).astype(np.float32)  # Threshold probabilities to create a binary mask

# Plotting
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].imshow(sample_image)
ax[0].title.set_text('Original Image')
ax[0].axis('off')

ax[1].imshow(sample_mask.squeeze(), cmap='gray')  # Assuming mask is single-channel
ax[1].title.set_text('True Mask')
ax[1].axis('off')

ax[2].imshow(predicted_mask.squeeze(), cmap='gray')  # Same as above for the predicted mask
ax[2].title.set_text('Predicted Mask')
ax[2].axis('off')

plt.show()
print(f'Index No.: {index}')

########### SHOW CONFUSION MATRIX
# Prediction and preprocessing as before
def predict_mask(model, image):
    pred = model.predict(np.expand_dims(image, axis=0))
    return (pred > 0.5).astype(np.float32)  # Apply a threshold to convert probabilities to binary mask

# Sample selection

# index = np.random.randint(0, len(X_test))

sample_image = X_test[index]
true_mask = y_test[index].squeeze()

# Get the prediction
pred_mask = predict_mask(model, sample_image).squeeze()

# Flatten arrays for confusion matrix computation
true_mask_flat = true_mask.flatten()
pred_mask_flat = pred_mask.flatten()

# Compute the confusion matrix
cm = confusion_matrix(true_mask_flat, pred_mask_flat, labels=[0, 1])

# Custom annotations
group_names = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)

# Plotting
fig, ax = plt.subplots(figsize=(8, 8))
sns.heatmap(cm, annot=labels, fmt='', ax=ax, cmap='Blues', cbar=False)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['Background', 'Object'])
ax.yaxis.set_ticklabels(['Background', 'Object'])
plt.show()
print(f'Index No.: {index}')
# Out:
# 1/1 [==============================] - 0s 412ms/step
# Index No.: 11
# 1/1 [==============================] - 0s 469ms/step
# Index No.: 11

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Function to make predictions
def make_prediction(model, image):
    image = np.expand_dims(image, axis=0)  # Ensure image has batch dimension
    pred_mask = model.predict(image)[0]    # Make prediction and remove batch dimension
    return pred_mask

# Select a random example
index = np.random.randint(0, len(X_test))
sample_image = X_test[index]
sample_mask = y_test[index].squeeze()  # Ensure the mask is 2D

# Get the model prediction
predicted_mask = make_prediction(model, sample_image)
predicted_mask = predicted_mask.squeeze()  # Ensure the mask is 2D
predicted_mask = (predicted_mask > 0.5).astype(np.float32)  # Threshold to create a binary mask

# Create an overlay image
overlay_image = np.zeros((sample_mask.shape[0]*2, sample_mask.shape[1]*2, 3))  # Initialize an overlay with 3 channels, doubled size
true_positive = (predicted_mask == 1) & (sample_mask == 1)
false_negative = (predicted_mask == 0) & (sample_mask == 1)

# Scaling up the images for better visibility
sample_image_large = np.kron(sample_image, np.ones((2,2,1)))
sample_mask_large = np.kron(sample_mask, np.ones((2,2)))
predicted_mask_large = np.kron(predicted_mask, np.ones((2,2)))

# Assigning colors
overlay_image[:, :, 1] = np.kron(true_positive, np.ones((2,2))) * 1  # True positive in orange (using green and red channels)
overlay_image[:, :, 0] = np.kron(true_positive, np.ones((2,2))) * 0.6
overlay_image[:, :, 2] = np.kron(false_negative, np.ones((2,2))) * 1  # False negative in blue

# Plotting
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axs[0, 0].imshow(sample_image_large)
axs[0, 0].title.set_text('Original Image')
axs[0, 0].axis('off')

axs[0, 1].imshow(sample_mask_large, cmap='gray')
axs[0, 1].title.set_text('True Mask')
axs[0, 1].axis('off')

axs[0, 2].imshow(predicted_mask_large, cmap='gray')
axs[0, 2].title.set_text('Predicted Mask')
axs[0, 2].axis('off')

axs[1, 0].axis('off')
axs[1, 1].imshow(overlay_image)
axs[1, 1].title.set_text('Overlay')
axs[1, 1].axis('off')
axs[1, 2].axis('off')

plt.show()
print(f'Index No.: {index}')


########### SHOW CONFUSION MATRIX
# Prediction and preprocessing as before
def predict_mask(model, image):
    pred = model.predict(np.expand_dims(image, axis=0))
    return (pred > 0.5).astype(np.float32)  # Apply a threshold to convert probabilities to binary mask

# Sample selection

# index = np.random.randint(0, len(X_test))

sample_image = X_test[index]
true_mask = y_test[index].squeeze()

# Get the prediction
pred_mask = predict_mask(model, sample_image).squeeze()

# Flatten arrays for confusion matrix computation
true_mask_flat = true_mask.flatten()
pred_mask_flat = pred_mask.flatten()

# Compute the confusion matrix
cm = confusion_matrix(true_mask_flat, pred_mask_flat, labels=[0, 1])

# Custom annotations
group_names = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)

# Plotting
fig, ax = plt.subplots(figsize=(8, 8))
sns.heatmap(cm, annot=labels, fmt='', ax=ax, cmap='Blues', cbar=False)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['Background', 'Object'])
ax.yaxis.set_ticklabels(['Background', 'Object'])
plt.show()
print(f'Index No.: {index}')
# Out:
# 1/1 [==============================] - 0s 433ms/step
# Index No.: 97
# 1/1 [==============================] - 0s 469ms/step
# Index No.: 97
