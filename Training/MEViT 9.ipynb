# %% [markdown]
# # MEViT
#
# This is the 9th iteration of MEViT.
#
# In this iteration I have included the following changes:
#
# - increased the dataset % to 50%
#
#
#
# **NOTE:** Connect to a High-RAM Environment

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# MODEL SETTINGS
model_name = 'mevit_model_9'
percentage_to_load = 50 / 100.0  # Set the % of dataset to be loaded here.
threshold = 0.5  # Set the threshold for metrics here
scale_factor = 2.0  # Factor by which to scale images and masks
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load*100}%')
print(f'Threshold: {threshold}')
print(f'Scale Factor: {scale_factor}')
# Out:
# Model Name: mevit_model_9
# Percentage to Load: 50.0%
# Threshold: 0.5
# Scale Factor: 2.0

# %% [markdown]
# Imports

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Mounted at /gdrive

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(tqdm(image_files[:number_of_files_to_load]), start=1):
    try:
        img_path = os.path.join(image_directory, image_name)
        mask_name = image_to_mask[image_name]
        mask_path = os.path.join(mask_directory, mask_name)

        if os.path.exists(mask_path):
            img = tiff.imread(img_path)
            mask = tiff.imread(mask_path)

            images.append(img)
            masks.append(mask)
        else:
            print(f'\nMask not found for image: {image_name}')
    except Exception as e:
        print(f'\nError loading image/mask pair {image_name}: {e}')

print("\nLoading complete.")

# Check if the number of images and masks loaded are equal
if len(images) != len(masks):
    raise ValueError("The number of loaded images and masks do not match!")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 50.0% of dataset: 2393 images/mask pairs...
# 100%|██████████| 2393/2393 [30:35<00:00,  1.30it/s]
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Function to resize and normalize images and masks
def preprocess_images_and_masks(images, masks, scale_factor):
    # Squeeze unnecessary singleton dimensions
    if images.ndim > 3 and images.shape[1] == 1:
        images = images.squeeze(axis=1)
    if masks.ndim > 3 and masks.shape[1] == 1:
        masks = masks.squeeze(axis=1)

    print(f"Original image shape: {images.shape}")
    new_size = (int(images.shape[1] * scale_factor), int(images.shape[2] * scale_factor))
    print(f"New size: {new_size}")

    if new_size[0] <= 0 or new_size[1] <= 0:
        raise ValueError("Scale factor resulted in invalid size. Check the scale factor and original dimensions.")

    resized_images = []
    resized_masks = []
    print("Resizing images and masks...")
    for img, mask in tqdm(zip(images, masks), total=len(images)):

        try:
            resized_img = cv2.resize(img, new_size)
            resized_mask = cv2.resize(mask, new_size, interpolation=cv2.INTER_NEAREST)
            resized_images.append(resized_img)
            resized_masks.append(resized_mask)
        except Exception as e:
            print(f"Error resizing image/mask pair: {e}")
            raise

    resized_images = np.array(resized_images, dtype=np.float32)
    resized_masks = np.array(resized_masks, dtype=np.float32)

    # Normalize images and masks
    resized_images /= 255.0
    resized_masks /= 255.0
    resized_masks = resized_masks.reshape((-1, new_size[0], new_size[1], 1))

    return resized_images, resized_masks

# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Resize and normalize images and masks
images, masks = preprocess_images_and_masks(images, masks, scale_factor)

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Original image shape: (2393, 256, 256, 3)
# New size: (512, 512)
# Resizing images and masks...
# 100%|██████████| 2393/2393 [00:02<00:00, 917.36it/s]
# Dataset Shapes:
# X_train: (1722, 512, 512, 3), y_train: (1722, 512, 512, 1)
# X_val:   (192, 512, 512, 3), y_val: (192, 512, 512, 1)
# X_test:  (479, 512, 512, 3), y_test: (479, 512, 512, 1)

# %% [markdown]
# Metrics & Loss

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# Custom Metrics
def dice_coefficient(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

def jaccard_index(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

def sensitivity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    possible_positives = tf.reduce_sum(y_true_f)
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_negatives = tf.reduce_sum((1-y_true_f) * (1-y_pred_f))
    possible_negatives = tf.reduce_sum(1-y_true_f)
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    predicted_positives = tf.reduce_sum(y_pred_f)
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# Loss Function
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)

# Visualize class weight distribution
plt.bar(class_weights.keys(), class_weights.values())
plt.title("Class Weight Distribution")
plt.xlabel("Class")
plt.ylabel("Weight")
plt.show()

weighted_loss = weighted_binary_crossentropy(class_weights)
# Out:
# Class weights: {0: 0.5339968946194886, 1: 7.853612816644959}

# %% [markdown]
# Model Definition

# %%
# Define the MEViT model
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = models.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim):
    inputs = layers.Input(shape=input_shape)
    # Flatten the input
    x = layers.Reshape((-1, input_shape[-1]))(inputs)

    # Create patches and embed
    patch_size = 16  # Adjust as necessary based on image size and memory constraints
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    patches = layers.Conv2D(filters=embed_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    patches = layers.Reshape((num_patches, embed_dim))(patches)

    # Add Transformer blocks
    for _ in range(8):
        patches = TransformerBlock(embed_dim, num_heads, ff_dim)(patches)

    # Reshape back to image
    x = layers.Reshape((input_shape[0] // patch_size, input_shape[1] // patch_size, embed_dim))(patches)
    x = Conv2DTranspose(num_classes, kernel_size=patch_size, strides=patch_size, padding="valid")(x)
    outputs = layers.Activation('sigmoid')(x)

    return Model(inputs, outputs)

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

input_shape = (int(256 * scale_factor), int(256 * scale_factor), 3)
num_classes = 1
embed_dim = 64  # Adjust as necessary
num_heads = 4   # Adjust as necessary
ff_dim = 128    # Adjust as necessary

model = create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim)
model._name = model_name
model.summary()

# Learning rate schedule
def lr_schedule(epoch, lr):
    if epoch >= 50 and epoch < 100:
        return lr * 0.99
    elif epoch >= 100 and epoch < 125:
        return lr * 0.9
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# Compile the model
initial_lr = 0.001  # Start with a lower initial learning rate
sgd = SGD(learning_rate=initial_lr, momentum=0.9)
model.compile(
    optimizer=sgd,
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

# %% [markdown]
# Model Training

# %%
# Setup callbacks
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=30,  # Reduced patience
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=16,  # Experiment with different values
    epochs=150,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping, lr_scheduler]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5443 - dice_coefficient: 0.1116 - jaccard_index: 0.0592 - sensitivity: 0.4514 - specificity: 0.5507 - precision: 0.0640
# Epoch 1: val_dice_coefficient improved from -inf to 0.10852, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 736s 7s/step - loss: 0.6939 - accuracy: 0.5443 - dice_coefficient: 0.1116 - jaccard_index: 0.0592 - sensitivity: 0.4514 - specificity: 0.5507 - precision: 0.0640 - val_loss: 0.6842 - val_accuracy: 0.5600 - val_dice_coefficient: 0.1085 - val_jaccard_index: 0.0575 - val_sensitivity: 0.4352 - val_specificity: 0.5682 - val_precision: 0.0623 - lr: 0.0010
# Epoch 2/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5346 - dice_coefficient: 0.1125 - jaccard_index: 0.0597 - sensitivity: 0.4656 - specificity: 0.5394 - precision: 0.0643
# Epoch 2: val_dice_coefficient improved from 0.10852 to 0.10970, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 740s 7s/step - loss: 0.6937 - accuracy: 0.5346 - dice_coefficient: 0.1125 - jaccard_index: 0.0597 - sensitivity: 0.4656 - specificity: 0.5394 - precision: 0.0643 - val_loss: 0.6839 - val_accuracy: 0.5583 - val_dice_coefficient: 0.1097 - val_jaccard_index: 0.0581 - val_sensitivity: 0.4422 - val_specificity: 0.5660 - val_precision: 0.0629 - lr: 0.0010
# Epoch 3/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5240 - dice_coefficient: 0.1138 - jaccard_index: 0.0605 - sensitivity: 0.4834 - specificity: 0.5269 - precision: 0.0649
# Epoch 3: val_dice_coefficient improved from 0.10970 to 0.11230, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 752s 7s/step - loss: 0.6934 - accuracy: 0.5240 - dice_coefficient: 0.1138 - jaccard_index: 0.0605 - sensitivity: 0.4834 - specificity: 0.5269 - precision: 0.0649 - val_loss: 0.6834 - val_accuracy: 0.5526 - val_dice_coefficient: 0.1123 - val_jaccard_index: 0.0596 - val_sensitivity: 0.4597 - val_specificity: 0.5588 - val_precision: 0.0642 - lr: 0.0010
# Epoch 4/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5235 - dice_coefficient: 0.1159 - jaccard_index: 0.0617 - sensitivity: 0.4944 - specificity: 0.5256 - precision: 0.0661
# Epoch 4: val_dice_coefficient improved from 0.11230 to 0.11666, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 747s 7s/step - loss: 0.6929 - accuracy: 0.5235 - dice_coefficient: 0.1159 - jaccard_index: 0.0617 - sensitivity: 0.4944 - specificity: 0.5256 - precision: 0.0661 - val_loss: 0.6826 - val_accuracy: 0.5465 - val_dice_coefficient: 0.1167 - val_jaccard_index: 0.0621 - val_sensitivity: 0.4866 - val_specificity: 0.5504 - val_precision: 0.0665 - lr: 0.0010
# Epoch 5/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5194 - dice_coefficient: 0.1196 - jaccard_index: 0.0638 - sensitivity: 0.5163 - specificity: 0.5195 - precision: 0.0680
# Epoch 5: val_dice_coefficient improved from 0.11666 to 0.12140, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 748s 7s/step - loss: 0.6921 - accuracy: 0.5194 - dice_coefficient: 0.1196 - jaccard_index: 0.0638 - sensitivity: 0.5163 - specificity: 0.5195 - precision: 0.0680 - val_loss: 0.6816 - val_accuracy: 0.5197 - val_dice_coefficient: 0.1214 - val_jaccard_index: 0.0647 - val_sensitivity: 0.5387 - val_specificity: 0.5184 - val_precision: 0.0687 - lr: 0.0010
# Epoch 6/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5360 - dice_coefficient: 0.1243 - jaccard_index: 0.0664 - sensitivity: 0.5208 - specificity: 0.5369 - precision: 0.0710
# Epoch 6: val_dice_coefficient improved from 0.12140 to 0.12676, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 735s 7s/step - loss: 0.6909 - accuracy: 0.5360 - dice_coefficient: 0.1243 - jaccard_index: 0.0664 - sensitivity: 0.5208 - specificity: 0.5369 - precision: 0.0710 - val_loss: 0.6802 - val_accuracy: 0.5210 - val_dice_coefficient: 0.1268 - val_jaccard_index: 0.0678 - val_sensitivity: 0.5640 - val_specificity: 0.5182 - val_precision: 0.0717 - lr: 0.0010
# Epoch 7/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.5449 - dice_coefficient: 0.1306 - jaccard_index: 0.0701 - sensitivity: 0.5397 - specificity: 0.5453 - precision: 0.0748
# Epoch 7: val_dice_coefficient improved from 0.12676 to 0.13374, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 706s 7s/step - loss: 0.6894 - accuracy: 0.5449 - dice_coefficient: 0.1306 - jaccard_index: 0.0701 - sensitivity: 0.5397 - specificity: 0.5453 - precision: 0.0748 - val_loss: 0.6786 - val_accuracy: 0.5891 - val_dice_coefficient: 0.1337 - val_jaccard_index: 0.0718 - val_sensitivity: 0.5155 - val_specificity: 0.5938 - val_precision: 0.0772 - lr: 0.0010
# Epoch 8/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6872 - accuracy: 0.5569 - dice_coefficient: 0.1397 - jaccard_index: 0.0754 - sensitivity: 0.5670 - specificity: 0.5560 - precision: 0.0803
# Epoch 8: val_dice_coefficient improved from 0.13374 to 0.13793, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 730s 7s/step - loss: 0.6872 - accuracy: 0.5569 - dice_coefficient: 0.1397 - jaccard_index: 0.0754 - sensitivity: 0.5670 - specificity: 0.5560 - precision: 0.0803 - val_loss: 0.6769 - val_accuracy: 0.4931 - val_dice_coefficient: 0.1379 - val_jaccard_index: 0.0743 - val_sensitivity: 0.6573 - val_specificity: 0.4824 - val_precision: 0.0774 - lr: 0.0010
# Epoch 9/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.5849 - dice_coefficient: 0.1488 - jaccard_index: 0.0807 - sensitivity: 0.5693 - specificity: 0.5856 - precision: 0.0862
# Epoch 9: val_dice_coefficient improved from 0.13793 to 0.15402, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 735s 7s/step - loss: 0.6849 - accuracy: 0.5849 - dice_coefficient: 0.1488 - jaccard_index: 0.0807 - sensitivity: 0.5693 - specificity: 0.5856 - precision: 0.0862 - val_loss: 0.6741 - val_accuracy: 0.6415 - val_dice_coefficient: 0.1540 - val_jaccard_index: 0.0836 - val_sensitivity: 0.5309 - val_specificity: 0.6486 - val_precision: 0.0905 - lr: 0.0010
# Epoch 10/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6827 - accuracy: 0.5836 - dice_coefficient: 0.1580 - jaccard_index: 0.0862 - sensitivity: 0.6086 - specificity: 0.5816 - precision: 0.0919
# Epoch 10: val_dice_coefficient improved from 0.15402 to 0.15631, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 737s 7s/step - loss: 0.6827 - accuracy: 0.5836 - dice_coefficient: 0.1580 - jaccard_index: 0.0862 - sensitivity: 0.6086 - specificity: 0.5816 - precision: 0.0919 - val_loss: 0.6712 - val_accuracy: 0.5211 - val_dice_coefficient: 0.1563 - val_jaccard_index: 0.0850 - val_sensitivity: 0.7194 - val_specificity: 0.5082 - val_precision: 0.0881 - lr: 0.0010
# Epoch 11/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6793 - accuracy: 0.6058 - dice_coefficient: 0.1685 - jaccard_index: 0.0925 - sensitivity: 0.6267 - specificity: 0.6040 - precision: 0.0981
# Epoch 11: val_dice_coefficient improved from 0.15631 to 0.17353, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 738s 7s/step - loss: 0.6793 - accuracy: 0.6058 - dice_coefficient: 0.1685 - jaccard_index: 0.0925 - sensitivity: 0.6267 - specificity: 0.6040 - precision: 0.0981 - val_loss: 0.6686 - val_accuracy: 0.6563 - val_dice_coefficient: 0.1735 - val_jaccard_index: 0.0953 - val_sensitivity: 0.5871 - val_specificity: 0.6607 - val_precision: 0.1022 - lr: 0.0010
# Epoch 12/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6768 - accuracy: 0.6024 - dice_coefficient: 0.1766 - jaccard_index: 0.0975 - sensitivity: 0.6602 - specificity: 0.5973 - precision: 0.1034
# Epoch 12: val_dice_coefficient did not improve from 0.17353
# 108/108 [==============================] - 729s 7s/step - loss: 0.6768 - accuracy: 0.6024 - dice_coefficient: 0.1766 - jaccard_index: 0.0975 - sensitivity: 0.6602 - specificity: 0.5973 - precision: 0.1034 - val_loss: 0.6644 - val_accuracy: 0.5610 - val_dice_coefficient: 0.1724 - val_jaccard_index: 0.0946 - val_sensitivity: 0.7433 - val_specificity: 0.5490 - val_precision: 0.0979 - lr: 0.0010
# Epoch 13/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6731 - accuracy: 0.6284 - dice_coefficient: 0.1861 - jaccard_index: 0.1032 - sensitivity: 0.6629 - specificity: 0.6250 - precision: 0.1095
# Epoch 13: val_dice_coefficient improved from 0.17353 to 0.18886, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 735s 7s/step - loss: 0.6731 - accuracy: 0.6284 - dice_coefficient: 0.1861 - jaccard_index: 0.1032 - sensitivity: 0.6629 - specificity: 0.6250 - precision: 0.1095 - val_loss: 0.6621 - val_accuracy: 0.6875 - val_dice_coefficient: 0.1889 - val_jaccard_index: 0.1046 - val_sensitivity: 0.5918 - val_specificity: 0.6936 - val_precision: 0.1128 - lr: 0.0010
# Epoch 14/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6717 - accuracy: 0.6185 - dice_coefficient: 0.1872 - jaccard_index: 0.1040 - sensitivity: 0.6677 - specificity: 0.6129 - precision: 0.1122
# Epoch 14: val_dice_coefficient did not improve from 0.18886
# 108/108 [==============================] - 713s 7s/step - loss: 0.6717 - accuracy: 0.6185 - dice_coefficient: 0.1872 - jaccard_index: 0.1040 - sensitivity: 0.6677 - specificity: 0.6129 - precision: 0.1122 - val_loss: 0.6693 - val_accuracy: 0.3372 - val_dice_coefficient: 0.1441 - val_jaccard_index: 0.0778 - val_sensitivity: 0.9046 - val_specificity: 0.3001 - val_precision: 0.0785 - lr: 0.0010
# Epoch 15/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.6227 - dice_coefficient: 0.1931 - jaccard_index: 0.1078 - sensitivity: 0.6834 - specificity: 0.6185 - precision: 0.1152
# Epoch 15: val_dice_coefficient improved from 0.18886 to 0.19269, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 726s 7s/step - loss: 0.6682 - accuracy: 0.6227 - dice_coefficient: 0.1931 - jaccard_index: 0.1078 - sensitivity: 0.6834 - specificity: 0.6185 - precision: 0.1152 - val_loss: 0.6575 - val_accuracy: 0.7023 - val_dice_coefficient: 0.1927 - val_jaccard_index: 0.1069 - val_sensitivity: 0.5773 - val_specificity: 0.7104 - val_precision: 0.1162 - lr: 0.0010
# Epoch 16/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6639 - accuracy: 0.6271 - dice_coefficient: 0.1966 - jaccard_index: 0.1098 - sensitivity: 0.7018 - specificity: 0.6215 - precision: 0.1164
# Epoch 16: val_dice_coefficient improved from 0.19269 to 0.19414, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 734s 7s/step - loss: 0.6639 - accuracy: 0.6271 - dice_coefficient: 0.1966 - jaccard_index: 0.1098 - sensitivity: 0.7018 - specificity: 0.6215 - precision: 0.1164 - val_loss: 0.6511 - val_accuracy: 0.6563 - val_dice_coefficient: 0.1941 - val_jaccard_index: 0.1078 - val_sensitivity: 0.6741 - val_specificity: 0.6549 - val_precision: 0.1138 - lr: 0.0010
# Epoch 17/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6614 - accuracy: 0.6280 - dice_coefficient: 0.1986 - jaccard_index: 0.1111 - sensitivity: 0.6930 - specificity: 0.6223 - precision: 0.1187
# Epoch 17: val_dice_coefficient did not improve from 0.19414
# 108/108 [==============================] - 714s 7s/step - loss: 0.6614 - accuracy: 0.6280 - dice_coefficient: 0.1986 - jaccard_index: 0.1111 - sensitivity: 0.6930 - specificity: 0.6223 - precision: 0.1187 - val_loss: 0.6498 - val_accuracy: 0.6370 - val_dice_coefficient: 0.1909 - val_jaccard_index: 0.1058 - val_sensitivity: 0.6973 - val_specificity: 0.6329 - val_precision: 0.1110 - lr: 0.0010
# Epoch 18/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6586 - accuracy: 0.6289 - dice_coefficient: 0.1967 - jaccard_index: 0.1099 - sensitivity: 0.7010 - specificity: 0.6232 - precision: 0.1163
# Epoch 18: val_dice_coefficient improved from 0.19414 to 0.19742, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 734s 7s/step - loss: 0.6586 - accuracy: 0.6289 - dice_coefficient: 0.1967 - jaccard_index: 0.1099 - sensitivity: 0.7010 - specificity: 0.6232 - precision: 0.1163 - val_loss: 0.6488 - val_accuracy: 0.7065 - val_dice_coefficient: 0.1974 - val_jaccard_index: 0.1099 - val_sensitivity: 0.5861 - val_specificity: 0.7144 - val_precision: 0.1193 - lr: 0.0010
# Epoch 19/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6609 - accuracy: 0.6099 - dice_coefficient: 0.1943 - jaccard_index: 0.1083 - sensitivity: 0.6908 - specificity: 0.6034 - precision: 0.1184
# Epoch 19: val_dice_coefficient did not improve from 0.19742
# 108/108 [==============================] - 726s 7s/step - loss: 0.6609 - accuracy: 0.6099 - dice_coefficient: 0.1943 - jaccard_index: 0.1083 - sensitivity: 0.6908 - specificity: 0.6034 - precision: 0.1184 - val_loss: 0.6508 - val_accuracy: 0.4548 - val_dice_coefficient: 0.1633 - val_jaccard_index: 0.0892 - val_sensitivity: 0.8615 - val_specificity: 0.4283 - val_precision: 0.0906 - lr: 0.0010
# Epoch 20/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.6253 - dice_coefficient: 0.2010 - jaccard_index: 0.1124 - sensitivity: 0.7193 - specificity: 0.6186 - precision: 0.1190
# Epoch 20: val_dice_coefficient did not improve from 0.19742
# 108/108 [==============================] - 734s 7s/step - loss: 0.6525 - accuracy: 0.6253 - dice_coefficient: 0.2010 - jaccard_index: 0.1124 - sensitivity: 0.7193 - specificity: 0.6186 - precision: 0.1190 - val_loss: 0.6395 - val_accuracy: 0.5831 - val_dice_coefficient: 0.1864 - val_jaccard_index: 0.1030 - val_sensitivity: 0.7778 - val_specificity: 0.5703 - val_precision: 0.1063 - lr: 0.0010
# Epoch 21/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6505 - accuracy: 0.6261 - dice_coefficient: 0.2003 - jaccard_index: 0.1123 - sensitivity: 0.7176 - specificity: 0.6200 - precision: 0.1187
# Epoch 21: val_dice_coefficient did not improve from 0.19742
# 108/108 [==============================] - 737s 7s/step - loss: 0.6505 - accuracy: 0.6261 - dice_coefficient: 0.2003 - jaccard_index: 0.1123 - sensitivity: 0.7176 - specificity: 0.6200 - precision: 0.1187 - val_loss: 0.6361 - val_accuracy: 0.6042 - val_dice_coefficient: 0.1908 - val_jaccard_index: 0.1057 - val_sensitivity: 0.7600 - val_specificity: 0.5938 - val_precision: 0.1094 - lr: 0.0010
# Epoch 22/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6454 - accuracy: 0.6291 - dice_coefficient: 0.2033 - jaccard_index: 0.1139 - sensitivity: 0.7252 - specificity: 0.6215 - precision: 0.1203
# Epoch 22: val_dice_coefficient did not improve from 0.19742
# 108/108 [==============================] - 726s 7s/step - loss: 0.6454 - accuracy: 0.6291 - dice_coefficient: 0.2033 - jaccard_index: 0.1139 - sensitivity: 0.7252 - specificity: 0.6215 - precision: 0.1203 - val_loss: 0.6328 - val_accuracy: 0.6255 - val_dice_coefficient: 0.1949 - val_jaccard_index: 0.1082 - val_sensitivity: 0.7381 - val_specificity: 0.6180 - val_precision: 0.1127 - lr: 0.0010
# Epoch 23/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6454 - accuracy: 0.6312 - dice_coefficient: 0.2036 - jaccard_index: 0.1143 - sensitivity: 0.7171 - specificity: 0.6258 - precision: 0.1223
# Epoch 23: val_dice_coefficient did not improve from 0.19742
# 108/108 [==============================] - 743s 7s/step - loss: 0.6454 - accuracy: 0.6312 - dice_coefficient: 0.2036 - jaccard_index: 0.1143 - sensitivity: 0.7171 - specificity: 0.6258 - precision: 0.1223 - val_loss: 0.6407 - val_accuracy: 0.4621 - val_dice_coefficient: 0.1667 - val_jaccard_index: 0.0912 - val_sensitivity: 0.8731 - val_specificity: 0.4353 - val_precision: 0.0926 - lr: 0.0010
# Epoch 24/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6416 - accuracy: 0.6195 - dice_coefficient: 0.2022 - jaccard_index: 0.1133 - sensitivity: 0.7348 - specificity: 0.6112 - precision: 0.1194
# Epoch 24: val_dice_coefficient improved from 0.19742 to 0.20112, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 740s 7s/step - loss: 0.6416 - accuracy: 0.6195 - dice_coefficient: 0.2022 - jaccard_index: 0.1133 - sensitivity: 0.7348 - specificity: 0.6112 - precision: 0.1194 - val_loss: 0.6328 - val_accuracy: 0.6896 - val_dice_coefficient: 0.2011 - val_jaccard_index: 0.1121 - val_sensitivity: 0.6349 - val_specificity: 0.6933 - val_precision: 0.1202 - lr: 0.0010
# Epoch 25/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.6268 - dice_coefficient: 0.2050 - jaccard_index: 0.1148 - sensitivity: 0.7429 - specificity: 0.6177 - precision: 0.1203
# Epoch 25: val_dice_coefficient did not improve from 0.20112
# 108/108 [==============================] - 719s 7s/step - loss: 0.6366 - accuracy: 0.6268 - dice_coefficient: 0.2050 - jaccard_index: 0.1148 - sensitivity: 0.7429 - specificity: 0.6177 - precision: 0.1203 - val_loss: 0.6345 - val_accuracy: 0.4683 - val_dice_coefficient: 0.1695 - val_jaccard_index: 0.0928 - val_sensitivity: 0.8811 - val_specificity: 0.4413 - val_precision: 0.0941 - lr: 0.0010
# Epoch 26/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6371 - accuracy: 0.6365 - dice_coefficient: 0.2029 - jaccard_index: 0.1138 - sensitivity: 0.7171 - specificity: 0.6305 - precision: 0.1202
# Epoch 26: val_dice_coefficient did not improve from 0.20112
# 108/108 [==============================] - 694s 6s/step - loss: 0.6371 - accuracy: 0.6365 - dice_coefficient: 0.2029 - jaccard_index: 0.1138 - sensitivity: 0.7171 - specificity: 0.6305 - precision: 0.1202 - val_loss: 0.6260 - val_accuracy: 0.5675 - val_dice_coefficient: 0.1859 - val_jaccard_index: 0.1027 - val_sensitivity: 0.8040 - val_specificity: 0.5520 - val_precision: 0.1055 - lr: 0.0010
# Epoch 27/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.6188 - dice_coefficient: 0.2035 - jaccard_index: 0.1141 - sensitivity: 0.7370 - specificity: 0.6102 - precision: 0.1204
# Epoch 27: val_dice_coefficient did not improve from 0.20112
# 108/108 [==============================] - 716s 7s/step - loss: 0.6354 - accuracy: 0.6188 - dice_coefficient: 0.2035 - jaccard_index: 0.1141 - sensitivity: 0.7370 - specificity: 0.6102 - precision: 0.1204 - val_loss: 0.6334 - val_accuracy: 0.4554 - val_dice_coefficient: 0.1669 - val_jaccard_index: 0.0913 - val_sensitivity: 0.8851 - val_specificity: 0.4272 - val_precision: 0.0925 - lr: 0.0010
# Epoch 28/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6348 - accuracy: 0.6142 - dice_coefficient: 0.2019 - jaccard_index: 0.1131 - sensitivity: 0.7421 - specificity: 0.6052 - precision: 0.1197
# Epoch 28: val_dice_coefficient did not improve from 0.20112
# 108/108 [==============================] - 704s 7s/step - loss: 0.6348 - accuracy: 0.6142 - dice_coefficient: 0.2019 - jaccard_index: 0.1131 - sensitivity: 0.7421 - specificity: 0.6052 - precision: 0.1197 - val_loss: 0.6218 - val_accuracy: 0.5671 - val_dice_coefficient: 0.1867 - val_jaccard_index: 0.1032 - val_sensitivity: 0.8093 - val_specificity: 0.5512 - val_precision: 0.1059 - lr: 0.0010
# Epoch 29/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.6224 - dice_coefficient: 0.2046 - jaccard_index: 0.1146 - sensitivity: 0.7495 - specificity: 0.6135 - precision: 0.1202
# Epoch 29: val_dice_coefficient did not improve from 0.20112
# 108/108 [==============================] - 719s 7s/step - loss: 0.6295 - accuracy: 0.6224 - dice_coefficient: 0.2046 - jaccard_index: 0.1146 - sensitivity: 0.7495 - specificity: 0.6135 - precision: 0.1202 - val_loss: 0.6190 - val_accuracy: 0.5465 - val_dice_coefficient: 0.1844 - val_jaccard_index: 0.1018 - val_sensitivity: 0.8346 - val_specificity: 0.5276 - val_precision: 0.1040 - lr: 0.0010
# Epoch 30/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.6312 - dice_coefficient: 0.2056 - jaccard_index: 0.1153 - sensitivity: 0.7442 - specificity: 0.6226 - precision: 0.1209
# Epoch 30: val_dice_coefficient improved from 0.20112 to 0.20166, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 728s 7s/step - loss: 0.6249 - accuracy: 0.6312 - dice_coefficient: 0.2056 - jaccard_index: 0.1153 - sensitivity: 0.7442 - specificity: 0.6226 - precision: 0.1209 - val_loss: 0.6165 - val_accuracy: 0.6579 - val_dice_coefficient: 0.2017 - val_jaccard_index: 0.1124 - val_sensitivity: 0.7028 - val_specificity: 0.6551 - val_precision: 0.1183 - lr: 0.0010
# Epoch 31/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6220 - accuracy: 0.6305 - dice_coefficient: 0.2095 - jaccard_index: 0.1176 - sensitivity: 0.7523 - specificity: 0.6221 - precision: 0.1234
# Epoch 31: val_dice_coefficient improved from 0.20166 to 0.21124, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 726s 7s/step - loss: 0.6220 - accuracy: 0.6305 - dice_coefficient: 0.2095 - jaccard_index: 0.1176 - sensitivity: 0.7523 - specificity: 0.6221 - precision: 0.1234 - val_loss: 0.6242 - val_accuracy: 0.7454 - val_dice_coefficient: 0.2112 - val_jaccard_index: 0.1184 - val_sensitivity: 0.5572 - val_specificity: 0.7582 - val_precision: 0.1316 - lr: 0.0010
# Epoch 32/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6225 - accuracy: 0.6317 - dice_coefficient: 0.2080 - jaccard_index: 0.1167 - sensitivity: 0.7459 - specificity: 0.6235 - precision: 0.1227
# Epoch 32: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 707s 7s/step - loss: 0.6225 - accuracy: 0.6317 - dice_coefficient: 0.2080 - jaccard_index: 0.1167 - sensitivity: 0.7459 - specificity: 0.6235 - precision: 0.1227 - val_loss: 0.6150 - val_accuracy: 0.6652 - val_dice_coefficient: 0.2027 - val_jaccard_index: 0.1131 - val_sensitivity: 0.6919 - val_specificity: 0.6638 - val_precision: 0.1194 - lr: 0.0010
# Epoch 33/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6178 - accuracy: 0.6283 - dice_coefficient: 0.2083 - jaccard_index: 0.1170 - sensitivity: 0.7591 - specificity: 0.6186 - precision: 0.1222
# Epoch 33: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 720s 7s/step - loss: 0.6178 - accuracy: 0.6283 - dice_coefficient: 0.2083 - jaccard_index: 0.1170 - sensitivity: 0.7591 - specificity: 0.6186 - precision: 0.1222 - val_loss: 0.6151 - val_accuracy: 0.5167 - val_dice_coefficient: 0.1800 - val_jaccard_index: 0.0992 - val_sensitivity: 0.8632 - val_specificity: 0.4939 - val_precision: 0.1008 - lr: 0.0010
# Epoch 34/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6235 - accuracy: 0.6216 - dice_coefficient: 0.2033 - jaccard_index: 0.1139 - sensitivity: 0.7357 - specificity: 0.6134 - precision: 0.1204
# Epoch 34: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 736s 7s/step - loss: 0.6235 - accuracy: 0.6216 - dice_coefficient: 0.2033 - jaccard_index: 0.1139 - sensitivity: 0.7357 - specificity: 0.6134 - precision: 0.1204 - val_loss: 0.6176 - val_accuracy: 0.7164 - val_dice_coefficient: 0.2080 - val_jaccard_index: 0.1163 - val_sensitivity: 0.6077 - val_specificity: 0.7239 - val_precision: 0.1265 - lr: 0.0010
# Epoch 35/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.6312 - dice_coefficient: 0.2091 - jaccard_index: 0.1175 - sensitivity: 0.7469 - specificity: 0.6235 - precision: 0.1237
# Epoch 35: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 705s 7s/step - loss: 0.6169 - accuracy: 0.6312 - dice_coefficient: 0.2091 - jaccard_index: 0.1175 - sensitivity: 0.7469 - specificity: 0.6235 - precision: 0.1237 - val_loss: 0.6065 - val_accuracy: 0.6484 - val_dice_coefficient: 0.2021 - val_jaccard_index: 0.1127 - val_sensitivity: 0.7243 - val_specificity: 0.6437 - val_precision: 0.1181 - lr: 0.0010
# Epoch 36/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.6303 - dice_coefficient: 0.2081 - jaccard_index: 0.1169 - sensitivity: 0.7504 - specificity: 0.6217 - precision: 0.1225
# Epoch 36: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 710s 7s/step - loss: 0.6147 - accuracy: 0.6303 - dice_coefficient: 0.2081 - jaccard_index: 0.1169 - sensitivity: 0.7504 - specificity: 0.6217 - precision: 0.1225 - val_loss: 0.6079 - val_accuracy: 0.6462 - val_dice_coefficient: 0.2004 - val_jaccard_index: 0.1116 - val_sensitivity: 0.7217 - val_specificity: 0.6416 - val_precision: 0.1170 - lr: 0.0010
# Epoch 37/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6096 - accuracy: 0.6378 - dice_coefficient: 0.2113 - jaccard_index: 0.1188 - sensitivity: 0.7518 - specificity: 0.6289 - precision: 0.1244
# Epoch 37: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 702s 7s/step - loss: 0.6096 - accuracy: 0.6378 - dice_coefficient: 0.2113 - jaccard_index: 0.1188 - sensitivity: 0.7518 - specificity: 0.6289 - precision: 0.1244 - val_loss: 0.6030 - val_accuracy: 0.5900 - val_dice_coefficient: 0.1947 - val_jaccard_index: 0.1081 - val_sensitivity: 0.8056 - val_specificity: 0.5760 - val_precision: 0.1112 - lr: 0.0010
# Epoch 38/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6104 - accuracy: 0.6321 - dice_coefficient: 0.2089 - jaccard_index: 0.1174 - sensitivity: 0.7552 - specificity: 0.6230 - precision: 0.1231
# Epoch 38: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 701s 6s/step - loss: 0.6104 - accuracy: 0.6321 - dice_coefficient: 0.2089 - jaccard_index: 0.1174 - sensitivity: 0.7552 - specificity: 0.6230 - precision: 0.1231 - val_loss: 0.6080 - val_accuracy: 0.6761 - val_dice_coefficient: 0.2045 - val_jaccard_index: 0.1142 - val_sensitivity: 0.6773 - val_specificity: 0.6764 - val_precision: 0.1212 - lr: 0.0010
# Epoch 39/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6064 - accuracy: 0.6417 - dice_coefficient: 0.2128 - jaccard_index: 0.1196 - sensitivity: 0.7518 - specificity: 0.6328 - precision: 0.1250
# Epoch 39: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 694s 6s/step - loss: 0.6064 - accuracy: 0.6417 - dice_coefficient: 0.2128 - jaccard_index: 0.1196 - sensitivity: 0.7518 - specificity: 0.6328 - precision: 0.1250 - val_loss: 0.5982 - val_accuracy: 0.5738 - val_dice_coefficient: 0.1930 - val_jaccard_index: 0.1071 - val_sensitivity: 0.8292 - val_specificity: 0.5571 - val_precision: 0.1096 - lr: 0.0010
# Epoch 40/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6038 - accuracy: 0.6375 - dice_coefficient: 0.2114 - jaccard_index: 0.1187 - sensitivity: 0.7617 - specificity: 0.6287 - precision: 0.1239
# Epoch 40: val_dice_coefficient did not improve from 0.21124
# 108/108 [==============================] - 694s 6s/step - loss: 0.6038 - accuracy: 0.6375 - dice_coefficient: 0.2114 - jaccard_index: 0.1187 - sensitivity: 0.7617 - specificity: 0.6287 - precision: 0.1239 - val_loss: 0.5958 - val_accuracy: 0.6351 - val_dice_coefficient: 0.2045 - val_jaccard_index: 0.1142 - val_sensitivity: 0.7616 - val_specificity: 0.6270 - val_precision: 0.1187 - lr: 0.0010
# Epoch 41/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6026 - accuracy: 0.6335 - dice_coefficient: 0.2130 - jaccard_index: 0.1197 - sensitivity: 0.7686 - specificity: 0.6246 - precision: 0.1250
# Epoch 41: val_dice_coefficient improved from 0.21124 to 0.21586, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 706s 7s/step - loss: 0.6026 - accuracy: 0.6335 - dice_coefficient: 0.2130 - jaccard_index: 0.1197 - sensitivity: 0.7686 - specificity: 0.6246 - precision: 0.1250 - val_loss: 0.6126 - val_accuracy: 0.7540 - val_dice_coefficient: 0.2159 - val_jaccard_index: 0.1212 - val_sensitivity: 0.5552 - val_specificity: 0.7676 - val_precision: 0.1356 - lr: 0.0010
# Epoch 42/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6021 - accuracy: 0.6431 - dice_coefficient: 0.2140 - jaccard_index: 0.1204 - sensitivity: 0.7535 - specificity: 0.6352 - precision: 0.1264
# Epoch 42: val_dice_coefficient improved from 0.21586 to 0.21791, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 723s 7s/step - loss: 0.6021 - accuracy: 0.6431 - dice_coefficient: 0.2140 - jaccard_index: 0.1204 - sensitivity: 0.7535 - specificity: 0.6352 - precision: 0.1264 - val_loss: 0.6020 - val_accuracy: 0.7232 - val_dice_coefficient: 0.2179 - val_jaccard_index: 0.1225 - val_sensitivity: 0.6309 - val_specificity: 0.7298 - val_precision: 0.1329 - lr: 0.0010
# Epoch 43/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6003 - accuracy: 0.6456 - dice_coefficient: 0.2132 - jaccard_index: 0.1201 - sensitivity: 0.7487 - specificity: 0.6381 - precision: 0.1256
# Epoch 43: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 699s 6s/step - loss: 0.6003 - accuracy: 0.6456 - dice_coefficient: 0.2132 - jaccard_index: 0.1201 - sensitivity: 0.7487 - specificity: 0.6381 - precision: 0.1256 - val_loss: 0.5949 - val_accuracy: 0.5668 - val_dice_coefficient: 0.1914 - val_jaccard_index: 0.1061 - val_sensitivity: 0.8333 - val_specificity: 0.5494 - val_precision: 0.1085 - lr: 0.0010
# Epoch 44/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.6375 - dice_coefficient: 0.2143 - jaccard_index: 0.1207 - sensitivity: 0.7675 - specificity: 0.6280 - precision: 0.1260
# Epoch 44: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 672s 6s/step - loss: 0.5970 - accuracy: 0.6375 - dice_coefficient: 0.2143 - jaccard_index: 0.1207 - sensitivity: 0.7675 - specificity: 0.6280 - precision: 0.1260 - val_loss: 0.5936 - val_accuracy: 0.5620 - val_dice_coefficient: 0.1912 - val_jaccard_index: 0.1060 - val_sensitivity: 0.8420 - val_specificity: 0.5436 - val_precision: 0.1083 - lr: 0.0010
# Epoch 45/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5940 - accuracy: 0.6378 - dice_coefficient: 0.2148 - jaccard_index: 0.1209 - sensitivity: 0.7723 - specificity: 0.6280 - precision: 0.1260
# Epoch 45: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 694s 6s/step - loss: 0.5940 - accuracy: 0.6378 - dice_coefficient: 0.2148 - jaccard_index: 0.1209 - sensitivity: 0.7723 - specificity: 0.6280 - precision: 0.1260 - val_loss: 0.5813 - val_accuracy: 0.6067 - val_dice_coefficient: 0.2035 - val_jaccard_index: 0.1135 - val_sensitivity: 0.8144 - val_specificity: 0.5931 - val_precision: 0.1168 - lr: 0.0010
# Epoch 46/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5960 - accuracy: 0.6410 - dice_coefficient: 0.2146 - jaccard_index: 0.1209 - sensitivity: 0.7607 - specificity: 0.6324 - precision: 0.1268
# Epoch 46: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 676s 6s/step - loss: 0.5960 - accuracy: 0.6410 - dice_coefficient: 0.2146 - jaccard_index: 0.1209 - sensitivity: 0.7607 - specificity: 0.6324 - precision: 0.1268 - val_loss: 0.5947 - val_accuracy: 0.6909 - val_dice_coefficient: 0.2097 - val_jaccard_index: 0.1173 - val_sensitivity: 0.6692 - val_specificity: 0.6928 - val_precision: 0.1252 - lr: 0.0010
# Epoch 47/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5918 - accuracy: 0.6499 - dice_coefficient: 0.2164 - jaccard_index: 0.1219 - sensitivity: 0.7592 - specificity: 0.6416 - precision: 0.1273
# Epoch 47: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 652s 6s/step - loss: 0.5918 - accuracy: 0.6499 - dice_coefficient: 0.2164 - jaccard_index: 0.1219 - sensitivity: 0.7592 - specificity: 0.6416 - precision: 0.1273 - val_loss: 0.5846 - val_accuracy: 0.5854 - val_dice_coefficient: 0.1971 - val_jaccard_index: 0.1096 - val_sensitivity: 0.8270 - val_specificity: 0.5696 - val_precision: 0.1123 - lr: 0.0010
# Epoch 48/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5889 - accuracy: 0.6510 - dice_coefficient: 0.2201 - jaccard_index: 0.1245 - sensitivity: 0.7693 - specificity: 0.6431 - precision: 0.1299
# Epoch 48: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 661s 6s/step - loss: 0.5889 - accuracy: 0.6510 - dice_coefficient: 0.2201 - jaccard_index: 0.1245 - sensitivity: 0.7693 - specificity: 0.6431 - precision: 0.1299 - val_loss: 0.5799 - val_accuracy: 0.6084 - val_dice_coefficient: 0.2030 - val_jaccard_index: 0.1132 - val_sensitivity: 0.8099 - val_specificity: 0.5953 - val_precision: 0.1165 - lr: 0.0010
# Epoch 49/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5855 - accuracy: 0.6583 - dice_coefficient: 0.2217 - jaccard_index: 0.1253 - sensitivity: 0.7622 - specificity: 0.6502 - precision: 0.1310
# Epoch 49: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 653s 6s/step - loss: 0.5855 - accuracy: 0.6583 - dice_coefficient: 0.2217 - jaccard_index: 0.1253 - sensitivity: 0.7622 - specificity: 0.6502 - precision: 0.1310 - val_loss: 0.5768 - val_accuracy: 0.6574 - val_dice_coefficient: 0.2170 - val_jaccard_index: 0.1221 - val_sensitivity: 0.7702 - val_specificity: 0.6503 - val_precision: 0.1270 - lr: 0.0010
# Epoch 50/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5862 - accuracy: 0.6574 - dice_coefficient: 0.2217 - jaccard_index: 0.1253 - sensitivity: 0.7621 - specificity: 0.6498 - precision: 0.1313
# Epoch 50: val_dice_coefficient did not improve from 0.21791
# 108/108 [==============================] - 658s 6s/step - loss: 0.5862 - accuracy: 0.6574 - dice_coefficient: 0.2217 - jaccard_index: 0.1253 - sensitivity: 0.7621 - specificity: 0.6498 - precision: 0.1313 - val_loss: 0.5720 - val_accuracy: 0.6539 - val_dice_coefficient: 0.2177 - val_jaccard_index: 0.1225 - val_sensitivity: 0.7818 - val_specificity: 0.6458 - val_precision: 0.1271 - lr: 0.0010
# Epoch 51/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5862 - accuracy: 0.6525 - dice_coefficient: 0.2213 - jaccard_index: 0.1250 - sensitivity: 0.7673 - specificity: 0.6446 - precision: 0.1309
# Epoch 51: val_dice_coefficient improved from 0.21791 to 0.23314, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 664s 6s/step - loss: 0.5862 - accuracy: 0.6525 - dice_coefficient: 0.2213 - jaccard_index: 0.1250 - sensitivity: 0.7673 - specificity: 0.6446 - precision: 0.1309 - val_loss: 0.5923 - val_accuracy: 0.7668 - val_dice_coefficient: 0.2331 - val_jaccard_index: 0.1323 - val_sensitivity: 0.5850 - val_specificity: 0.7794 - val_precision: 0.1473 - lr: 9.9000e-04
# Epoch 52/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5855 - accuracy: 0.6641 - dice_coefficient: 0.2243 - jaccard_index: 0.1271 - sensitivity: 0.7517 - specificity: 0.6583 - precision: 0.1333
# Epoch 52: val_dice_coefficient improved from 0.23314 to 0.23370, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 667s 6s/step - loss: 0.5855 - accuracy: 0.6641 - dice_coefficient: 0.2243 - jaccard_index: 0.1271 - sensitivity: 0.7517 - specificity: 0.6583 - precision: 0.1333 - val_loss: 0.5812 - val_accuracy: 0.7387 - val_dice_coefficient: 0.2337 - val_jaccard_index: 0.1327 - val_sensitivity: 0.6549 - val_specificity: 0.7448 - val_precision: 0.1435 - lr: 9.8010e-04
# Epoch 53/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.6582 - dice_coefficient: 0.2223 - jaccard_index: 0.1256 - sensitivity: 0.7593 - specificity: 0.6506 - precision: 0.1316
# Epoch 53: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 653s 6s/step - loss: 0.5839 - accuracy: 0.6582 - dice_coefficient: 0.2223 - jaccard_index: 0.1256 - sensitivity: 0.7593 - specificity: 0.6506 - precision: 0.1316 - val_loss: 0.5731 - val_accuracy: 0.7187 - val_dice_coefficient: 0.2325 - val_jaccard_index: 0.1319 - val_sensitivity: 0.6965 - val_specificity: 0.7206 - val_precision: 0.1405 - lr: 9.7030e-04
# Epoch 54/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5888 - accuracy: 0.6566 - dice_coefficient: 0.2214 - jaccard_index: 0.1253 - sensitivity: 0.7517 - specificity: 0.6501 - precision: 0.1323
# Epoch 54: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 660s 6s/step - loss: 0.5888 - accuracy: 0.6566 - dice_coefficient: 0.2214 - jaccard_index: 0.1253 - sensitivity: 0.7517 - specificity: 0.6501 - precision: 0.1323 - val_loss: 0.5794 - val_accuracy: 0.5817 - val_dice_coefficient: 0.1979 - val_jaccard_index: 0.1102 - val_sensitivity: 0.8358 - val_specificity: 0.5653 - val_precision: 0.1128 - lr: 9.6060e-04
# Epoch 55/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.6596 - dice_coefficient: 0.2231 - jaccard_index: 0.1262 - sensitivity: 0.7599 - specificity: 0.6522 - precision: 0.1325
# Epoch 55: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 651s 6s/step - loss: 0.5829 - accuracy: 0.6596 - dice_coefficient: 0.2231 - jaccard_index: 0.1262 - sensitivity: 0.7599 - specificity: 0.6522 - precision: 0.1325 - val_loss: 0.5705 - val_accuracy: 0.6987 - val_dice_coefficient: 0.2278 - val_jaccard_index: 0.1289 - val_sensitivity: 0.7231 - val_specificity: 0.6974 - val_precision: 0.1361 - lr: 9.5099e-04
# Epoch 56/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5870 - accuracy: 0.6537 - dice_coefficient: 0.2200 - jaccard_index: 0.1244 - sensitivity: 0.7544 - specificity: 0.6470 - precision: 0.1308
# Epoch 56: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 655s 6s/step - loss: 0.5870 - accuracy: 0.6537 - dice_coefficient: 0.2200 - jaccard_index: 0.1244 - sensitivity: 0.7544 - specificity: 0.6470 - precision: 0.1308 - val_loss: 0.5712 - val_accuracy: 0.7157 - val_dice_coefficient: 0.2311 - val_jaccard_index: 0.1310 - val_sensitivity: 0.7008 - val_specificity: 0.7172 - val_precision: 0.1394 - lr: 9.4148e-04
# Epoch 57/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5740 - accuracy: 0.6666 - dice_coefficient: 0.2286 - jaccard_index: 0.1296 - sensitivity: 0.7725 - specificity: 0.6583 - precision: 0.1353
# Epoch 57: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 650s 6s/step - loss: 0.5740 - accuracy: 0.6666 - dice_coefficient: 0.2286 - jaccard_index: 0.1296 - sensitivity: 0.7725 - specificity: 0.6583 - precision: 0.1353 - val_loss: 0.5664 - val_accuracy: 0.6012 - val_dice_coefficient: 0.2074 - val_jaccard_index: 0.1161 - val_sensitivity: 0.8445 - val_specificity: 0.5854 - val_precision: 0.1188 - lr: 9.3207e-04
# Epoch 58/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5790 - accuracy: 0.6639 - dice_coefficient: 0.2264 - jaccard_index: 0.1283 - sensitivity: 0.7616 - specificity: 0.6571 - precision: 0.1346
# Epoch 58: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 659s 6s/step - loss: 0.5790 - accuracy: 0.6639 - dice_coefficient: 0.2264 - jaccard_index: 0.1283 - sensitivity: 0.7616 - specificity: 0.6571 - precision: 0.1346 - val_loss: 0.5777 - val_accuracy: 0.6089 - val_dice_coefficient: 0.2042 - val_jaccard_index: 0.1141 - val_sensitivity: 0.8123 - val_specificity: 0.5957 - val_precision: 0.1173 - lr: 9.2274e-04
# Epoch 59/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5754 - accuracy: 0.6630 - dice_coefficient: 0.2253 - jaccard_index: 0.1276 - sensitivity: 0.7692 - specificity: 0.6544 - precision: 0.1333
# Epoch 59: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 647s 6s/step - loss: 0.5754 - accuracy: 0.6630 - dice_coefficient: 0.2253 - jaccard_index: 0.1276 - sensitivity: 0.7692 - specificity: 0.6544 - precision: 0.1333 - val_loss: 0.5635 - val_accuracy: 0.6725 - val_dice_coefficient: 0.2238 - val_jaccard_index: 0.1265 - val_sensitivity: 0.7649 - val_specificity: 0.6667 - val_precision: 0.1319 - lr: 9.1352e-04
# Epoch 60/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5752 - accuracy: 0.6696 - dice_coefficient: 0.2285 - jaccard_index: 0.1296 - sensitivity: 0.7602 - specificity: 0.6622 - precision: 0.1357
# Epoch 60: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 652s 6s/step - loss: 0.5752 - accuracy: 0.6696 - dice_coefficient: 0.2285 - jaccard_index: 0.1296 - sensitivity: 0.7602 - specificity: 0.6622 - precision: 0.1357 - val_loss: 0.5685 - val_accuracy: 0.6064 - val_dice_coefficient: 0.2068 - val_jaccard_index: 0.1157 - val_sensitivity: 0.8308 - val_specificity: 0.5919 - val_precision: 0.1187 - lr: 9.0438e-04
# Epoch 61/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5766 - accuracy: 0.6653 - dice_coefficient: 0.2264 - jaccard_index: 0.1283 - sensitivity: 0.7610 - specificity: 0.6579 - precision: 0.1347
# Epoch 61: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 656s 6s/step - loss: 0.5766 - accuracy: 0.6653 - dice_coefficient: 0.2264 - jaccard_index: 0.1283 - sensitivity: 0.7610 - specificity: 0.6579 - precision: 0.1347 - val_loss: 0.5626 - val_accuracy: 0.7058 - val_dice_coefficient: 0.2317 - val_jaccard_index: 0.1314 - val_sensitivity: 0.7232 - val_specificity: 0.7050 - val_precision: 0.1389 - lr: 8.9534e-04
# Epoch 62/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5680 - accuracy: 0.6746 - dice_coefficient: 0.2319 - jaccard_index: 0.1318 - sensitivity: 0.7687 - specificity: 0.6676 - precision: 0.1376
# Epoch 62: val_dice_coefficient did not improve from 0.23370
# 108/108 [==============================] - 668s 6s/step - loss: 0.5680 - accuracy: 0.6746 - dice_coefficient: 0.2319 - jaccard_index: 0.1318 - sensitivity: 0.7687 - specificity: 0.6676 - precision: 0.1376 - val_loss: 0.5579 - val_accuracy: 0.6511 - val_dice_coefficient: 0.2210 - val_jaccard_index: 0.1247 - val_sensitivity: 0.8022 - val_specificity: 0.6414 - val_precision: 0.1289 - lr: 8.8638e-04
# Epoch 63/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5671 - accuracy: 0.6725 - dice_coefficient: 0.2312 - jaccard_index: 0.1313 - sensitivity: 0.7708 - specificity: 0.6654 - precision: 0.1371
# Epoch 63: val_dice_coefficient improved from 0.23370 to 0.24402, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 675s 6s/step - loss: 0.5671 - accuracy: 0.6725 - dice_coefficient: 0.2312 - jaccard_index: 0.1313 - sensitivity: 0.7708 - specificity: 0.6654 - precision: 0.1371 - val_loss: 0.5502 - val_accuracy: 0.7142 - val_dice_coefficient: 0.2440 - val_jaccard_index: 0.1393 - val_sensitivity: 0.7525 - val_specificity: 0.7120 - val_precision: 0.1465 - lr: 8.7752e-04
# Epoch 64/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5637 - accuracy: 0.6767 - dice_coefficient: 0.2341 - jaccard_index: 0.1332 - sensitivity: 0.7759 - specificity: 0.6686 - precision: 0.1390
# Epoch 64: val_dice_coefficient did not improve from 0.24402
# 108/108 [==============================] - 664s 6s/step - loss: 0.5637 - accuracy: 0.6767 - dice_coefficient: 0.2341 - jaccard_index: 0.1332 - sensitivity: 0.7759 - specificity: 0.6686 - precision: 0.1390 - val_loss: 0.5523 - val_accuracy: 0.6226 - val_dice_coefficient: 0.2171 - val_jaccard_index: 0.1221 - val_sensitivity: 0.8473 - val_specificity: 0.6079 - val_precision: 0.1250 - lr: 8.6875e-04
# Epoch 65/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5641 - accuracy: 0.6730 - dice_coefficient: 0.2343 - jaccard_index: 0.1334 - sensitivity: 0.7805 - specificity: 0.6656 - precision: 0.1392
# Epoch 65: val_dice_coefficient improved from 0.24402 to 0.25610, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 696s 6s/step - loss: 0.5641 - accuracy: 0.6730 - dice_coefficient: 0.2343 - jaccard_index: 0.1334 - sensitivity: 0.7805 - specificity: 0.6656 - precision: 0.1392 - val_loss: 0.5670 - val_accuracy: 0.7675 - val_dice_coefficient: 0.2561 - val_jaccard_index: 0.1472 - val_sensitivity: 0.6547 - val_specificity: 0.7754 - val_precision: 0.1605 - lr: 8.6006e-04
# Epoch 66/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5621 - accuracy: 0.6773 - dice_coefficient: 0.2351 - jaccard_index: 0.1340 - sensitivity: 0.7754 - specificity: 0.6693 - precision: 0.1398
# Epoch 66: val_dice_coefficient did not improve from 0.25610
# 108/108 [==============================] - 684s 6s/step - loss: 0.5621 - accuracy: 0.6773 - dice_coefficient: 0.2351 - jaccard_index: 0.1340 - sensitivity: 0.7754 - specificity: 0.6693 - precision: 0.1398 - val_loss: 0.5444 - val_accuracy: 0.6881 - val_dice_coefficient: 0.2369 - val_jaccard_index: 0.1347 - val_sensitivity: 0.7881 - val_specificity: 0.6817 - val_precision: 0.1401 - lr: 8.5146e-04
# Epoch 67/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5627 - accuracy: 0.6752 - dice_coefficient: 0.2342 - jaccard_index: 0.1332 - sensitivity: 0.7761 - specificity: 0.6673 - precision: 0.1390
# Epoch 67: val_dice_coefficient did not improve from 0.25610
# 108/108 [==============================] - 687s 6s/step - loss: 0.5627 - accuracy: 0.6752 - dice_coefficient: 0.2342 - jaccard_index: 0.1332 - sensitivity: 0.7761 - specificity: 0.6673 - precision: 0.1390 - val_loss: 0.5426 - val_accuracy: 0.6568 - val_dice_coefficient: 0.2289 - val_jaccard_index: 0.1296 - val_sensitivity: 0.8281 - val_specificity: 0.6456 - val_precision: 0.1334 - lr: 8.4294e-04
# Epoch 68/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5621 - accuracy: 0.6801 - dice_coefficient: 0.2353 - jaccard_index: 0.1338 - sensitivity: 0.7687 - specificity: 0.6730 - precision: 0.1400
# Epoch 68: val_dice_coefficient did not improve from 0.25610
# 108/108 [==============================] - 694s 6s/step - loss: 0.5621 - accuracy: 0.6801 - dice_coefficient: 0.2353 - jaccard_index: 0.1338 - sensitivity: 0.7687 - specificity: 0.6730 - precision: 0.1400 - val_loss: 0.5460 - val_accuracy: 0.6503 - val_dice_coefficient: 0.2247 - val_jaccard_index: 0.1270 - val_sensitivity: 0.8204 - val_specificity: 0.6392 - val_precision: 0.1309 - lr: 8.3451e-04
# Epoch 69/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5595 - accuracy: 0.6781 - dice_coefficient: 0.2358 - jaccard_index: 0.1343 - sensitivity: 0.7787 - specificity: 0.6702 - precision: 0.1404
# Epoch 69: val_dice_coefficient did not improve from 0.25610
# 108/108 [==============================] - 671s 6s/step - loss: 0.5595 - accuracy: 0.6781 - dice_coefficient: 0.2358 - jaccard_index: 0.1343 - sensitivity: 0.7787 - specificity: 0.6702 - precision: 0.1404 - val_loss: 0.5562 - val_accuracy: 0.5666 - val_dice_coefficient: 0.2040 - val_jaccard_index: 0.1140 - val_sensitivity: 0.8981 - val_specificity: 0.5446 - val_precision: 0.1155 - lr: 8.2617e-04
# Epoch 70/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5626 - accuracy: 0.6692 - dice_coefficient: 0.2324 - jaccard_index: 0.1322 - sensitivity: 0.7816 - specificity: 0.6607 - precision: 0.1382
# Epoch 70: val_dice_coefficient did not improve from 0.25610
# 108/108 [==============================] - 639s 6s/step - loss: 0.5626 - accuracy: 0.6692 - dice_coefficient: 0.2324 - jaccard_index: 0.1322 - sensitivity: 0.7816 - specificity: 0.6607 - precision: 0.1382 - val_loss: 0.5369 - val_accuracy: 0.7165 - val_dice_coefficient: 0.2506 - val_jaccard_index: 0.1437 - val_sensitivity: 0.7706 - val_specificity: 0.7130 - val_precision: 0.1505 - lr: 8.1791e-04
# Epoch 71/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5557 - accuracy: 0.6799 - dice_coefficient: 0.2366 - jaccard_index: 0.1349 - sensitivity: 0.7810 - specificity: 0.6719 - precision: 0.1404
# Epoch 71: val_dice_coefficient did not improve from 0.25610
# 108/108 [==============================] - 637s 6s/step - loss: 0.5557 - accuracy: 0.6799 - dice_coefficient: 0.2366 - jaccard_index: 0.1349 - sensitivity: 0.7810 - specificity: 0.6719 - precision: 0.1404 - val_loss: 0.5491 - val_accuracy: 0.5810 - val_dice_coefficient: 0.2085 - val_jaccard_index: 0.1168 - val_sensitivity: 0.8950 - val_specificity: 0.5601 - val_precision: 0.1184 - lr: 8.0973e-04
# Epoch 72/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5573 - accuracy: 0.6765 - dice_coefficient: 0.2363 - jaccard_index: 0.1346 - sensitivity: 0.7793 - specificity: 0.6684 - precision: 0.1406
# Epoch 72: val_dice_coefficient improved from 0.25610 to 0.25705, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 645s 6s/step - loss: 0.5573 - accuracy: 0.6765 - dice_coefficient: 0.2363 - jaccard_index: 0.1346 - sensitivity: 0.7793 - specificity: 0.6684 - precision: 0.1406 - val_loss: 0.5438 - val_accuracy: 0.7436 - val_dice_coefficient: 0.2571 - val_jaccard_index: 0.1479 - val_sensitivity: 0.7217 - val_specificity: 0.7451 - val_precision: 0.1575 - lr: 8.0163e-04
# Epoch 73/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5538 - accuracy: 0.6781 - dice_coefficient: 0.2385 - jaccard_index: 0.1359 - sensitivity: 0.7870 - specificity: 0.6703 - precision: 0.1416
# Epoch 73: val_dice_coefficient did not improve from 0.25705
# 108/108 [==============================] - 627s 6s/step - loss: 0.5538 - accuracy: 0.6781 - dice_coefficient: 0.2385 - jaccard_index: 0.1359 - sensitivity: 0.7870 - specificity: 0.6703 - precision: 0.1416 - val_loss: 0.5391 - val_accuracy: 0.7120 - val_dice_coefficient: 0.2469 - val_jaccard_index: 0.1412 - val_sensitivity: 0.7672 - val_specificity: 0.7085 - val_precision: 0.1480 - lr: 7.9361e-04
# Epoch 74/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5502 - accuracy: 0.6828 - dice_coefficient: 0.2409 - jaccard_index: 0.1376 - sensitivity: 0.7892 - specificity: 0.6745 - precision: 0.1432
# Epoch 74: val_dice_coefficient did not improve from 0.25705
# 108/108 [==============================] - 635s 6s/step - loss: 0.5502 - accuracy: 0.6828 - dice_coefficient: 0.2409 - jaccard_index: 0.1376 - sensitivity: 0.7892 - specificity: 0.6745 - precision: 0.1432 - val_loss: 0.5437 - val_accuracy: 0.6162 - val_dice_coefficient: 0.2175 - val_jaccard_index: 0.1224 - val_sensitivity: 0.8621 - val_specificity: 0.6000 - val_precision: 0.1250 - lr: 7.8568e-04
# Epoch 75/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5612 - accuracy: 0.6670 - dice_coefficient: 0.2332 - jaccard_index: 0.1327 - sensitivity: 0.7816 - specificity: 0.6583 - precision: 0.1389
# Epoch 75: val_dice_coefficient did not improve from 0.25705
# 108/108 [==============================] - 628s 6s/step - loss: 0.5612 - accuracy: 0.6670 - dice_coefficient: 0.2332 - jaccard_index: 0.1327 - sensitivity: 0.7816 - specificity: 0.6583 - precision: 0.1389 - val_loss: 0.5405 - val_accuracy: 0.6610 - val_dice_coefficient: 0.2291 - val_jaccard_index: 0.1297 - val_sensitivity: 0.8189 - val_specificity: 0.6507 - val_precision: 0.1337 - lr: 7.7782e-04
# Epoch 76/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5521 - accuracy: 0.6852 - dice_coefficient: 0.2394 - jaccard_index: 0.1366 - sensitivity: 0.7784 - specificity: 0.6775 - precision: 0.1427
# Epoch 76: val_dice_coefficient did not improve from 0.25705
# 108/108 [==============================] - 635s 6s/step - loss: 0.5521 - accuracy: 0.6852 - dice_coefficient: 0.2394 - jaccard_index: 0.1366 - sensitivity: 0.7784 - specificity: 0.6775 - precision: 0.1427 - val_loss: 0.5272 - val_accuracy: 0.6866 - val_dice_coefficient: 0.2436 - val_jaccard_index: 0.1391 - val_sensitivity: 0.8189 - val_specificity: 0.6779 - val_precision: 0.1438 - lr: 7.7004e-04
# Epoch 77/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5509 - accuracy: 0.6785 - dice_coefficient: 0.2393 - jaccard_index: 0.1366 - sensitivity: 0.7910 - specificity: 0.6701 - precision: 0.1421
# Epoch 77: val_dice_coefficient did not improve from 0.25705
# 108/108 [==============================] - 627s 6s/step - loss: 0.5509 - accuracy: 0.6785 - dice_coefficient: 0.2393 - jaccard_index: 0.1366 - sensitivity: 0.7910 - specificity: 0.6701 - precision: 0.1421 - val_loss: 0.5318 - val_accuracy: 0.7003 - val_dice_coefficient: 0.2457 - val_jaccard_index: 0.1405 - val_sensitivity: 0.7925 - val_specificity: 0.6943 - val_precision: 0.1462 - lr: 7.6234e-04
# Epoch 78/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5499 - accuracy: 0.6774 - dice_coefficient: 0.2384 - jaccard_index: 0.1359 - sensitivity: 0.7906 - specificity: 0.6680 - precision: 0.1414
# Epoch 78: val_dice_coefficient did not improve from 0.25705
# 108/108 [==============================] - 636s 6s/step - loss: 0.5499 - accuracy: 0.6774 - dice_coefficient: 0.2384 - jaccard_index: 0.1359 - sensitivity: 0.7906 - specificity: 0.6680 - precision: 0.1414 - val_loss: 0.5272 - val_accuracy: 0.6839 - val_dice_coefficient: 0.2431 - val_jaccard_index: 0.1388 - val_sensitivity: 0.8233 - val_specificity: 0.6746 - val_precision: 0.1433 - lr: 7.5472e-04
# Epoch 79/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5588 - accuracy: 0.6722 - dice_coefficient: 0.2354 - jaccard_index: 0.1341 - sensitivity: 0.7815 - specificity: 0.6645 - precision: 0.1403
# Epoch 79: val_dice_coefficient did not improve from 0.25705
# 108/108 [==============================] - 633s 6s/step - loss: 0.5588 - accuracy: 0.6722 - dice_coefficient: 0.2354 - jaccard_index: 0.1341 - sensitivity: 0.7815 - specificity: 0.6645 - precision: 0.1403 - val_loss: 0.5360 - val_accuracy: 0.7252 - val_dice_coefficient: 0.2527 - val_jaccard_index: 0.1450 - val_sensitivity: 0.7569 - val_specificity: 0.7233 - val_precision: 0.1526 - lr: 7.4717e-04
# Epoch 80/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5447 - accuracy: 0.6861 - dice_coefficient: 0.2419 - jaccard_index: 0.1381 - sensitivity: 0.7919 - specificity: 0.6780 - precision: 0.1436
# Epoch 80: val_dice_coefficient improved from 0.25705 to 0.25910, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_9
# 108/108 [==============================] - 649s 6s/step - loss: 0.5447 - accuracy: 0.6861 - dice_coefficient: 0.2419 - jaccard_index: 0.1381 - sensitivity: 0.7919 - specificity: 0.6780 - precision: 0.1436 - val_loss: 0.5333 - val_accuracy: 0.7404 - val_dice_coefficient: 0.2591 - val_jaccard_index: 0.1493 - val_sensitivity: 0.7386 - val_specificity: 0.7406 - val_precision: 0.1582 - lr: 7.3970e-04
# Epoch 81/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5469 - accuracy: 0.6861 - dice_coefficient: 0.2425 - jaccard_index: 0.1387 - sensitivity: 0.7876 - specificity: 0.6774 - precision: 0.1445
# Epoch 81: val_dice_coefficient did not improve from 0.25910
# 108/108 [==============================] - 632s 6s/step - loss: 0.5469 - accuracy: 0.6861 - dice_coefficient: 0.2425 - jaccard_index: 0.1387 - sensitivity: 0.7876 - specificity: 0.6774 - precision: 0.1445 - val_loss: 0.5337 - val_accuracy: 0.6242 - val_dice_coefficient: 0.2228 - val_jaccard_index: 0.1257 - val_sensitivity: 0.8747 - val_specificity: 0.6075 - val_precision: 0.1281 - lr: 7.3230e-04
# Epoch 82/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5539 - accuracy: 0.6768 - dice_coefficient: 0.2370 - jaccard_index: 0.1350 - sensitivity: 0.7776 - specificity: 0.6690 - precision: 0.1411
# Epoch 82: val_dice_coefficient did not improve from 0.25910
# 108/108 [==============================] - 646s 6s/step - loss: 0.5539 - accuracy: 0.6768 - dice_coefficient: 0.2370 - jaccard_index: 0.1350 - sensitivity: 0.7776 - specificity: 0.6690 - precision: 0.1411 - val_loss: 0.5387 - val_accuracy: 0.7382 - val_dice_coefficient: 0.2542 - val_jaccard_index: 0.1460 - val_sensitivity: 0.7278 - val_specificity: 0.7390 - val_precision: 0.1550 - lr: 7.2498e-04
# Epoch 83/150
# 108/108 [==============================] - ETA: 0s - loss: 0.5436 - accuracy: 0.6846 - dice_coefficient: 0.2431 - jaccard_index: 0.1390 - sensitivity: 0.7962 - specificity: 0.6767 - precision: 0.1446
# Epoch 83: val_dice_coefficient did not improve from 0.25910
# 108/108 [==============================] - 627s 6s/step - loss: 0.5436 - accuracy: 0.6846 - dice_coefficient: 0.2431 - jaccard_index: 0.1390 - sensitivity: 0.7962 - specificity: 0.6767 - precision: 0.1446 - val_loss: 0.5214 - val_accuracy: 0.6823 - val_dice_coefficient: 0.2435 - val_jaccard_index: 0.1391 - val_sensitivity: 0.8304 - val_specificity: 0.6725 - val_precision: 0.1433 - lr: 7.1773e-04
# Epoch 84/150
#  50/108 [============>.................] - ETA: 5:24 - loss: 0.5563 - accuracy: 0.6674 - dice_coefficient: 0.2462 - jaccard_index: 0.1409 - sensitivity: 0.8082 - specificity: 0.6562 - precision: 0.1462

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_auc_score

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred, threshold=threshold):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > threshold).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative (Correct: No Buildings)', 'False Positive (Incorrect: There Was No Building)', 'False Negative (Incorrect: There Was A Building Here)', 'True Positive (Correct: There Is A Building Here)']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred, threshold=threshold)
plot_confusion_matrix(y_test, y_pred, threshold=threshold)
print(classification_report(y_test.flatten(), (y_pred.flatten() > threshold).astype(int)))
print("ROC-AUC:", roc_auc_score(y_test.flatten(), y_pred.flatten()))
