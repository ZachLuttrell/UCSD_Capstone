# %% [markdown]
# # UNet+VGG16 4
# This is the 4th iteration of UNet+VGG16
#
# In this iteration I:
# - Maintained the structure of the model from UNet+VGG16 3
# - I have implemented GPU utilization to improve training speeds.
#
#
# **NOTE:** Connect to a High-RAM Environment with GPU enabled

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# Check for GPU availability
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# MODEL SETTINGS
model_name = 'unet_vgg_4'  # Name of the model
percentage_to_load = 50 / 100.0  # Set the % of dataset to be loaded here.
threshold = 0.75  # Set the threshold for metrics here
initial_lr = 0.01  # Learning rate at the beginning of training (NOT INCORPORATED CURRENTLY, set at 1e-4)
print(f'\nSETTINGS:')
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load*100}%')
print(f'Threshold: {threshold}')
print(f'Initial Learning Rate: {initial_lr}')
print()

# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Num GPUs Available:  1
#
# SETTINGS:
# Model Name: unet_vgg_4
# Percentage to Load: 50.0%
# Threshold: 0.75
# Initial Learning Rate: 0.01
#
# Mounted at /gdrive

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(tqdm(image_files[:number_of_files_to_load]), start=1):
    try:
        img_path = os.path.join(image_directory, image_name)
        mask_name = image_to_mask[image_name]
        mask_path = os.path.join(mask_directory, mask_name)

        if os.path.exists(mask_path):
            img = tiff.imread(img_path)
            mask = tiff.imread(mask_path)

            images.append(img)
            masks.append(mask)
        else:
            print(f'\nMask not found for image: {image_name}')
    except Exception as e:
        print(f'\nError loading image/mask pair {image_name}: {e}')

print("\nLoading complete.")

# Check if the number of images and masks loaded are equal
if len(images) != len(masks):
    raise ValueError("The number of loaded images and masks do not match!")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 50.0% of dataset: 2393 images/mask pairs...
# 100%|██████████| 2393/2393 [31:58<00:00,  1.25it/s]
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If X_train, X_test, X_val have an extra unnecessary dimension at axis=1, remove it:
X_train = X_train.squeeze(axis=1)
X_test = X_test.squeeze(axis=1)
X_val = X_val.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (1722, 256, 256, 3), y_train: (1722, 256, 256, 1)
# X_val:   (192, 256, 256, 3), y_val: (192, 256, 256, 1)
# X_test:  (479, 256, 256, 3), y_test: (479, 256, 256, 1)

# %% [markdown]
# Metrics & Loss

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# CUSTOM METRICS

# Dice Coefficient: Measures overlap between true and predicted masks.
def dice_coefficient(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

# Jaccard Index: Measures the ratio of intersection to the union of true and predicted masks.
def jaccard_index(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

# Sensitivity: Measures the proportion of actual positives correctly identified.
def sensitivity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    possible_positives = tf.reduce_sum(y_true_f)
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

# Specificity: Measures the proportion of actual negatives correctly identified.
def specificity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_negatives = tf.reduce_sum((1-y_true_f) * (1-y_pred_f))
    possible_negatives = tf.reduce_sum(1-y_true_f)
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# Precision: Measures the proportion of predicted positives that are actually true positives.
def precision(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    predicted_positives = tf.reduce_sum(y_pred_f)
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())


# LOSS FUNCTION
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)

# Visualize class weight distribution
plt.bar(class_weights.keys(), class_weights.values())
plt.title("Class Weight Distribution")
plt.xlabel("Class")
plt.ylabel("Weight")
plt.show()

weighted_loss = weighted_binary_crossentropy(class_weights)
# Out:
# Class weights: {0: 0.5339968946194886, 1: 7.853612816644959}

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16

def vgg16_unet(input_size=(256, 256, 3), freeze_vgg16=True):
    inputs = Input(input_size)
    vgg16 = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_vgg16:
        # Freeze the VGG16 layers
        for layer in vgg16.layers:
            layer.trainable = False

    # Skip connections from VGG16 layers
    s1 = vgg16.get_layer("block1_conv2").output
    s2 = vgg16.get_layer("block2_conv2").output
    s3 = vgg16.get_layer("block3_conv3").output
    s4 = vgg16.get_layer("block4_conv3").output
    bridge = vgg16.get_layer("block5_conv3").output

    # Decoder
    up1 = UpSampling2D((2, 2))(bridge)
    up1 = concatenate([up1, s4])
    up1 = Conv2D(512, (3, 3), activation='relu', padding='same')(up1)

    up2 = UpSampling2D((2, 2))(up1)
    up2 = concatenate([up2, s3])
    up2 = Conv2D(256, (3, 3), activation='relu', padding='same')(up2)

    up3 = UpSampling2D((2, 2))(up2)
    up3 = concatenate([up3, s2])
    up3 = Conv2D(128, (3, 3), activation='relu', padding='same')(up3)

    up4 = UpSampling2D((2, 2))(up3)
    up4 = concatenate([up4, s1])
    up4 = Conv2D(64, (3, 3), activation='relu', padding='same')(up4)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(up4)

    model = Model(inputs, outputs)
    return model

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Define the model
model = vgg16_unet()

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)          0         ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)          2359808   ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv2[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 512)          0         ['block5_conv3[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 1024)         0         ['up_sampling2d[0][0]',
#                                                                      'block4_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 512)          4719104   ['concatenate[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 512)          0         ['conv2d[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 768)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'block3_conv3[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 256)          1769728   ['concatenate_1[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 256)        0         ['conv2d_1[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'block2_conv2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        442496    ['concatenate_2[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 128)        0         ['conv2d_2[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_3[0][0]',
#  )                                                                   'block1_conv2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         110656    ['concatenate_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 1)          65        ['conv2d_3[0][0]']
#
# ==================================================================================================
# Total params: 21756737 (83.00 MB)
# Trainable params: 7042049 (26.86 MB)
# Non-trainable params: 14714688 (56.13 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Early Stopping to prevent overfitting
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=15,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}.h5',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=16,
    epochs=50,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
print(f'Model saved to: /gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/50
# 108/108 [==============================] - ETA: 0s - loss: 0.4877 - accuracy: 0.7527 - dice_coefficient: 0.3474 - jaccard_index: 0.2120 - sensitivity: 0.5386 - specificity: 0.8905 - precision: 0.2693
# Epoch 1: val_dice_coefficient improved from -inf to 0.37993, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 108/108 [==============================] - 72s 462ms/step - loss: 0.4877 - accuracy: 0.7527 - dice_coefficient: 0.3474 - jaccard_index: 0.2120 - sensitivity: 0.5386 - specificity: 0.8905 - precision: 0.2693 - val_loss: 0.4062 - val_accuracy: 0.7374 - val_dice_coefficient: 0.3799 - val_jaccard_index: 0.2350 - val_sensitivity: 0.6890 - val_specificity: 0.8721 - val_precision: 0.2630
# Epoch 2/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3881 - accuracy: 0.7850 - dice_coefficient: 0.4134 - jaccard_index: 0.2613 - sensitivity: 0.6061 - specificity: 0.9087 - precision: 0.3186
# Epoch 2: val_dice_coefficient improved from 0.37993 to 0.42756, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 304ms/step - loss: 0.3881 - accuracy: 0.7850 - dice_coefficient: 0.4134 - jaccard_index: 0.2613 - sensitivity: 0.6061 - specificity: 0.9087 - precision: 0.3186 - val_loss: 0.3655 - val_accuracy: 0.8110 - val_dice_coefficient: 0.4276 - val_jaccard_index: 0.2724 - val_sensitivity: 0.5997 - val_specificity: 0.9204 - val_precision: 0.3333
# Epoch 3/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3646 - accuracy: 0.7928 - dice_coefficient: 0.4362 - jaccard_index: 0.2796 - sensitivity: 0.6448 - specificity: 0.9101 - precision: 0.3369
# Epoch 3: val_dice_coefficient improved from 0.42756 to 0.44649, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 32s 299ms/step - loss: 0.3646 - accuracy: 0.7928 - dice_coefficient: 0.4362 - jaccard_index: 0.2796 - sensitivity: 0.6448 - specificity: 0.9101 - precision: 0.3369 - val_loss: 0.3510 - val_accuracy: 0.8200 - val_dice_coefficient: 0.4465 - val_jaccard_index: 0.2880 - val_sensitivity: 0.5712 - val_specificity: 0.9345 - val_precision: 0.3675
# Epoch 4/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8046 - dice_coefficient: 0.4546 - jaccard_index: 0.2949 - sensitivity: 0.6744 - specificity: 0.9115 - precision: 0.3465
# Epoch 4: val_dice_coefficient did not improve from 0.44649
# 108/108 [==============================] - 31s 283ms/step - loss: 0.3418 - accuracy: 0.8046 - dice_coefficient: 0.4546 - jaccard_index: 0.2949 - sensitivity: 0.6744 - specificity: 0.9115 - precision: 0.3465 - val_loss: 0.3389 - val_accuracy: 0.7814 - val_dice_coefficient: 0.4433 - val_jaccard_index: 0.2853 - val_sensitivity: 0.7128 - val_specificity: 0.9005 - val_precision: 0.3221
# Epoch 5/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3312 - accuracy: 0.8100 - dice_coefficient: 0.4653 - jaccard_index: 0.3039 - sensitivity: 0.6869 - specificity: 0.9131 - precision: 0.3570
# Epoch 5: val_dice_coefficient improved from 0.44649 to 0.46259, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 303ms/step - loss: 0.3312 - accuracy: 0.8100 - dice_coefficient: 0.4653 - jaccard_index: 0.3039 - sensitivity: 0.6869 - specificity: 0.9131 - precision: 0.3570 - val_loss: 0.3232 - val_accuracy: 0.8122 - val_dice_coefficient: 0.4626 - val_jaccard_index: 0.3014 - val_sensitivity: 0.6860 - val_specificity: 0.9153 - val_precision: 0.3494
# Epoch 6/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.8184 - dice_coefficient: 0.4790 - jaccard_index: 0.3156 - sensitivity: 0.7067 - specificity: 0.9146 - precision: 0.3647
# Epoch 6: val_dice_coefficient did not improve from 0.46259
# 108/108 [==============================] - 31s 284ms/step - loss: 0.3160 - accuracy: 0.8184 - dice_coefficient: 0.4790 - jaccard_index: 0.3156 - sensitivity: 0.7067 - specificity: 0.9146 - precision: 0.3647 - val_loss: 0.3237 - val_accuracy: 0.7856 - val_dice_coefficient: 0.4507 - val_jaccard_index: 0.2913 - val_sensitivity: 0.7699 - val_specificity: 0.8914 - val_precision: 0.3189
# Epoch 7/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3115 - accuracy: 0.8202 - dice_coefficient: 0.4865 - jaccard_index: 0.3225 - sensitivity: 0.7170 - specificity: 0.9148 - precision: 0.3746
# Epoch 7: val_dice_coefficient improved from 0.46259 to 0.47156, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 302ms/step - loss: 0.3115 - accuracy: 0.8202 - dice_coefficient: 0.4865 - jaccard_index: 0.3225 - sensitivity: 0.7170 - specificity: 0.9148 - precision: 0.3746 - val_loss: 0.3079 - val_accuracy: 0.8166 - val_dice_coefficient: 0.4716 - val_jaccard_index: 0.3090 - val_sensitivity: 0.7299 - val_specificity: 0.9098 - val_precision: 0.3486
# Epoch 8/50
# 108/108 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8267 - dice_coefficient: 0.4937 - jaccard_index: 0.3285 - sensitivity: 0.7313 - specificity: 0.9160 - precision: 0.3754
# Epoch 8: val_dice_coefficient improved from 0.47156 to 0.49394, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 306ms/step - loss: 0.3003 - accuracy: 0.8267 - dice_coefficient: 0.4937 - jaccard_index: 0.3285 - sensitivity: 0.7313 - specificity: 0.9160 - precision: 0.3754 - val_loss: 0.3018 - val_accuracy: 0.8347 - val_dice_coefficient: 0.4939 - val_jaccard_index: 0.3285 - val_sensitivity: 0.6747 - val_specificity: 0.9300 - val_precision: 0.3899
# Epoch 9/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.8314 - dice_coefficient: 0.4991 - jaccard_index: 0.3336 - sensitivity: 0.7350 - specificity: 0.9172 - precision: 0.3812
# Epoch 9: val_dice_coefficient did not improve from 0.49394
# 108/108 [==============================] - 31s 285ms/step - loss: 0.2924 - accuracy: 0.8314 - dice_coefficient: 0.4991 - jaccard_index: 0.3336 - sensitivity: 0.7350 - specificity: 0.9172 - precision: 0.3812 - val_loss: 0.2931 - val_accuracy: 0.8287 - val_dice_coefficient: 0.4871 - val_jaccard_index: 0.3225 - val_sensitivity: 0.7448 - val_specificity: 0.9128 - val_precision: 0.3623
# Epoch 10/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.8350 - dice_coefficient: 0.5077 - jaccard_index: 0.3409 - sensitivity: 0.7522 - specificity: 0.9173 - precision: 0.3855
# Epoch 10: val_dice_coefficient improved from 0.49394 to 0.50197, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 32s 301ms/step - loss: 0.2852 - accuracy: 0.8350 - dice_coefficient: 0.5077 - jaccard_index: 0.3409 - sensitivity: 0.7522 - specificity: 0.9173 - precision: 0.3855 - val_loss: 0.2884 - val_accuracy: 0.8395 - val_dice_coefficient: 0.5020 - val_jaccard_index: 0.3357 - val_sensitivity: 0.7142 - val_specificity: 0.9250 - val_precision: 0.3872
# Epoch 11/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.8384 - dice_coefficient: 0.5126 - jaccard_index: 0.3456 - sensitivity: 0.7570 - specificity: 0.9181 - precision: 0.3910
# Epoch 11: val_dice_coefficient did not improve from 0.50197
# 108/108 [==============================] - 31s 284ms/step - loss: 0.2796 - accuracy: 0.8384 - dice_coefficient: 0.5126 - jaccard_index: 0.3456 - sensitivity: 0.7570 - specificity: 0.9181 - precision: 0.3910 - val_loss: 0.2887 - val_accuracy: 0.8113 - val_dice_coefficient: 0.4839 - val_jaccard_index: 0.3197 - val_sensitivity: 0.7947 - val_specificity: 0.9014 - val_precision: 0.3483
# Epoch 12/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.8420 - dice_coefficient: 0.5177 - jaccard_index: 0.3503 - sensitivity: 0.7643 - specificity: 0.9191 - precision: 0.3943
# Epoch 12: val_dice_coefficient improved from 0.50197 to 0.50898, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 303ms/step - loss: 0.2735 - accuracy: 0.8420 - dice_coefficient: 0.5177 - jaccard_index: 0.3503 - sensitivity: 0.7643 - specificity: 0.9191 - precision: 0.3943 - val_loss: 0.2825 - val_accuracy: 0.8505 - val_dice_coefficient: 0.5090 - val_jaccard_index: 0.3419 - val_sensitivity: 0.7236 - val_specificity: 0.9256 - val_precision: 0.3930
# Epoch 13/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.8439 - dice_coefficient: 0.5221 - jaccard_index: 0.3541 - sensitivity: 0.7712 - specificity: 0.9192 - precision: 0.3983
# Epoch 13: val_dice_coefficient did not improve from 0.50898
# 108/108 [==============================] - 31s 284ms/step - loss: 0.2699 - accuracy: 0.8439 - dice_coefficient: 0.5221 - jaccard_index: 0.3541 - sensitivity: 0.7712 - specificity: 0.9192 - precision: 0.3983 - val_loss: 0.2773 - val_accuracy: 0.8261 - val_dice_coefficient: 0.4923 - val_jaccard_index: 0.3270 - val_sensitivity: 0.8141 - val_specificity: 0.9010 - val_precision: 0.3531
# Epoch 14/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8454 - dice_coefficient: 0.5274 - jaccard_index: 0.3591 - sensitivity: 0.7766 - specificity: 0.9191 - precision: 0.4032
# Epoch 14: val_dice_coefficient improved from 0.50898 to 0.53000, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 306ms/step - loss: 0.2663 - accuracy: 0.8454 - dice_coefficient: 0.5274 - jaccard_index: 0.3591 - sensitivity: 0.7766 - specificity: 0.9191 - precision: 0.4032 - val_loss: 0.3010 - val_accuracy: 0.8845 - val_dice_coefficient: 0.5300 - val_jaccard_index: 0.3615 - val_sensitivity: 0.6212 - val_specificity: 0.9519 - val_precision: 0.4629
# Epoch 15/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.8484 - dice_coefficient: 0.5308 - jaccard_index: 0.3623 - sensitivity: 0.7819 - specificity: 0.9204 - precision: 0.4054
# Epoch 15: val_dice_coefficient did not improve from 0.53000
# 108/108 [==============================] - 31s 285ms/step - loss: 0.2623 - accuracy: 0.8484 - dice_coefficient: 0.5308 - jaccard_index: 0.3623 - sensitivity: 0.7819 - specificity: 0.9204 - precision: 0.4054 - val_loss: 0.2676 - val_accuracy: 0.8576 - val_dice_coefficient: 0.5247 - val_jaccard_index: 0.3564 - val_sensitivity: 0.7514 - val_specificity: 0.9262 - val_precision: 0.4034
# Epoch 16/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2539 - accuracy: 0.8528 - dice_coefficient: 0.5387 - jaccard_index: 0.3695 - sensitivity: 0.7903 - specificity: 0.9213 - precision: 0.4110
# Epoch 16: val_dice_coefficient did not improve from 0.53000
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2539 - accuracy: 0.8528 - dice_coefficient: 0.5387 - jaccard_index: 0.3695 - sensitivity: 0.7903 - specificity: 0.9213 - precision: 0.4110 - val_loss: 0.2631 - val_accuracy: 0.8460 - val_dice_coefficient: 0.5203 - val_jaccard_index: 0.3523 - val_sensitivity: 0.7866 - val_specificity: 0.9180 - val_precision: 0.3891
# Epoch 17/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.8552 - dice_coefficient: 0.5412 - jaccard_index: 0.3719 - sensitivity: 0.7971 - specificity: 0.9216 - precision: 0.4112
# Epoch 17: val_dice_coefficient did not improve from 0.53000
# 108/108 [==============================] - 31s 285ms/step - loss: 0.2496 - accuracy: 0.8552 - dice_coefficient: 0.5412 - jaccard_index: 0.3719 - sensitivity: 0.7971 - specificity: 0.9216 - precision: 0.4112 - val_loss: 0.2606 - val_accuracy: 0.8494 - val_dice_coefficient: 0.5271 - val_jaccard_index: 0.3586 - val_sensitivity: 0.7766 - val_specificity: 0.9225 - val_precision: 0.3992
# Epoch 18/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.8556 - dice_coefficient: 0.5423 - jaccard_index: 0.3729 - sensitivity: 0.7973 - specificity: 0.9217 - precision: 0.4135
# Epoch 18: val_dice_coefficient did not improve from 0.53000
# 108/108 [==============================] - 31s 285ms/step - loss: 0.2487 - accuracy: 0.8556 - dice_coefficient: 0.5423 - jaccard_index: 0.3729 - sensitivity: 0.7973 - specificity: 0.9217 - precision: 0.4135 - val_loss: 0.2568 - val_accuracy: 0.8509 - val_dice_coefficient: 0.5264 - val_jaccard_index: 0.3580 - val_sensitivity: 0.7957 - val_specificity: 0.9185 - val_precision: 0.3938
# Epoch 19/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2421 - accuracy: 0.8594 - dice_coefficient: 0.5492 - jaccard_index: 0.3794 - sensitivity: 0.8064 - specificity: 0.9228 - precision: 0.4182
# Epoch 19: val_dice_coefficient did not improve from 0.53000
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2421 - accuracy: 0.8594 - dice_coefficient: 0.5492 - jaccard_index: 0.3794 - sensitivity: 0.8064 - specificity: 0.9228 - precision: 0.4182 - val_loss: 0.2590 - val_accuracy: 0.8432 - val_dice_coefficient: 0.5096 - val_jaccard_index: 0.3424 - val_sensitivity: 0.8317 - val_specificity: 0.9049 - val_precision: 0.3677
# Epoch 20/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2410 - accuracy: 0.8596 - dice_coefficient: 0.5491 - jaccard_index: 0.3793 - sensitivity: 0.8071 - specificity: 0.9222 - precision: 0.4183
# Epoch 20: val_dice_coefficient improved from 0.53000 to 0.54015, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 302ms/step - loss: 0.2410 - accuracy: 0.8596 - dice_coefficient: 0.5491 - jaccard_index: 0.3793 - sensitivity: 0.8071 - specificity: 0.9222 - precision: 0.4183 - val_loss: 0.2536 - val_accuracy: 0.8650 - val_dice_coefficient: 0.5402 - val_jaccard_index: 0.3707 - val_sensitivity: 0.7714 - val_specificity: 0.9281 - val_precision: 0.4160
# Epoch 21/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.8624 - dice_coefficient: 0.5560 - jaccard_index: 0.3860 - sensitivity: 0.8135 - specificity: 0.9237 - precision: 0.4242
# Epoch 21: val_dice_coefficient improved from 0.54015 to 0.55403, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 308ms/step - loss: 0.2364 - accuracy: 0.8624 - dice_coefficient: 0.5560 - jaccard_index: 0.3860 - sensitivity: 0.8135 - specificity: 0.9237 - precision: 0.4242 - val_loss: 0.2769 - val_accuracy: 0.8903 - val_dice_coefficient: 0.5540 - val_jaccard_index: 0.3841 - val_sensitivity: 0.6895 - val_specificity: 0.9467 - val_precision: 0.4636
# Epoch 22/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.8589 - dice_coefficient: 0.5506 - jaccard_index: 0.3808 - sensitivity: 0.8054 - specificity: 0.9224 - precision: 0.4229
# Epoch 22: val_dice_coefficient did not improve from 0.55403
# 108/108 [==============================] - 31s 285ms/step - loss: 0.2428 - accuracy: 0.8589 - dice_coefficient: 0.5506 - jaccard_index: 0.3808 - sensitivity: 0.8054 - specificity: 0.9224 - precision: 0.4229 - val_loss: 0.2609 - val_accuracy: 0.8784 - val_dice_coefficient: 0.5487 - val_jaccard_index: 0.3789 - val_sensitivity: 0.7460 - val_specificity: 0.9351 - val_precision: 0.4345
# Epoch 23/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.8640 - dice_coefficient: 0.5595 - jaccard_index: 0.3894 - sensitivity: 0.8174 - specificity: 0.9238 - precision: 0.4284
# Epoch 23: val_dice_coefficient did not improve from 0.55403
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2338 - accuracy: 0.8640 - dice_coefficient: 0.5595 - jaccard_index: 0.3894 - sensitivity: 0.8174 - specificity: 0.9238 - precision: 0.4284 - val_loss: 0.2515 - val_accuracy: 0.8742 - val_dice_coefficient: 0.5530 - val_jaccard_index: 0.3830 - val_sensitivity: 0.7497 - val_specificity: 0.9360 - val_precision: 0.4386
# Epoch 24/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2314 - accuracy: 0.8655 - dice_coefficient: 0.5614 - jaccard_index: 0.3912 - sensitivity: 0.8208 - specificity: 0.9241 - precision: 0.4294
# Epoch 24: val_dice_coefficient did not improve from 0.55403
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2314 - accuracy: 0.8655 - dice_coefficient: 0.5614 - jaccard_index: 0.3912 - sensitivity: 0.8208 - specificity: 0.9241 - precision: 0.4294 - val_loss: 0.2475 - val_accuracy: 0.8638 - val_dice_coefficient: 0.5458 - val_jaccard_index: 0.3761 - val_sensitivity: 0.7836 - val_specificity: 0.9276 - val_precision: 0.4193
# Epoch 25/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.8684 - dice_coefficient: 0.5644 - jaccard_index: 0.3939 - sensitivity: 0.8251 - specificity: 0.9250 - precision: 0.4304
# Epoch 25: val_dice_coefficient did not improve from 0.55403
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2258 - accuracy: 0.8684 - dice_coefficient: 0.5644 - jaccard_index: 0.3939 - sensitivity: 0.8251 - specificity: 0.9250 - precision: 0.4304 - val_loss: 0.2449 - val_accuracy: 0.8527 - val_dice_coefficient: 0.5270 - val_jaccard_index: 0.3585 - val_sensitivity: 0.8520 - val_specificity: 0.9080 - val_precision: 0.3820
# Epoch 26/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.8706 - dice_coefficient: 0.5693 - jaccard_index: 0.3987 - sensitivity: 0.8314 - specificity: 0.9257 - precision: 0.4343
# Epoch 26: val_dice_coefficient did not improve from 0.55403
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2218 - accuracy: 0.8706 - dice_coefficient: 0.5693 - jaccard_index: 0.3987 - sensitivity: 0.8314 - specificity: 0.9257 - precision: 0.4343 - val_loss: 0.2414 - val_accuracy: 0.8501 - val_dice_coefficient: 0.5291 - val_jaccard_index: 0.3604 - val_sensitivity: 0.8566 - val_specificity: 0.9080 - val_precision: 0.3833
# Epoch 27/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.8706 - dice_coefficient: 0.5694 - jaccard_index: 0.3989 - sensitivity: 0.8291 - specificity: 0.9254 - precision: 0.4359
# Epoch 27: val_dice_coefficient improved from 0.55403 to 0.55739, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 34s 314ms/step - loss: 0.2217 - accuracy: 0.8706 - dice_coefficient: 0.5694 - jaccard_index: 0.3989 - sensitivity: 0.8291 - specificity: 0.9254 - precision: 0.4359 - val_loss: 0.2474 - val_accuracy: 0.8752 - val_dice_coefficient: 0.5574 - val_jaccard_index: 0.3873 - val_sensitivity: 0.7587 - val_specificity: 0.9358 - val_precision: 0.4411
# Epoch 28/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2216 - accuracy: 0.8706 - dice_coefficient: 0.5708 - jaccard_index: 0.4003 - sensitivity: 0.8315 - specificity: 0.9254 - precision: 0.4370
# Epoch 28: val_dice_coefficient improved from 0.55739 to 0.56775, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 302ms/step - loss: 0.2216 - accuracy: 0.8706 - dice_coefficient: 0.5708 - jaccard_index: 0.4003 - sensitivity: 0.8315 - specificity: 0.9254 - precision: 0.4370 - val_loss: 0.2554 - val_accuracy: 0.8901 - val_dice_coefficient: 0.5677 - val_jaccard_index: 0.3974 - val_sensitivity: 0.7403 - val_specificity: 0.9421 - val_precision: 0.4611
# Epoch 29/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.8751 - dice_coefficient: 0.5774 - jaccard_index: 0.4068 - sensitivity: 0.8400 - specificity: 0.9269 - precision: 0.4410
# Epoch 29: val_dice_coefficient did not improve from 0.56775
# 108/108 [==============================] - 31s 287ms/step - loss: 0.2137 - accuracy: 0.8751 - dice_coefficient: 0.5774 - jaccard_index: 0.4068 - sensitivity: 0.8400 - specificity: 0.9269 - precision: 0.4410 - val_loss: 0.2389 - val_accuracy: 0.8761 - val_dice_coefficient: 0.5575 - val_jaccard_index: 0.3873 - val_sensitivity: 0.8056 - val_specificity: 0.9279 - val_precision: 0.4268
# Epoch 30/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2121 - accuracy: 0.8762 - dice_coefficient: 0.5798 - jaccard_index: 0.4092 - sensitivity: 0.8407 - specificity: 0.9272 - precision: 0.4439
# Epoch 30: val_dice_coefficient did not improve from 0.56775
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2121 - accuracy: 0.8762 - dice_coefficient: 0.5798 - jaccard_index: 0.4092 - sensitivity: 0.8407 - specificity: 0.9272 - precision: 0.4439 - val_loss: 0.2387 - val_accuracy: 0.8653 - val_dice_coefficient: 0.5484 - val_jaccard_index: 0.3786 - val_sensitivity: 0.8170 - val_specificity: 0.9224 - val_precision: 0.4133
# Epoch 31/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2129 - accuracy: 0.8756 - dice_coefficient: 0.5806 - jaccard_index: 0.4101 - sensitivity: 0.8419 - specificity: 0.9270 - precision: 0.4453
# Epoch 31: val_dice_coefficient did not improve from 0.56775
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2129 - accuracy: 0.8756 - dice_coefficient: 0.5806 - jaccard_index: 0.4101 - sensitivity: 0.8419 - specificity: 0.9270 - precision: 0.4453 - val_loss: 0.2504 - val_accuracy: 0.8824 - val_dice_coefficient: 0.5564 - val_jaccard_index: 0.3863 - val_sensitivity: 0.7907 - val_specificity: 0.9299 - val_precision: 0.4300
# Epoch 32/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.8752 - dice_coefficient: 0.5793 - jaccard_index: 0.4088 - sensitivity: 0.8366 - specificity: 0.9267 - precision: 0.4463
# Epoch 32: val_dice_coefficient improved from 0.56775 to 0.57207, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 303ms/step - loss: 0.2138 - accuracy: 0.8752 - dice_coefficient: 0.5793 - jaccard_index: 0.4088 - sensitivity: 0.8366 - specificity: 0.9267 - precision: 0.4463 - val_loss: 0.2459 - val_accuracy: 0.8836 - val_dice_coefficient: 0.5721 - val_jaccard_index: 0.4017 - val_sensitivity: 0.7405 - val_specificity: 0.9434 - val_precision: 0.4669
# Epoch 33/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2077 - accuracy: 0.8789 - dice_coefficient: 0.5843 - jaccard_index: 0.4136 - sensitivity: 0.8448 - specificity: 0.9281 - precision: 0.4481
# Epoch 33: val_dice_coefficient did not improve from 0.57207
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2077 - accuracy: 0.8789 - dice_coefficient: 0.5843 - jaccard_index: 0.4136 - sensitivity: 0.8448 - specificity: 0.9281 - precision: 0.4481 - val_loss: 0.2310 - val_accuracy: 0.8741 - val_dice_coefficient: 0.5612 - val_jaccard_index: 0.3908 - val_sensitivity: 0.8241 - val_specificity: 0.9260 - val_precision: 0.4258
# Epoch 34/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.8791 - dice_coefficient: 0.5867 - jaccard_index: 0.4162 - sensitivity: 0.8489 - specificity: 0.9280 - precision: 0.4506
# Epoch 34: val_dice_coefficient did not improve from 0.57207
# 108/108 [==============================] - 31s 287ms/step - loss: 0.2070 - accuracy: 0.8791 - dice_coefficient: 0.5867 - jaccard_index: 0.4162 - sensitivity: 0.8489 - specificity: 0.9280 - precision: 0.4506 - val_loss: 0.2424 - val_accuracy: 0.8726 - val_dice_coefficient: 0.5532 - val_jaccard_index: 0.3833 - val_sensitivity: 0.8027 - val_specificity: 0.9265 - val_precision: 0.4226
# Epoch 35/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.8785 - dice_coefficient: 0.5846 - jaccard_index: 0.4140 - sensitivity: 0.8492 - specificity: 0.9279 - precision: 0.4479
# Epoch 35: val_dice_coefficient did not improve from 0.57207
# 108/108 [==============================] - 31s 286ms/step - loss: 0.2081 - accuracy: 0.8785 - dice_coefficient: 0.5846 - jaccard_index: 0.4140 - sensitivity: 0.8492 - specificity: 0.9279 - precision: 0.4479 - val_loss: 0.2338 - val_accuracy: 0.8749 - val_dice_coefficient: 0.5529 - val_jaccard_index: 0.3829 - val_sensitivity: 0.8435 - val_specificity: 0.9194 - val_precision: 0.4120
# Epoch 36/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.8832 - dice_coefficient: 0.5937 - jaccard_index: 0.4231 - sensitivity: 0.8574 - specificity: 0.9295 - precision: 0.4551
# Epoch 36: val_dice_coefficient improved from 0.57207 to 0.57212, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 302ms/step - loss: 0.1996 - accuracy: 0.8832 - dice_coefficient: 0.5937 - jaccard_index: 0.4231 - sensitivity: 0.8574 - specificity: 0.9295 - precision: 0.4551 - val_loss: 0.2296 - val_accuracy: 0.8836 - val_dice_coefficient: 0.5721 - val_jaccard_index: 0.4016 - val_sensitivity: 0.8227 - val_specificity: 0.9297 - val_precision: 0.4392
# Epoch 37/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.8837 - dice_coefficient: 0.5939 - jaccard_index: 0.4233 - sensitivity: 0.8586 - specificity: 0.9296 - precision: 0.4555
# Epoch 37: val_dice_coefficient improved from 0.57212 to 0.57334, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 305ms/step - loss: 0.1986 - accuracy: 0.8837 - dice_coefficient: 0.5939 - jaccard_index: 0.4233 - sensitivity: 0.8586 - specificity: 0.9296 - precision: 0.4555 - val_loss: 0.2468 - val_accuracy: 0.8911 - val_dice_coefficient: 0.5733 - val_jaccard_index: 0.4028 - val_sensitivity: 0.7946 - val_specificity: 0.9347 - val_precision: 0.4491
# Epoch 38/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.8837 - dice_coefficient: 0.5942 - jaccard_index: 0.4239 - sensitivity: 0.8567 - specificity: 0.9296 - precision: 0.4569
# Epoch 38: val_dice_coefficient did not improve from 0.57334
# 108/108 [==============================] - 31s 287ms/step - loss: 0.1994 - accuracy: 0.8837 - dice_coefficient: 0.5942 - jaccard_index: 0.4239 - sensitivity: 0.8567 - specificity: 0.9296 - precision: 0.4569 - val_loss: 0.2243 - val_accuracy: 0.8747 - val_dice_coefficient: 0.5637 - val_jaccard_index: 0.3934 - val_sensitivity: 0.8490 - val_specificity: 0.9225 - val_precision: 0.4227
# Epoch 39/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.8861 - dice_coefficient: 0.5968 - jaccard_index: 0.4262 - sensitivity: 0.8617 - specificity: 0.9302 - precision: 0.4577
# Epoch 39: val_dice_coefficient did not improve from 0.57334
# 108/108 [==============================] - 31s 287ms/step - loss: 0.1945 - accuracy: 0.8861 - dice_coefficient: 0.5968 - jaccard_index: 0.4262 - sensitivity: 0.8617 - specificity: 0.9302 - precision: 0.4577 - val_loss: 0.2223 - val_accuracy: 0.8769 - val_dice_coefficient: 0.5725 - val_jaccard_index: 0.4018 - val_sensitivity: 0.8334 - val_specificity: 0.9285 - val_precision: 0.4364
# Epoch 40/50
# 108/108 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.8816 - dice_coefficient: 0.5899 - jaccard_index: 0.4194 - sensitivity: 0.8555 - specificity: 0.9285 - precision: 0.4535
# Epoch 40: val_dice_coefficient improved from 0.57334 to 0.57944, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 305ms/step - loss: 0.2026 - accuracy: 0.8816 - dice_coefficient: 0.5899 - jaccard_index: 0.4194 - sensitivity: 0.8555 - specificity: 0.9285 - precision: 0.4535 - val_loss: 0.2280 - val_accuracy: 0.8870 - val_dice_coefficient: 0.5794 - val_jaccard_index: 0.4089 - val_sensitivity: 0.8156 - val_specificity: 0.9333 - val_precision: 0.4500
# Epoch 41/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.8873 - dice_coefficient: 0.6013 - jaccard_index: 0.4307 - sensitivity: 0.8650 - specificity: 0.9307 - precision: 0.4621
# Epoch 41: val_dice_coefficient improved from 0.57944 to 0.58676, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 306ms/step - loss: 0.1926 - accuracy: 0.8873 - dice_coefficient: 0.6013 - jaccard_index: 0.4307 - sensitivity: 0.8650 - specificity: 0.9307 - precision: 0.4621 - val_loss: 0.2398 - val_accuracy: 0.8963 - val_dice_coefficient: 0.5868 - val_jaccard_index: 0.4163 - val_sensitivity: 0.7857 - val_specificity: 0.9404 - val_precision: 0.4692
# Epoch 42/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.8845 - dice_coefficient: 0.5975 - jaccard_index: 0.4272 - sensitivity: 0.8587 - specificity: 0.9299 - precision: 0.4621
# Epoch 42: val_dice_coefficient did not improve from 0.58676
# 108/108 [==============================] - 31s 287ms/step - loss: 0.1987 - accuracy: 0.8845 - dice_coefficient: 0.5975 - jaccard_index: 0.4272 - sensitivity: 0.8587 - specificity: 0.9299 - precision: 0.4621 - val_loss: 0.2296 - val_accuracy: 0.8511 - val_dice_coefficient: 0.5428 - val_jaccard_index: 0.3732 - val_sensitivity: 0.8816 - val_specificity: 0.9092 - val_precision: 0.3926
# Epoch 43/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.8889 - dice_coefficient: 0.6047 - jaccard_index: 0.4343 - sensitivity: 0.8658 - specificity: 0.9314 - precision: 0.4660
# Epoch 43: val_dice_coefficient did not improve from 0.58676
# 108/108 [==============================] - 31s 286ms/step - loss: 0.1902 - accuracy: 0.8889 - dice_coefficient: 0.6047 - jaccard_index: 0.4343 - sensitivity: 0.8658 - specificity: 0.9314 - precision: 0.4660 - val_loss: 0.2199 - val_accuracy: 0.8790 - val_dice_coefficient: 0.5693 - val_jaccard_index: 0.3988 - val_sensitivity: 0.8660 - val_specificity: 0.9216 - val_precision: 0.4247
# Epoch 44/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.8907 - dice_coefficient: 0.6064 - jaccard_index: 0.4362 - sensitivity: 0.8707 - specificity: 0.9319 - precision: 0.4664
# Epoch 44: val_dice_coefficient did not improve from 0.58676
# 108/108 [==============================] - 31s 286ms/step - loss: 0.1868 - accuracy: 0.8907 - dice_coefficient: 0.6064 - jaccard_index: 0.4362 - sensitivity: 0.8707 - specificity: 0.9319 - precision: 0.4664 - val_loss: 0.2317 - val_accuracy: 0.8925 - val_dice_coefficient: 0.5810 - val_jaccard_index: 0.4104 - val_sensitivity: 0.8325 - val_specificity: 0.9311 - val_precision: 0.4469
# Epoch 45/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 0.8919 - dice_coefficient: 0.6109 - jaccard_index: 0.4407 - sensitivity: 0.8741 - specificity: 0.9326 - precision: 0.4706
# Epoch 45: val_dice_coefficient improved from 0.58676 to 0.59970, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 108/108 [==============================] - 33s 305ms/step - loss: 0.1849 - accuracy: 0.8919 - dice_coefficient: 0.6109 - jaccard_index: 0.4407 - sensitivity: 0.8741 - specificity: 0.9326 - precision: 0.4706 - val_loss: 0.2427 - val_accuracy: 0.9060 - val_dice_coefficient: 0.5997 - val_jaccard_index: 0.4294 - val_sensitivity: 0.7678 - val_specificity: 0.9470 - val_precision: 0.4927
# Epoch 46/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.8874 - dice_coefficient: 0.6019 - jaccard_index: 0.4316 - sensitivity: 0.8639 - specificity: 0.9305 - precision: 0.4658
# Epoch 46: val_dice_coefficient did not improve from 0.59970
# 108/108 [==============================] - 31s 286ms/step - loss: 0.1933 - accuracy: 0.8874 - dice_coefficient: 0.6019 - jaccard_index: 0.4316 - sensitivity: 0.8639 - specificity: 0.9305 - precision: 0.4658 - val_loss: 0.2349 - val_accuracy: 0.8392 - val_dice_coefficient: 0.5186 - val_jaccard_index: 0.3507 - val_sensitivity: 0.9271 - val_specificity: 0.8908 - val_precision: 0.3605
# Epoch 47/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1858 - accuracy: 0.8913 - dice_coefficient: 0.6084 - jaccard_index: 0.4382 - sensitivity: 0.8731 - specificity: 0.9320 - precision: 0.4685
# Epoch 47: val_dice_coefficient did not improve from 0.59970
# 108/108 [==============================] - 31s 287ms/step - loss: 0.1858 - accuracy: 0.8913 - dice_coefficient: 0.6084 - jaccard_index: 0.4382 - sensitivity: 0.8731 - specificity: 0.9320 - precision: 0.4685 - val_loss: 0.2196 - val_accuracy: 0.8896 - val_dice_coefficient: 0.5865 - val_jaccard_index: 0.4160 - val_sensitivity: 0.8445 - val_specificity: 0.9309 - val_precision: 0.4501
# Epoch 48/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.8938 - dice_coefficient: 0.6158 - jaccard_index: 0.4460 - sensitivity: 0.8782 - specificity: 0.9332 - precision: 0.4757
# Epoch 48: val_dice_coefficient did not improve from 0.59970
# 108/108 [==============================] - 31s 287ms/step - loss: 0.1816 - accuracy: 0.8938 - dice_coefficient: 0.6158 - jaccard_index: 0.4460 - sensitivity: 0.8782 - specificity: 0.9332 - precision: 0.4757 - val_loss: 0.2166 - val_accuracy: 0.8911 - val_dice_coefficient: 0.5913 - val_jaccard_index: 0.4207 - val_sensitivity: 0.8377 - val_specificity: 0.9337 - val_precision: 0.4574
# Epoch 49/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.8953 - dice_coefficient: 0.6173 - jaccard_index: 0.4474 - sensitivity: 0.8806 - specificity: 0.9337 - precision: 0.4763
# Epoch 49: val_dice_coefficient did not improve from 0.59970
# 108/108 [==============================] - 31s 287ms/step - loss: 0.1790 - accuracy: 0.8953 - dice_coefficient: 0.6173 - jaccard_index: 0.4474 - sensitivity: 0.8806 - specificity: 0.9337 - precision: 0.4763 - val_loss: 0.2232 - val_accuracy: 0.8950 - val_dice_coefficient: 0.5911 - val_jaccard_index: 0.4205 - val_sensitivity: 0.8342 - val_specificity: 0.9341 - val_precision: 0.4583
# Epoch 50/50
# 108/108 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.8956 - dice_coefficient: 0.6189 - jaccard_index: 0.4493 - sensitivity: 0.8813 - specificity: 0.9338 - precision: 0.4781
# Epoch 50: val_dice_coefficient did not improve from 0.59970
# 108/108 [==============================] - 31s 287ms/step - loss: 0.1784 - accuracy: 0.8956 - dice_coefficient: 0.6189 - jaccard_index: 0.4493 - sensitivity: 0.8813 - specificity: 0.9338 - precision: 0.4781 - val_loss: 0.2253 - val_accuracy: 0.8985 - val_dice_coefficient: 0.5962 - val_jaccard_index: 0.4257 - val_sensitivity: 0.8245 - val_specificity: 0.9374 - val_precision: 0.4674
# Model saved to: /gdrive/My Drive/Dataset/Models/unet_vgg_4.h5

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.metrics import roc_auc_score

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred, threshold=threshold):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > threshold).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred, threshold=threshold)
plot_confusion_matrix(y_test, y_pred, threshold=threshold)
print(classification_report(y_test.flatten(), (y_pred.flatten() > threshold).astype(int)))
print("ROC-AUC:", roc_auc_score(y_test.flatten(), y_pred.flatten()))
print(f'Dice Score (coef): {dice_coefficient(y_test, y_pred, threshold=threshold)}')
print(f'Jaccard Index: {jaccard_index(y_test, y_pred, threshold=threshold)}')
# Out:
# 15/15 [==============================] - 4s 293ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.93      0.96  29326208
#          1.0       0.46      0.81      0.59   2065536
#
#     accuracy                           0.93  31391744
#    macro avg       0.73      0.87      0.78  31391744
# weighted avg       0.95      0.93      0.94  31391744
#
# ROC-AUC: 0.963267138459341
# Dice Score (coef): 0.5916304588317871
# Jaccard Index: 0.42008182406425476

# %%
def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)
    threshold = 0.97
    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

# Show predictions
show_predictions(X_test, y_test, y_pred, threshold=threshold)
