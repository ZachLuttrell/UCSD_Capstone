# %% [markdown]
# # MEViT
#
# This is the 3rd iteration of MEViT. In this one I will keep 50% of the dataset and experiment with the learning rate by increasing it to .1.
#
# **NOTE:** Connect to a High-RAM Environment

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# MODEL SETTINGS
model_name = 'mevit_model_3'
percentage_to_load = 50 / 100.0  # Set the % of dataset to be loaded here.

# %% [markdown]
# Imports

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(image_files[:number_of_files_to_load], start=1):
    img_path = os.path.join(image_directory, image_name)
    mask_name = image_to_mask[image_name]
    mask_path = os.path.join(mask_directory, mask_name)

    if os.path.exists(mask_path):
        img = tiff.imread(img_path)
        mask = tiff.imread(mask_path)

        images.append(img)
        masks.append(mask)
    else:
        print(f'\nMask not found for image: {image_name}')

    # Update the count in the same line
    print(f'\rProcessed: {count}/{number_of_files_to_load}', end='')

print("\nLoading complete.")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 50.0% of dataset: 2393 images/mask pairs...
# Processed: 2393/2393
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If there is an unnecessary singleton dimension in your dataset, remove it:
if X_train.ndim > 3:
    X_train = X_train.squeeze(axis=1)
    X_val = X_val.squeeze(axis=1)
    X_test = X_test.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (1722, 256, 256, 3), y_train: (1722, 256, 256, 1)
# X_val:   (192, 256, 256, 3), y_val: (192, 256, 256, 1)
# X_test:  (479, 256, 256, 3), y_test: (479, 256, 256, 1)

# %% [markdown]
# Model Definition

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler

# Custom Metrics
def dice_coefficient(y_true, y_pred, threshold=0.5):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

def jaccard_index(y_true, y_pred, threshold=0.5):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# Loss Function
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)
weighted_loss = weighted_binary_crossentropy(class_weights)

# Define the MEVit model
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = models.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim):
    inputs = layers.Input(shape=input_shape)
    # Flatten the input
    x = layers.Reshape((-1, input_shape[-1]))(inputs)

    # Create patches and embed
    patch_size = 16
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    patches = layers.Conv2D(filters=embed_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    patches = layers.Reshape((num_patches, embed_dim))(patches)

    # Add Transformer blocks
    for _ in range(8):
        patches = TransformerBlock(embed_dim, num_heads, ff_dim)(patches)

    # Reshape back to image
    x = layers.Reshape((input_shape[0] // patch_size, input_shape[1] // patch_size, embed_dim))(patches)
    x = Conv2DTranspose(num_classes, kernel_size=patch_size, strides=patch_size, padding="valid")(x)
    outputs = layers.Activation('sigmoid')(x)

    return Model(inputs, outputs)
# Out:
# Class weights: {0: 0.5339968946194886, 1: 7.853612816644959}

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

input_shape = (256, 256, 3)
num_classes = 1
embed_dim = 64
num_heads = 4
ff_dim = 128

model = create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim)
model._name = model_name
model.summary()

# Learning rate schedule
def lr_schedule(epoch, lr):
    if epoch >= 40 and epoch < 60:
        return lr * 0.1
    elif epoch >= 60:
        return lr * 0.1
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# Compile the model
sgd = SGD(learning_rate=0.1, momentum=0.9)
model.compile(
    optimizer=sgd,
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

# Setup callbacks
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=10,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)
# Out:
# Model: "mevit_model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 16, 16, 64)        49216
#
#  reshape_1 (Reshape)         (None, 256, 64)           0
#
#  transformer_block (Transfo  (None, 256, 64)           83200
#  rmerBlock)
#
#  transformer_block_1 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_2 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_3 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_4 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_5 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_6 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_7 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  reshape_2 (Reshape)         (None, 16, 16, 64)        0
#
#  conv2d_transpose (Conv2DTr  (None, 256, 256, 1)       16385
#  anspose)
#
#  activation (Activation)     (None, 256, 256, 1)       0
#
# =================================================================
# Total params: 731201 (2.79 MB)
# Trainable params: 731201 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=16,
    epochs=70,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping, lr_scheduler]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5694 - dice_coefficient: 0.0910 - jaccard_index: 0.0481 - sensitivity: 0.4247 - specificity: 0.5793 - precision: 0.0647
# Epoch 1: val_dice_coefficient improved from -inf to 0.00000, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 101s 845ms/step - loss: 0.6934 - accuracy: 0.5694 - dice_coefficient: 0.0910 - jaccard_index: 0.0481 - sensitivity: 0.4247 - specificity: 0.5793 - precision: 0.0647 - val_loss: 0.6869 - val_accuracy: 0.9381 - val_dice_coefficient: 1.5981e-12 - val_jaccard_index: 1.5981e-12 - val_sensitivity: 0.0000e+00 - val_specificity: 0.9999 - val_precision: 0.0000e+00 - lr: 0.1000
# Epoch 2/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6883 - accuracy: 0.5069 - dice_coefficient: 0.1059 - jaccard_index: 0.0571 - sensitivity: 0.5677 - specificity: 0.5038 - precision: 0.0711
# Epoch 2: val_dice_coefficient improved from 0.00000 to 0.14643, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 90s 836ms/step - loss: 0.6883 - accuracy: 0.5069 - dice_coefficient: 0.1059 - jaccard_index: 0.0571 - sensitivity: 0.5677 - specificity: 0.5038 - precision: 0.0711 - val_loss: 0.6532 - val_accuracy: 0.4163 - val_dice_coefficient: 0.1464 - val_jaccard_index: 0.0792 - val_sensitivity: 0.8086 - val_specificity: 0.3905 - val_precision: 0.0808 - lr: 0.1000
# Epoch 3/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6584 - accuracy: 0.5843 - dice_coefficient: 0.1697 - jaccard_index: 0.0933 - sensitivity: 0.6376 - specificity: 0.5812 - precision: 0.1039
# Epoch 3: val_dice_coefficient improved from 0.14643 to 0.16913, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 89s 828ms/step - loss: 0.6584 - accuracy: 0.5843 - dice_coefficient: 0.1697 - jaccard_index: 0.0933 - sensitivity: 0.6376 - specificity: 0.5812 - precision: 0.1039 - val_loss: 0.6374 - val_accuracy: 0.6303 - val_dice_coefficient: 0.1691 - val_jaccard_index: 0.0926 - val_sensitivity: 0.6166 - val_specificity: 0.6315 - val_precision: 0.0986 - lr: 0.1000
# Epoch 4/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6312 - accuracy: 0.6578 - dice_coefficient: 0.1925 - jaccard_index: 0.1070 - sensitivity: 0.6318 - specificity: 0.6599 - precision: 0.1181
# Epoch 4: val_dice_coefficient did not improve from 0.16913
# 108/108 [==============================] - 78s 727ms/step - loss: 0.6312 - accuracy: 0.6578 - dice_coefficient: 0.1925 - jaccard_index: 0.1070 - sensitivity: 0.6318 - specificity: 0.6599 - precision: 0.1181 - val_loss: 0.6206 - val_accuracy: 0.4809 - val_dice_coefficient: 0.1667 - val_jaccard_index: 0.0912 - val_sensitivity: 0.8453 - val_specificity: 0.4570 - val_precision: 0.0928 - lr: 0.1000
# Epoch 5/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6171 - accuracy: 0.6490 - dice_coefficient: 0.2009 - jaccard_index: 0.1125 - sensitivity: 0.6753 - specificity: 0.6472 - precision: 0.1214
# Epoch 5: val_dice_coefficient improved from 0.16913 to 0.17552, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 90s 838ms/step - loss: 0.6171 - accuracy: 0.6490 - dice_coefficient: 0.2009 - jaccard_index: 0.1125 - sensitivity: 0.6753 - specificity: 0.6472 - precision: 0.1214 - val_loss: 0.6028 - val_accuracy: 0.5480 - val_dice_coefficient: 0.1755 - val_jaccard_index: 0.0965 - val_sensitivity: 0.7826 - val_specificity: 0.5329 - val_precision: 0.0993 - lr: 0.1000
# Epoch 6/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.6361 - dice_coefficient: 0.1986 - jaccard_index: 0.1110 - sensitivity: 0.6792 - specificity: 0.6333 - precision: 0.1202
# Epoch 6: val_dice_coefficient improved from 0.17552 to 0.19854, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 89s 826ms/step - loss: 0.6147 - accuracy: 0.6361 - dice_coefficient: 0.1986 - jaccard_index: 0.1110 - sensitivity: 0.6792 - specificity: 0.6333 - precision: 0.1202 - val_loss: 0.6321 - val_accuracy: 0.7698 - val_dice_coefficient: 0.1985 - val_jaccard_index: 0.1106 - val_sensitivity: 0.4723 - val_specificity: 0.7898 - val_precision: 0.1273 - lr: 0.1000
# Epoch 7/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.6487 - dice_coefficient: 0.1992 - jaccard_index: 0.1113 - sensitivity: 0.6561 - specificity: 0.6477 - precision: 0.1217
# Epoch 7: val_dice_coefficient did not improve from 0.19854
# 108/108 [==============================] - 77s 715ms/step - loss: 0.6158 - accuracy: 0.6487 - dice_coefficient: 0.1992 - jaccard_index: 0.1113 - sensitivity: 0.6561 - specificity: 0.6477 - precision: 0.1217 - val_loss: 0.6017 - val_accuracy: 0.6437 - val_dice_coefficient: 0.1925 - val_jaccard_index: 0.1068 - val_sensitivity: 0.6901 - val_specificity: 0.6413 - val_precision: 0.1126 - lr: 0.1000
# Epoch 8/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6052 - accuracy: 0.6462 - dice_coefficient: 0.2037 - jaccard_index: 0.1140 - sensitivity: 0.6918 - specificity: 0.6426 - precision: 0.1227
# Epoch 8: val_dice_coefficient improved from 0.19854 to 0.20168, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 90s 834ms/step - loss: 0.6052 - accuracy: 0.6462 - dice_coefficient: 0.2037 - jaccard_index: 0.1140 - sensitivity: 0.6918 - specificity: 0.6426 - precision: 0.1227 - val_loss: 0.5954 - val_accuracy: 0.6758 - val_dice_coefficient: 0.2017 - val_jaccard_index: 0.1126 - val_sensitivity: 0.6654 - val_specificity: 0.6769 - val_precision: 0.1197 - lr: 0.1000
# Epoch 9/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6021 - accuracy: 0.6474 - dice_coefficient: 0.2058 - jaccard_index: 0.1155 - sensitivity: 0.6916 - specificity: 0.6447 - precision: 0.1249
# Epoch 9: val_dice_coefficient did not improve from 0.20168
# 108/108 [==============================] - 77s 712ms/step - loss: 0.6021 - accuracy: 0.6474 - dice_coefficient: 0.2058 - jaccard_index: 0.1155 - sensitivity: 0.6916 - specificity: 0.6447 - precision: 0.1249 - val_loss: 0.5986 - val_accuracy: 0.5922 - val_dice_coefficient: 0.1916 - val_jaccard_index: 0.1063 - val_sensitivity: 0.7830 - val_specificity: 0.5799 - val_precision: 0.1096 - lr: 0.1000
# Epoch 10/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.6341 - dice_coefficient: 0.2038 - jaccard_index: 0.1142 - sensitivity: 0.7210 - specificity: 0.6285 - precision: 0.1217
# Epoch 10: val_dice_coefficient improved from 0.20168 to 0.20799, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 89s 830ms/step - loss: 0.5970 - accuracy: 0.6341 - dice_coefficient: 0.2038 - jaccard_index: 0.1142 - sensitivity: 0.7210 - specificity: 0.6285 - precision: 0.1217 - val_loss: 0.5989 - val_accuracy: 0.7376 - val_dice_coefficient: 0.2080 - val_jaccard_index: 0.1165 - val_sensitivity: 0.5626 - val_specificity: 0.7497 - val_precision: 0.1288 - lr: 0.1000
# Epoch 11/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.6458 - dice_coefficient: 0.2052 - jaccard_index: 0.1150 - sensitivity: 0.7071 - specificity: 0.6414 - precision: 0.1224
# Epoch 11: val_dice_coefficient did not improve from 0.20799
# 108/108 [==============================] - 77s 713ms/step - loss: 0.5970 - accuracy: 0.6458 - dice_coefficient: 0.2052 - jaccard_index: 0.1150 - sensitivity: 0.7071 - specificity: 0.6414 - precision: 0.1224 - val_loss: 0.5891 - val_accuracy: 0.6706 - val_dice_coefficient: 0.1955 - val_jaccard_index: 0.1087 - val_sensitivity: 0.6563 - val_specificity: 0.6722 - val_precision: 0.1158 - lr: 0.1000
# Epoch 12/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5858 - accuracy: 0.6676 - dice_coefficient: 0.2153 - jaccard_index: 0.1213 - sensitivity: 0.7071 - specificity: 0.6646 - precision: 0.1294
# Epoch 12: val_dice_coefficient did not improve from 0.20799
# 108/108 [==============================] - 77s 715ms/step - loss: 0.5858 - accuracy: 0.6676 - dice_coefficient: 0.2153 - jaccard_index: 0.1213 - sensitivity: 0.7071 - specificity: 0.6646 - precision: 0.1294 - val_loss: 0.5796 - val_accuracy: 0.5440 - val_dice_coefficient: 0.1873 - val_jaccard_index: 0.1036 - val_sensitivity: 0.8514 - val_specificity: 0.5239 - val_precision: 0.1056 - lr: 0.1000
# Epoch 13/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5857 - accuracy: 0.6502 - dice_coefficient: 0.2112 - jaccard_index: 0.1188 - sensitivity: 0.7195 - specificity: 0.6453 - precision: 0.1261
# Epoch 13: val_dice_coefficient did not improve from 0.20799
# 108/108 [==============================] - 77s 713ms/step - loss: 0.5857 - accuracy: 0.6502 - dice_coefficient: 0.2112 - jaccard_index: 0.1188 - sensitivity: 0.7195 - specificity: 0.6453 - precision: 0.1261 - val_loss: 0.5764 - val_accuracy: 0.6512 - val_dice_coefficient: 0.1984 - val_jaccard_index: 0.1103 - val_sensitivity: 0.7093 - val_specificity: 0.6479 - val_precision: 0.1161 - lr: 0.1000
# Epoch 14/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5831 - accuracy: 0.6559 - dice_coefficient: 0.2105 - jaccard_index: 0.1183 - sensitivity: 0.7150 - specificity: 0.6519 - precision: 0.1259
# Epoch 14: val_dice_coefficient improved from 0.20799 to 0.21562, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 90s 834ms/step - loss: 0.5831 - accuracy: 0.6559 - dice_coefficient: 0.2105 - jaccard_index: 0.1183 - sensitivity: 0.7150 - specificity: 0.6519 - precision: 0.1259 - val_loss: 0.5705 - val_accuracy: 0.7096 - val_dice_coefficient: 0.2156 - val_jaccard_index: 0.1212 - val_sensitivity: 0.6517 - val_specificity: 0.7139 - val_precision: 0.1301 - lr: 0.1000
# Epoch 15/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5807 - accuracy: 0.6544 - dice_coefficient: 0.2139 - jaccard_index: 0.1205 - sensitivity: 0.7196 - specificity: 0.6492 - precision: 0.1281
# Epoch 15: val_dice_coefficient did not improve from 0.21562
# 108/108 [==============================] - 77s 709ms/step - loss: 0.5807 - accuracy: 0.6544 - dice_coefficient: 0.2139 - jaccard_index: 0.1205 - sensitivity: 0.7196 - specificity: 0.6492 - precision: 0.1281 - val_loss: 0.5938 - val_accuracy: 0.5132 - val_dice_coefficient: 0.1749 - val_jaccard_index: 0.0960 - val_sensitivity: 0.8405 - val_specificity: 0.4917 - val_precision: 0.0979 - lr: 0.1000
# Epoch 16/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5837 - accuracy: 0.6583 - dice_coefficient: 0.2124 - jaccard_index: 0.1195 - sensitivity: 0.7145 - specificity: 0.6543 - precision: 0.1265
# Epoch 16: val_dice_coefficient improved from 0.21562 to 0.22538, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 89s 821ms/step - loss: 0.5837 - accuracy: 0.6583 - dice_coefficient: 0.2124 - jaccard_index: 0.1195 - sensitivity: 0.7145 - specificity: 0.6543 - precision: 0.1265 - val_loss: 0.5711 - val_accuracy: 0.7465 - val_dice_coefficient: 0.2254 - val_jaccard_index: 0.1274 - val_sensitivity: 0.6086 - val_specificity: 0.7562 - val_precision: 0.1400 - lr: 0.1000
# Epoch 17/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5789 - accuracy: 0.6668 - dice_coefficient: 0.2165 - jaccard_index: 0.1222 - sensitivity: 0.7080 - specificity: 0.6632 - precision: 0.1302
# Epoch 17: val_dice_coefficient did not improve from 0.22538
# 108/108 [==============================] - 76s 703ms/step - loss: 0.5789 - accuracy: 0.6668 - dice_coefficient: 0.2165 - jaccard_index: 0.1222 - sensitivity: 0.7080 - specificity: 0.6632 - precision: 0.1302 - val_loss: 0.5742 - val_accuracy: 0.6180 - val_dice_coefficient: 0.2001 - val_jaccard_index: 0.1115 - val_sensitivity: 0.7774 - val_specificity: 0.6079 - val_precision: 0.1154 - lr: 0.1000
# Epoch 18/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5735 - accuracy: 0.6641 - dice_coefficient: 0.2179 - jaccard_index: 0.1230 - sensitivity: 0.7267 - specificity: 0.6602 - precision: 0.1303
# Epoch 18: val_dice_coefficient improved from 0.22538 to 0.23776, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 89s 826ms/step - loss: 0.5735 - accuracy: 0.6641 - dice_coefficient: 0.2179 - jaccard_index: 0.1230 - sensitivity: 0.7267 - specificity: 0.6602 - precision: 0.1303 - val_loss: 0.5623 - val_accuracy: 0.7642 - val_dice_coefficient: 0.2378 - val_jaccard_index: 0.1352 - val_sensitivity: 0.6058 - val_specificity: 0.7751 - val_precision: 0.1493 - lr: 0.1000
# Epoch 19/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5637 - accuracy: 0.6669 - dice_coefficient: 0.2197 - jaccard_index: 0.1240 - sensitivity: 0.7339 - specificity: 0.6617 - precision: 0.1306
# Epoch 19: val_dice_coefficient did not improve from 0.23776
# 108/108 [==============================] - 77s 711ms/step - loss: 0.5637 - accuracy: 0.6669 - dice_coefficient: 0.2197 - jaccard_index: 0.1240 - sensitivity: 0.7339 - specificity: 0.6617 - precision: 0.1306 - val_loss: 0.5503 - val_accuracy: 0.7093 - val_dice_coefficient: 0.2264 - val_jaccard_index: 0.1281 - val_sensitivity: 0.6918 - val_specificity: 0.7108 - val_precision: 0.1363 - lr: 0.1000
# Epoch 20/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5604 - accuracy: 0.6777 - dice_coefficient: 0.2262 - jaccard_index: 0.1281 - sensitivity: 0.7323 - specificity: 0.6737 - precision: 0.1357
# Epoch 20: val_dice_coefficient did not improve from 0.23776
# 108/108 [==============================] - 77s 717ms/step - loss: 0.5604 - accuracy: 0.6777 - dice_coefficient: 0.2262 - jaccard_index: 0.1281 - sensitivity: 0.7323 - specificity: 0.6737 - precision: 0.1357 - val_loss: 0.5389 - val_accuracy: 0.6834 - val_dice_coefficient: 0.2289 - val_jaccard_index: 0.1295 - val_sensitivity: 0.7683 - val_specificity: 0.6781 - val_precision: 0.1352 - lr: 0.1000
# Epoch 21/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5624 - accuracy: 0.6763 - dice_coefficient: 0.2247 - jaccard_index: 0.1272 - sensitivity: 0.7309 - specificity: 0.6721 - precision: 0.1346
# Epoch 21: val_dice_coefficient did not improve from 0.23776
# 108/108 [==============================] - 77s 714ms/step - loss: 0.5624 - accuracy: 0.6763 - dice_coefficient: 0.2247 - jaccard_index: 0.1272 - sensitivity: 0.7309 - specificity: 0.6721 - precision: 0.1346 - val_loss: 0.5473 - val_accuracy: 0.6547 - val_dice_coefficient: 0.2182 - val_jaccard_index: 0.1229 - val_sensitivity: 0.7808 - val_specificity: 0.6465 - val_precision: 0.1275 - lr: 0.1000
# Epoch 22/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5571 - accuracy: 0.6797 - dice_coefficient: 0.2297 - jaccard_index: 0.1304 - sensitivity: 0.7432 - specificity: 0.6749 - precision: 0.1377
# Epoch 22: val_dice_coefficient did not improve from 0.23776
# 108/108 [==============================] - 77s 715ms/step - loss: 0.5571 - accuracy: 0.6797 - dice_coefficient: 0.2297 - jaccard_index: 0.1304 - sensitivity: 0.7432 - specificity: 0.6749 - precision: 0.1377 - val_loss: 0.5648 - val_accuracy: 0.6204 - val_dice_coefficient: 0.2031 - val_jaccard_index: 0.1134 - val_sensitivity: 0.7905 - val_specificity: 0.6095 - val_precision: 0.1172 - lr: 0.1000
# Epoch 23/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5585 - accuracy: 0.6728 - dice_coefficient: 0.2263 - jaccard_index: 0.1284 - sensitivity: 0.7432 - specificity: 0.6681 - precision: 0.1355
# Epoch 23: val_dice_coefficient did not improve from 0.23776
# 108/108 [==============================] - 77s 716ms/step - loss: 0.5585 - accuracy: 0.6728 - dice_coefficient: 0.2263 - jaccard_index: 0.1284 - sensitivity: 0.7432 - specificity: 0.6681 - precision: 0.1355 - val_loss: 0.5415 - val_accuracy: 0.6078 - val_dice_coefficient: 0.2130 - val_jaccard_index: 0.1196 - val_sensitivity: 0.8627 - val_specificity: 0.5907 - val_precision: 0.1220 - lr: 0.1000
# Epoch 24/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5560 - accuracy: 0.6801 - dice_coefficient: 0.2298 - jaccard_index: 0.1306 - sensitivity: 0.7431 - specificity: 0.6747 - precision: 0.1379
# Epoch 24: val_dice_coefficient did not improve from 0.23776
# 108/108 [==============================] - 77s 715ms/step - loss: 0.5560 - accuracy: 0.6801 - dice_coefficient: 0.2298 - jaccard_index: 0.1306 - sensitivity: 0.7431 - specificity: 0.6747 - precision: 0.1379 - val_loss: 0.5219 - val_accuracy: 0.6653 - val_dice_coefficient: 0.2332 - val_jaccard_index: 0.1324 - val_sensitivity: 0.8278 - val_specificity: 0.6543 - val_precision: 0.1362 - lr: 0.1000
# Epoch 25/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5542 - accuracy: 0.6810 - dice_coefficient: 0.2343 - jaccard_index: 0.1333 - sensitivity: 0.7520 - specificity: 0.6751 - precision: 0.1417
# Epoch 25: val_dice_coefficient did not improve from 0.23776
# 108/108 [==============================] - 78s 719ms/step - loss: 0.5542 - accuracy: 0.6810 - dice_coefficient: 0.2343 - jaccard_index: 0.1333 - sensitivity: 0.7520 - specificity: 0.6751 - precision: 0.1417 - val_loss: 0.5173 - val_accuracy: 0.6740 - val_dice_coefficient: 0.2362 - val_jaccard_index: 0.1342 - val_sensitivity: 0.8210 - val_specificity: 0.6641 - val_precision: 0.1385 - lr: 0.1000
# Epoch 26/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5564 - accuracy: 0.6763 - dice_coefficient: 0.2307 - jaccard_index: 0.1311 - sensitivity: 0.7475 - specificity: 0.6707 - precision: 0.1386
# Epoch 26: val_dice_coefficient improved from 0.23776 to 0.24602, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 90s 836ms/step - loss: 0.5564 - accuracy: 0.6763 - dice_coefficient: 0.2307 - jaccard_index: 0.1311 - sensitivity: 0.7475 - specificity: 0.6707 - precision: 0.1386 - val_loss: 0.5056 - val_accuracy: 0.6914 - val_dice_coefficient: 0.2460 - val_jaccard_index: 0.1406 - val_sensitivity: 0.8192 - val_specificity: 0.6826 - val_precision: 0.1453 - lr: 0.1000
# Epoch 27/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5419 - accuracy: 0.6895 - dice_coefficient: 0.2411 - jaccard_index: 0.1377 - sensitivity: 0.7667 - specificity: 0.6832 - precision: 0.1448
# Epoch 27: val_dice_coefficient did not improve from 0.24602
# 108/108 [==============================] - 78s 718ms/step - loss: 0.5419 - accuracy: 0.6895 - dice_coefficient: 0.2411 - jaccard_index: 0.1377 - sensitivity: 0.7667 - specificity: 0.6832 - precision: 0.1448 - val_loss: 0.5211 - val_accuracy: 0.6739 - val_dice_coefficient: 0.2349 - val_jaccard_index: 0.1334 - val_sensitivity: 0.8159 - val_specificity: 0.6644 - val_precision: 0.1378 - lr: 0.1000
# Epoch 28/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5375 - accuracy: 0.6929 - dice_coefficient: 0.2438 - jaccard_index: 0.1393 - sensitivity: 0.7656 - specificity: 0.6870 - precision: 0.1464
# Epoch 28: val_dice_coefficient improved from 0.24602 to 0.27563, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 89s 829ms/step - loss: 0.5375 - accuracy: 0.6929 - dice_coefficient: 0.2438 - jaccard_index: 0.1393 - sensitivity: 0.7656 - specificity: 0.6870 - precision: 0.1464 - val_loss: 0.5029 - val_accuracy: 0.7568 - val_dice_coefficient: 0.2756 - val_jaccard_index: 0.1603 - val_sensitivity: 0.7516 - val_specificity: 0.7566 - val_precision: 0.1694 - lr: 0.1000
# Epoch 29/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5313 - accuracy: 0.6942 - dice_coefficient: 0.2484 - jaccard_index: 0.1426 - sensitivity: 0.7765 - specificity: 0.6880 - precision: 0.1497
# Epoch 29: val_dice_coefficient did not improve from 0.27563
# 108/108 [==============================] - 77s 714ms/step - loss: 0.5313 - accuracy: 0.6942 - dice_coefficient: 0.2484 - jaccard_index: 0.1426 - sensitivity: 0.7765 - specificity: 0.6880 - precision: 0.1497 - val_loss: 0.4966 - val_accuracy: 0.7261 - val_dice_coefficient: 0.2643 - val_jaccard_index: 0.1527 - val_sensitivity: 0.7984 - val_specificity: 0.7209 - val_precision: 0.1589 - lr: 0.1000
# Epoch 30/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5342 - accuracy: 0.6938 - dice_coefficient: 0.2478 - jaccard_index: 0.1421 - sensitivity: 0.7722 - specificity: 0.6881 - precision: 0.1495
# Epoch 30: val_dice_coefficient improved from 0.27563 to 0.28501, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 90s 839ms/step - loss: 0.5342 - accuracy: 0.6938 - dice_coefficient: 0.2478 - jaccard_index: 0.1421 - sensitivity: 0.7722 - specificity: 0.6881 - precision: 0.1495 - val_loss: 0.5235 - val_accuracy: 0.7977 - val_dice_coefficient: 0.2850 - val_jaccard_index: 0.1665 - val_sensitivity: 0.6581 - val_specificity: 0.8067 - val_precision: 0.1828 - lr: 0.1000
# Epoch 31/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5259 - accuracy: 0.7050 - dice_coefficient: 0.2526 - jaccard_index: 0.1451 - sensitivity: 0.7741 - specificity: 0.6985 - precision: 0.1521
# Epoch 31: val_dice_coefficient did not improve from 0.28501
# 108/108 [==============================] - 77s 710ms/step - loss: 0.5259 - accuracy: 0.7050 - dice_coefficient: 0.2526 - jaccard_index: 0.1451 - sensitivity: 0.7741 - specificity: 0.6985 - precision: 0.1521 - val_loss: 0.5034 - val_accuracy: 0.7024 - val_dice_coefficient: 0.2514 - val_jaccard_index: 0.1442 - val_sensitivity: 0.8091 - val_specificity: 0.6949 - val_precision: 0.1494 - lr: 0.1000
# Epoch 32/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5338 - accuracy: 0.6946 - dice_coefficient: 0.2463 - jaccard_index: 0.1413 - sensitivity: 0.7700 - specificity: 0.6888 - precision: 0.1486
# Epoch 32: val_dice_coefficient did not improve from 0.28501
# 108/108 [==============================] - 78s 719ms/step - loss: 0.5338 - accuracy: 0.6946 - dice_coefficient: 0.2463 - jaccard_index: 0.1413 - sensitivity: 0.7700 - specificity: 0.6888 - precision: 0.1486 - val_loss: 0.4985 - val_accuracy: 0.7613 - val_dice_coefficient: 0.2796 - val_jaccard_index: 0.1628 - val_sensitivity: 0.7531 - val_specificity: 0.7615 - val_precision: 0.1722 - lr: 0.1000
# Epoch 33/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5181 - accuracy: 0.7109 - dice_coefficient: 0.2572 - jaccard_index: 0.1481 - sensitivity: 0.7821 - specificity: 0.7056 - precision: 0.1552
# Epoch 33: val_dice_coefficient improved from 0.28501 to 0.29221, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_3
# 108/108 [==============================] - 90s 836ms/step - loss: 0.5181 - accuracy: 0.7109 - dice_coefficient: 0.2572 - jaccard_index: 0.1481 - sensitivity: 0.7821 - specificity: 0.7056 - precision: 0.1552 - val_loss: 0.5306 - val_accuracy: 0.8133 - val_dice_coefficient: 0.2922 - val_jaccard_index: 0.1714 - val_sensitivity: 0.6273 - val_specificity: 0.8252 - val_precision: 0.1911 - lr: 0.1000
# Epoch 34/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.7125 - dice_coefficient: 0.2622 - jaccard_index: 0.1515 - sensitivity: 0.7857 - specificity: 0.7058 - precision: 0.1591
# Epoch 34: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 78s 719ms/step - loss: 0.5147 - accuracy: 0.7125 - dice_coefficient: 0.2622 - jaccard_index: 0.1515 - sensitivity: 0.7857 - specificity: 0.7058 - precision: 0.1591 - val_loss: 0.4925 - val_accuracy: 0.7063 - val_dice_coefficient: 0.2562 - val_jaccard_index: 0.1473 - val_sensitivity: 0.8230 - val_specificity: 0.6981 - val_precision: 0.1521 - lr: 0.1000
# Epoch 35/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7120 - dice_coefficient: 0.2590 - jaccard_index: 0.1494 - sensitivity: 0.7816 - specificity: 0.7054 - precision: 0.1568
# Epoch 35: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 77s 713ms/step - loss: 0.5156 - accuracy: 0.7120 - dice_coefficient: 0.2590 - jaccard_index: 0.1494 - sensitivity: 0.7816 - specificity: 0.7054 - precision: 0.1568 - val_loss: 0.5003 - val_accuracy: 0.6799 - val_dice_coefficient: 0.2446 - val_jaccard_index: 0.1397 - val_sensitivity: 0.8431 - val_specificity: 0.6685 - val_precision: 0.1434 - lr: 0.1000
# Epoch 36/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5106 - accuracy: 0.7118 - dice_coefficient: 0.2600 - jaccard_index: 0.1501 - sensitivity: 0.7868 - specificity: 0.7048 - precision: 0.1570
# Epoch 36: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 78s 722ms/step - loss: 0.5106 - accuracy: 0.7118 - dice_coefficient: 0.2600 - jaccard_index: 0.1501 - sensitivity: 0.7868 - specificity: 0.7048 - precision: 0.1570 - val_loss: 0.4946 - val_accuracy: 0.7433 - val_dice_coefficient: 0.2720 - val_jaccard_index: 0.1577 - val_sensitivity: 0.7803 - val_specificity: 0.7401 - val_precision: 0.1650 - lr: 0.1000
# Epoch 37/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.7096 - dice_coefficient: 0.2580 - jaccard_index: 0.1487 - sensitivity: 0.7825 - specificity: 0.7037 - precision: 0.1559
# Epoch 37: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 78s 718ms/step - loss: 0.5185 - accuracy: 0.7096 - dice_coefficient: 0.2580 - jaccard_index: 0.1487 - sensitivity: 0.7825 - specificity: 0.7037 - precision: 0.1559 - val_loss: 0.5210 - val_accuracy: 0.7131 - val_dice_coefficient: 0.2482 - val_jaccard_index: 0.1420 - val_sensitivity: 0.7662 - val_specificity: 0.7092 - val_precision: 0.1491 - lr: 0.1000
# Epoch 38/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5123 - accuracy: 0.7110 - dice_coefficient: 0.2607 - jaccard_index: 0.1506 - sensitivity: 0.7878 - specificity: 0.7044 - precision: 0.1579
# Epoch 38: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 77s 717ms/step - loss: 0.5123 - accuracy: 0.7110 - dice_coefficient: 0.2607 - jaccard_index: 0.1506 - sensitivity: 0.7878 - specificity: 0.7044 - precision: 0.1579 - val_loss: 0.5014 - val_accuracy: 0.7765 - val_dice_coefficient: 0.2887 - val_jaccard_index: 0.1689 - val_sensitivity: 0.7379 - val_specificity: 0.7786 - val_precision: 0.1798 - lr: 0.1000
# Epoch 39/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5187 - accuracy: 0.7078 - dice_coefficient: 0.2569 - jaccard_index: 0.1480 - sensitivity: 0.7838 - specificity: 0.7009 - precision: 0.1551
# Epoch 39: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 77s 717ms/step - loss: 0.5187 - accuracy: 0.7078 - dice_coefficient: 0.2569 - jaccard_index: 0.1480 - sensitivity: 0.7838 - specificity: 0.7009 - precision: 0.1551 - val_loss: 0.4888 - val_accuracy: 0.6946 - val_dice_coefficient: 0.2533 - val_jaccard_index: 0.1454 - val_sensitivity: 0.8408 - val_specificity: 0.6843 - val_precision: 0.1495 - lr: 0.1000
# Epoch 40/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4973 - accuracy: 0.7222 - dice_coefficient: 0.2709 - jaccard_index: 0.1572 - sensitivity: 0.8018 - specificity: 0.7146 - precision: 0.1641
# Epoch 40: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 77s 713ms/step - loss: 0.4973 - accuracy: 0.7222 - dice_coefficient: 0.2709 - jaccard_index: 0.1572 - sensitivity: 0.8018 - specificity: 0.7146 - precision: 0.1641 - val_loss: 0.4864 - val_accuracy: 0.7415 - val_dice_coefficient: 0.2754 - val_jaccard_index: 0.1599 - val_sensitivity: 0.7977 - val_specificity: 0.7371 - val_precision: 0.1666 - lr: 0.1000
# Epoch 41/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7359 - dice_coefficient: 0.2786 - jaccard_index: 0.1623 - sensitivity: 0.7935 - specificity: 0.7306 - precision: 0.1703
# Epoch 41: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 78s 723ms/step - loss: 0.4907 - accuracy: 0.7359 - dice_coefficient: 0.2786 - jaccard_index: 0.1623 - sensitivity: 0.7935 - specificity: 0.7306 - precision: 0.1703 - val_loss: 0.4800 - val_accuracy: 0.7386 - val_dice_coefficient: 0.2756 - val_jaccard_index: 0.1600 - val_sensitivity: 0.8067 - val_specificity: 0.7333 - val_precision: 0.1664 - lr: 0.0100
# Epoch 42/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.7423 - dice_coefficient: 0.2840 - jaccard_index: 0.1659 - sensitivity: 0.8037 - specificity: 0.7368 - precision: 0.1728
# Epoch 42: val_dice_coefficient did not improve from 0.29221
# 108/108 [==============================] - 78s 720ms/step - loss: 0.4808 - accuracy: 0.7423 - dice_coefficient: 0.2840 - jaccard_index: 0.1659 - sensitivity: 0.8037 - specificity: 0.7368 - precision: 0.1728 - val_loss: 0.4792 - val_accuracy: 0.7321 - val_dice_coefficient: 0.2727 - val_jaccard_index: 0.1581 - val_sensitivity: 0.8144 - val_specificity: 0.7258 - val_precision: 0.1640 - lr: 1.0000e-03
# Epoch 43/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.7315 - dice_coefficient: 0.2782 - jaccard_index: 0.1620 - sensitivity: 0.8154 - specificity: 0.7245 - precision: 0.1681
# Epoch 43: val_dice_coefficient did not improve from 0.29221
# Restoring model weights from the end of the best epoch: 33.
# 108/108 [==============================] - 78s 722ms/step - loss: 0.4804 - accuracy: 0.7315 - dice_coefficient: 0.2782 - jaccard_index: 0.1620 - sensitivity: 0.8154 - specificity: 0.7245 - precision: 0.1681 - val_loss: 0.4792 - val_accuracy: 0.7320 - val_dice_coefficient: 0.2727 - val_jaccard_index: 0.1581 - val_sensitivity: 0.8145 - val_specificity: 0.7257 - val_precision: 0.1640 - lr: 1.0000e-04
# Epoch 43: early stopping
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > 0.5, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > 0.5).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred)
plot_confusion_matrix(y_test, y_pred)
print(classification_report(y_test.flatten(), (y_pred.flatten() > 0.5).astype(int)))
# Out:
# 15/15 [==============================] - 10s 598ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.82      0.89  29326208
#          1.0       0.20      0.63      0.30   2065536
#
#     accuracy                           0.81  31391744
#    macro avg       0.58      0.73      0.60  31391744
# weighted avg       0.92      0.81      0.85  31391744
