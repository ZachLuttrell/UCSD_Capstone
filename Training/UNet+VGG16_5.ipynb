# %% [markdown]
# # UNet+VGG16 5
# This is the 5th iteration of UNet+VGG16
#
# In this iteration I:
# - batch size of 32
#
#
# **NOTE:** Connect to a High-RAM Environment with GPU enabled

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# Check for GPU availability
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# MODEL SETTINGS
model_name = 'unet_vgg_5'  # Name of the model
percentage_to_load = 50 / 100.0  # Set the % of dataset to be loaded here.
threshold = 0.75  # Set the threshold for metrics here
initial_lr = 0.01  # Learning rate at the beginning of training (NOT INCORPORATED CURRENTLY, set at 1e-4)
print(f'\nSETTINGS:')
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load*100}%')
print(f'Threshold: {threshold}')
print(f'Initial Learning Rate: {initial_lr}')
print()

# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Num GPUs Available:  1
#
# SETTINGS:
# Model Name: unet_vgg_4
# Percentage to Load: 50.0%
# Threshold: 0.75
# Initial Learning Rate: 0.01
#
# Mounted at /gdrive

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(tqdm(image_files[:number_of_files_to_load]), start=1):
    try:
        img_path = os.path.join(image_directory, image_name)
        mask_name = image_to_mask[image_name]
        mask_path = os.path.join(mask_directory, mask_name)

        if os.path.exists(mask_path):
            img = tiff.imread(img_path)
            mask = tiff.imread(mask_path)

            images.append(img)
            masks.append(mask)
        else:
            print(f'\nMask not found for image: {image_name}')
    except Exception as e:
        print(f'\nError loading image/mask pair {image_name}: {e}')

print("\nLoading complete.")

# Check if the number of images and masks loaded are equal
if len(images) != len(masks):
    raise ValueError("The number of loaded images and masks do not match!")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 50.0% of dataset: 2393 images/mask pairs...
# 100%|██████████| 2393/2393 [34:17<00:00,  1.16it/s]
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If X_train, X_test, X_val have an extra unnecessary dimension at axis=1, remove it:
X_train = X_train.squeeze(axis=1)
X_test = X_test.squeeze(axis=1)
X_val = X_val.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (1722, 256, 256, 3), y_train: (1722, 256, 256, 1)
# X_val:   (192, 256, 256, 3), y_val: (192, 256, 256, 1)
# X_test:  (479, 256, 256, 3), y_test: (479, 256, 256, 1)

# %% [markdown]
# Metrics & Loss

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# CUSTOM METRICS

# Dice Coefficient: Measures overlap between true and predicted masks.
def dice_coefficient(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

# Jaccard Index: Measures the ratio of intersection to the union of true and predicted masks.
def jaccard_index(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

# Sensitivity: Measures the proportion of actual positives correctly identified.
def sensitivity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    possible_positives = tf.reduce_sum(y_true_f)
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

# Specificity: Measures the proportion of actual negatives correctly identified.
def specificity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_negatives = tf.reduce_sum((1-y_true_f) * (1-y_pred_f))
    possible_negatives = tf.reduce_sum(1-y_true_f)
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# Precision: Measures the proportion of predicted positives that are actually true positives.
def precision(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    predicted_positives = tf.reduce_sum(y_pred_f)
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())


# LOSS FUNCTION
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)

# Visualize class weight distribution
plt.bar(class_weights.keys(), class_weights.values())
plt.title("Class Weight Distribution")
plt.xlabel("Class")
plt.ylabel("Weight")
plt.show()

weighted_loss = weighted_binary_crossentropy(class_weights)
# Out:
# Class weights: {0: 0.5339968946194886, 1: 7.853612816644959}

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16

def vgg16_unet(input_size=(256, 256, 3), freeze_vgg16=True):
    inputs = Input(input_size)
    vgg16 = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_vgg16:
        # Freeze the VGG16 layers
        for layer in vgg16.layers:
            layer.trainable = False

    # Skip connections from VGG16 layers
    s1 = vgg16.get_layer("block1_conv2").output
    s2 = vgg16.get_layer("block2_conv2").output
    s3 = vgg16.get_layer("block3_conv3").output
    s4 = vgg16.get_layer("block4_conv3").output
    bridge = vgg16.get_layer("block5_conv3").output

    # Decoder
    up1 = UpSampling2D((2, 2))(bridge)
    up1 = concatenate([up1, s4])
    up1 = Conv2D(512, (3, 3), activation='relu', padding='same')(up1)

    up2 = UpSampling2D((2, 2))(up1)
    up2 = concatenate([up2, s3])
    up2 = Conv2D(256, (3, 3), activation='relu', padding='same')(up2)

    up3 = UpSampling2D((2, 2))(up2)
    up3 = concatenate([up3, s2])
    up3 = Conv2D(128, (3, 3), activation='relu', padding='same')(up3)

    up4 = UpSampling2D((2, 2))(up3)
    up4 = concatenate([up4, s1])
    up4 = Conv2D(64, (3, 3), activation='relu', padding='same')(up4)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(up4)

    model = Model(inputs, outputs)
    return model

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Define the model
model = vgg16_unet()

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)          0         ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)          2359808   ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv2[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 512)          0         ['block5_conv3[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 1024)         0         ['up_sampling2d[0][0]',
#                                                                      'block4_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 512)          4719104   ['concatenate[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 512)          0         ['conv2d[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 768)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'block3_conv3[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 256)          1769728   ['concatenate_1[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 256)        0         ['conv2d_1[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'block2_conv2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        442496    ['concatenate_2[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 128)        0         ['conv2d_2[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_3[0][0]',
#  )                                                                   'block1_conv2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         110656    ['concatenate_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 1)          65        ['conv2d_3[0][0]']
#
# ==================================================================================================
# Total params: 21756737 (83.00 MB)
# Trainable params: 7042049 (26.86 MB)
# Non-trainable params: 14714688 (56.13 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Early Stopping to prevent overfitting
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=15,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}.h5',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=50,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
print(f'Model saved to: /gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/50
# 54/54 [==============================] - ETA: 0s - loss: 0.5709 - accuracy: 0.7301 - dice_coefficient: 0.3092 - jaccard_index: 0.1848 - sensitivity: 0.4995 - specificity: 0.8734 - precision: 0.2430
# Epoch 1: val_dice_coefficient improved from -inf to 0.37963, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 54/54 [==============================] - 116s 2s/step - loss: 0.5709 - accuracy: 0.7301 - dice_coefficient: 0.3092 - jaccard_index: 0.1848 - sensitivity: 0.4995 - specificity: 0.8734 - precision: 0.2430 - val_loss: 0.4402 - val_accuracy: 0.8281 - val_dice_coefficient: 0.3796 - val_jaccard_index: 0.2343 - val_sensitivity: 0.4479 - val_specificity: 0.9398 - val_precision: 0.3303
# Epoch 2/50
# 54/54 [==============================] - ETA: 0s - loss: 0.4196 - accuracy: 0.7764 - dice_coefficient: 0.3922 - jaccard_index: 0.2443 - sensitivity: 0.5782 - specificity: 0.9072 - precision: 0.3001
# Epoch 2: val_dice_coefficient improved from 0.37963 to 0.39431, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 34s 633ms/step - loss: 0.4196 - accuracy: 0.7764 - dice_coefficient: 0.3922 - jaccard_index: 0.2443 - sensitivity: 0.5782 - specificity: 0.9072 - precision: 0.3001 - val_loss: 0.3972 - val_accuracy: 0.7527 - val_dice_coefficient: 0.3943 - val_jaccard_index: 0.2456 - val_sensitivity: 0.6493 - val_specificity: 0.8917 - val_precision: 0.2835
# Epoch 3/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.7835 - dice_coefficient: 0.4137 - jaccard_index: 0.2613 - sensitivity: 0.6137 - specificity: 0.9082 - precision: 0.3152
# Epoch 3: val_dice_coefficient improved from 0.39431 to 0.41140, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 34s 637ms/step - loss: 0.3907 - accuracy: 0.7835 - dice_coefficient: 0.4137 - jaccard_index: 0.2613 - sensitivity: 0.6137 - specificity: 0.9082 - precision: 0.3152 - val_loss: 0.3744 - val_accuracy: 0.7706 - val_dice_coefficient: 0.4114 - val_jaccard_index: 0.2591 - val_sensitivity: 0.6645 - val_specificity: 0.8969 - val_precision: 0.2982
# Epoch 4/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.7897 - dice_coefficient: 0.4286 - jaccard_index: 0.2731 - sensitivity: 0.6361 - specificity: 0.9092 - precision: 0.3275
# Epoch 4: val_dice_coefficient improved from 0.41140 to 0.43520, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 590ms/step - loss: 0.3743 - accuracy: 0.7897 - dice_coefficient: 0.4286 - jaccard_index: 0.2731 - sensitivity: 0.6361 - specificity: 0.9092 - precision: 0.3275 - val_loss: 0.3627 - val_accuracy: 0.8164 - val_dice_coefficient: 0.4352 - val_jaccard_index: 0.2782 - val_sensitivity: 0.5957 - val_specificity: 0.9246 - val_precision: 0.3433
# Epoch 5/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3589 - accuracy: 0.7977 - dice_coefficient: 0.4415 - jaccard_index: 0.2837 - sensitivity: 0.6501 - specificity: 0.9111 - precision: 0.3375
# Epoch 5: val_dice_coefficient did not improve from 0.43520
# 54/54 [==============================] - 30s 556ms/step - loss: 0.3589 - accuracy: 0.7977 - dice_coefficient: 0.4415 - jaccard_index: 0.2837 - sensitivity: 0.6501 - specificity: 0.9111 - precision: 0.3375 - val_loss: 0.3605 - val_accuracy: 0.7620 - val_dice_coefficient: 0.4194 - val_jaccard_index: 0.2654 - val_sensitivity: 0.7209 - val_specificity: 0.8870 - val_precision: 0.2960
# Epoch 6/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8014 - dice_coefficient: 0.4501 - jaccard_index: 0.2908 - sensitivity: 0.6684 - specificity: 0.9107 - precision: 0.3423
# Epoch 6: val_dice_coefficient improved from 0.43520 to 0.45015, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 33s 606ms/step - loss: 0.3470 - accuracy: 0.8014 - dice_coefficient: 0.4501 - jaccard_index: 0.2908 - sensitivity: 0.6684 - specificity: 0.9107 - precision: 0.3423 - val_loss: 0.3436 - val_accuracy: 0.8248 - val_dice_coefficient: 0.4502 - val_jaccard_index: 0.2906 - val_sensitivity: 0.6378 - val_specificity: 0.9210 - val_precision: 0.3483
# Epoch 7/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.8070 - dice_coefficient: 0.4600 - jaccard_index: 0.2991 - sensitivity: 0.6845 - specificity: 0.9116 - precision: 0.3491
# Epoch 7: val_dice_coefficient improved from 0.45015 to 0.45999, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 587ms/step - loss: 0.3378 - accuracy: 0.8070 - dice_coefficient: 0.4600 - jaccard_index: 0.2991 - sensitivity: 0.6845 - specificity: 0.9116 - precision: 0.3491 - val_loss: 0.3368 - val_accuracy: 0.8312 - val_dice_coefficient: 0.4600 - val_jaccard_index: 0.2988 - val_sensitivity: 0.6196 - val_specificity: 0.9290 - val_precision: 0.3662
# Epoch 8/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3291 - accuracy: 0.8127 - dice_coefficient: 0.4663 - jaccard_index: 0.3044 - sensitivity: 0.6890 - specificity: 0.9131 - precision: 0.3546
# Epoch 8: val_dice_coefficient improved from 0.45999 to 0.46192, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 594ms/step - loss: 0.3291 - accuracy: 0.8127 - dice_coefficient: 0.4663 - jaccard_index: 0.3044 - sensitivity: 0.6890 - specificity: 0.9131 - precision: 0.3546 - val_loss: 0.3312 - val_accuracy: 0.8230 - val_dice_coefficient: 0.4619 - val_jaccard_index: 0.3004 - val_sensitivity: 0.6595 - val_specificity: 0.9211 - val_precision: 0.3557
# Epoch 9/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3215 - accuracy: 0.8155 - dice_coefficient: 0.4726 - jaccard_index: 0.3098 - sensitivity: 0.7066 - specificity: 0.9127 - precision: 0.3564
# Epoch 9: val_dice_coefficient improved from 0.46192 to 0.47090, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 592ms/step - loss: 0.3215 - accuracy: 0.8155 - dice_coefficient: 0.4726 - jaccard_index: 0.3098 - sensitivity: 0.7066 - specificity: 0.9127 - precision: 0.3564 - val_loss: 0.3198 - val_accuracy: 0.8291 - val_dice_coefficient: 0.4709 - val_jaccard_index: 0.3081 - val_sensitivity: 0.6642 - val_specificity: 0.9237 - val_precision: 0.3650
# Epoch 10/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3168 - accuracy: 0.8191 - dice_coefficient: 0.4770 - jaccard_index: 0.3137 - sensitivity: 0.7115 - specificity: 0.9138 - precision: 0.3623
# Epoch 10: val_dice_coefficient did not improve from 0.47090
# 54/54 [==============================] - 30s 555ms/step - loss: 0.3168 - accuracy: 0.8191 - dice_coefficient: 0.4770 - jaccard_index: 0.3137 - sensitivity: 0.7115 - specificity: 0.9138 - precision: 0.3623 - val_loss: 0.3150 - val_accuracy: 0.8156 - val_dice_coefficient: 0.4658 - val_jaccard_index: 0.3037 - val_sensitivity: 0.7145 - val_specificity: 0.9109 - val_precision: 0.3459
# Epoch 11/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.8225 - dice_coefficient: 0.4851 - jaccard_index: 0.3206 - sensitivity: 0.7253 - specificity: 0.9137 - precision: 0.3664
# Epoch 11: val_dice_coefficient improved from 0.47090 to 0.48140, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 594ms/step - loss: 0.3073 - accuracy: 0.8225 - dice_coefficient: 0.4851 - jaccard_index: 0.3206 - sensitivity: 0.7253 - specificity: 0.9137 - precision: 0.3664 - val_loss: 0.3099 - val_accuracy: 0.8305 - val_dice_coefficient: 0.4814 - val_jaccard_index: 0.3171 - val_sensitivity: 0.6723 - val_specificity: 0.9260 - val_precision: 0.3751
# Epoch 12/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.8261 - dice_coefficient: 0.4912 - jaccard_index: 0.3260 - sensitivity: 0.7302 - specificity: 0.9150 - precision: 0.3725
# Epoch 12: val_dice_coefficient did not improve from 0.48140
# 54/54 [==============================] - 30s 554ms/step - loss: 0.3027 - accuracy: 0.8261 - dice_coefficient: 0.4912 - jaccard_index: 0.3260 - sensitivity: 0.7302 - specificity: 0.9150 - precision: 0.3725 - val_loss: 0.3062 - val_accuracy: 0.8133 - val_dice_coefficient: 0.4695 - val_jaccard_index: 0.3068 - val_sensitivity: 0.7523 - val_specificity: 0.9042 - val_precision: 0.3414
# Epoch 13/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2967 - accuracy: 0.8292 - dice_coefficient: 0.4956 - jaccard_index: 0.3299 - sensitivity: 0.7379 - specificity: 0.9154 - precision: 0.3752
# Epoch 13: val_dice_coefficient did not improve from 0.48140
# 54/54 [==============================] - 30s 556ms/step - loss: 0.2967 - accuracy: 0.8292 - dice_coefficient: 0.4956 - jaccard_index: 0.3299 - sensitivity: 0.7379 - specificity: 0.9154 - precision: 0.3752 - val_loss: 0.3120 - val_accuracy: 0.7851 - val_dice_coefficient: 0.4524 - val_jaccard_index: 0.2924 - val_sensitivity: 0.8143 - val_specificity: 0.8826 - val_precision: 0.3134
# Epoch 14/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.8290 - dice_coefficient: 0.4977 - jaccard_index: 0.3317 - sensitivity: 0.7430 - specificity: 0.9150 - precision: 0.3777
# Epoch 14: val_dice_coefficient improved from 0.48140 to 0.48580, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 591ms/step - loss: 0.2954 - accuracy: 0.8290 - dice_coefficient: 0.4977 - jaccard_index: 0.3317 - sensitivity: 0.7430 - specificity: 0.9150 - precision: 0.3777 - val_loss: 0.2973 - val_accuracy: 0.8347 - val_dice_coefficient: 0.4858 - val_jaccard_index: 0.3209 - val_sensitivity: 0.7314 - val_specificity: 0.9157 - val_precision: 0.3639
# Epoch 15/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.8319 - dice_coefficient: 0.5004 - jaccard_index: 0.3342 - sensitivity: 0.7469 - specificity: 0.9155 - precision: 0.3793
# Epoch 15: val_dice_coefficient improved from 0.48580 to 0.49735, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 591ms/step - loss: 0.2906 - accuracy: 0.8319 - dice_coefficient: 0.5004 - jaccard_index: 0.3342 - sensitivity: 0.7469 - specificity: 0.9155 - precision: 0.3793 - val_loss: 0.2982 - val_accuracy: 0.8503 - val_dice_coefficient: 0.4973 - val_jaccard_index: 0.3311 - val_sensitivity: 0.6976 - val_specificity: 0.9269 - val_precision: 0.3866
# Epoch 16/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.8350 - dice_coefficient: 0.5055 - jaccard_index: 0.3387 - sensitivity: 0.7522 - specificity: 0.9162 - precision: 0.3833
# Epoch 16: val_dice_coefficient improved from 0.49735 to 0.49805, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 599ms/step - loss: 0.2859 - accuracy: 0.8350 - dice_coefficient: 0.5055 - jaccard_index: 0.3387 - sensitivity: 0.7522 - specificity: 0.9162 - precision: 0.3833 - val_loss: 0.2913 - val_accuracy: 0.8431 - val_dice_coefficient: 0.4980 - val_jaccard_index: 0.3317 - val_sensitivity: 0.7183 - val_specificity: 0.9231 - val_precision: 0.3814
# Epoch 17/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.8312 - dice_coefficient: 0.5022 - jaccard_index: 0.3358 - sensitivity: 0.7473 - specificity: 0.9152 - precision: 0.3847
# Epoch 17: val_dice_coefficient improved from 0.49805 to 0.50800, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 603ms/step - loss: 0.2907 - accuracy: 0.8312 - dice_coefficient: 0.5022 - jaccard_index: 0.3358 - sensitivity: 0.7473 - specificity: 0.9152 - precision: 0.3847 - val_loss: 0.3200 - val_accuracy: 0.8778 - val_dice_coefficient: 0.5080 - val_jaccard_index: 0.3406 - val_sensitivity: 0.5956 - val_specificity: 0.9505 - val_precision: 0.4431
# Epoch 18/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2779 - accuracy: 0.8392 - dice_coefficient: 0.5133 - jaccard_index: 0.3457 - sensitivity: 0.7626 - specificity: 0.9174 - precision: 0.3887
# Epoch 18: val_dice_coefficient did not improve from 0.50800
# 54/54 [==============================] - 30s 555ms/step - loss: 0.2779 - accuracy: 0.8392 - dice_coefficient: 0.5133 - jaccard_index: 0.3457 - sensitivity: 0.7626 - specificity: 0.9174 - precision: 0.3887 - val_loss: 0.2869 - val_accuracy: 0.8486 - val_dice_coefficient: 0.5041 - val_jaccard_index: 0.3371 - val_sensitivity: 0.7220 - val_specificity: 0.9246 - val_precision: 0.3874
# Epoch 19/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.8419 - dice_coefficient: 0.5171 - jaccard_index: 0.3491 - sensitivity: 0.7680 - specificity: 0.9180 - precision: 0.3910
# Epoch 19: val_dice_coefficient did not improve from 0.50800
# 54/54 [==============================] - 30s 556ms/step - loss: 0.2731 - accuracy: 0.8419 - dice_coefficient: 0.5171 - jaccard_index: 0.3491 - sensitivity: 0.7680 - specificity: 0.9180 - precision: 0.3910 - val_loss: 0.2839 - val_accuracy: 0.8409 - val_dice_coefficient: 0.4990 - val_jaccard_index: 0.3326 - val_sensitivity: 0.7578 - val_specificity: 0.9156 - val_precision: 0.3722
# Epoch 20/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.8418 - dice_coefficient: 0.5169 - jaccard_index: 0.3491 - sensitivity: 0.7722 - specificity: 0.9175 - precision: 0.3909
# Epoch 20: val_dice_coefficient did not improve from 0.50800
# 54/54 [==============================] - 30s 552ms/step - loss: 0.2727 - accuracy: 0.8418 - dice_coefficient: 0.5169 - jaccard_index: 0.3491 - sensitivity: 0.7722 - specificity: 0.9175 - precision: 0.3909 - val_loss: 0.2816 - val_accuracy: 0.8458 - val_dice_coefficient: 0.5075 - val_jaccard_index: 0.3402 - val_sensitivity: 0.7375 - val_specificity: 0.9229 - val_precision: 0.3871
# Epoch 21/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.8431 - dice_coefficient: 0.5199 - jaccard_index: 0.3518 - sensitivity: 0.7751 - specificity: 0.9180 - precision: 0.3935
# Epoch 21: val_dice_coefficient did not improve from 0.50800
# 54/54 [==============================] - 30s 555ms/step - loss: 0.2699 - accuracy: 0.8431 - dice_coefficient: 0.5199 - jaccard_index: 0.3518 - sensitivity: 0.7751 - specificity: 0.9180 - precision: 0.3935 - val_loss: 0.2802 - val_accuracy: 0.8243 - val_dice_coefficient: 0.4904 - val_jaccard_index: 0.3249 - val_sensitivity: 0.8070 - val_specificity: 0.9021 - val_precision: 0.3523
# Epoch 22/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.8455 - dice_coefficient: 0.5242 - jaccard_index: 0.3556 - sensitivity: 0.7828 - specificity: 0.9181 - precision: 0.3956
# Epoch 22: val_dice_coefficient did not improve from 0.50800
# 54/54 [==============================] - 30s 556ms/step - loss: 0.2654 - accuracy: 0.8455 - dice_coefficient: 0.5242 - jaccard_index: 0.3556 - sensitivity: 0.7828 - specificity: 0.9181 - precision: 0.3956 - val_loss: 0.2758 - val_accuracy: 0.8415 - val_dice_coefficient: 0.5042 - val_jaccard_index: 0.3372 - val_sensitivity: 0.7742 - val_specificity: 0.9145 - val_precision: 0.3740
# Epoch 23/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.8470 - dice_coefficient: 0.5267 - jaccard_index: 0.3578 - sensitivity: 0.7771 - specificity: 0.9192 - precision: 0.4006
# Epoch 23: val_dice_coefficient did not improve from 0.50800
# 54/54 [==============================] - 30s 553ms/step - loss: 0.2641 - accuracy: 0.8470 - dice_coefficient: 0.5267 - jaccard_index: 0.3578 - sensitivity: 0.7771 - specificity: 0.9192 - precision: 0.4006 - val_loss: 0.2845 - val_accuracy: 0.8056 - val_dice_coefficient: 0.4740 - val_jaccard_index: 0.3106 - val_sensitivity: 0.8542 - val_specificity: 0.8847 - val_precision: 0.3281
# Epoch 24/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.8480 - dice_coefficient: 0.5294 - jaccard_index: 0.3605 - sensitivity: 0.7870 - specificity: 0.9187 - precision: 0.4005
# Epoch 24: val_dice_coefficient did not improve from 0.50800
# 54/54 [==============================] - 30s 555ms/step - loss: 0.2605 - accuracy: 0.8480 - dice_coefficient: 0.5294 - jaccard_index: 0.3605 - sensitivity: 0.7870 - specificity: 0.9187 - precision: 0.4005 - val_loss: 0.2721 - val_accuracy: 0.8341 - val_dice_coefficient: 0.4996 - val_jaccard_index: 0.3331 - val_sensitivity: 0.8081 - val_specificity: 0.9059 - val_precision: 0.3617
# Epoch 25/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2576 - accuracy: 0.8497 - dice_coefficient: 0.5306 - jaccard_index: 0.3616 - sensitivity: 0.7883 - specificity: 0.9193 - precision: 0.4016
# Epoch 25: val_dice_coefficient improved from 0.50800 to 0.52352, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 596ms/step - loss: 0.2576 - accuracy: 0.8497 - dice_coefficient: 0.5306 - jaccard_index: 0.3616 - sensitivity: 0.7883 - specificity: 0.9193 - precision: 0.4016 - val_loss: 0.2775 - val_accuracy: 0.8650 - val_dice_coefficient: 0.5235 - val_jaccard_index: 0.3547 - val_sensitivity: 0.7209 - val_specificity: 0.9318 - val_precision: 0.4112
# Epoch 26/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2561 - accuracy: 0.8504 - dice_coefficient: 0.5329 - jaccard_index: 0.3638 - sensitivity: 0.7917 - specificity: 0.9194 - precision: 0.4038
# Epoch 26: val_dice_coefficient improved from 0.52352 to 0.52700, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 592ms/step - loss: 0.2561 - accuracy: 0.8504 - dice_coefficient: 0.5329 - jaccard_index: 0.3638 - sensitivity: 0.7917 - specificity: 0.9194 - precision: 0.4038 - val_loss: 0.2755 - val_accuracy: 0.8663 - val_dice_coefficient: 0.5270 - val_jaccard_index: 0.3579 - val_sensitivity: 0.7220 - val_specificity: 0.9327 - val_precision: 0.4152
# Epoch 27/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.8519 - dice_coefficient: 0.5351 - jaccard_index: 0.3658 - sensitivity: 0.7951 - specificity: 0.9198 - precision: 0.4054
# Epoch 27: val_dice_coefficient did not improve from 0.52700
# 54/54 [==============================] - 30s 557ms/step - loss: 0.2540 - accuracy: 0.8519 - dice_coefficient: 0.5351 - jaccard_index: 0.3658 - sensitivity: 0.7951 - specificity: 0.9198 - precision: 0.4054 - val_loss: 0.2665 - val_accuracy: 0.8499 - val_dice_coefficient: 0.5199 - val_jaccard_index: 0.3514 - val_sensitivity: 0.7705 - val_specificity: 0.9212 - val_precision: 0.3924
# Epoch 28/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.8531 - dice_coefficient: 0.5371 - jaccard_index: 0.3676 - sensitivity: 0.7973 - specificity: 0.9203 - precision: 0.4066
# Epoch 28: val_dice_coefficient did not improve from 0.52700
# 54/54 [==============================] - 30s 557ms/step - loss: 0.2521 - accuracy: 0.8531 - dice_coefficient: 0.5371 - jaccard_index: 0.3676 - sensitivity: 0.7973 - specificity: 0.9203 - precision: 0.4066 - val_loss: 0.2654 - val_accuracy: 0.8460 - val_dice_coefficient: 0.5189 - val_jaccard_index: 0.3505 - val_sensitivity: 0.7785 - val_specificity: 0.9193 - val_precision: 0.3893
# Epoch 29/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2479 - accuracy: 0.8551 - dice_coefficient: 0.5408 - jaccard_index: 0.3710 - sensitivity: 0.8012 - specificity: 0.9205 - precision: 0.4096
# Epoch 29: val_dice_coefficient did not improve from 0.52700
# 54/54 [==============================] - 30s 556ms/step - loss: 0.2479 - accuracy: 0.8551 - dice_coefficient: 0.5408 - jaccard_index: 0.3710 - sensitivity: 0.8012 - specificity: 0.9205 - precision: 0.4096 - val_loss: 0.2644 - val_accuracy: 0.8360 - val_dice_coefficient: 0.5037 - val_jaccard_index: 0.3367 - val_sensitivity: 0.8329 - val_specificity: 0.9027 - val_precision: 0.3611
# Epoch 30/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2459 - accuracy: 0.8563 - dice_coefficient: 0.5431 - jaccard_index: 0.3731 - sensitivity: 0.8027 - specificity: 0.9209 - precision: 0.4116
# Epoch 30: val_dice_coefficient did not improve from 0.52700
# 54/54 [==============================] - 30s 556ms/step - loss: 0.2459 - accuracy: 0.8563 - dice_coefficient: 0.5431 - jaccard_index: 0.3731 - sensitivity: 0.8027 - specificity: 0.9209 - precision: 0.4116 - val_loss: 0.2642 - val_accuracy: 0.8351 - val_dice_coefficient: 0.5045 - val_jaccard_index: 0.3375 - val_sensitivity: 0.8352 - val_specificity: 0.9026 - val_precision: 0.3616
# Epoch 31/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2437 - accuracy: 0.8570 - dice_coefficient: 0.5435 - jaccard_index: 0.3736 - sensitivity: 0.8054 - specificity: 0.9208 - precision: 0.4115
# Epoch 31: val_dice_coefficient improved from 0.52700 to 0.53198, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 596ms/step - loss: 0.2437 - accuracy: 0.8570 - dice_coefficient: 0.5435 - jaccard_index: 0.3736 - sensitivity: 0.8054 - specificity: 0.9208 - precision: 0.4115 - val_loss: 0.2609 - val_accuracy: 0.8602 - val_dice_coefficient: 0.5320 - val_jaccard_index: 0.3625 - val_sensitivity: 0.7625 - val_specificity: 0.9271 - val_precision: 0.4086
# Epoch 32/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.8575 - dice_coefficient: 0.5467 - jaccard_index: 0.3765 - sensitivity: 0.8094 - specificity: 0.9212 - precision: 0.4143
# Epoch 32: val_dice_coefficient improved from 0.53198 to 0.54019, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 597ms/step - loss: 0.2429 - accuracy: 0.8575 - dice_coefficient: 0.5467 - jaccard_index: 0.3765 - sensitivity: 0.8094 - specificity: 0.9212 - precision: 0.4143 - val_loss: 0.2670 - val_accuracy: 0.8750 - val_dice_coefficient: 0.5402 - val_jaccard_index: 0.3702 - val_sensitivity: 0.7272 - val_specificity: 0.9363 - val_precision: 0.4298
# Epoch 33/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2436 - accuracy: 0.8577 - dice_coefficient: 0.5483 - jaccard_index: 0.3784 - sensitivity: 0.8064 - specificity: 0.9217 - precision: 0.4183
# Epoch 33: val_dice_coefficient did not improve from 0.54019
# 54/54 [==============================] - 30s 557ms/step - loss: 0.2436 - accuracy: 0.8577 - dice_coefficient: 0.5483 - jaccard_index: 0.3784 - sensitivity: 0.8064 - specificity: 0.9217 - precision: 0.4183 - val_loss: 0.2571 - val_accuracy: 0.8423 - val_dice_coefficient: 0.5161 - val_jaccard_index: 0.3479 - val_sensitivity: 0.8227 - val_specificity: 0.9099 - val_precision: 0.3761
# Epoch 34/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.8595 - dice_coefficient: 0.5492 - jaccard_index: 0.3791 - sensitivity: 0.8134 - specificity: 0.9217 - precision: 0.4164
# Epoch 34: val_dice_coefficient improved from 0.54019 to 0.54049, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 594ms/step - loss: 0.2391 - accuracy: 0.8595 - dice_coefficient: 0.5492 - jaccard_index: 0.3791 - sensitivity: 0.8134 - specificity: 0.9217 - precision: 0.4164 - val_loss: 0.2622 - val_accuracy: 0.8714 - val_dice_coefficient: 0.5405 - val_jaccard_index: 0.3705 - val_sensitivity: 0.7461 - val_specificity: 0.9330 - val_precision: 0.4239
# Epoch 35/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.8554 - dice_coefficient: 0.5434 - jaccard_index: 0.3736 - sensitivity: 0.8018 - specificity: 0.9208 - precision: 0.4142
# Epoch 35: val_dice_coefficient did not improve from 0.54049
# 54/54 [==============================] - 30s 556ms/step - loss: 0.2468 - accuracy: 0.8554 - dice_coefficient: 0.5434 - jaccard_index: 0.3736 - sensitivity: 0.8018 - specificity: 0.9208 - precision: 0.4142 - val_loss: 0.2572 - val_accuracy: 0.8405 - val_dice_coefficient: 0.5117 - val_jaccard_index: 0.3439 - val_sensitivity: 0.8377 - val_specificity: 0.9054 - val_precision: 0.3685
# Epoch 36/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.8620 - dice_coefficient: 0.5537 - jaccard_index: 0.3833 - sensitivity: 0.8152 - specificity: 0.9224 - precision: 0.4203
# Epoch 36: val_dice_coefficient did not improve from 0.54049
# 54/54 [==============================] - 30s 558ms/step - loss: 0.2350 - accuracy: 0.8620 - dice_coefficient: 0.5537 - jaccard_index: 0.3833 - sensitivity: 0.8152 - specificity: 0.9224 - precision: 0.4203 - val_loss: 0.2540 - val_accuracy: 0.8444 - val_dice_coefficient: 0.5209 - val_jaccard_index: 0.3523 - val_sensitivity: 0.8262 - val_specificity: 0.9112 - val_precision: 0.3805
# Epoch 37/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.8606 - dice_coefficient: 0.5535 - jaccard_index: 0.3832 - sensitivity: 0.8177 - specificity: 0.9220 - precision: 0.4214
# Epoch 37: val_dice_coefficient did not improve from 0.54049
# 54/54 [==============================] - 30s 557ms/step - loss: 0.2367 - accuracy: 0.8606 - dice_coefficient: 0.5535 - jaccard_index: 0.3832 - sensitivity: 0.8177 - specificity: 0.9220 - precision: 0.4214 - val_loss: 0.2597 - val_accuracy: 0.8657 - val_dice_coefficient: 0.5360 - val_jaccard_index: 0.3662 - val_sensitivity: 0.7664 - val_specificity: 0.9277 - val_precision: 0.4122
# Epoch 38/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.8631 - dice_coefficient: 0.5549 - jaccard_index: 0.3845 - sensitivity: 0.8171 - specificity: 0.9226 - precision: 0.4216
# Epoch 38: val_dice_coefficient did not improve from 0.54049
# 54/54 [==============================] - 30s 558ms/step - loss: 0.2339 - accuracy: 0.8631 - dice_coefficient: 0.5549 - jaccard_index: 0.3845 - sensitivity: 0.8171 - specificity: 0.9226 - precision: 0.4216 - val_loss: 0.2532 - val_accuracy: 0.8663 - val_dice_coefficient: 0.5394 - val_jaccard_index: 0.3694 - val_sensitivity: 0.7815 - val_specificity: 0.9263 - val_precision: 0.4120
# Epoch 39/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.8630 - dice_coefficient: 0.5563 - jaccard_index: 0.3858 - sensitivity: 0.8193 - specificity: 0.9229 - precision: 0.4234
# Epoch 39: val_dice_coefficient did not improve from 0.54049
# 54/54 [==============================] - 30s 557ms/step - loss: 0.2336 - accuracy: 0.8630 - dice_coefficient: 0.5563 - jaccard_index: 0.3858 - sensitivity: 0.8193 - specificity: 0.9229 - precision: 0.4234 - val_loss: 0.2539 - val_accuracy: 0.8668 - val_dice_coefficient: 0.5398 - val_jaccard_index: 0.3698 - val_sensitivity: 0.7799 - val_specificity: 0.9269 - val_precision: 0.4129
# Epoch 40/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.8618 - dice_coefficient: 0.5551 - jaccard_index: 0.3847 - sensitivity: 0.8171 - specificity: 0.9225 - precision: 0.4238
# Epoch 40: val_dice_coefficient improved from 0.54049 to 0.55265, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 600ms/step - loss: 0.2356 - accuracy: 0.8618 - dice_coefficient: 0.5551 - jaccard_index: 0.3847 - sensitivity: 0.8171 - specificity: 0.9225 - precision: 0.4238 - val_loss: 0.2601 - val_accuracy: 0.8812 - val_dice_coefficient: 0.5527 - val_jaccard_index: 0.3820 - val_sensitivity: 0.7319 - val_specificity: 0.9394 - val_precision: 0.4441
# Epoch 41/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.8644 - dice_coefficient: 0.5592 - jaccard_index: 0.3888 - sensitivity: 0.8218 - specificity: 0.9233 - precision: 0.4265
# Epoch 41: val_dice_coefficient did not improve from 0.55265
# 54/54 [==============================] - 30s 558ms/step - loss: 0.2305 - accuracy: 0.8644 - dice_coefficient: 0.5592 - jaccard_index: 0.3888 - sensitivity: 0.8218 - specificity: 0.9233 - precision: 0.4265 - val_loss: 0.2514 - val_accuracy: 0.8651 - val_dice_coefficient: 0.5382 - val_jaccard_index: 0.3684 - val_sensitivity: 0.7951 - val_specificity: 0.9234 - val_precision: 0.4070
# Epoch 42/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.8649 - dice_coefficient: 0.5604 - jaccard_index: 0.3899 - sensitivity: 0.8231 - specificity: 0.9233 - precision: 0.4272
# Epoch 42: val_dice_coefficient did not improve from 0.55265
# 54/54 [==============================] - 30s 558ms/step - loss: 0.2305 - accuracy: 0.8649 - dice_coefficient: 0.5604 - jaccard_index: 0.3899 - sensitivity: 0.8231 - specificity: 0.9233 - precision: 0.4272 - val_loss: 0.2468 - val_accuracy: 0.8544 - val_dice_coefficient: 0.5310 - val_jaccard_index: 0.3616 - val_sensitivity: 0.8283 - val_specificity: 0.9147 - val_precision: 0.3909
# Epoch 43/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.8676 - dice_coefficient: 0.5646 - jaccard_index: 0.3937 - sensitivity: 0.8289 - specificity: 0.9242 - precision: 0.4293
# Epoch 43: val_dice_coefficient did not improve from 0.55265
# 54/54 [==============================] - 30s 557ms/step - loss: 0.2254 - accuracy: 0.8676 - dice_coefficient: 0.5646 - jaccard_index: 0.3937 - sensitivity: 0.8289 - specificity: 0.9242 - precision: 0.4293 - val_loss: 0.2472 - val_accuracy: 0.8480 - val_dice_coefficient: 0.5230 - val_jaccard_index: 0.3542 - val_sensitivity: 0.8516 - val_specificity: 0.9072 - val_precision: 0.3775
# Epoch 44/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.8685 - dice_coefficient: 0.5653 - jaccard_index: 0.3943 - sensitivity: 0.8317 - specificity: 0.9242 - precision: 0.4289
# Epoch 44: val_dice_coefficient improved from 0.55265 to 0.55309, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 598ms/step - loss: 0.2229 - accuracy: 0.8685 - dice_coefficient: 0.5653 - jaccard_index: 0.3943 - sensitivity: 0.8317 - specificity: 0.9242 - precision: 0.4289 - val_loss: 0.2554 - val_accuracy: 0.8801 - val_dice_coefficient: 0.5531 - val_jaccard_index: 0.3824 - val_sensitivity: 0.7614 - val_specificity: 0.9345 - val_precision: 0.4344
# Epoch 45/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.8668 - dice_coefficient: 0.5636 - jaccard_index: 0.3928 - sensitivity: 0.8279 - specificity: 0.9238 - precision: 0.4295
# Epoch 45: val_dice_coefficient did not improve from 0.55309
# 54/54 [==============================] - 30s 557ms/step - loss: 0.2266 - accuracy: 0.8668 - dice_coefficient: 0.5636 - jaccard_index: 0.3928 - sensitivity: 0.8279 - specificity: 0.9238 - precision: 0.4295 - val_loss: 0.2481 - val_accuracy: 0.8743 - val_dice_coefficient: 0.5520 - val_jaccard_index: 0.3814 - val_sensitivity: 0.7761 - val_specificity: 0.9316 - val_precision: 0.4285
# Epoch 46/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.8586 - dice_coefficient: 0.5514 - jaccard_index: 0.3814 - sensitivity: 0.8181 - specificity: 0.9203 - precision: 0.4216
# Epoch 46: val_dice_coefficient did not improve from 0.55309
# 54/54 [==============================] - 30s 558ms/step - loss: 0.2395 - accuracy: 0.8586 - dice_coefficient: 0.5514 - jaccard_index: 0.3814 - sensitivity: 0.8181 - specificity: 0.9203 - precision: 0.4216 - val_loss: 0.2924 - val_accuracy: 0.8882 - val_dice_coefficient: 0.5405 - val_jaccard_index: 0.3704 - val_sensitivity: 0.6081 - val_specificity: 0.9576 - val_precision: 0.4865
# Epoch 47/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.8577 - dice_coefficient: 0.5491 - jaccard_index: 0.3795 - sensitivity: 0.8115 - specificity: 0.9214 - precision: 0.4223
# Epoch 47: val_dice_coefficient did not improve from 0.55309
# 54/54 [==============================] - 30s 554ms/step - loss: 0.2434 - accuracy: 0.8577 - dice_coefficient: 0.5491 - jaccard_index: 0.3795 - sensitivity: 0.8115 - specificity: 0.9214 - precision: 0.4223 - val_loss: 0.2543 - val_accuracy: 0.8798 - val_dice_coefficient: 0.5518 - val_jaccard_index: 0.3812 - val_sensitivity: 0.7660 - val_specificity: 0.9331 - val_precision: 0.4314
# Epoch 48/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.8705 - dice_coefficient: 0.5687 - jaccard_index: 0.3978 - sensitivity: 0.8353 - specificity: 0.9249 - precision: 0.4318
# Epoch 48: val_dice_coefficient improved from 0.55309 to 0.55736, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_4.h5
# 54/54 [==============================] - 32s 589ms/step - loss: 0.2195 - accuracy: 0.8705 - dice_coefficient: 0.5687 - jaccard_index: 0.3978 - sensitivity: 0.8353 - specificity: 0.9249 - precision: 0.4318 - val_loss: 0.2490 - val_accuracy: 0.8799 - val_dice_coefficient: 0.5574 - val_jaccard_index: 0.3865 - val_sensitivity: 0.7675 - val_specificity: 0.9349 - val_precision: 0.4377
# Epoch 49/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.8686 - dice_coefficient: 0.5682 - jaccard_index: 0.3974 - sensitivity: 0.8297 - specificity: 0.9246 - precision: 0.4351
# Epoch 49: val_dice_coefficient did not improve from 0.55736
# 54/54 [==============================] - 30s 558ms/step - loss: 0.2237 - accuracy: 0.8686 - dice_coefficient: 0.5682 - jaccard_index: 0.3974 - sensitivity: 0.8297 - specificity: 0.9246 - precision: 0.4351 - val_loss: 0.2452 - val_accuracy: 0.8699 - val_dice_coefficient: 0.5444 - val_jaccard_index: 0.3741 - val_sensitivity: 0.8117 - val_specificity: 0.9228 - val_precision: 0.4096
# Epoch 50/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.8716 - dice_coefficient: 0.5720 - jaccard_index: 0.4010 - sensitivity: 0.8373 - specificity: 0.9254 - precision: 0.4357
# Epoch 50: val_dice_coefficient did not improve from 0.55736
# 54/54 [==============================] - 30s 558ms/step - loss: 0.2180 - accuracy: 0.8716 - dice_coefficient: 0.5720 - jaccard_index: 0.4010 - sensitivity: 0.8373 - specificity: 0.9254 - precision: 0.4357 - val_loss: 0.2412 - val_accuracy: 0.8716 - val_dice_coefficient: 0.5536 - val_jaccard_index: 0.3829 - val_sensitivity: 0.7993 - val_specificity: 0.9282 - val_precision: 0.4236
# Model saved to: /gdrive/My Drive/Dataset/Models/unet_vgg_4.h5

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_auc_score

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred, threshold=threshold):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > threshold).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative (Correct: No Buildings)', 'False Positive (Incorrect: There Was No Building)', 'False Negative (Incorrect: There Was A Building Here)', 'True Positive (Correct: There Is A Building Here)']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred, threshold=threshold)
plot_confusion_matrix(y_test, y_pred, threshold=threshold)
print(classification_report(y_test.flatten(), (y_pred.flatten() > threshold).astype(int)))
print("ROC-AUC:", roc_auc_score(y_test.flatten(), y_pred.flatten()))
# Out:
# 15/15 [==============================] - 17s 1s/step
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.92      0.95  29326208
#          1.0       0.43      0.79      0.55   2065536
#
#     accuracy                           0.92  31391744
#    macro avg       0.71      0.86      0.75  31391744
# weighted avg       0.95      0.92      0.93  31391744
#
# ROC-AUC: 0.9554031161631071
