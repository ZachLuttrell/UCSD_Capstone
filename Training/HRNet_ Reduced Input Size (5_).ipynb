# %% [markdown]
# **NOTE:**
# Connect to a High-RAM environment

# %%
# HRNet Implementation: https://github.com/niecongchong/HRNet-keras-semantic-segmentation/blob/master/model/seg_hrnet.py

# %% [markdown]
# Import the libraries

# %%
from google.colab import drive
drive.mount('/gdrive')

import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
# Out:
# Mounted at /gdrive

# %% [markdown]
# Load the dataset

# %%
def count_files(directory, extension=".tif"):
    # List all files in the directory and count those with the specified extension
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")
# Out:
# Number of image files: 4787
# Number of mask files: 4787

# %%
# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
percentage_to_load = 5 / 100.0  # Set the % of dataset to be loaded here.
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Loading {number_of_files_to_load} images and masks...')
for count, image_name in enumerate(image_files[:number_of_files_to_load], start=1):
    img_path = os.path.join(image_directory, image_name)
    mask_name = image_to_mask[image_name]
    mask_path = os.path.join(mask_directory, mask_name)

    if os.path.exists(mask_path):
        img = tiff.imread(img_path)
        mask = tiff.imread(mask_path)

        images.append(img)
        masks.append(mask)
    else:
        print(f'\nMask not found for image: {image_name}')

    # Update the count in the same line
    print(f'\rProcessed: {count}/{number_of_files_to_load}', end='')

print("\nLoading complete.")

# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))
# Out:
# Loading 239 images and masks...
# Processed: 239/239
# Loading complete.

# %% [markdown]
# Perform Train/Test/Val Split

# %%
# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If there is an unnecessary singleton dimension in your dataset, remove it:
if X_train.ndim > 3:  # Assuming the desired dimension is 3 (e.g., height x width x channels)
    X_train = X_train.squeeze(axis=1)
    X_val = X_val.squeeze(axis=1)
    X_test = X_test.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (171, 256, 256, 3), y_train: (171, 256, 256, 1)
# X_val:   (20, 256, 256, 3), y_val: (20, 256, 256, 1)
# X_test:  (48, 256, 256, 3), y_test: (48, 256, 256, 1)

# %% [markdown]
# Define the model

# %%
from keras.layers import Input, Conv2D, BatchNormalization, Activation, UpSampling2D, add, concatenate
from keras.models import Model
import tensorflow as tf
from tensorflow.keras.backend import epsilon

def stem_net(input):
    # Start with a convolution with stride 1 to maintain resolution
    x = Conv2D(64, 3, strides=(1, 1), padding='same', use_bias=False, kernel_initializer='he_normal')(input)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    # Reduced stride in the next layers or adjust according to your network depth need
    x = Conv2D(64, 3, strides=(1, 1), padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    return x

def transition_layer1(x, out_filters_list=[32, 64]):
    # Branch maintaining the current resolution
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    # Branch with reduced resolution
    x1 = Conv2D(out_filters_list[1], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    return [x0, x1]

def make_branch1_0(x, out_filters=32):
    # Applying multiple basic blocks to process high-resolution features
    x = basic_Block(x, out_filters, with_conv_shortcut=True)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch1_1(x, out_filters=64):
    # Processing slightly lower resolution features
    x = basic_Block(x, out_filters, with_conv_shortcut=True)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def fuse_layer1(x):
    # x is a list of feature maps from different branches
    x0_0 = x[0]  # High-resolution feature map
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)  # Upsampling to match high-res dimensions
    x0 = add([x0_0, x0_1])  # Adding features from different resolutions

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]  # Lower resolution features
    x1 = add([x1_0, x1_1])  # Combining features with downsampling high-res features

    return [x0, x1]

def transition_layer2(x, out_filters_list=[32, 64, 128]):
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    x1 = Conv2D(out_filters_list[1], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    x2 = Conv2D(out_filters_list[2], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2 = BatchNormalization(axis=3)(x2)
    x2 = Activation('relu')(x2)

    return [x0, x1, x2]

def make_branch2_0(x, out_filters=32):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch2_1(x, out_filters=64):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch2_2(x, out_filters=128):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def fuse_layer2(x):
    x0_0 = x[0]
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)
    x0_2 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x0_2 = BatchNormalization(axis=3)(x0_2)
    x0_2 = UpSampling2D(size=(4, 4))(x0_2)
    x0 = add([x0_0, x0_1, x0_2])

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]
    x1_2 = Conv2D(64, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x1_2 = BatchNormalization(axis=3)(x1_2)
    x1_2 = UpSampling2D(size=(2, 2))(x1_2)
    x1 = add([x1_0, x1_1, x1_2])

    x2_0 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_0 = Activation('relu')(x2_0)
    x2_0 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x2_0)
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_1 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2_1 = BatchNormalization(axis=3)(x2_1)
    x2_2 = x[2]
    x2 = add([x2_0, x2_1, x2_2])

    return [x0, x1, x2]

def final_layer(x, classes=1):
    # No upsampling might be needed if the output is already too large
    x = Conv2D(classes, 1, use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('sigmoid')(x)  # Use 'sigmoid' for binary classification, 'softmax' if more classes
    return x

def seg_hrnet(input_shape=(256, 256, 3), classes=1):
    inputs = Input(shape=input_shape)

    # Stem network
    x = stem_net(inputs)

    # Transition Layer 1
    x = transition_layer1(x)
    x0 = make_branch1_0(x[0])
    x1 = make_branch1_1(x[1])
    x = fuse_layer1([x0, x1])

    # Transition Layer 2
    x = transition_layer2(x)
    x0 = make_branch2_0(x[0])
    x1 = make_branch2_1(x[1])
    x2 = make_branch2_2(x[2])
    x = fuse_layer2([x0, x1, x2])

    # Final Layer
    out = final_layer(x[0], classes=classes)

    model = Model(inputs=inputs, outputs=out)
    return model

# CUSTOM METRICS
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + epsilon())

def jaccard_index(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + epsilon()) / (union + epsilon())

def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# MODEL FEATURES
def basic_Block(input, out_filters, strides=(1, 1), with_conv_shortcut=False):
    x = conv3x3(input, out_filters, strides)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = conv3x3(x, out_filters)
    x = BatchNormalization(axis=3)(x)

    if with_conv_shortcut:
        residual = Conv2D(out_filters, 1, strides=strides, use_bias=False, kernel_initializer='he_normal')(input)
        residual = BatchNormalization(axis=3)(residual)
        x = add([x, residual])
    else:
        x = add([x, input])

    x = Activation('relu')(x)
    return x

def conv3x3(x, out_filters, strides=(1, 1)):
    x = Conv2D(out_filters, 3, padding='same', strides=strides, use_bias=False, kernel_initializer='he_normal')(x)
    return x

# %% [markdown]
# Compile the model

# %%
from tensorflow.keras.optimizers import Adam

model = seg_hrnet()

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         1728      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)         36864     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 32)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256, 256, 32)         128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)         36864     ['activation_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 32)         9216      ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 64)         256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 256, 256, 32)         128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 32)         9216      ['activation_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 32)         1024      ['activation_2[0][0]']
#
#  batch_normalization_13 (Ba  (None, 128, 128, 64)         256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_5 (Bat  (None, 256, 256, 32)         128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 256, 256, 32)         128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_12 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  add (Add)                   (None, 256, 256, 32)         0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_12[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 64)         4096      ['activation_3[0][0]']
#
#  activation_5 (Activation)   (None, 256, 256, 32)         0         ['add[0][0]']
#
#  batch_normalization_14 (Ba  (None, 128, 128, 64)         256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 128, 128, 64)         256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 32)         9216      ['activation_5[0][0]']
#
#  add_4 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_7 (Bat  (None, 256, 256, 32)         128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_13 (Activation)  (None, 128, 128, 64)         0         ['add_4[0][0]']
#
#  activation_6 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_13[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 32)         9216      ['activation_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 128, 128, 64)         256       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_14 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     , 'activation_5[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_14[0][0]']
#
#  activation_7 (Activation)   (None, 256, 256, 32)         0         ['add_1[0][0]']
#
#  batch_normalization_17 (Ba  (None, 128, 128, 64)         256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 32)         9216      ['activation_7[0][0]']
#
#  add_5 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'activation_13[0][0]']
#
#  batch_normalization_9 (Bat  (None, 256, 256, 32)         128       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_15 (Activation)  (None, 128, 128, 64)         0         ['add_5[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_15[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_8[0][0]']
#
#  batch_normalization_18 (Ba  (None, 128, 128, 64)         256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_10 (Ba  (None, 256, 256, 32)         128       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 256, 256, 32)         0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'activation_7[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_16[0][0]']
#
#  activation_9 (Activation)   (None, 256, 256, 32)         0         ['add_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 128, 128, 64)         256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_9[0][0]']
#
#  add_6 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'activation_15[0][0]']
#
#  batch_normalization_11 (Ba  (None, 256, 256, 32)         128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 128, 128, 64)         0         ['add_6[0][0]']
#
#  activation_10 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_17[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_10[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128, 128, 64)         256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 256, 256, 32)         128       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, 256, 256, 32)         0         ['batch_normalization_12[0][0]
#                                                                     ',
#                                                                      'activation_9[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_18[0][0]']
#
#  activation_11 (Activation)  (None, 256, 256, 32)         0         ['add_3[0][0]']
#
#  batch_normalization_21 (Ba  (None, 128, 128, 64)         256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 64)         18432     ['activation_11[0][0]']
#
#  activation_19 (Activation)  (None, 128, 128, 64)         0         ['add_7[0][0]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 64)         256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 32)         2048      ['activation_19[0][0]']
#
#  add_9 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'activation_19[0][0]']
#
#  batch_normalization_22 (Ba  (None, 128, 128, 32)         128       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 64)         36864     ['add_9[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 128)          73728     ['add_9[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 256, 256, 32)         0         ['batch_normalization_22[0][0]
#  D)                                                                 ']
#
#  batch_normalization_25 (Ba  (None, 128, 128, 64)         256       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 64, 64, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 256, 256, 32)         0         ['activation_11[0][0]',
#                                                                      'up_sampling2d[0][0]']
#
#  activation_21 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 256, 256, 32)         9216      ['add_8[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_21[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_22[0][0]']
#
#  batch_normalization_24 (Ba  (None, 256, 256, 32)         128       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 128, 128, 64)         256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 64, 64, 128)          512       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_20[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_31[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_39[0][0]']
#
#  batch_normalization_27 (Ba  (None, 256, 256, 32)         128       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 128, 128, 64)         256       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 64, 64, 128)          512       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_36[0][0]
#                                                                     ',
#                                                                      'activation_21[0][0]']
#
#  add_18 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_44[0][0]
#                                                                     ',
#                                                                      'activation_22[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_23[0][0]']
#
#  activation_32 (Activation)  (None, 128, 128, 64)         0         ['add_14[0][0]']
#
#  activation_40 (Activation)  (None, 64, 64, 128)          0         ['add_18[0][0]']
#
#  batch_normalization_28 (Ba  (None, 256, 256, 32)         128       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  conv2d_37 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_32[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_40[0][0]']
#
#  add_10 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_28[0][0]
#                                                                     ',
#                                                                      'activation_20[0][0]']
#
#  batch_normalization_37 (Ba  (None, 128, 128, 64)         256       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 64, 64, 128)          512       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 256, 256, 32)         0         ['add_10[0][0]']
#
#  activation_33 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_24[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_33[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_41[0][0]']
#
#  batch_normalization_29 (Ba  (None, 256, 256, 32)         128       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 128, 128, 64)         256       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 64, 64, 128)          512       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  add_15 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_38[0][0]
#                                                                     ',
#                                                                      'activation_32[0][0]']
#
#  add_19 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_46[0][0]
#                                                                     ',
#                                                                      'activation_40[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_25[0][0]']
#
#  activation_34 (Activation)  (None, 128, 128, 64)         0         ['add_15[0][0]']
#
#  activation_42 (Activation)  (None, 64, 64, 128)          0         ['add_19[0][0]']
#
#  batch_normalization_30 (Ba  (None, 256, 256, 32)         128       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  conv2d_39 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_34[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_42[0][0]']
#
#  add_11 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_30[0][0]
#                                                                     ',
#                                                                      'activation_24[0][0]']
#
#  batch_normalization_39 (Ba  (None, 128, 128, 64)         256       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 64, 64, 128)          512       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 256, 256, 32)         0         ['add_11[0][0]']
#
#  activation_35 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_26[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_35[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_43[0][0]']
#
#  batch_normalization_31 (Ba  (None, 256, 256, 32)         128       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 128, 128, 64)         256       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 64, 64, 128)          512       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  add_16 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'activation_34[0][0]']
#
#  add_20 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_48[0][0]
#                                                                     ',
#                                                                      'activation_42[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_27[0][0]']
#
#  activation_36 (Activation)  (None, 128, 128, 64)         0         ['add_16[0][0]']
#
#  activation_44 (Activation)  (None, 64, 64, 128)          0         ['add_20[0][0]']
#
#  batch_normalization_32 (Ba  (None, 256, 256, 32)         128       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  conv2d_41 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_36[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_44[0][0]']
#
#  add_12 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'activation_26[0][0]']
#
#  batch_normalization_41 (Ba  (None, 128, 128, 64)         256       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 64, 64, 128)          512       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 256, 256, 32)         0         ['add_12[0][0]']
#
#  activation_37 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_28[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_37[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 64, 64, 128)          147456    ['activation_45[0][0]']
#
#  batch_normalization_33 (Ba  (None, 256, 256, 32)         128       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 128, 128, 64)         256       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_50 (Ba  (None, 64, 64, 128)          512       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  add_17 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_42[0][0]
#                                                                     ',
#                                                                      'activation_36[0][0]']
#
#  add_21 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_50[0][0]
#                                                                     ',
#                                                                      'activation_44[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_29[0][0]']
#
#  activation_38 (Activation)  (None, 128, 128, 64)         0         ['add_17[0][0]']
#
#  activation_46 (Activation)  (None, 64, 64, 128)          0         ['add_21[0][0]']
#
#  batch_normalization_34 (Ba  (None, 256, 256, 32)         128       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  conv2d_51 (Conv2D)          (None, 128, 128, 32)         2048      ['activation_38[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 64, 64, 32)           4096      ['activation_46[0][0]']
#
#  add_13 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'activation_28[0][0]']
#
#  batch_normalization_51 (Ba  (None, 128, 128, 32)         128       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 64, 64, 32)           128       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 256, 256, 32)         0         ['add_13[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 256, 256, 32)         0         ['batch_normalization_51[0][0]
#  g2D)                                                               ']
#
#  up_sampling2d_2 (UpSamplin  (None, 256, 256, 32)         0         ['batch_normalization_52[0][0]
#  g2D)                                                               ']
#
#  add_22 (Add)                (None, 256, 256, 32)         0         ['activation_30[0][0]',
#                                                                      'up_sampling2d_1[0][0]',
#                                                                      'up_sampling2d_2[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 256, 256, 1)          32        ['add_22[0][0]']
#
#  batch_normalization_58 (Ba  (None, 256, 256, 1)          4         ['conv2d_58[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 256, 256, 1)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 2175460 (8.30 MB)
# Trainable params: 2168930 (8.27 MB)
# Non-trainable params: 6530 (25.51 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Train

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Setup early stopping to monitor the 'val_loss' and stop training after 10 epochs of no improvements
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True  # Restores model weights from the epoch with the best value of the monitored quantity
)

# Setup model checkpointing to save the best model observed during training for later use
model_checkpoint = ModelCheckpoint(
    '/gdrive/My Drive/Dataset/Models/best_hrnet1',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    epochs=50,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, model_checkpoint]
)

# Save the model
model.save('/gdrive/My Drive/Dataset/Models/hrnet1.h5')
# Out:
# Epoch 1/50
# 6/6 [==============================] - ETA: 0s - loss: 0.7581 - dice_coefficient: 0.1220 - jaccard_index: 0.0652 - sensitivity: 0.6565 - specificity: 0.6110 - precision: 0.0903
# Epoch 1: val_dice_coefficient improved from -inf to 0.13766, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet1
# 6/6 [==============================] - 293s 46s/step - loss: 0.7581 - dice_coefficient: 0.1220 - jaccard_index: 0.0652 - sensitivity: 0.6565 - specificity: 0.6110 - precision: 0.0903 - val_loss: 37.0618 - val_dice_coefficient: 0.1377 - val_jaccard_index: 0.0739 - val_sensitivity: 1.0000 - val_specificity: 5.7649e-06 - val_precision: 0.0736
# Epoch 2/50
# 6/6 [==============================] - ETA: 0s - loss: 0.7219 - dice_coefficient: 0.1269 - jaccard_index: 0.0678 - sensitivity: 0.6776 - specificity: 0.7134 - precision: 0.1163
# Epoch 2: val_dice_coefficient improved from 0.13766 to 0.13845, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet1
# 6/6 [==============================] - 269s 45s/step - loss: 0.7219 - dice_coefficient: 0.1269 - jaccard_index: 0.0678 - sensitivity: 0.6776 - specificity: 0.7134 - precision: 0.1163 - val_loss: 18.4524 - val_dice_coefficient: 0.1385 - val_jaccard_index: 0.0744 - val_sensitivity: 1.0000 - val_specificity: 2.1413e-05 - val_precision: 0.0736
# Epoch 3/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6947 - dice_coefficient: 0.1200 - jaccard_index: 0.0638 - sensitivity: 0.6427 - specificity: 0.7604 - precision: 0.1276
# Epoch 3: val_dice_coefficient improved from 0.13845 to 0.14913, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet1
# 6/6 [==============================] - 271s 45s/step - loss: 0.6947 - dice_coefficient: 0.1200 - jaccard_index: 0.0638 - sensitivity: 0.6427 - specificity: 0.7604 - precision: 0.1276 - val_loss: 4.2509 - val_dice_coefficient: 0.1491 - val_jaccard_index: 0.0806 - val_sensitivity: 0.9962 - val_specificity: 0.0081 - val_precision: 0.0739
# Epoch 4/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6814 - dice_coefficient: 0.1143 - jaccard_index: 0.0607 - sensitivity: 0.6312 - specificity: 0.7557 - precision: 0.1217
# Epoch 4: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 251s 41s/step - loss: 0.6814 - dice_coefficient: 0.1143 - jaccard_index: 0.0607 - sensitivity: 0.6312 - specificity: 0.7557 - precision: 0.1217 - val_loss: 1.1176 - val_dice_coefficient: 0.1419 - val_jaccard_index: 0.0764 - val_sensitivity: 0.8884 - val_specificity: 0.1167 - val_precision: 0.0740
# Epoch 5/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6719 - dice_coefficient: 0.1162 - jaccard_index: 0.0617 - sensitivity: 0.6798 - specificity: 0.7355 - precision: 0.1244
# Epoch 5: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 254s 42s/step - loss: 0.6719 - dice_coefficient: 0.1162 - jaccard_index: 0.0617 - sensitivity: 0.6798 - specificity: 0.7355 - precision: 0.1244 - val_loss: 0.7694 - val_dice_coefficient: 0.1326 - val_jaccard_index: 0.0710 - val_sensitivity: 0.6166 - val_specificity: 0.3425 - val_precision: 0.0694
# Epoch 6/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6697 - dice_coefficient: 0.1167 - jaccard_index: 0.0620 - sensitivity: 0.7149 - specificity: 0.7352 - precision: 0.1280
# Epoch 6: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 255s 42s/step - loss: 0.6697 - dice_coefficient: 0.1167 - jaccard_index: 0.0620 - sensitivity: 0.7149 - specificity: 0.7352 - precision: 0.1280 - val_loss: 0.6762 - val_dice_coefficient: 0.1324 - val_jaccard_index: 0.0709 - val_sensitivity: 0.4483 - val_specificity: 0.5983 - val_precision: 0.0814
# Epoch 7/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6665 - dice_coefficient: 0.1218 - jaccard_index: 0.0650 - sensitivity: 0.7648 - specificity: 0.7283 - precision: 0.1393
# Epoch 7: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 250s 41s/step - loss: 0.6665 - dice_coefficient: 0.1218 - jaccard_index: 0.0650 - sensitivity: 0.7648 - specificity: 0.7283 - precision: 0.1393 - val_loss: 0.6109 - val_dice_coefficient: 0.1283 - val_jaccard_index: 0.0686 - val_sensitivity: 0.1944 - val_specificity: 0.8092 - val_precision: 0.0749
# Epoch 8/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6646 - dice_coefficient: 0.1140 - jaccard_index: 0.0606 - sensitivity: 0.7910 - specificity: 0.7275 - precision: 0.1300
# Epoch 8: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 255s 42s/step - loss: 0.6646 - dice_coefficient: 0.1140 - jaccard_index: 0.0606 - sensitivity: 0.7910 - specificity: 0.7275 - precision: 0.1300 - val_loss: 0.5965 - val_dice_coefficient: 0.1293 - val_jaccard_index: 0.0691 - val_sensitivity: 0.1576 - val_specificity: 0.8631 - val_precision: 0.0838
# Epoch 9/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6610 - dice_coefficient: 0.1154 - jaccard_index: 0.0614 - sensitivity: 0.7906 - specificity: 0.7432 - precision: 0.1369
# Epoch 9: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 249s 41s/step - loss: 0.6610 - dice_coefficient: 0.1154 - jaccard_index: 0.0614 - sensitivity: 0.7906 - specificity: 0.7432 - precision: 0.1369 - val_loss: 0.5952 - val_dice_coefficient: 0.1306 - val_jaccard_index: 0.0699 - val_sensitivity: 0.1691 - val_specificity: 0.8746 - val_precision: 0.0968
# Epoch 10/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6590 - dice_coefficient: 0.1244 - jaccard_index: 0.0664 - sensitivity: 0.7848 - specificity: 0.7592 - precision: 0.1553
# Epoch 10: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 256s 42s/step - loss: 0.6590 - dice_coefficient: 0.1244 - jaccard_index: 0.0664 - sensitivity: 0.7848 - specificity: 0.7592 - precision: 0.1553 - val_loss: 0.5824 - val_dice_coefficient: 0.1309 - val_jaccard_index: 0.0700 - val_sensitivity: 0.1216 - val_specificity: 0.9363 - val_precision: 0.1316
# Epoch 11/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6577 - dice_coefficient: 0.1177 - jaccard_index: 0.0627 - sensitivity: 0.7976 - specificity: 0.7717 - precision: 0.1531
# Epoch 11: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 252s 41s/step - loss: 0.6577 - dice_coefficient: 0.1177 - jaccard_index: 0.0627 - sensitivity: 0.7976 - specificity: 0.7717 - precision: 0.1531 - val_loss: 0.5893 - val_dice_coefficient: 0.1312 - val_jaccard_index: 0.0702 - val_sensitivity: 0.1370 - val_specificity: 0.9334 - val_precision: 0.1406
# Epoch 12/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6587 - dice_coefficient: 0.1192 - jaccard_index: 0.0635 - sensitivity: 0.7876 - specificity: 0.7823 - precision: 0.1586
# Epoch 12: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 258s 42s/step - loss: 0.6587 - dice_coefficient: 0.1192 - jaccard_index: 0.0635 - sensitivity: 0.7876 - specificity: 0.7823 - precision: 0.1586 - val_loss: 0.5850 - val_dice_coefficient: 0.1300 - val_jaccard_index: 0.0695 - val_sensitivity: 0.0886 - val_specificity: 0.9597 - val_precision: 0.1488
# Epoch 13/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6563 - dice_coefficient: 0.1222 - jaccard_index: 0.0652 - sensitivity: 0.7910 - specificity: 0.7742 - precision: 0.1618
# Epoch 13: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 257s 42s/step - loss: 0.6563 - dice_coefficient: 0.1222 - jaccard_index: 0.0652 - sensitivity: 0.7910 - specificity: 0.7742 - precision: 0.1618 - val_loss: 0.5994 - val_dice_coefficient: 0.1302 - val_jaccard_index: 0.0696 - val_sensitivity: 0.1212 - val_specificity: 0.9450 - val_precision: 0.1489
# Epoch 14/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6547 - dice_coefficient: 0.1239 - jaccard_index: 0.0660 - sensitivity: 0.7837 - specificity: 0.7883 - precision: 0.1697
# Epoch 14: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 260s 43s/step - loss: 0.6547 - dice_coefficient: 0.1239 - jaccard_index: 0.0660 - sensitivity: 0.7837 - specificity: 0.7883 - precision: 0.1697 - val_loss: 0.5983 - val_dice_coefficient: 0.1312 - val_jaccard_index: 0.0702 - val_sensitivity: 0.1486 - val_specificity: 0.9429 - val_precision: 0.1714
# Epoch 15/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6536 - dice_coefficient: 0.1262 - jaccard_index: 0.0674 - sensitivity: 0.8037 - specificity: 0.7829 - precision: 0.1714
# Epoch 15: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 259s 42s/step - loss: 0.6536 - dice_coefficient: 0.1262 - jaccard_index: 0.0674 - sensitivity: 0.8037 - specificity: 0.7829 - precision: 0.1714 - val_loss: 0.5822 - val_dice_coefficient: 0.1294 - val_jaccard_index: 0.0692 - val_sensitivity: 0.0598 - val_specificity: 0.9853 - val_precision: 0.2440
# Epoch 16/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6529 - dice_coefficient: 0.1289 - jaccard_index: 0.0690 - sensitivity: 0.8261 - specificity: 0.7756 - precision: 0.1718
# Epoch 16: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 261s 43s/step - loss: 0.6529 - dice_coefficient: 0.1289 - jaccard_index: 0.0690 - sensitivity: 0.8261 - specificity: 0.7756 - precision: 0.1718 - val_loss: 0.5922 - val_dice_coefficient: 0.1300 - val_jaccard_index: 0.0695 - val_sensitivity: 0.0854 - val_specificity: 0.9758 - val_precision: 0.2192
# Epoch 17/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6516 - dice_coefficient: 0.1260 - jaccard_index: 0.0673 - sensitivity: 0.8239 - specificity: 0.7880 - precision: 0.1749
# Epoch 17: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 263s 43s/step - loss: 0.6516 - dice_coefficient: 0.1260 - jaccard_index: 0.0673 - sensitivity: 0.8239 - specificity: 0.7880 - precision: 0.1749 - val_loss: 0.5953 - val_dice_coefficient: 0.1295 - val_jaccard_index: 0.0692 - val_sensitivity: 0.0756 - val_specificity: 0.9815 - val_precision: 0.2449
# Epoch 18/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6508 - dice_coefficient: 0.1319 - jaccard_index: 0.0708 - sensitivity: 0.8098 - specificity: 0.7938 - precision: 0.1841
# Epoch 18: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 254s 42s/step - loss: 0.6508 - dice_coefficient: 0.1319 - jaccard_index: 0.0708 - sensitivity: 0.8098 - specificity: 0.7938 - precision: 0.1841 - val_loss: 0.5919 - val_dice_coefficient: 0.1284 - val_jaccard_index: 0.0686 - val_sensitivity: 0.0443 - val_specificity: 0.9923 - val_precision: 0.3133
# Epoch 19/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6497 - dice_coefficient: 0.1261 - jaccard_index: 0.0673 - sensitivity: 0.8343 - specificity: 0.7967 - precision: 0.1784
# Epoch 19: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 255s 42s/step - loss: 0.6497 - dice_coefficient: 0.1261 - jaccard_index: 0.0673 - sensitivity: 0.8343 - specificity: 0.7967 - precision: 0.1784 - val_loss: 0.5867 - val_dice_coefficient: 0.1277 - val_jaccard_index: 0.0682 - val_sensitivity: 0.0297 - val_specificity: 0.9961 - val_precision: 0.3759
# Epoch 20/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6489 - dice_coefficient: 0.1275 - jaccard_index: 0.0682 - sensitivity: 0.8267 - specificity: 0.8007 - precision: 0.1833
# Epoch 20: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 260s 43s/step - loss: 0.6489 - dice_coefficient: 0.1275 - jaccard_index: 0.0682 - sensitivity: 0.8267 - specificity: 0.8007 - precision: 0.1833 - val_loss: 0.5925 - val_dice_coefficient: 0.1284 - val_jaccard_index: 0.0686 - val_sensitivity: 0.0435 - val_specificity: 0.9935 - val_precision: 0.3463
# Epoch 21/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6512 - dice_coefficient: 0.1290 - jaccard_index: 0.0690 - sensitivity: 0.8048 - specificity: 0.8094 - precision: 0.1911
# Epoch 21: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 261s 43s/step - loss: 0.6512 - dice_coefficient: 0.1290 - jaccard_index: 0.0690 - sensitivity: 0.8048 - specificity: 0.8094 - precision: 0.1911 - val_loss: 0.5925 - val_dice_coefficient: 0.1290 - val_jaccard_index: 0.0690 - val_sensitivity: 0.0616 - val_specificity: 0.9909 - val_precision: 0.3495
# Epoch 22/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6485 - dice_coefficient: 0.1272 - jaccard_index: 0.0679 - sensitivity: 0.8129 - specificity: 0.7938 - precision: 0.1780
# Epoch 22: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 255s 42s/step - loss: 0.6485 - dice_coefficient: 0.1272 - jaccard_index: 0.0679 - sensitivity: 0.8129 - specificity: 0.7938 - precision: 0.1780 - val_loss: 0.5895 - val_dice_coefficient: 0.1282 - val_jaccard_index: 0.0685 - val_sensitivity: 0.0338 - val_specificity: 0.9956 - val_precision: 0.3787
# Epoch 23/50
# 6/6 [==============================] - ETA: 0s - loss: 0.6470 - dice_coefficient: 0.1282 - jaccard_index: 0.0685 - sensitivity: 0.8341 - specificity: 0.7910 - precision: 0.1789
# Epoch 23: val_dice_coefficient did not improve from 0.14913
# 6/6 [==============================] - 259s 43s/step - loss: 0.6470 - dice_coefficient: 0.1282 - jaccard_index: 0.0685 - sensitivity: 0.8341 - specificity: 0.7910 - precision: 0.1789 - val_loss: 0.6014 - val_dice_coefficient: 0.1280 - val_jaccard_index: 0.0684 - val_sensitivity: 0.0401 - val_specificity: 0.9931 - val_precision: 0.3171
# Epoch 24/50
# 1/6 [====>.........................] - ETA: 3:53 - loss: 0.6505 - dice_coefficient: 0.1315 - jaccard_index: 0.0704 - sensitivity: 0.8539 - specificity: 0.7943 - precision: 0.1886

# %% [markdown]
# Evaluate

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title('True Mask')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > 0.5, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title('Predicted Mask')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred):
    # Flattening the masks
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > 0.5).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    # Adding labels for each quadrant
    labels = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    # Position labels in the center of each quadrant
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix with Detailed Annotations')
    plt.show()


# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred)
plot_confusion_matrix(y_test, y_pred)
print(classification_report(y_test.flatten(), (y_pred.flatten() > 0.5).astype(int)))
# Out:
# 2/2 [==============================] - 16s 5s/step
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97   2970502
#          1.0       0.28      0.08      0.13    175226
#
#     accuracy                           0.94   3145728
#    macro avg       0.61      0.53      0.55   3145728
# weighted avg       0.91      0.94      0.92   3145728
