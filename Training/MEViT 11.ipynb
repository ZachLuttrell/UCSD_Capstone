# %% [markdown]
# # MEViT
#
# This is the 11th iteration of MEViT.
#
# In this iteration I have included the following changes:
#
# - scale factor of 3x
# - 5% of dataset
# - learning rate of .01
#
#
#
# **NOTE:** Connect to a High-RAM Environment

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# MODEL SETTINGS
model_name = 'mevit_model_11'
percentage_to_load = 5 / 100.0  # Set the % of dataset to be loaded here.
threshold = 0.5  # Set the threshold for metrics here
scale_factor = 3.0  # Factor by which to scale images and masks
initial_lr = 0.01  # Learning rate at the beginning of training
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load*100}%')
print(f'Threshold: {threshold}')
print(f'Scale Factor: {scale_factor}')
print(f'Initial Learning Rate: {initial_lr}')
# Out:
# Model Name: mevit_model_11
# Percentage to Load: 5.0%
# Threshold: 0.5
# Scale Factor: 3.0
# Initial Learning Rate: 0.01

# %% [markdown]
# Imports

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Mounted at /gdrive

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(tqdm(image_files[:number_of_files_to_load]), start=1):
    try:
        img_path = os.path.join(image_directory, image_name)
        mask_name = image_to_mask[image_name]
        mask_path = os.path.join(mask_directory, mask_name)

        if os.path.exists(mask_path):
            img = tiff.imread(img_path)
            mask = tiff.imread(mask_path)

            images.append(img)
            masks.append(mask)
        else:
            print(f'\nMask not found for image: {image_name}')
    except Exception as e:
        print(f'\nError loading image/mask pair {image_name}: {e}')

print("\nLoading complete.")

# Check if the number of images and masks loaded are equal
if len(images) != len(masks):
    raise ValueError("The number of loaded images and masks do not match!")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 5.0% of dataset: 239 images/mask pairs...
# 100%|██████████| 239/239 [06:04<00:00,  1.52s/it]
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Function to resize and normalize images and masks
def preprocess_images_and_masks(images, masks, scale_factor):
    # Squeeze unnecessary singleton dimensions
    if images.ndim > 3 and images.shape[1] == 1:
        images = images.squeeze(axis=1)
    if masks.ndim > 3 and masks.shape[1] == 1:
        masks = masks.squeeze(axis=1)

    print(f"Original image shape: {images.shape}")
    new_size = (int(images.shape[1] * scale_factor), int(images.shape[2] * scale_factor))
    print(f"New size: {new_size}")

    if new_size[0] <= 0 or new_size[1] <= 0:
        raise ValueError("Scale factor resulted in invalid size. Check the scale factor and original dimensions.")

    resized_images = []
    resized_masks = []
    print("Resizing images and masks...")
    for img, mask in tqdm(zip(images, masks), total=len(images)):

        try:
            resized_img = cv2.resize(img, new_size)
            resized_mask = cv2.resize(mask, new_size, interpolation=cv2.INTER_NEAREST)
            resized_images.append(resized_img)
            resized_masks.append(resized_mask)
        except Exception as e:
            print(f"Error resizing image/mask pair: {e}")
            raise

    resized_images = np.array(resized_images, dtype=np.float32)
    resized_masks = np.array(resized_masks, dtype=np.float32)

    # Normalize images and masks
    resized_images /= 255.0
    resized_masks /= 255.0
    resized_masks = resized_masks.reshape((-1, new_size[0], new_size[1], 1))

    return resized_images, resized_masks

# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Resize and normalize images and masks
images, masks = preprocess_images_and_masks(images, masks, scale_factor)

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Original image shape: (239, 256, 256, 3)
# New size: (768, 768)
# Resizing images and masks...
# 100%|██████████| 239/239 [00:00<00:00, 521.14it/s]
# Dataset Shapes:
# X_train: (171, 768, 768, 3), y_train: (171, 768, 768, 1)
# X_val:   (20, 768, 768, 3), y_val: (20, 768, 768, 1)
# X_test:  (48, 768, 768, 3), y_test: (48, 768, 768, 1)

# %% [markdown]
# Metrics & Loss

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# Custom Metrics
def dice_coefficient(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

def jaccard_index(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

def sensitivity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    possible_positives = tf.reduce_sum(y_true_f)
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_negatives = tf.reduce_sum((1-y_true_f) * (1-y_pred_f))
    possible_negatives = tf.reduce_sum(1-y_true_f)
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    predicted_positives = tf.reduce_sum(y_pred_f)
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# Loss Function
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)

# Visualize class weight distribution
plt.bar(class_weights.keys(), class_weights.values())
plt.title("Class Weight Distribution")
plt.xlabel("Class")
plt.ylabel("Weight")
plt.show()

weighted_loss = weighted_binary_crossentropy(class_weights)
# Out:
# Class weights: {0: 0.5274949720047702, 1: 9.592571542048715}

# %% [markdown]
# Model Definition

# %%
# Define the MEViT model
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = models.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim):
    inputs = layers.Input(shape=input_shape)
    # Flatten the input
    x = layers.Reshape((-1, input_shape[-1]))(inputs)

    # Create patches and embed
    patch_size = 16  # Adjust as necessary based on image size and memory constraints
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    patches = layers.Conv2D(filters=embed_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    patches = layers.Reshape((num_patches, embed_dim))(patches)

    # Add Transformer blocks
    for _ in range(8):
        patches = TransformerBlock(embed_dim, num_heads, ff_dim)(patches)

    # Reshape back to image
    x = layers.Reshape((input_shape[0] // patch_size, input_shape[1] // patch_size, embed_dim))(patches)
    x = Conv2DTranspose(num_classes, kernel_size=patch_size, strides=patch_size, padding="valid")(x)
    outputs = layers.Activation('sigmoid')(x)

    return Model(inputs, outputs)

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

input_shape = (int(256 * scale_factor), int(256 * scale_factor), 3)
num_classes = 1
embed_dim = 64  # Adjust as necessary
num_heads = 4   # Adjust as necessary
ff_dim = 128    # Adjust as necessary

model = create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim)
model._name = model_name
model.summary()

# Learning rate schedule
def lr_schedule(epoch, lr):
    if epoch >= 50 and epoch < 100:
        return lr * 0.99
    elif epoch >= 100 and epoch < 125:
        return lr * 0.9
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# Compile the model
sgd = SGD(learning_rate=initial_lr, momentum=0.9)
model.compile(
    optimizer=sgd,
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)
# Out:
# Model: "mevit_model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 768, 768, 3)]     0
#
#  conv2d (Conv2D)             (None, 48, 48, 64)        49216
#
#  reshape_1 (Reshape)         (None, 2304, 64)          0
#
#  transformer_block (Transfo  (None, 2304, 64)          83200
#  rmerBlock)
#
#  transformer_block_1 (Trans  (None, 2304, 64)          83200
#  formerBlock)
#
#  transformer_block_2 (Trans  (None, 2304, 64)          83200
#  formerBlock)
#
#  transformer_block_3 (Trans  (None, 2304, 64)          83200
#  formerBlock)
#
#  transformer_block_4 (Trans  (None, 2304, 64)          83200
#  formerBlock)
#
#  transformer_block_5 (Trans  (None, 2304, 64)          83200
#  formerBlock)
#
#  transformer_block_6 (Trans  (None, 2304, 64)          83200
#  formerBlock)
#
#  transformer_block_7 (Trans  (None, 2304, 64)          83200
#  formerBlock)
#
#  reshape_2 (Reshape)         (None, 48, 48, 64)        0
#
#  conv2d_transpose (Conv2DTr  (None, 768, 768, 1)       16385
#  anspose)
#
#  activation (Activation)     (None, 768, 768, 1)       0
#
# =================================================================
# Total params: 731201 (2.79 MB)
# Trainable params: 731201 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Setup callbacks
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=30,  # Reduced patience
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=16,  # Experiment with different values
    epochs=150,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping, lr_scheduler]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.5426 - dice_coefficient: 0.0933 - jaccard_index: 0.0490 - sensitivity: 0.4539 - specificity: 0.5479 - precision: 0.0523
# Epoch 1: val_dice_coefficient improved from -inf to 0.13256, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 294s 26s/step - loss: 0.6940 - accuracy: 0.5426 - dice_coefficient: 0.0933 - jaccard_index: 0.0490 - sensitivity: 0.4539 - specificity: 0.5479 - precision: 0.0523 - val_loss: 0.8299 - val_accuracy: 0.5381 - val_dice_coefficient: 0.1326 - val_jaccard_index: 0.0710 - val_sensitivity: 0.4641 - val_specificity: 0.5439 - val_precision: 0.0774 - lr: 0.0100
# Epoch 2/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5474 - dice_coefficient: 0.0949 - jaccard_index: 0.0499 - sensitivity: 0.4532 - specificity: 0.5530 - precision: 0.0533
# Epoch 2: val_dice_coefficient improved from 0.13256 to 0.13455, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 277s 25s/step - loss: 0.6937 - accuracy: 0.5474 - dice_coefficient: 0.0949 - jaccard_index: 0.0499 - sensitivity: 0.4532 - specificity: 0.5530 - precision: 0.0533 - val_loss: 0.8293 - val_accuracy: 0.5490 - val_dice_coefficient: 0.1345 - val_jaccard_index: 0.0721 - val_sensitivity: 0.4604 - val_specificity: 0.5566 - val_precision: 0.0788 - lr: 0.0100
# Epoch 3/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5252 - dice_coefficient: 0.0956 - jaccard_index: 0.0503 - sensitivity: 0.4845 - specificity: 0.5266 - precision: 0.0532
# Epoch 3: val_dice_coefficient improved from 0.13455 to 0.13900, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 279s 26s/step - loss: 0.6933 - accuracy: 0.5252 - dice_coefficient: 0.0956 - jaccard_index: 0.0503 - sensitivity: 0.4845 - specificity: 0.5266 - precision: 0.0532 - val_loss: 0.8273 - val_accuracy: 0.5012 - val_dice_coefficient: 0.1390 - val_jaccard_index: 0.0747 - val_sensitivity: 0.5286 - val_specificity: 0.4995 - val_precision: 0.0801 - lr: 0.0100
# Epoch 4/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4811 - dice_coefficient: 0.0974 - jaccard_index: 0.0513 - sensitivity: 0.5409 - specificity: 0.4775 - precision: 0.0537
# Epoch 4: val_dice_coefficient improved from 0.13900 to 0.14276, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 280s 26s/step - loss: 0.6930 - accuracy: 0.4811 - dice_coefficient: 0.0974 - jaccard_index: 0.0513 - sensitivity: 0.5409 - specificity: 0.4775 - precision: 0.0537 - val_loss: 0.8260 - val_accuracy: 0.4907 - val_dice_coefficient: 0.1428 - val_jaccard_index: 0.0769 - val_sensitivity: 0.5566 - val_specificity: 0.4859 - val_precision: 0.0819 - lr: 0.0100
# Epoch 5/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.4495 - dice_coefficient: 0.0991 - jaccard_index: 0.0523 - sensitivity: 0.5866 - specificity: 0.4424 - precision: 0.0544
# Epoch 5: val_dice_coefficient improved from 0.14276 to 0.14597, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 278s 25s/step - loss: 0.6925 - accuracy: 0.4495 - dice_coefficient: 0.0991 - jaccard_index: 0.0523 - sensitivity: 0.5866 - specificity: 0.4424 - precision: 0.0544 - val_loss: 0.8250 - val_accuracy: 0.5052 - val_dice_coefficient: 0.1460 - val_jaccard_index: 0.0787 - val_sensitivity: 0.5540 - val_specificity: 0.5027 - val_precision: 0.0841 - lr: 0.0100
# Epoch 6/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5180 - dice_coefficient: 0.1005 - jaccard_index: 0.0530 - sensitivity: 0.5227 - specificity: 0.5157 - precision: 0.0558
# Epoch 6: val_dice_coefficient improved from 0.14597 to 0.15089, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 271s 25s/step - loss: 0.6920 - accuracy: 0.5180 - dice_coefficient: 0.1005 - jaccard_index: 0.0530 - sensitivity: 0.5227 - specificity: 0.5157 - precision: 0.0558 - val_loss: 0.8227 - val_accuracy: 0.4730 - val_dice_coefficient: 0.1509 - val_jaccard_index: 0.0816 - val_sensitivity: 0.6150 - val_specificity: 0.4615 - val_precision: 0.0860 - lr: 0.0100
# Epoch 7/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.5023 - dice_coefficient: 0.1047 - jaccard_index: 0.0553 - sensitivity: 0.5539 - specificity: 0.5018 - precision: 0.0581
# Epoch 7: val_dice_coefficient improved from 0.15089 to 0.15982, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 275s 25s/step - loss: 0.6911 - accuracy: 0.5023 - dice_coefficient: 0.1047 - jaccard_index: 0.0553 - sensitivity: 0.5539 - specificity: 0.5018 - precision: 0.0581 - val_loss: 0.8237 - val_accuracy: 0.6025 - val_dice_coefficient: 0.1598 - val_jaccard_index: 0.0869 - val_sensitivity: 0.4930 - val_specificity: 0.6146 - val_precision: 0.0954 - lr: 0.0100
# Epoch 8/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6898 - accuracy: 0.5389 - dice_coefficient: 0.1089 - jaccard_index: 0.0577 - sensitivity: 0.5424 - specificity: 0.5373 - precision: 0.0608
# Epoch 8: val_dice_coefficient improved from 0.15982 to 0.16733, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 279s 26s/step - loss: 0.6898 - accuracy: 0.5389 - dice_coefficient: 0.1089 - jaccard_index: 0.0577 - sensitivity: 0.5424 - specificity: 0.5373 - precision: 0.0608 - val_loss: 0.8185 - val_accuracy: 0.5134 - val_dice_coefficient: 0.1673 - val_jaccard_index: 0.0913 - val_sensitivity: 0.6398 - val_specificity: 0.5050 - val_precision: 0.0963 - lr: 0.0100
# Epoch 9/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6887 - accuracy: 0.5302 - dice_coefficient: 0.1121 - jaccard_index: 0.0595 - sensitivity: 0.5663 - specificity: 0.5313 - precision: 0.0626
# Epoch 9: val_dice_coefficient improved from 0.16733 to 0.17854, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 280s 26s/step - loss: 0.6887 - accuracy: 0.5302 - dice_coefficient: 0.1121 - jaccard_index: 0.0595 - sensitivity: 0.5663 - specificity: 0.5313 - precision: 0.0626 - val_loss: 0.8228 - val_accuracy: 0.6891 - val_dice_coefficient: 0.1785 - val_jaccard_index: 0.0981 - val_sensitivity: 0.4355 - val_specificity: 0.7157 - val_precision: 0.1124 - lr: 0.0100
# Epoch 10/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6883 - accuracy: 0.4744 - dice_coefficient: 0.1156 - jaccard_index: 0.0616 - sensitivity: 0.6474 - specificity: 0.4708 - precision: 0.0643
# Epoch 10: val_dice_coefficient improved from 0.17854 to 0.18433, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 279s 26s/step - loss: 0.6883 - accuracy: 0.4744 - dice_coefficient: 0.1156 - jaccard_index: 0.0616 - sensitivity: 0.6474 - specificity: 0.4708 - precision: 0.0643 - val_loss: 0.8237 - val_accuracy: 0.7352 - val_dice_coefficient: 0.1843 - val_jaccard_index: 0.1016 - val_sensitivity: 0.3846 - val_specificity: 0.7698 - val_precision: 0.1215 - lr: 0.0100
# Epoch 11/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6866 - accuracy: 0.5456 - dice_coefficient: 0.1219 - jaccard_index: 0.0651 - sensitivity: 0.5949 - specificity: 0.5472 - precision: 0.0689
# Epoch 11: val_dice_coefficient improved from 0.18433 to 0.20516, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 277s 25s/step - loss: 0.6866 - accuracy: 0.5456 - dice_coefficient: 0.1219 - jaccard_index: 0.0651 - sensitivity: 0.5949 - specificity: 0.5472 - precision: 0.0689 - val_loss: 0.8212 - val_accuracy: 0.7546 - val_dice_coefficient: 0.2052 - val_jaccard_index: 0.1144 - val_sensitivity: 0.4036 - val_specificity: 0.7905 - val_precision: 0.1379 - lr: 0.0100
# Epoch 12/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6844 - accuracy: 0.6257 - dice_coefficient: 0.1340 - jaccard_index: 0.0722 - sensitivity: 0.5369 - specificity: 0.6345 - precision: 0.0782
# Epoch 12: val_dice_coefficient improved from 0.20516 to 0.22475, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 285s 26s/step - loss: 0.6844 - accuracy: 0.6257 - dice_coefficient: 0.1340 - jaccard_index: 0.0722 - sensitivity: 0.5369 - specificity: 0.6345 - precision: 0.0782 - val_loss: 0.8100 - val_accuracy: 0.6649 - val_dice_coefficient: 0.2248 - val_jaccard_index: 0.1268 - val_sensitivity: 0.6150 - val_specificity: 0.6805 - val_precision: 0.1377 - lr: 0.0100
# Epoch 13/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6818 - accuracy: 0.5996 - dice_coefficient: 0.1377 - jaccard_index: 0.0743 - sensitivity: 0.5919 - specificity: 0.6050 - precision: 0.0793
# Epoch 13: val_dice_coefficient improved from 0.22475 to 0.24437, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 279s 25s/step - loss: 0.6818 - accuracy: 0.5996 - dice_coefficient: 0.1377 - jaccard_index: 0.0743 - sensitivity: 0.5919 - specificity: 0.6050 - precision: 0.0793 - val_loss: 0.8131 - val_accuracy: 0.7604 - val_dice_coefficient: 0.2444 - val_jaccard_index: 0.1396 - val_sensitivity: 0.4827 - val_specificity: 0.7946 - val_precision: 0.1642 - lr: 0.0100
# Epoch 14/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.6025 - dice_coefficient: 0.1459 - jaccard_index: 0.0791 - sensitivity: 0.6061 - specificity: 0.6081 - precision: 0.0854
# Epoch 14: val_dice_coefficient did not improve from 0.24437
# 11/11 [==============================] - 268s 24s/step - loss: 0.6813 - accuracy: 0.6025 - dice_coefficient: 0.1459 - jaccard_index: 0.0791 - sensitivity: 0.6061 - specificity: 0.6081 - precision: 0.0854 - val_loss: 0.8038 - val_accuracy: 0.6608 - val_dice_coefficient: 0.2378 - val_jaccard_index: 0.1352 - val_sensitivity: 0.6680 - val_specificity: 0.6726 - val_precision: 0.1449 - lr: 0.0100
# Epoch 15/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6803 - accuracy: 0.6643 - dice_coefficient: 0.1579 - jaccard_index: 0.0864 - sensitivity: 0.5465 - specificity: 0.6763 - precision: 0.1019
# Epoch 15: val_dice_coefficient did not improve from 0.24437
# 11/11 [==============================] - 271s 25s/step - loss: 0.6803 - accuracy: 0.6643 - dice_coefficient: 0.1579 - jaccard_index: 0.0864 - sensitivity: 0.5465 - specificity: 0.6763 - precision: 0.1019 - val_loss: 0.8034 - val_accuracy: 0.6848 - val_dice_coefficient: 0.2442 - val_jaccard_index: 0.1394 - val_sensitivity: 0.6411 - val_specificity: 0.7005 - val_precision: 0.1511 - lr: 0.0100
# Epoch 16/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6772 - accuracy: 0.5052 - dice_coefficient: 0.1400 - jaccard_index: 0.0759 - sensitivity: 0.7300 - specificity: 0.4992 - precision: 0.0793
# Epoch 16: val_dice_coefficient improved from 0.24437 to 0.26254, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 279s 25s/step - loss: 0.6772 - accuracy: 0.5052 - dice_coefficient: 0.1400 - jaccard_index: 0.0759 - sensitivity: 0.7300 - specificity: 0.4992 - precision: 0.0793 - val_loss: 0.8133 - val_accuracy: 0.8113 - val_dice_coefficient: 0.2625 - val_jaccard_index: 0.1517 - val_sensitivity: 0.4091 - val_specificity: 0.8568 - val_precision: 0.1948 - lr: 0.0100
# Epoch 17/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6722 - accuracy: 0.6642 - dice_coefficient: 0.1630 - jaccard_index: 0.0889 - sensitivity: 0.6274 - specificity: 0.6687 - precision: 0.0950
# Epoch 17: val_dice_coefficient improved from 0.26254 to 0.26736, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 281s 26s/step - loss: 0.6722 - accuracy: 0.6642 - dice_coefficient: 0.1630 - jaccard_index: 0.0889 - sensitivity: 0.6274 - specificity: 0.6687 - precision: 0.0950 - val_loss: 0.8080 - val_accuracy: 0.7944 - val_dice_coefficient: 0.2674 - val_jaccard_index: 0.1550 - val_sensitivity: 0.4587 - val_specificity: 0.8347 - val_precision: 0.1897 - lr: 0.0100
# Epoch 18/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6731 - accuracy: 0.6090 - dice_coefficient: 0.1615 - jaccard_index: 0.0891 - sensitivity: 0.6579 - specificity: 0.6040 - precision: 0.0979
# Epoch 18: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 269s 25s/step - loss: 0.6731 - accuracy: 0.6090 - dice_coefficient: 0.1615 - jaccard_index: 0.0891 - sensitivity: 0.6579 - specificity: 0.6040 - precision: 0.0979 - val_loss: 0.7972 - val_accuracy: 0.6500 - val_dice_coefficient: 0.2297 - val_jaccard_index: 0.1301 - val_sensitivity: 0.6676 - val_specificity: 0.6566 - val_precision: 0.1388 - lr: 0.0100
# Epoch 19/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6702 - accuracy: 0.7619 - dice_coefficient: 0.1958 - jaccard_index: 0.1092 - sensitivity: 0.5341 - specificity: 0.7695 - precision: 0.1287
# Epoch 19: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 271s 25s/step - loss: 0.6702 - accuracy: 0.7619 - dice_coefficient: 0.1958 - jaccard_index: 0.1092 - sensitivity: 0.5341 - specificity: 0.7695 - precision: 0.1287 - val_loss: 0.7878 - val_accuracy: 0.5591 - val_dice_coefficient: 0.2196 - val_jaccard_index: 0.1235 - val_sensitivity: 0.8039 - val_specificity: 0.5442 - val_precision: 0.1272 - lr: 0.0100
# Epoch 20/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6653 - accuracy: 0.5792 - dice_coefficient: 0.1619 - jaccard_index: 0.0889 - sensitivity: 0.7243 - specificity: 0.5790 - precision: 0.0941
# Epoch 20: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 273s 25s/step - loss: 0.6653 - accuracy: 0.5792 - dice_coefficient: 0.1619 - jaccard_index: 0.0889 - sensitivity: 0.7243 - specificity: 0.5790 - precision: 0.0941 - val_loss: 0.8078 - val_accuracy: 0.8040 - val_dice_coefficient: 0.2630 - val_jaccard_index: 0.1520 - val_sensitivity: 0.4251 - val_specificity: 0.8483 - val_precision: 0.1919 - lr: 0.0100
# Epoch 21/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6598 - accuracy: 0.7411 - dice_coefficient: 0.1984 - jaccard_index: 0.1107 - sensitivity: 0.5991 - specificity: 0.7495 - precision: 0.1207
# Epoch 21: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 274s 25s/step - loss: 0.6598 - accuracy: 0.7411 - dice_coefficient: 0.1984 - jaccard_index: 0.1107 - sensitivity: 0.5991 - specificity: 0.7495 - precision: 0.1207 - val_loss: 0.7889 - val_accuracy: 0.6751 - val_dice_coefficient: 0.2374 - val_jaccard_index: 0.1352 - val_sensitivity: 0.6506 - val_specificity: 0.6831 - val_precision: 0.1453 - lr: 0.0100
# Epoch 22/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6528 - accuracy: 0.7212 - dice_coefficient: 0.1956 - jaccard_index: 0.1088 - sensitivity: 0.6596 - specificity: 0.7254 - precision: 0.1161
# Epoch 22: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 275s 25s/step - loss: 0.6528 - accuracy: 0.7212 - dice_coefficient: 0.1956 - jaccard_index: 0.1088 - sensitivity: 0.6596 - specificity: 0.7254 - precision: 0.1161 - val_loss: 0.7880 - val_accuracy: 0.6876 - val_dice_coefficient: 0.2399 - val_jaccard_index: 0.1368 - val_sensitivity: 0.6332 - val_specificity: 0.6982 - val_precision: 0.1480 - lr: 0.0100
# Epoch 23/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.7246 - dice_coefficient: 0.1980 - jaccard_index: 0.1104 - sensitivity: 0.6559 - specificity: 0.7244 - precision: 0.1174
# Epoch 23: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 270s 25s/step - loss: 0.6475 - accuracy: 0.7246 - dice_coefficient: 0.1980 - jaccard_index: 0.1104 - sensitivity: 0.6559 - specificity: 0.7244 - precision: 0.1174 - val_loss: 0.7772 - val_accuracy: 0.6057 - val_dice_coefficient: 0.2258 - val_jaccard_index: 0.1276 - val_sensitivity: 0.7462 - val_specificity: 0.5981 - val_precision: 0.1330 - lr: 0.0100
# Epoch 24/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6442 - accuracy: 0.6994 - dice_coefficient: 0.1940 - jaccard_index: 0.1079 - sensitivity: 0.6874 - specificity: 0.7004 - precision: 0.1145
# Epoch 24: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 267s 24s/step - loss: 0.6442 - accuracy: 0.6994 - dice_coefficient: 0.1940 - jaccard_index: 0.1079 - sensitivity: 0.6874 - specificity: 0.7004 - precision: 0.1145 - val_loss: 0.7833 - val_accuracy: 0.6815 - val_dice_coefficient: 0.2409 - val_jaccard_index: 0.1375 - val_sensitivity: 0.6468 - val_specificity: 0.6916 - val_precision: 0.1481 - lr: 0.0100
# Epoch 25/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6384 - accuracy: 0.7371 - dice_coefficient: 0.2046 - jaccard_index: 0.1143 - sensitivity: 0.6601 - specificity: 0.7394 - precision: 0.1221
# Epoch 25: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 267s 24s/step - loss: 0.6384 - accuracy: 0.7371 - dice_coefficient: 0.2046 - jaccard_index: 0.1143 - sensitivity: 0.6601 - specificity: 0.7394 - precision: 0.1221 - val_loss: 0.7755 - val_accuracy: 0.6472 - val_dice_coefficient: 0.2363 - val_jaccard_index: 0.1346 - val_sensitivity: 0.7014 - val_specificity: 0.6495 - val_precision: 0.1421 - lr: 0.0100
# Epoch 26/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6348 - accuracy: 0.7479 - dice_coefficient: 0.2137 - jaccard_index: 0.1198 - sensitivity: 0.6396 - specificity: 0.7538 - precision: 0.1320
# Epoch 26: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 263s 24s/step - loss: 0.6348 - accuracy: 0.7479 - dice_coefficient: 0.2137 - jaccard_index: 0.1198 - sensitivity: 0.6396 - specificity: 0.7538 - precision: 0.1320 - val_loss: 0.7688 - val_accuracy: 0.6509 - val_dice_coefficient: 0.2413 - val_jaccard_index: 0.1378 - val_sensitivity: 0.7119 - val_specificity: 0.6533 - val_precision: 0.1454 - lr: 0.0100
# Epoch 27/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6308 - accuracy: 0.7092 - dice_coefficient: 0.1971 - jaccard_index: 0.1101 - sensitivity: 0.6974 - specificity: 0.7106 - precision: 0.1165
# Epoch 27: val_dice_coefficient did not improve from 0.26736
# 11/11 [==============================] - 264s 24s/step - loss: 0.6308 - accuracy: 0.7092 - dice_coefficient: 0.1971 - jaccard_index: 0.1101 - sensitivity: 0.6974 - specificity: 0.7106 - precision: 0.1165 - val_loss: 0.7767 - val_accuracy: 0.6361 - val_dice_coefficient: 0.2273 - val_jaccard_index: 0.1288 - val_sensitivity: 0.6799 - val_specificity: 0.6430 - val_precision: 0.1366 - lr: 0.0100
# Epoch 28/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.7231 - dice_coefficient: 0.2017 - jaccard_index: 0.1132 - sensitivity: 0.6343 - specificity: 0.7312 - precision: 0.1239
# Epoch 28: val_dice_coefficient improved from 0.26736 to 0.28077, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 278s 25s/step - loss: 0.6354 - accuracy: 0.7231 - dice_coefficient: 0.2017 - jaccard_index: 0.1132 - sensitivity: 0.6343 - specificity: 0.7312 - precision: 0.1239 - val_loss: 0.7940 - val_accuracy: 0.8049 - val_dice_coefficient: 0.2808 - val_jaccard_index: 0.1641 - val_sensitivity: 0.4665 - val_specificity: 0.8446 - val_precision: 0.2018 - lr: 0.0100
# Epoch 29/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6311 - accuracy: 0.6899 - dice_coefficient: 0.2001 - jaccard_index: 0.1121 - sensitivity: 0.6882 - specificity: 0.6925 - precision: 0.1201
# Epoch 29: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 268s 24s/step - loss: 0.6311 - accuracy: 0.6899 - dice_coefficient: 0.2001 - jaccard_index: 0.1121 - sensitivity: 0.6882 - specificity: 0.6925 - precision: 0.1201 - val_loss: 0.7926 - val_accuracy: 0.7658 - val_dice_coefficient: 0.2538 - val_jaccard_index: 0.1458 - val_sensitivity: 0.4835 - val_specificity: 0.8053 - val_precision: 0.1733 - lr: 0.0100
# Epoch 30/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.7322 - dice_coefficient: 0.2046 - jaccard_index: 0.1146 - sensitivity: 0.6692 - specificity: 0.7361 - precision: 0.1236
# Epoch 30: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 265s 24s/step - loss: 0.6260 - accuracy: 0.7322 - dice_coefficient: 0.2046 - jaccard_index: 0.1146 - sensitivity: 0.6692 - specificity: 0.7361 - precision: 0.1236 - val_loss: 0.7794 - val_accuracy: 0.7122 - val_dice_coefficient: 0.2465 - val_jaccard_index: 0.1412 - val_sensitivity: 0.5958 - val_specificity: 0.7311 - val_precision: 0.1555 - lr: 0.0100
# Epoch 31/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6183 - accuracy: 0.7099 - dice_coefficient: 0.2008 - jaccard_index: 0.1119 - sensitivity: 0.6930 - specificity: 0.7115 - precision: 0.1182
# Epoch 31: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 263s 24s/step - loss: 0.6183 - accuracy: 0.7099 - dice_coefficient: 0.2008 - jaccard_index: 0.1119 - sensitivity: 0.6930 - specificity: 0.7115 - precision: 0.1182 - val_loss: 0.7824 - val_accuracy: 0.7058 - val_dice_coefficient: 0.2432 - val_jaccard_index: 0.1390 - val_sensitivity: 0.5878 - val_specificity: 0.7294 - val_precision: 0.1537 - lr: 0.0100
# Epoch 32/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.7213 - dice_coefficient: 0.2037 - jaccard_index: 0.1139 - sensitivity: 0.6909 - specificity: 0.7202 - precision: 0.1209
# Epoch 32: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 265s 24s/step - loss: 0.6152 - accuracy: 0.7213 - dice_coefficient: 0.2037 - jaccard_index: 0.1139 - sensitivity: 0.6909 - specificity: 0.7202 - precision: 0.1209 - val_loss: 0.7607 - val_accuracy: 0.6400 - val_dice_coefficient: 0.2377 - val_jaccard_index: 0.1355 - val_sensitivity: 0.7194 - val_specificity: 0.6412 - val_precision: 0.1424 - lr: 0.0100
# Epoch 33/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.6992 - dice_coefficient: 0.2058 - jaccard_index: 0.1152 - sensitivity: 0.7298 - specificity: 0.7001 - precision: 0.1214
# Epoch 33: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 263s 24s/step - loss: 0.6109 - accuracy: 0.6992 - dice_coefficient: 0.2058 - jaccard_index: 0.1152 - sensitivity: 0.7298 - specificity: 0.7001 - precision: 0.1214 - val_loss: 0.7877 - val_accuracy: 0.7652 - val_dice_coefficient: 0.2617 - val_jaccard_index: 0.1511 - val_sensitivity: 0.5081 - val_specificity: 0.8013 - val_precision: 0.1772 - lr: 0.0100
# Epoch 34/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.7187 - dice_coefficient: 0.2136 - jaccard_index: 0.1203 - sensitivity: 0.6696 - specificity: 0.7193 - precision: 0.1321
# Epoch 34: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 262s 24s/step - loss: 0.6169 - accuracy: 0.7187 - dice_coefficient: 0.2136 - jaccard_index: 0.1203 - sensitivity: 0.6696 - specificity: 0.7193 - precision: 0.1321 - val_loss: 0.7553 - val_accuracy: 0.6658 - val_dice_coefficient: 0.2450 - val_jaccard_index: 0.1402 - val_sensitivity: 0.6986 - val_specificity: 0.6688 - val_precision: 0.1486 - lr: 0.0100
# Epoch 35/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6112 - accuracy: 0.7184 - dice_coefficient: 0.2017 - jaccard_index: 0.1129 - sensitivity: 0.6961 - specificity: 0.7214 - precision: 0.1201
# Epoch 35: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 261s 24s/step - loss: 0.6112 - accuracy: 0.7184 - dice_coefficient: 0.2017 - jaccard_index: 0.1129 - sensitivity: 0.6961 - specificity: 0.7214 - precision: 0.1201 - val_loss: 0.7713 - val_accuracy: 0.7441 - val_dice_coefficient: 0.2657 - val_jaccard_index: 0.1539 - val_sensitivity: 0.5851 - val_specificity: 0.7659 - val_precision: 0.1720 - lr: 0.0100
# Epoch 36/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6101 - accuracy: 0.7403 - dice_coefficient: 0.2128 - jaccard_index: 0.1194 - sensitivity: 0.6486 - specificity: 0.7399 - precision: 0.1305
# Epoch 36: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 265s 24s/step - loss: 0.6101 - accuracy: 0.7403 - dice_coefficient: 0.2128 - jaccard_index: 0.1194 - sensitivity: 0.6486 - specificity: 0.7399 - precision: 0.1305 - val_loss: 0.7566 - val_accuracy: 0.6349 - val_dice_coefficient: 0.2352 - val_jaccard_index: 0.1339 - val_sensitivity: 0.7222 - val_specificity: 0.6344 - val_precision: 0.1405 - lr: 0.0100
# Epoch 37/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.7231 - dice_coefficient: 0.2084 - jaccard_index: 0.1168 - sensitivity: 0.7114 - specificity: 0.7233 - precision: 0.1241
# Epoch 37: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 272s 25s/step - loss: 0.6020 - accuracy: 0.7231 - dice_coefficient: 0.2084 - jaccard_index: 0.1168 - sensitivity: 0.7114 - specificity: 0.7233 - precision: 0.1241 - val_loss: 0.7594 - val_accuracy: 0.6819 - val_dice_coefficient: 0.2505 - val_jaccard_index: 0.1439 - val_sensitivity: 0.6790 - val_specificity: 0.6900 - val_precision: 0.1536 - lr: 0.0100
# Epoch 38/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6131 - accuracy: 0.7101 - dice_coefficient: 0.2028 - jaccard_index: 0.1136 - sensitivity: 0.6754 - specificity: 0.7154 - precision: 0.1242
# Epoch 38: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 268s 24s/step - loss: 0.6131 - accuracy: 0.7101 - dice_coefficient: 0.2028 - jaccard_index: 0.1136 - sensitivity: 0.6754 - specificity: 0.7154 - precision: 0.1242 - val_loss: 0.7903 - val_accuracy: 0.7780 - val_dice_coefficient: 0.2611 - val_jaccard_index: 0.1506 - val_sensitivity: 0.4809 - val_specificity: 0.8162 - val_precision: 0.1803 - lr: 0.0100
# Epoch 39/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6194 - accuracy: 0.7512 - dice_coefficient: 0.2113 - jaccard_index: 0.1188 - sensitivity: 0.6147 - specificity: 0.7558 - precision: 0.1350
# Epoch 39: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 271s 25s/step - loss: 0.6194 - accuracy: 0.7512 - dice_coefficient: 0.2113 - jaccard_index: 0.1188 - sensitivity: 0.6147 - specificity: 0.7558 - precision: 0.1350 - val_loss: 0.7528 - val_accuracy: 0.6456 - val_dice_coefficient: 0.2385 - val_jaccard_index: 0.1361 - val_sensitivity: 0.7131 - val_specificity: 0.6470 - val_precision: 0.1433 - lr: 0.0100
# Epoch 40/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.7423 - dice_coefficient: 0.2133 - jaccard_index: 0.1196 - sensitivity: 0.6778 - specificity: 0.7465 - precision: 0.1272
# Epoch 40: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 268s 24s/step - loss: 0.5975 - accuracy: 0.7423 - dice_coefficient: 0.2133 - jaccard_index: 0.1196 - sensitivity: 0.6778 - specificity: 0.7465 - precision: 0.1272 - val_loss: 0.7681 - val_accuracy: 0.6986 - val_dice_coefficient: 0.2517 - val_jaccard_index: 0.1447 - val_sensitivity: 0.6433 - val_specificity: 0.7123 - val_precision: 0.1566 - lr: 0.0100
# Epoch 41/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5916 - accuracy: 0.7397 - dice_coefficient: 0.2213 - jaccard_index: 0.1246 - sensitivity: 0.7080 - specificity: 0.7395 - precision: 0.1333
# Epoch 41: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 264s 24s/step - loss: 0.5916 - accuracy: 0.7397 - dice_coefficient: 0.2213 - jaccard_index: 0.1246 - sensitivity: 0.7080 - specificity: 0.7395 - precision: 0.1333 - val_loss: 0.7372 - val_accuracy: 0.6690 - val_dice_coefficient: 0.2547 - val_jaccard_index: 0.1465 - val_sensitivity: 0.7250 - val_specificity: 0.6716 - val_precision: 0.1545 - lr: 0.0100
# Epoch 42/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5842 - accuracy: 0.7256 - dice_coefficient: 0.2198 - jaccard_index: 0.1237 - sensitivity: 0.7350 - specificity: 0.7247 - precision: 0.1300
# Epoch 42: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 265s 24s/step - loss: 0.5842 - accuracy: 0.7256 - dice_coefficient: 0.2198 - jaccard_index: 0.1237 - sensitivity: 0.7350 - specificity: 0.7247 - precision: 0.1300 - val_loss: 0.7593 - val_accuracy: 0.7417 - val_dice_coefficient: 0.2757 - val_jaccard_index: 0.1608 - val_sensitivity: 0.6195 - val_specificity: 0.7613 - val_precision: 0.1775 - lr: 0.0100
# Epoch 43/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.7481 - dice_coefficient: 0.2306 - jaccard_index: 0.1308 - sensitivity: 0.7320 - specificity: 0.7503 - precision: 0.1384
# Epoch 43: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 262s 24s/step - loss: 0.5793 - accuracy: 0.7481 - dice_coefficient: 0.2306 - jaccard_index: 0.1308 - sensitivity: 0.7320 - specificity: 0.7503 - precision: 0.1384 - val_loss: 0.7463 - val_accuracy: 0.7142 - val_dice_coefficient: 0.2712 - val_jaccard_index: 0.1576 - val_sensitivity: 0.6826 - val_specificity: 0.7229 - val_precision: 0.1693 - lr: 0.0100
# Epoch 44/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.7197 - dice_coefficient: 0.2201 - jaccard_index: 0.1246 - sensitivity: 0.7538 - specificity: 0.7131 - precision: 0.1312
# Epoch 44: val_dice_coefficient did not improve from 0.28077
# 11/11 [==============================] - 263s 24s/step - loss: 0.5793 - accuracy: 0.7197 - dice_coefficient: 0.2201 - jaccard_index: 0.1246 - sensitivity: 0.7538 - specificity: 0.7131 - precision: 0.1312 - val_loss: 0.7387 - val_accuracy: 0.6791 - val_dice_coefficient: 0.2584 - val_jaccard_index: 0.1491 - val_sensitivity: 0.7174 - val_specificity: 0.6827 - val_precision: 0.1576 - lr: 0.0100
# Epoch 45/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5730 - accuracy: 0.7386 - dice_coefficient: 0.2292 - jaccard_index: 0.1302 - sensitivity: 0.7268 - specificity: 0.7394 - precision: 0.1377
# Epoch 45: val_dice_coefficient improved from 0.28077 to 0.28498, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 276s 25s/step - loss: 0.5730 - accuracy: 0.7386 - dice_coefficient: 0.2292 - jaccard_index: 0.1302 - sensitivity: 0.7268 - specificity: 0.7394 - precision: 0.1377 - val_loss: 0.7546 - val_accuracy: 0.7447 - val_dice_coefficient: 0.2850 - val_jaccard_index: 0.1671 - val_sensitivity: 0.6464 - val_specificity: 0.7606 - val_precision: 0.1829 - lr: 0.0100
# Epoch 46/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5677 - accuracy: 0.7555 - dice_coefficient: 0.2376 - jaccard_index: 0.1353 - sensitivity: 0.7437 - specificity: 0.7562 - precision: 0.1430
# Epoch 46: val_dice_coefficient did not improve from 0.28498
# 11/11 [==============================] - 262s 24s/step - loss: 0.5677 - accuracy: 0.7555 - dice_coefficient: 0.2376 - jaccard_index: 0.1353 - sensitivity: 0.7437 - specificity: 0.7562 - precision: 0.1430 - val_loss: 0.7517 - val_accuracy: 0.7107 - val_dice_coefficient: 0.2720 - val_jaccard_index: 0.1584 - val_sensitivity: 0.6747 - val_specificity: 0.7265 - val_precision: 0.1706 - lr: 0.0100
# Epoch 47/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5947 - accuracy: 0.7262 - dice_coefficient: 0.2157 - jaccard_index: 0.1219 - sensitivity: 0.6637 - specificity: 0.7338 - precision: 0.1369
# Epoch 47: val_dice_coefficient improved from 0.28498 to 0.30556, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 267s 24s/step - loss: 0.5947 - accuracy: 0.7262 - dice_coefficient: 0.2157 - jaccard_index: 0.1219 - sensitivity: 0.6637 - specificity: 0.7338 - precision: 0.1369 - val_loss: 0.7857 - val_accuracy: 0.8196 - val_dice_coefficient: 0.3056 - val_jaccard_index: 0.1813 - val_sensitivity: 0.5019 - val_specificity: 0.8521 - val_precision: 0.2199 - lr: 0.0100
# Epoch 48/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.7217 - dice_coefficient: 0.2116 - jaccard_index: 0.1189 - sensitivity: 0.7334 - specificity: 0.7246 - precision: 0.1271
# Epoch 48: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 260s 24s/step - loss: 0.5848 - accuracy: 0.7217 - dice_coefficient: 0.2116 - jaccard_index: 0.1189 - sensitivity: 0.7334 - specificity: 0.7246 - precision: 0.1271 - val_loss: 0.7801 - val_accuracy: 0.7425 - val_dice_coefficient: 0.2600 - val_jaccard_index: 0.1500 - val_sensitivity: 0.5478 - val_specificity: 0.7765 - val_precision: 0.1713 - lr: 0.0100
# Epoch 49/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5726 - accuracy: 0.7300 - dice_coefficient: 0.2200 - jaccard_index: 0.1237 - sensitivity: 0.7365 - specificity: 0.7304 - precision: 0.1301
# Epoch 49: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 262s 24s/step - loss: 0.5726 - accuracy: 0.7300 - dice_coefficient: 0.2200 - jaccard_index: 0.1237 - sensitivity: 0.7365 - specificity: 0.7304 - precision: 0.1301 - val_loss: 0.7550 - val_accuracy: 0.7384 - val_dice_coefficient: 0.2785 - val_jaccard_index: 0.1626 - val_sensitivity: 0.6429 - val_specificity: 0.7537 - val_precision: 0.1779 - lr: 0.0100
# Epoch 50/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5831 - accuracy: 0.7070 - dice_coefficient: 0.2123 - jaccard_index: 0.1195 - sensitivity: 0.7422 - specificity: 0.7062 - precision: 0.1272
# Epoch 50: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 260s 24s/step - loss: 0.5831 - accuracy: 0.7070 - dice_coefficient: 0.2123 - jaccard_index: 0.1195 - sensitivity: 0.7422 - specificity: 0.7062 - precision: 0.1272 - val_loss: 0.7763 - val_accuracy: 0.7041 - val_dice_coefficient: 0.2508 - val_jaccard_index: 0.1439 - val_sensitivity: 0.6113 - val_specificity: 0.7276 - val_precision: 0.1582 - lr: 0.0100
# Epoch 51/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5652 - accuracy: 0.7513 - dice_coefficient: 0.2370 - jaccard_index: 0.1349 - sensitivity: 0.7336 - specificity: 0.7481 - precision: 0.1426
# Epoch 51: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 259s 24s/step - loss: 0.5652 - accuracy: 0.7513 - dice_coefficient: 0.2370 - jaccard_index: 0.1349 - sensitivity: 0.7336 - specificity: 0.7481 - precision: 0.1426 - val_loss: 0.7124 - val_accuracy: 0.6234 - val_dice_coefficient: 0.2457 - val_jaccard_index: 0.1405 - val_sensitivity: 0.7896 - val_specificity: 0.6164 - val_precision: 0.1455 - lr: 0.0099
# Epoch 52/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.7191 - dice_coefficient: 0.2243 - jaccard_index: 0.1271 - sensitivity: 0.7544 - specificity: 0.7161 - precision: 0.1356
# Epoch 52: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 256s 23s/step - loss: 0.5697 - accuracy: 0.7191 - dice_coefficient: 0.2243 - jaccard_index: 0.1271 - sensitivity: 0.7544 - specificity: 0.7161 - precision: 0.1356 - val_loss: 0.7667 - val_accuracy: 0.7333 - val_dice_coefficient: 0.2749 - val_jaccard_index: 0.1604 - val_sensitivity: 0.6288 - val_specificity: 0.7546 - val_precision: 0.1762 - lr: 0.0098
# Epoch 53/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5671 - accuracy: 0.7673 - dice_coefficient: 0.2384 - jaccard_index: 0.1355 - sensitivity: 0.7075 - specificity: 0.7726 - precision: 0.1466
# Epoch 53: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 254s 23s/step - loss: 0.5671 - accuracy: 0.7673 - dice_coefficient: 0.2384 - jaccard_index: 0.1355 - sensitivity: 0.7075 - specificity: 0.7726 - precision: 0.1466 - val_loss: 0.7379 - val_accuracy: 0.6335 - val_dice_coefficient: 0.2443 - val_jaccard_index: 0.1396 - val_sensitivity: 0.7668 - val_specificity: 0.6272 - val_precision: 0.1453 - lr: 0.0097
# Epoch 54/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5636 - accuracy: 0.6968 - dice_coefficient: 0.2192 - jaccard_index: 0.1239 - sensitivity: 0.7760 - specificity: 0.6959 - precision: 0.1297
# Epoch 54: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 251s 23s/step - loss: 0.5636 - accuracy: 0.6968 - dice_coefficient: 0.2192 - jaccard_index: 0.1239 - sensitivity: 0.7760 - specificity: 0.6959 - precision: 0.1297 - val_loss: 0.7448 - val_accuracy: 0.7291 - val_dice_coefficient: 0.2788 - val_jaccard_index: 0.1628 - val_sensitivity: 0.6735 - val_specificity: 0.7391 - val_precision: 0.1758 - lr: 0.0096
# Epoch 55/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5558 - accuracy: 0.7459 - dice_coefficient: 0.2317 - jaccard_index: 0.1314 - sensitivity: 0.7458 - specificity: 0.7405 - precision: 0.1381
# Epoch 55: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 252s 23s/step - loss: 0.5558 - accuracy: 0.7459 - dice_coefficient: 0.2317 - jaccard_index: 0.1314 - sensitivity: 0.7458 - specificity: 0.7405 - precision: 0.1381 - val_loss: 0.7146 - val_accuracy: 0.5631 - val_dice_coefficient: 0.2297 - val_jaccard_index: 0.1301 - val_sensitivity: 0.8270 - val_specificity: 0.5544 - val_precision: 0.1335 - lr: 0.0095
# Epoch 56/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5548 - accuracy: 0.7383 - dice_coefficient: 0.2337 - jaccard_index: 0.1332 - sensitivity: 0.7636 - specificity: 0.7360 - precision: 0.1402
# Epoch 56: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 249s 23s/step - loss: 0.5548 - accuracy: 0.7383 - dice_coefficient: 0.2337 - jaccard_index: 0.1332 - sensitivity: 0.7636 - specificity: 0.7360 - precision: 0.1402 - val_loss: 0.7372 - val_accuracy: 0.6519 - val_dice_coefficient: 0.2538 - val_jaccard_index: 0.1461 - val_sensitivity: 0.7402 - val_specificity: 0.6594 - val_precision: 0.1533 - lr: 0.0094
# Epoch 57/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5568 - accuracy: 0.7122 - dice_coefficient: 0.2237 - jaccard_index: 0.1263 - sensitivity: 0.7778 - specificity: 0.7097 - precision: 0.1318
# Epoch 57: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 249s 23s/step - loss: 0.5568 - accuracy: 0.7122 - dice_coefficient: 0.2237 - jaccard_index: 0.1263 - sensitivity: 0.7778 - specificity: 0.7097 - precision: 0.1318 - val_loss: 0.7742 - val_accuracy: 0.7803 - val_dice_coefficient: 0.3030 - val_jaccard_index: 0.1797 - val_sensitivity: 0.5969 - val_specificity: 0.8052 - val_precision: 0.2033 - lr: 0.0093
# Epoch 58/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5594 - accuracy: 0.7520 - dice_coefficient: 0.2366 - jaccard_index: 0.1346 - sensitivity: 0.7263 - specificity: 0.7527 - precision: 0.1441
# Epoch 58: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 254s 23s/step - loss: 0.5594 - accuracy: 0.7520 - dice_coefficient: 0.2366 - jaccard_index: 0.1346 - sensitivity: 0.7263 - specificity: 0.7527 - precision: 0.1441 - val_loss: 0.7680 - val_accuracy: 0.7475 - val_dice_coefficient: 0.2835 - val_jaccard_index: 0.1662 - val_sensitivity: 0.6240 - val_specificity: 0.7688 - val_precision: 0.1836 - lr: 0.0092
# Epoch 59/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5460 - accuracy: 0.7521 - dice_coefficient: 0.2412 - jaccard_index: 0.1374 - sensitivity: 0.7549 - specificity: 0.7527 - precision: 0.1446
# Epoch 59: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 291s 27s/step - loss: 0.5460 - accuracy: 0.7521 - dice_coefficient: 0.2412 - jaccard_index: 0.1374 - sensitivity: 0.7549 - specificity: 0.7527 - precision: 0.1446 - val_loss: 0.7422 - val_accuracy: 0.7203 - val_dice_coefficient: 0.2781 - val_jaccard_index: 0.1622 - val_sensitivity: 0.6931 - val_specificity: 0.7280 - val_precision: 0.1740 - lr: 0.0091
# Epoch 60/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5414 - accuracy: 0.7584 - dice_coefficient: 0.2453 - jaccard_index: 0.1402 - sensitivity: 0.7561 - specificity: 0.7555 - precision: 0.1469
# Epoch 60: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 299s 27s/step - loss: 0.5414 - accuracy: 0.7584 - dice_coefficient: 0.2453 - jaccard_index: 0.1402 - sensitivity: 0.7561 - specificity: 0.7555 - precision: 0.1469 - val_loss: 0.7327 - val_accuracy: 0.6706 - val_dice_coefficient: 0.2584 - val_jaccard_index: 0.1490 - val_sensitivity: 0.7383 - val_specificity: 0.6713 - val_precision: 0.1567 - lr: 0.0090
# Epoch 61/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5391 - accuracy: 0.7533 - dice_coefficient: 0.2431 - jaccard_index: 0.1387 - sensitivity: 0.7685 - specificity: 0.7497 - precision: 0.1452
# Epoch 61: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 300s 27s/step - loss: 0.5391 - accuracy: 0.7533 - dice_coefficient: 0.2431 - jaccard_index: 0.1387 - sensitivity: 0.7685 - specificity: 0.7497 - precision: 0.1452 - val_loss: 0.7143 - val_accuracy: 0.5815 - val_dice_coefficient: 0.2355 - val_jaccard_index: 0.1338 - val_sensitivity: 0.8182 - val_specificity: 0.5746 - val_precision: 0.1376 - lr: 0.0090
# Epoch 62/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5455 - accuracy: 0.7395 - dice_coefficient: 0.2335 - jaccard_index: 0.1325 - sensitivity: 0.7634 - specificity: 0.7396 - precision: 0.1386
# Epoch 62: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 298s 27s/step - loss: 0.5455 - accuracy: 0.7395 - dice_coefficient: 0.2335 - jaccard_index: 0.1325 - sensitivity: 0.7634 - specificity: 0.7396 - precision: 0.1386 - val_loss: 0.7633 - val_accuracy: 0.6836 - val_dice_coefficient: 0.2566 - val_jaccard_index: 0.1479 - val_sensitivity: 0.6641 - val_specificity: 0.7057 - val_precision: 0.1595 - lr: 0.0089
# Epoch 63/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.7416 - dice_coefficient: 0.2370 - jaccard_index: 0.1348 - sensitivity: 0.7733 - specificity: 0.7405 - precision: 0.1411
# Epoch 63: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 301s 27s/step - loss: 0.5456 - accuracy: 0.7416 - dice_coefficient: 0.2370 - jaccard_index: 0.1348 - sensitivity: 0.7733 - specificity: 0.7405 - precision: 0.1411 - val_loss: 0.7451 - val_accuracy: 0.7149 - val_dice_coefficient: 0.2768 - val_jaccard_index: 0.1615 - val_sensitivity: 0.6859 - val_specificity: 0.7284 - val_precision: 0.1735 - lr: 0.0088
# Epoch 64/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5401 - accuracy: 0.7470 - dice_coefficient: 0.2407 - jaccard_index: 0.1372 - sensitivity: 0.7705 - specificity: 0.7464 - precision: 0.1439
# Epoch 64: val_dice_coefficient did not improve from 0.30556
# 11/11 [==============================] - 298s 27s/step - loss: 0.5401 - accuracy: 0.7470 - dice_coefficient: 0.2407 - jaccard_index: 0.1372 - sensitivity: 0.7705 - specificity: 0.7464 - precision: 0.1439 - val_loss: 0.7670 - val_accuracy: 0.7561 - val_dice_coefficient: 0.2931 - val_jaccard_index: 0.1728 - val_sensitivity: 0.6244 - val_specificity: 0.7801 - val_precision: 0.1918 - lr: 0.0087
# Epoch 65/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5608 - accuracy: 0.7235 - dice_coefficient: 0.2416 - jaccard_index: 0.1394 - sensitivity: 0.7313 - specificity: 0.7286 - precision: 0.1519
# Epoch 65: val_dice_coefficient improved from 0.30556 to 0.30613, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_11
# 11/11 [==============================] - 306s 28s/step - loss: 0.5608 - accuracy: 0.7235 - dice_coefficient: 0.2416 - jaccard_index: 0.1394 - sensitivity: 0.7313 - specificity: 0.7286 - precision: 0.1519 - val_loss: 0.8022 - val_accuracy: 0.8272 - val_dice_coefficient: 0.3061 - val_jaccard_index: 0.1815 - val_sensitivity: 0.4676 - val_specificity: 0.8674 - val_precision: 0.2290 - lr: 0.0086
# Epoch 66/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5717 - accuracy: 0.7273 - dice_coefficient: 0.2253 - jaccard_index: 0.1282 - sensitivity: 0.7322 - specificity: 0.7311 - precision: 0.1383
# Epoch 66: val_dice_coefficient did not improve from 0.30613
# 11/11 [==============================] - 302s 28s/step - loss: 0.5717 - accuracy: 0.7273 - dice_coefficient: 0.2253 - jaccard_index: 0.1282 - sensitivity: 0.7322 - specificity: 0.7311 - precision: 0.1383 - val_loss: 0.7885 - val_accuracy: 0.7546 - val_dice_coefficient: 0.2838 - val_jaccard_index: 0.1663 - val_sensitivity: 0.6064 - val_specificity: 0.7780 - val_precision: 0.1855 - lr: 0.0085
# Epoch 67/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5451 - accuracy: 0.7449 - dice_coefficient: 0.2359 - jaccard_index: 0.1345 - sensitivity: 0.7597 - specificity: 0.7426 - precision: 0.1416
# Epoch 67: val_dice_coefficient did not improve from 0.30613
# 11/11 [==============================] - 305s 28s/step - loss: 0.5451 - accuracy: 0.7449 - dice_coefficient: 0.2359 - jaccard_index: 0.1345 - sensitivity: 0.7597 - specificity: 0.7426 - precision: 0.1416 - val_loss: 0.7251 - val_accuracy: 0.6950 - val_dice_coefficient: 0.2696 - val_jaccard_index: 0.1564 - val_sensitivity: 0.7267 - val_specificity: 0.6972 - val_precision: 0.1655 - lr: 0.0084
# Epoch 68/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5404 - accuracy: 0.7399 - dice_coefficient: 0.2347 - jaccard_index: 0.1340 - sensitivity: 0.7705 - specificity: 0.7377 - precision: 0.1399
# Epoch 68: val_dice_coefficient did not improve from 0.30613
# 11/11 [==============================] - 300s 27s/step - loss: 0.5404 - accuracy: 0.7399 - dice_coefficient: 0.2347 - jaccard_index: 0.1340 - sensitivity: 0.7705 - specificity: 0.7377 - precision: 0.1399 - val_loss: 0.7468 - val_accuracy: 0.6976 - val_dice_coefficient: 0.2661 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7062 - val_specificity: 0.7024 - val_precision: 0.1640 - lr: 0.0083
# Epoch 69/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5394 - accuracy: 0.7447 - dice_coefficient: 0.2360 - jaccard_index: 0.1349 - sensitivity: 0.7776 - specificity: 0.7387 - precision: 0.1412
# Epoch 69: val_dice_coefficient did not improve from 0.30613
# 11/11 [==============================] - 306s 28s/step - loss: 0.5394 - accuracy: 0.7447 - dice_coefficient: 0.2360 - jaccard_index: 0.1349 - sensitivity: 0.7776 - specificity: 0.7387 - precision: 0.1412 - val_loss: 0.7089 - val_accuracy: 0.6375 - val_dice_coefficient: 0.2492 - val_jaccard_index: 0.1427 - val_sensitivity: 0.7808 - val_specificity: 0.6296 - val_precision: 0.1483 - lr: 0.0083
# Epoch 70/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5330 - accuracy: 0.7496 - dice_coefficient: 0.2425 - jaccard_index: 0.1386 - sensitivity: 0.7666 - specificity: 0.7487 - precision: 0.1449
# Epoch 70: val_dice_coefficient did not improve from 0.30613
# 11/11 [==============================] - 309s 28s/step - loss: 0.5330 - accuracy: 0.7496 - dice_coefficient: 0.2425 - jaccard_index: 0.1386 - sensitivity: 0.7666 - specificity: 0.7487 - precision: 0.1449 - val_loss: 0.7623 - val_accuracy: 0.7487 - val_dice_coefficient: 0.2891 - val_jaccard_index: 0.1701 - val_sensitivity: 0.6304 - val_specificity: 0.7721 - val_precision: 0.1880 - lr: 0.0082
# Epoch 71/150
# ...
# Epoch 83/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5348 - accuracy: 0.7412 - dice_coefficient: 0.2377 - jaccard_index: 0.1359 - sensitivity: 0.7808 - specificity: 0.7360 - precision: 0.1436
# Epoch 83: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 303s 28s/step - loss: 0.5348 - accuracy: 0.7412 - dice_coefficient: 0.2377 - jaccard_index: 0.1359 - sensitivity: 0.7808 - specificity: 0.7360 - precision: 0.1436 - val_loss: 0.7087 - val_accuracy: 0.6047 - val_dice_coefficient: 0.2357 - val_jaccard_index: 0.1339 - val_sensitivity: 0.7973 - val_specificity: 0.5901 - val_precision: 0.1383 - lr: 0.0072
# Epoch 84/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5250 - accuracy: 0.7679 - dice_coefficient: 0.2544 - jaccard_index: 0.1461 - sensitivity: 0.7576 - specificity: 0.7693 - precision: 0.1537
# Epoch 84: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 301s 27s/step - loss: 0.5250 - accuracy: 0.7679 - dice_coefficient: 0.2544 - jaccard_index: 0.1461 - sensitivity: 0.7576 - specificity: 0.7693 - precision: 0.1537 - val_loss: 0.7292 - val_accuracy: 0.7076 - val_dice_coefficient: 0.2726 - val_jaccard_index: 0.1584 - val_sensitivity: 0.7007 - val_specificity: 0.7153 - val_precision: 0.1693 - lr: 0.0071
# Epoch 85/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.7598 - dice_coefficient: 0.2458 - jaccard_index: 0.1405 - sensitivity: 0.7681 - specificity: 0.7618 - precision: 0.1478
# Epoch 85: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 295s 27s/step - loss: 0.5265 - accuracy: 0.7598 - dice_coefficient: 0.2458 - jaccard_index: 0.1405 - sensitivity: 0.7681 - specificity: 0.7618 - precision: 0.1478 - val_loss: 0.7207 - val_accuracy: 0.7095 - val_dice_coefficient: 0.2747 - val_jaccard_index: 0.1599 - val_sensitivity: 0.7087 - val_specificity: 0.7148 - val_precision: 0.1704 - lr: 0.0070
# Epoch 86/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5248 - accuracy: 0.7605 - dice_coefficient: 0.2495 - jaccard_index: 0.1429 - sensitivity: 0.7737 - specificity: 0.7595 - precision: 0.1493
# Epoch 86: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 295s 27s/step - loss: 0.5248 - accuracy: 0.7605 - dice_coefficient: 0.2495 - jaccard_index: 0.1429 - sensitivity: 0.7737 - specificity: 0.7595 - precision: 0.1493 - val_loss: 0.7059 - val_accuracy: 0.6307 - val_dice_coefficient: 0.2452 - val_jaccard_index: 0.1401 - val_sensitivity: 0.7758 - val_specificity: 0.6238 - val_precision: 0.1456 - lr: 0.0070
# Epoch 87/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.7371 - dice_coefficient: 0.2418 - jaccard_index: 0.1385 - sensitivity: 0.7821 - specificity: 0.7359 - precision: 0.1450
# Epoch 87: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 305s 28s/step - loss: 0.5239 - accuracy: 0.7371 - dice_coefficient: 0.2418 - jaccard_index: 0.1385 - sensitivity: 0.7821 - specificity: 0.7359 - precision: 0.1450 - val_loss: 0.7460 - val_accuracy: 0.7057 - val_dice_coefficient: 0.2747 - val_jaccard_index: 0.1600 - val_sensitivity: 0.6994 - val_specificity: 0.7181 - val_precision: 0.1711 - lr: 0.0069
# Epoch 88/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.7605 - dice_coefficient: 0.2509 - jaccard_index: 0.1438 - sensitivity: 0.7807 - specificity: 0.7593 - precision: 0.1503
# Epoch 88: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 304s 28s/step - loss: 0.5208 - accuracy: 0.7605 - dice_coefficient: 0.2509 - jaccard_index: 0.1438 - sensitivity: 0.7807 - specificity: 0.7593 - precision: 0.1503 - val_loss: 0.6930 - val_accuracy: 0.6968 - val_dice_coefficient: 0.2758 - val_jaccard_index: 0.1605 - val_sensitivity: 0.7336 - val_specificity: 0.7030 - val_precision: 0.1700 - lr: 0.0068
# Epoch 89/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5254 - accuracy: 0.7533 - dice_coefficient: 0.2415 - jaccard_index: 0.1377 - sensitivity: 0.7650 - specificity: 0.7518 - precision: 0.1442
# Epoch 89: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 301s 28s/step - loss: 0.5254 - accuracy: 0.7533 - dice_coefficient: 0.2415 - jaccard_index: 0.1377 - sensitivity: 0.7650 - specificity: 0.7518 - precision: 0.1442 - val_loss: 0.6773 - val_accuracy: 0.6423 - val_dice_coefficient: 0.2551 - val_jaccard_index: 0.1465 - val_sensitivity: 0.7851 - val_specificity: 0.6386 - val_precision: 0.1524 - lr: 0.0068
# Epoch 90/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5283 - accuracy: 0.7555 - dice_coefficient: 0.2473 - jaccard_index: 0.1418 - sensitivity: 0.7605 - specificity: 0.7564 - precision: 0.1496
# Epoch 90: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 310s 28s/step - loss: 0.5283 - accuracy: 0.7555 - dice_coefficient: 0.2473 - jaccard_index: 0.1418 - sensitivity: 0.7605 - specificity: 0.7564 - precision: 0.1496 - val_loss: 0.7346 - val_accuracy: 0.6297 - val_dice_coefficient: 0.2425 - val_jaccard_index: 0.1384 - val_sensitivity: 0.7685 - val_specificity: 0.6225 - val_precision: 0.1440 - lr: 0.0067
# Epoch 91/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5204 - accuracy: 0.7568 - dice_coefficient: 0.2533 - jaccard_index: 0.1458 - sensitivity: 0.7766 - specificity: 0.7558 - precision: 0.1532
# Epoch 91: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 299s 27s/step - loss: 0.5204 - accuracy: 0.7568 - dice_coefficient: 0.2533 - jaccard_index: 0.1458 - sensitivity: 0.7766 - specificity: 0.7558 - precision: 0.1532 - val_loss: 0.6841 - val_accuracy: 0.6862 - val_dice_coefficient: 0.2713 - val_jaccard_index: 0.1574 - val_sensitivity: 0.7464 - val_specificity: 0.6891 - val_precision: 0.1658 - lr: 0.0066
# Epoch 92/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5240 - accuracy: 0.7136 - dice_coefficient: 0.2328 - jaccard_index: 0.1324 - sensitivity: 0.7976 - specificity: 0.7104 - precision: 0.1379
# Epoch 92: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 294s 27s/step - loss: 0.5240 - accuracy: 0.7136 - dice_coefficient: 0.2328 - jaccard_index: 0.1324 - sensitivity: 0.7976 - specificity: 0.7104 - precision: 0.1379 - val_loss: 0.7747 - val_accuracy: 0.7683 - val_dice_coefficient: 0.3013 - val_jaccard_index: 0.1786 - val_sensitivity: 0.6167 - val_specificity: 0.7934 - val_precision: 0.1998 - lr: 0.0066
# Epoch 93/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.7441 - dice_coefficient: 0.2401 - jaccard_index: 0.1367 - sensitivity: 0.7801 - specificity: 0.7440 - precision: 0.1430
# Epoch 93: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 294s 27s/step - loss: 0.5301 - accuracy: 0.7441 - dice_coefficient: 0.2401 - jaccard_index: 0.1367 - sensitivity: 0.7801 - specificity: 0.7440 - precision: 0.1430 - val_loss: 0.7334 - val_accuracy: 0.7619 - val_dice_coefficient: 0.3014 - val_jaccard_index: 0.1784 - val_sensitivity: 0.6455 - val_specificity: 0.7811 - val_precision: 0.1968 - lr: 0.0065
# Epoch 94/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5355 - accuracy: 0.7462 - dice_coefficient: 0.2434 - jaccard_index: 0.1395 - sensitivity: 0.7563 - specificity: 0.7420 - precision: 0.1484
# Epoch 94: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 306s 28s/step - loss: 0.5355 - accuracy: 0.7462 - dice_coefficient: 0.2434 - jaccard_index: 0.1395 - sensitivity: 0.7563 - specificity: 0.7420 - precision: 0.1484 - val_loss: 0.7392 - val_accuracy: 0.6311 - val_dice_coefficient: 0.2428 - val_jaccard_index: 0.1386 - val_sensitivity: 0.7686 - val_specificity: 0.6232 - val_precision: 0.1442 - lr: 0.0064
# Epoch 95/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5347 - accuracy: 0.7739 - dice_coefficient: 0.2538 - jaccard_index: 0.1460 - sensitivity: 0.7359 - specificity: 0.7753 - precision: 0.1560
# Epoch 95: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 296s 27s/step - loss: 0.5347 - accuracy: 0.7739 - dice_coefficient: 0.2538 - jaccard_index: 0.1460 - sensitivity: 0.7359 - specificity: 0.7753 - precision: 0.1560 - val_loss: 0.6897 - val_accuracy: 0.6357 - val_dice_coefficient: 0.2491 - val_jaccard_index: 0.1425 - val_sensitivity: 0.7920 - val_specificity: 0.6233 - val_precision: 0.1478 - lr: 0.0064
# Epoch 96/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5223 - accuracy: 0.7500 - dice_coefficient: 0.2394 - jaccard_index: 0.1363 - sensitivity: 0.7522 - specificity: 0.7498 - precision: 0.1430
# Epoch 96: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 295s 27s/step - loss: 0.5223 - accuracy: 0.7500 - dice_coefficient: 0.2394 - jaccard_index: 0.1363 - sensitivity: 0.7522 - specificity: 0.7498 - precision: 0.1430 - val_loss: 0.7235 - val_accuracy: 0.7289 - val_dice_coefficient: 0.2848 - val_jaccard_index: 0.1669 - val_sensitivity: 0.6824 - val_specificity: 0.7421 - val_precision: 0.1801 - lr: 0.0063
# Epoch 97/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5220 - accuracy: 0.7484 - dice_coefficient: 0.2446 - jaccard_index: 0.1398 - sensitivity: 0.7840 - specificity: 0.7492 - precision: 0.1462
# Epoch 97: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 286s 26s/step - loss: 0.5220 - accuracy: 0.7484 - dice_coefficient: 0.2446 - jaccard_index: 0.1398 - sensitivity: 0.7840 - specificity: 0.7492 - precision: 0.1462 - val_loss: 0.7284 - val_accuracy: 0.7121 - val_dice_coefficient: 0.2753 - val_jaccard_index: 0.1603 - val_sensitivity: 0.7031 - val_specificity: 0.7186 - val_precision: 0.1712 - lr: 0.0062
# Epoch 98/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5150 - accuracy: 0.7634 - dice_coefficient: 0.2526 - jaccard_index: 0.1447 - sensitivity: 0.7711 - specificity: 0.7643 - precision: 0.1517
# Epoch 98: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 290s 26s/step - loss: 0.5150 - accuracy: 0.7634 - dice_coefficient: 0.2526 - jaccard_index: 0.1447 - sensitivity: 0.7711 - specificity: 0.7643 - precision: 0.1517 - val_loss: 0.7337 - val_accuracy: 0.7511 - val_dice_coefficient: 0.2956 - val_jaccard_index: 0.1744 - val_sensitivity: 0.6583 - val_specificity: 0.7681 - val_precision: 0.1908 - lr: 0.0062
# Epoch 99/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.7552 - dice_coefficient: 0.2447 - jaccard_index: 0.1398 - sensitivity: 0.7736 - specificity: 0.7535 - precision: 0.1464
# Epoch 99: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 294s 27s/step - loss: 0.5217 - accuracy: 0.7552 - dice_coefficient: 0.2447 - jaccard_index: 0.1398 - sensitivity: 0.7736 - specificity: 0.7535 - precision: 0.1464 - val_loss: 0.7260 - val_accuracy: 0.6835 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1546 - val_sensitivity: 0.7325 - val_specificity: 0.6887 - val_precision: 0.1633 - lr: 0.0061
# Epoch 100/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5251 - accuracy: 0.7443 - dice_coefficient: 0.2401 - jaccard_index: 0.1370 - sensitivity: 0.7826 - specificity: 0.7418 - precision: 0.1442
# Epoch 100: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 290s 26s/step - loss: 0.5251 - accuracy: 0.7443 - dice_coefficient: 0.2401 - jaccard_index: 0.1370 - sensitivity: 0.7826 - specificity: 0.7418 - precision: 0.1442 - val_loss: 0.7504 - val_accuracy: 0.7351 - val_dice_coefficient: 0.2879 - val_jaccard_index: 0.1691 - val_sensitivity: 0.6703 - val_specificity: 0.7518 - val_precision: 0.1835 - lr: 0.0061
# Epoch 101/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5235 - accuracy: 0.7647 - dice_coefficient: 0.2528 - jaccard_index: 0.1450 - sensitivity: 0.7702 - specificity: 0.7653 - precision: 0.1527
# Epoch 101: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 293s 27s/step - loss: 0.5235 - accuracy: 0.7647 - dice_coefficient: 0.2528 - jaccard_index: 0.1450 - sensitivity: 0.7702 - specificity: 0.7653 - precision: 0.1527 - val_loss: 0.7092 - val_accuracy: 0.6891 - val_dice_coefficient: 0.2694 - val_jaccard_index: 0.1562 - val_sensitivity: 0.7391 - val_specificity: 0.6903 - val_precision: 0.1648 - lr: 0.0054
# Epoch 102/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5171 - accuracy: 0.7547 - dice_coefficient: 0.2463 - jaccard_index: 0.1407 - sensitivity: 0.7771 - specificity: 0.7539 - precision: 0.1467
# Epoch 102: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 301s 27s/step - loss: 0.5171 - accuracy: 0.7547 - dice_coefficient: 0.2463 - jaccard_index: 0.1407 - sensitivity: 0.7771 - specificity: 0.7539 - precision: 0.1467 - val_loss: 0.7435 - val_accuracy: 0.6879 - val_dice_coefficient: 0.2684 - val_jaccard_index: 0.1557 - val_sensitivity: 0.7252 - val_specificity: 0.6950 - val_precision: 0.1648 - lr: 0.0049
# Epoch 103/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5214 - accuracy: 0.7609 - dice_coefficient: 0.2556 - jaccard_index: 0.1470 - sensitivity: 0.7703 - specificity: 0.7614 - precision: 0.1546
# Epoch 103: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 293s 27s/step - loss: 0.5214 - accuracy: 0.7609 - dice_coefficient: 0.2556 - jaccard_index: 0.1470 - sensitivity: 0.7703 - specificity: 0.7614 - precision: 0.1546 - val_loss: 0.7064 - val_accuracy: 0.7019 - val_dice_coefficient: 0.2745 - val_jaccard_index: 0.1597 - val_sensitivity: 0.7184 - val_specificity: 0.7089 - val_precision: 0.1698 - lr: 0.0044
# Epoch 104/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5167 - accuracy: 0.7369 - dice_coefficient: 0.2416 - jaccard_index: 0.1378 - sensitivity: 0.7912 - specificity: 0.7330 - precision: 0.1438
# Epoch 104: val_dice_coefficient did not improve from 0.31435
# 11/11 [==============================] - 290s 26s/step - loss: 0.5167 - accuracy: 0.7369 - dice_coefficient: 0.2416 - jaccard_index: 0.1378 - sensitivity: 0.7912 - specificity: 0.7330 - precision: 0.1438 - val_loss: 0.7420 - val_accuracy: 0.7499 - val_dice_coefficient: 0.2968 - val_jaccard_index: 0.1753 - val_sensitivity: 0.6565 - val_specificity: 0.7697 - val_precision: 0.1920 - lr: 0.0040
# Epoch 105/150
# 11/11 [==============================] - ETA: 0s - loss: 0.5182 - accuracy: 0.7756 - dice_coefficient: 0.2595 - jaccard_index: 0.1496 - sensitivity: 0.7612 - specificity: 0.7738 - precision: 0.1575
# Epoch 105: val_dice_coefficient did not improve from 0.31435
# Restoring model weights from the end of the best epoch: 75.
# 11/11 [==============================] - 287s 26s/step - loss: 0.5182 - accuracy: 0.7756 - dice_coefficient: 0.2595 - jaccard_index: 0.1496 - sensitivity: 0.7612 - specificity: 0.7738 - precision: 0.1575 - val_loss: 0.7054 - val_accuracy: 0.6953 - val_dice_coefficient: 0.2689 - val_jaccard_index: 0.1559 - val_sensitivity: 0.7183 - val_specificity: 0.7002 - val_precision: 0.1655 - lr: 0.0036
# Epoch 105: early stopping
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_auc_score

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred, threshold=threshold):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > threshold).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative (Correct: No Buildings)', 'False Positive (Incorrect: There Was No Building)', 'False Negative (Incorrect: There Was A Building Here)', 'True Positive (Correct: There Is A Building Here)']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred, threshold=threshold)
plot_confusion_matrix(y_test, y_pred, threshold=threshold)
print(classification_report(y_test.flatten(), (y_pred.flatten() > threshold).astype(int)))
print("ROC-AUC:", roc_auc_score(y_test.flatten(), y_pred.flatten()))
# Out:
# 2/2 [==============================] - 44s 14s/step
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.85      0.91  26734518
#          1.0       0.20      0.64      0.30   1577034
#
#     accuracy                           0.84  28311552
#    macro avg       0.59      0.74      0.60  28311552
# weighted avg       0.93      0.84      0.87  28311552
#
# ROC-AUC: 0.8211077391115085
