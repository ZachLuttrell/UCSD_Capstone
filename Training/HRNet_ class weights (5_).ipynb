# %% [markdown]
# **NOTE:**
# Connect to a High-RAM environment
#
# **HRNet Implementation:** https://github.com/niecongchong/HRNet-keras-semantic-segmentation/blob/master/model/seg_hrnet.py

# %% [markdown]
# Import the libraries

# %%
from google.colab import drive
drive.mount('/gdrive')

import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Load the dataset

# %%
def count_files(directory, extension=".tif"):
    # List all files in the directory and count those with the specified extension
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")
# Out:
# Number of image files: 4787
# Number of mask files: 4787

# %%
# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
percentage_to_load = 5 / 100.0  # Set the % of dataset to be loaded here.
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(image_files[:number_of_files_to_load], start=1):
    img_path = os.path.join(image_directory, image_name)
    mask_name = image_to_mask[image_name]
    mask_path = os.path.join(mask_directory, mask_name)

    if os.path.exists(mask_path):
        img = tiff.imread(img_path)
        mask = tiff.imread(mask_path)

        images.append(img)
        masks.append(mask)
    else:
        print(f'\nMask not found for image: {image_name}')

    # Update the count in the same line
    print(f'\rProcessed: {count}/{number_of_files_to_load}', end='')

print("\nLoading complete.")

# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))
# Out:
# Attempting to load 5.0% of dataset: 239 images/mask pairs...
# Processed: 239/239
# Loading complete.

# %% [markdown]
# Perform Train/Test/Val Split

# %%
# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If there is an unnecessary singleton dimension in your dataset, remove it:
if X_train.ndim > 3:  # Assuming the desired dimension is 3 (e.g., height x width x channels)
    X_train = X_train.squeeze(axis=1)
    X_val = X_val.squeeze(axis=1)
    X_test = X_test.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (171, 256, 256, 3), y_train: (171, 256, 256, 1)
# X_val:   (20, 256, 256, 3), y_val: (20, 256, 256, 1)
# X_test:  (48, 256, 256, 3), y_test: (48, 256, 256, 1)

# %% [markdown]
# Define the model

# %%
from keras.layers import Input, Conv2D, BatchNormalization, Activation, UpSampling2D, add, concatenate
from keras.models import Model
import tensorflow as tf
from tensorflow.keras.backend import epsilon
from tensorflow.keras.losses import BinaryCrossentropy
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import backend as K

def stem_net(input):
    # Start with a convolution with stride 1 to maintain resolution
    x = Conv2D(64, 3, strides=(1, 1), padding='same', use_bias=False, kernel_initializer='he_normal')(input)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    # Reduced stride in the next layers or adjust according to your network depth need
    x = Conv2D(64, 3, strides=(1, 1), padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    return x

def transition_layer1(x, out_filters_list=[32, 64]):
    # Branch maintaining the current resolution
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    # Branch with reduced resolution
    x1 = Conv2D(out_filters_list[1], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    return [x0, x1]

def make_branch1_0(x, out_filters=32):
    # Applying multiple basic blocks to process high-resolution features
    x = basic_Block(x, out_filters, with_conv_shortcut=True)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch1_1(x, out_filters=64):
    # Processing slightly lower resolution features
    x = basic_Block(x, out_filters, with_conv_shortcut=True)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def fuse_layer1(x):
    # x is a list of feature maps from different branches
    x0_0 = x[0]  # High-resolution feature map
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)  # Upsampling to match high-res dimensions
    x0 = add([x0_0, x0_1])  # Adding features from different resolutions

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]  # Lower resolution features
    x1 = add([x1_0, x1_1])  # Combining features with downsampling high-res features

    return [x0, x1]

def transition_layer2(x, out_filters_list=[32, 64, 128]):
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    x1 = Conv2D(out_filters_list[1], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    x2 = Conv2D(out_filters_list[2], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2 = BatchNormalization(axis=3)(x2)
    x2 = Activation('relu')(x2)

    return [x0, x1, x2]

def make_branch2_0(x, out_filters=32):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch2_1(x, out_filters=64):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch2_2(x, out_filters=128):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def fuse_layer2(x):
    x0_0 = x[0]
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)
    x0_2 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x0_2 = BatchNormalization(axis=3)(x0_2)
    x0_2 = UpSampling2D(size=(4, 4))(x0_2)
    x0 = add([x0_0, x0_1, x0_2])

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]
    x1_2 = Conv2D(64, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x1_2 = BatchNormalization(axis=3)(x1_2)
    x1_2 = UpSampling2D(size=(2, 2))(x1_2)
    x1 = add([x1_0, x1_1, x1_2])

    x2_0 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_0 = Activation('relu')(x2_0)
    x2_0 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x2_0)
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_1 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2_1 = BatchNormalization(axis=3)(x2_1)
    x2_2 = x[2]
    x2 = add([x2_0, x2_1, x2_2])

    return [x0, x1, x2]

def final_layer(x, classes=1):
    # Removing the sigmoid activation to use logits
    x = Conv2D(classes, 1, use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    # No activation layer here
    return x

def seg_hrnet(input_shape=(256, 256, 3), classes=1):
    inputs = Input(shape=input_shape)

    # Stem network
    x = stem_net(inputs)

    # Transition Layer 1
    x = transition_layer1(x)
    x0 = make_branch1_0(x[0])
    x1 = make_branch1_1(x[1])
    x = fuse_layer1([x0, x1])

    # Transition Layer 2
    x = transition_layer2(x)
    x0 = make_branch2_0(x[0])
    x1 = make_branch2_1(x[1])
    x2 = make_branch2_2(x[2])
    x = fuse_layer2([x0, x1, x2])

    # Final Layer
    out = final_layer(x[0], classes=classes)

    model = Model(inputs=inputs, outputs=out)
    return model

# CUSTOM METRICS
def dice_coefficient(y_true, y_pred, threshold=0.5):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + K.epsilon())

def jaccard_index(y_true, y_pred, threshold=0.5):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + K.epsilon()) / (union + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# LOSS FUNCTION
def calculate_class_weights(masks):
    # Flatten the mask array to get a 1D array of labels
    flat_labels = masks.flatten().astype(int)

    # Calculate the class weights
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)

    # Create a dictionary to map class labels to weights
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        # Calculate the binary cross-entropy loss
        bce = K.binary_crossentropy(y_true, y_pred)

        # Apply the weights
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))

        return K.mean(weighted_bce)

    return loss

# MODEL FEATURES
def basic_Block(input, out_filters, strides=(1, 1), with_conv_shortcut=False):
    x = conv3x3(input, out_filters, strides)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = conv3x3(x, out_filters)
    x = BatchNormalization(axis=3)(x)

    if with_conv_shortcut:
        residual = Conv2D(out_filters, 1, strides=strides, use_bias=False, kernel_initializer='he_normal')(input)
        residual = BatchNormalization(axis=3)(residual)
        x = add([x, residual])
    else:
        x = add([x, input])

    x = Activation('relu')(x)
    return x

def conv3x3(x, out_filters, strides=(1, 1)):
    x = Conv2D(out_filters, 3, padding='same', strides=strides, use_bias=False, kernel_initializer='he_normal')(x)
    return x

# %% [markdown]
# Compile the model

# %%
from tensorflow.keras.optimizers import Adam

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)
weighted_loss = weighted_binary_crossentropy(class_weights)

model = seg_hrnet()
model._name = 'HRNet_class_weights'
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

model.summary()
# Out:
# Class weights: {0: 0.5274949720047702, 1: 9.592571542048715}
# Model: "HRNet_class_weights"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 64)         1728      ['input_2[0][0]']
#
#  batch_normalization_59 (Ba  (None, 256, 256, 64)         256       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 256, 256, 64)         36864     ['activation_48[0][0]']
#
#  batch_normalization_60 (Ba  (None, 256, 256, 64)         256       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_61 (Conv2D)          (None, 256, 256, 32)         18432     ['activation_49[0][0]']
#
#  batch_normalization_61 (Ba  (None, 256, 256, 32)         128       ['conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_49[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_50[0][0]']
#
#  batch_normalization_62 (Ba  (None, 128, 128, 64)         256       ['conv2d_62[0][0]']
#  tchNormalization)
#
#  batch_normalization_63 (Ba  (None, 256, 256, 32)         128       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  activation_52 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_72 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_51[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_52[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 256, 256, 32)         1024      ['activation_50[0][0]']
#
#  batch_normalization_72 (Ba  (None, 128, 128, 64)         256       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  batch_normalization_64 (Ba  (None, 256, 256, 32)         128       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  batch_normalization_65 (Ba  (None, 256, 256, 32)         128       ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  add_25 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_64[0][0]
#                                                                     ',
#                                                                      'batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_73 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_60[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 128, 128, 64)         4096      ['activation_51[0][0]']
#
#  activation_53 (Activation)  (None, 256, 256, 32)         0         ['add_25[0][0]']
#
#  batch_normalization_73 (Ba  (None, 128, 128, 64)         256       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  batch_normalization_74 (Ba  (None, 128, 128, 64)         256       ['conv2d_74[0][0]']
#  tchNormalization)
#
#  conv2d_66 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_53[0][0]']
#
#  add_29 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_73[0][0]
#                                                                     ',
#                                                                      'batch_normalization_74[0][0]
#                                                                     ']
#
#  batch_normalization_66 (Ba  (None, 256, 256, 32)         128       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 128, 128, 64)         0         ['add_29[0][0]']
#
#  activation_54 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_75 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_61[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_54[0][0]']
#
#  batch_normalization_75 (Ba  (None, 128, 128, 64)         256       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  batch_normalization_67 (Ba  (None, 256, 256, 32)         128       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  add_26 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_67[0][0]
#                                                                     ',
#                                                                      'activation_53[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_62[0][0]']
#
#  activation_55 (Activation)  (None, 256, 256, 32)         0         ['add_26[0][0]']
#
#  batch_normalization_76 (Ba  (None, 128, 128, 64)         256       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  conv2d_68 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_55[0][0]']
#
#  add_30 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_76[0][0]
#                                                                     ',
#                                                                      'activation_61[0][0]']
#
#  batch_normalization_68 (Ba  (None, 256, 256, 32)         128       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 128, 128, 64)         0         ['add_30[0][0]']
#
#  activation_56 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_63[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_56[0][0]']
#
#  batch_normalization_77 (Ba  (None, 128, 128, 64)         256       ['conv2d_77[0][0]']
#  tchNormalization)
#
#  batch_normalization_69 (Ba  (None, 256, 256, 32)         128       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  add_27 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_69[0][0]
#                                                                     ',
#                                                                      'activation_55[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_64[0][0]']
#
#  activation_57 (Activation)  (None, 256, 256, 32)         0         ['add_27[0][0]']
#
#  batch_normalization_78 (Ba  (None, 128, 128, 64)         256       ['conv2d_78[0][0]']
#  tchNormalization)
#
#  conv2d_70 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_57[0][0]']
#
#  add_31 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_78[0][0]
#                                                                     ',
#                                                                      'activation_63[0][0]']
#
#  batch_normalization_70 (Ba  (None, 256, 256, 32)         128       ['conv2d_70[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 128, 128, 64)         0         ['add_31[0][0]']
#
#  activation_58 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_79 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_65[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_58[0][0]']
#
#  batch_normalization_79 (Ba  (None, 128, 128, 64)         256       ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_71 (Ba  (None, 256, 256, 32)         128       ['conv2d_71[0][0]']
#  tchNormalization)
#
#  activation_66 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  add_28 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_71[0][0]
#                                                                     ',
#                                                                      'activation_57[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_66[0][0]']
#
#  activation_59 (Activation)  (None, 256, 256, 32)         0         ['add_28[0][0]']
#
#  batch_normalization_80 (Ba  (None, 128, 128, 64)         256       ['conv2d_80[0][0]']
#  tchNormalization)
#
#  add_32 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_80[0][0]
#                                                                     ',
#                                                                      'activation_65[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 128, 128, 64)         18432     ['activation_59[0][0]']
#
#  activation_67 (Activation)  (None, 128, 128, 64)         0         ['add_32[0][0]']
#
#  batch_normalization_82 (Ba  (None, 128, 128, 64)         256       ['conv2d_82[0][0]']
#  tchNormalization)
#
#  conv2d_81 (Conv2D)          (None, 128, 128, 32)         2048      ['activation_67[0][0]']
#
#  add_34 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_82[0][0]
#                                                                     ',
#                                                                      'activation_67[0][0]']
#
#  batch_normalization_81 (Ba  (None, 128, 128, 32)         128       ['conv2d_81[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 128, 128, 64)         36864     ['add_34[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 64, 64, 128)          73728     ['add_34[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 256, 256, 32)         0         ['batch_normalization_81[0][0]
#  g2D)                                                               ']
#
#  batch_normalization_84 (Ba  (None, 128, 128, 64)         256       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  batch_normalization_85 (Ba  (None, 64, 64, 128)          512       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  add_33 (Add)                (None, 256, 256, 32)         0         ['activation_59[0][0]',
#                                                                      'up_sampling2d_4[0][0]']
#
#  activation_69 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  activation_70 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 256, 256, 32)         9216      ['add_33[0][0]']
#
#  conv2d_94 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_69[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_70[0][0]']
#
#  batch_normalization_83 (Ba  (None, 256, 256, 32)         128       ['conv2d_83[0][0]']
#  tchNormalization)
#
#  batch_normalization_94 (Ba  (None, 128, 128, 64)         256       ['conv2d_94[0][0]']
#  tchNormalization)
#
#  batch_normalization_102 (B  (None, 64, 64, 128)          512       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  activation_68 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  activation_87 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_102[0][0
#                                                                     ]']
#
#  conv2d_86 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_68[0][0]']
#
#  conv2d_95 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_79[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_87[0][0]']
#
#  batch_normalization_86 (Ba  (None, 256, 256, 32)         128       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_95 (Ba  (None, 128, 128, 64)         256       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  batch_normalization_103 (B  (None, 64, 64, 128)          512       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_71 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  add_39 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_95[0][0]
#                                                                     ',
#                                                                      'activation_69[0][0]']
#
#  add_43 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_103[0][0
#                                                                     ]',
#                                                                      'activation_70[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_71[0][0]']
#
#  activation_80 (Activation)  (None, 128, 128, 64)         0         ['add_39[0][0]']
#
#  activation_88 (Activation)  (None, 64, 64, 128)          0         ['add_43[0][0]']
#
#  batch_normalization_87 (Ba  (None, 256, 256, 32)         128       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  conv2d_96 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_80[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_88[0][0]']
#
#  add_35 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_87[0][0]
#                                                                     ',
#                                                                      'activation_68[0][0]']
#
#  batch_normalization_96 (Ba  (None, 128, 128, 64)         256       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  batch_normalization_104 (B  (None, 64, 64, 128)          512       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  activation_72 (Activation)  (None, 256, 256, 32)         0         ['add_35[0][0]']
#
#  activation_81 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  activation_89 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_104[0][0
#                                                                     ]']
#
#  conv2d_88 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_72[0][0]']
#
#  conv2d_97 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_81[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_89[0][0]']
#
#  batch_normalization_88 (Ba  (None, 256, 256, 32)         128       ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_97 (Ba  (None, 128, 128, 64)         256       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  batch_normalization_105 (B  (None, 64, 64, 128)          512       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_73 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  add_40 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_97[0][0]
#                                                                     ',
#                                                                      'activation_80[0][0]']
#
#  add_44 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_105[0][0
#                                                                     ]',
#                                                                      'activation_88[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_73[0][0]']
#
#  activation_82 (Activation)  (None, 128, 128, 64)         0         ['add_40[0][0]']
#
#  activation_90 (Activation)  (None, 64, 64, 128)          0         ['add_44[0][0]']
#
#  batch_normalization_89 (Ba  (None, 256, 256, 32)         128       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  conv2d_98 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_82[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_90[0][0]']
#
#  add_36 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_89[0][0]
#                                                                     ',
#                                                                      'activation_72[0][0]']
#
#  batch_normalization_98 (Ba  (None, 128, 128, 64)         256       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  batch_normalization_106 (B  (None, 64, 64, 128)          512       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_74 (Activation)  (None, 256, 256, 32)         0         ['add_36[0][0]']
#
#  activation_83 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_106[0][0
#                                                                     ]']
#
#  conv2d_90 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_74[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 128, 128, 64)         36864     ['activation_83[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_91[0][0]']
#
#  batch_normalization_90 (Ba  (None, 256, 256, 32)         128       ['conv2d_90[0][0]']
#  tchNormalization)
#
#  batch_normalization_99 (Ba  (None, 128, 128, 64)         256       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  batch_normalization_107 (B  (None, 64, 64, 128)          512       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_75 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  add_41 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_99[0][0]
#                                                                     ',
#                                                                      'activation_82[0][0]']
#
#  add_45 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_107[0][0
#                                                                     ]',
#                                                                      'activation_90[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_75[0][0]']
#
#  activation_84 (Activation)  (None, 128, 128, 64)         0         ['add_41[0][0]']
#
#  activation_92 (Activation)  (None, 64, 64, 128)          0         ['add_45[0][0]']
#
#  batch_normalization_91 (Ba  (None, 256, 256, 32)         128       ['conv2d_91[0][0]']
#  tchNormalization)
#
#  conv2d_100 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_84[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_92[0][0]']
#
#  add_37 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_91[0][0]
#                                                                     ',
#                                                                      'activation_74[0][0]']
#
#  batch_normalization_100 (B  (None, 128, 128, 64)         256       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 64, 64, 128)          512       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_76 (Activation)  (None, 256, 256, 32)         0         ['add_37[0][0]']
#
#  activation_85 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  activation_93 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_108[0][0
#                                                                     ]']
#
#  conv2d_92 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_76[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_85[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_93[0][0]']
#
#  batch_normalization_92 (Ba  (None, 256, 256, 32)         128       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 128, 128, 64)         256       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_109 (B  (None, 64, 64, 128)          512       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_77 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  add_42 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_101[0][0
#                                                                     ]',
#                                                                      'activation_84[0][0]']
#
#  add_46 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_109[0][0
#                                                                     ]',
#                                                                      'activation_92[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 256, 256, 32)         9216      ['activation_77[0][0]']
#
#  activation_86 (Activation)  (None, 128, 128, 64)         0         ['add_42[0][0]']
#
#  activation_94 (Activation)  (None, 64, 64, 128)          0         ['add_46[0][0]']
#
#  batch_normalization_93 (Ba  (None, 256, 256, 32)         128       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  conv2d_110 (Conv2D)         (None, 128, 128, 32)         2048      ['activation_86[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 64, 64, 32)           4096      ['activation_94[0][0]']
#
#  add_38 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_93[0][0]
#                                                                     ',
#                                                                      'activation_76[0][0]']
#
#  batch_normalization_110 (B  (None, 128, 128, 32)         128       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 64, 64, 32)           128       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_78 (Activation)  (None, 256, 256, 32)         0         ['add_38[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 256, 256, 32)         0         ['batch_normalization_110[0][0
#  g2D)                                                               ]']
#
#  up_sampling2d_6 (UpSamplin  (None, 256, 256, 32)         0         ['batch_normalization_111[0][0
#  g2D)                                                               ]']
#
#  add_47 (Add)                (None, 256, 256, 32)         0         ['activation_78[0][0]',
#                                                                      'up_sampling2d_5[0][0]',
#                                                                      'up_sampling2d_6[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 256, 256, 1)          32        ['add_47[0][0]']
#
#  batch_normalization_117 (B  (None, 256, 256, 1)          4         ['conv2d_117[0][0]']
#  atchNormalization)
#
# ==================================================================================================
# Total params: 2175460 (8.30 MB)
# Trainable params: 2168930 (8.27 MB)
# Non-trainable params: 6530 (25.51 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Train

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Setup early stopping to monitor the 'val_loss' and stop training after 10 epochs of no improvements
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=10,
    verbose=1,
    restore_best_weights=True  # Restores model weights from the epoch with the best value of the monitored quantity
)

# Setup model checkpointing to save the best model observed during training for later use
model_checkpoint = ModelCheckpoint(
    '/gdrive/My Drive/Dataset/Models/best_hrnet_class_weights',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    epochs=50,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, model_checkpoint]
)

# Save the model
model.save('/gdrive/My Drive/Dataset/Models/hrnet_class_weights.h5')
model.save('/gdrive/My Drive/Dataset/Models/hrnet_class_weights')
# Out:
# Epoch 1/50
# 6/6 [==============================] - ETA: 0s - loss: 4.0202 - accuracy: 0.7590 - dice_coefficient: 0.1638 - jaccard_index: 0.0893 - sensitivity: 0.4406 - specificity: 0.7757 - precision: 0.1009
# Epoch 1: val_dice_coefficient improved from -inf to 0.13758, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_class_weights
# 6/6 [==============================] - 309s 49s/step - loss: 4.0202 - accuracy: 0.7590 - dice_coefficient: 0.1638 - jaccard_index: 0.0893 - sensitivity: 0.4406 - specificity: 0.7757 - precision: 0.1009 - val_loss: 7.3467 - val_accuracy: 0.0771 - val_dice_coefficient: 0.1376 - val_jaccard_index: 0.0739 - val_sensitivity: 1.0000 - val_specificity: 0.0038 - val_precision: 0.0739
# Epoch 2/50
# 6/6 [==============================] - ETA: 0s - loss: 3.2490 - accuracy: 0.7599 - dice_coefficient: 0.1847 - jaccard_index: 0.1018 - sensitivity: 0.5458 - specificity: 0.7707 - precision: 0.1117
# Epoch 2: val_dice_coefficient improved from 0.13758 to 0.13963, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_class_weights
# 6/6 [==============================] - 290s 48s/step - loss: 3.2490 - accuracy: 0.7599 - dice_coefficient: 0.1847 - jaccard_index: 0.1018 - sensitivity: 0.5458 - specificity: 0.7707 - precision: 0.1117 - val_loss: 7.0841 - val_accuracy: 0.0944 - val_dice_coefficient: 0.1396 - val_jaccard_index: 0.0751 - val_sensitivity: 0.9983 - val_specificity: 0.0226 - val_precision: 0.0751
# Epoch 3/50
# 6/6 [==============================] - ETA: 0s - loss: 2.9154 - accuracy: 0.7446 - dice_coefficient: 0.1948 - jaccard_index: 0.1080 - sensitivity: 0.5818 - specificity: 0.7546 - precision: 0.1173
# Epoch 3: val_dice_coefficient improved from 0.13963 to 0.16022, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_class_weights
# 6/6 [==============================] - 291s 49s/step - loss: 2.9154 - accuracy: 0.7446 - dice_coefficient: 0.1948 - jaccard_index: 0.1080 - sensitivity: 0.5818 - specificity: 0.7546 - precision: 0.1173 - val_loss: 5.6116 - val_accuracy: 0.2833 - val_dice_coefficient: 0.1602 - val_jaccard_index: 0.0871 - val_sensitivity: 0.9288 - val_specificity: 0.2320 - val_precision: 0.0877
# Epoch 4/50
# 6/6 [==============================] - ETA: 0s - loss: 2.7950 - accuracy: 0.7350 - dice_coefficient: 0.1865 - jaccard_index: 0.1029 - sensitivity: 0.6051 - specificity: 0.7437 - precision: 0.1107
# Epoch 4: val_dice_coefficient improved from 0.16022 to 0.19279, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_class_weights
# 6/6 [==============================] - 295s 49s/step - loss: 2.7950 - accuracy: 0.7350 - dice_coefficient: 0.1865 - jaccard_index: 0.1029 - sensitivity: 0.6051 - specificity: 0.7437 - precision: 0.1107 - val_loss: 4.9008 - val_accuracy: 0.5542 - val_dice_coefficient: 0.1928 - val_jaccard_index: 0.1067 - val_sensitivity: 0.7232 - val_specificity: 0.5407 - val_precision: 0.1112
# Epoch 5/50
# 6/6 [==============================] - ETA: 0s - loss: 2.7375 - accuracy: 0.7294 - dice_coefficient: 0.1830 - jaccard_index: 0.1008 - sensitivity: 0.5989 - specificity: 0.7357 - precision: 0.1082
# Epoch 5: val_dice_coefficient improved from 0.19279 to 0.22205, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_class_weights
# 6/6 [==============================] - 295s 49s/step - loss: 2.7375 - accuracy: 0.7294 - dice_coefficient: 0.1830 - jaccard_index: 0.1008 - sensitivity: 0.5989 - specificity: 0.7357 - precision: 0.1082 - val_loss: 5.3529 - val_accuracy: 0.7325 - val_dice_coefficient: 0.2221 - val_jaccard_index: 0.1249 - val_sensitivity: 0.5186 - val_specificity: 0.7495 - val_precision: 0.1413
# Epoch 6/50
# 6/6 [==============================] - ETA: 0s - loss: 2.5036 - accuracy: 0.7211 - dice_coefficient: 0.1856 - jaccard_index: 0.1024 - sensitivity: 0.6278 - specificity: 0.7274 - precision: 0.1092
# Epoch 6: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 276s 45s/step - loss: 2.5036 - accuracy: 0.7211 - dice_coefficient: 0.1856 - jaccard_index: 0.1024 - sensitivity: 0.6278 - specificity: 0.7274 - precision: 0.1092 - val_loss: 6.0062 - val_accuracy: 0.7977 - val_dice_coefficient: 0.2219 - val_jaccard_index: 0.1248 - val_sensitivity: 0.3919 - val_specificity: 0.8300 - val_precision: 0.1548
# Epoch 7/50
# 6/6 [==============================] - ETA: 0s - loss: 2.3922 - accuracy: 0.7167 - dice_coefficient: 0.1914 - jaccard_index: 0.1059 - sensitivity: 0.6581 - specificity: 0.7200 - precision: 0.1124
# Epoch 7: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 278s 46s/step - loss: 2.3922 - accuracy: 0.7167 - dice_coefficient: 0.1914 - jaccard_index: 0.1059 - sensitivity: 0.6581 - specificity: 0.7200 - precision: 0.1124 - val_loss: 6.9218 - val_accuracy: 0.8414 - val_dice_coefficient: 0.1970 - val_jaccard_index: 0.1092 - val_sensitivity: 0.2642 - val_specificity: 0.8873 - val_precision: 0.1570
# Epoch 8/50
# 6/6 [==============================] - ETA: 0s - loss: 2.1971 - accuracy: 0.7140 - dice_coefficient: 0.1907 - jaccard_index: 0.1055 - sensitivity: 0.6667 - specificity: 0.7169 - precision: 0.1116
# Epoch 8: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 274s 45s/step - loss: 2.1971 - accuracy: 0.7140 - dice_coefficient: 0.1907 - jaccard_index: 0.1055 - sensitivity: 0.6667 - specificity: 0.7169 - precision: 0.1116 - val_loss: 8.4395 - val_accuracy: 0.8822 - val_dice_coefficient: 0.1330 - val_jaccard_index: 0.0713 - val_sensitivity: 0.1228 - val_specificity: 0.9426 - val_precision: 0.1452
# Epoch 9/50
# 6/6 [==============================] - ETA: 0s - loss: 2.2614 - accuracy: 0.7110 - dice_coefficient: 0.1894 - jaccard_index: 0.1048 - sensitivity: 0.6387 - specificity: 0.7140 - precision: 0.1118
# Epoch 9: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 272s 44s/step - loss: 2.2614 - accuracy: 0.7110 - dice_coefficient: 0.1894 - jaccard_index: 0.1048 - sensitivity: 0.6387 - specificity: 0.7140 - precision: 0.1118 - val_loss: 9.8090 - val_accuracy: 0.9111 - val_dice_coefficient: 0.0673 - val_jaccard_index: 0.0348 - val_sensitivity: 0.0436 - val_specificity: 0.9800 - val_precision: 0.1477
# Epoch 10/50
# 6/6 [==============================] - ETA: 0s - loss: 1.9054 - accuracy: 0.7012 - dice_coefficient: 0.1871 - jaccard_index: 0.1033 - sensitivity: 0.6539 - specificity: 0.7054 - precision: 0.1097
# Epoch 10: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 273s 45s/step - loss: 1.9054 - accuracy: 0.7012 - dice_coefficient: 0.1871 - jaccard_index: 0.1033 - sensitivity: 0.6539 - specificity: 0.7054 - precision: 0.1097 - val_loss: 10.2936 - val_accuracy: 0.9218 - val_dice_coefficient: 0.0357 - val_jaccard_index: 0.0182 - val_sensitivity: 0.0197 - val_specificity: 0.9935 - val_precision: 0.1939
# Epoch 11/50
# 6/6 [==============================] - ETA: 0s - loss: 1.7689 - accuracy: 0.6960 - dice_coefficient: 0.1867 - jaccard_index: 0.1031 - sensitivity: 0.6611 - specificity: 0.6996 - precision: 0.1091
# Epoch 11: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 272s 44s/step - loss: 1.7689 - accuracy: 0.6960 - dice_coefficient: 0.1867 - jaccard_index: 0.1031 - sensitivity: 0.6611 - specificity: 0.6996 - precision: 0.1091 - val_loss: 10.5395 - val_accuracy: 0.9257 - val_dice_coefficient: 0.0149 - val_jaccard_index: 0.0075 - val_sensitivity: 0.0076 - val_specificity: 0.9987 - val_precision: 0.3149
# Epoch 12/50
# 6/6 [==============================] - ETA: 0s - loss: 1.7866 - accuracy: 0.6913 - dice_coefficient: 0.1729 - jaccard_index: 0.0947 - sensitivity: 0.6572 - specificity: 0.6903 - precision: 0.1003
# Epoch 12: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 274s 45s/step - loss: 1.7866 - accuracy: 0.6913 - dice_coefficient: 0.1729 - jaccard_index: 0.0947 - sensitivity: 0.6572 - specificity: 0.6903 - precision: 0.1003 - val_loss: 10.6193 - val_accuracy: 0.9260 - val_dice_coefficient: 0.0045 - val_jaccard_index: 0.0022 - val_sensitivity: 0.0022 - val_specificity: 0.9995 - val_precision: 0.2460
# Epoch 13/50
# 6/6 [==============================] - ETA: 0s - loss: 1.5574 - accuracy: 0.6950 - dice_coefficient: 0.1683 - jaccard_index: 0.0923 - sensitivity: 0.6471 - specificity: 0.6987 - precision: 0.0978
# Epoch 13: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 272s 45s/step - loss: 1.5574 - accuracy: 0.6950 - dice_coefficient: 0.1683 - jaccard_index: 0.0923 - sensitivity: 0.6471 - specificity: 0.6987 - precision: 0.0978 - val_loss: 10.5796 - val_accuracy: 0.9260 - val_dice_coefficient: 0.0041 - val_jaccard_index: 0.0020 - val_sensitivity: 0.0021 - val_specificity: 0.9994 - val_precision: 0.2049
# Epoch 14/50
# 6/6 [==============================] - ETA: 0s - loss: 1.4648 - accuracy: 0.6859 - dice_coefficient: 0.1806 - jaccard_index: 0.0994 - sensitivity: 0.6556 - specificity: 0.6881 - precision: 0.1051
# Epoch 14: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 271s 44s/step - loss: 1.4648 - accuracy: 0.6859 - dice_coefficient: 0.1806 - jaccard_index: 0.0994 - sensitivity: 0.6556 - specificity: 0.6881 - precision: 0.1051 - val_loss: 10.4654 - val_accuracy: 0.9257 - val_dice_coefficient: 0.0053 - val_jaccard_index: 0.0027 - val_sensitivity: 0.0027 - val_specificity: 0.9990 - val_precision: 0.1753
# Epoch 15/50
# 6/6 [==============================] - ETA: 0s - loss: 1.4117 - accuracy: 0.6852 - dice_coefficient: 0.1829 - jaccard_index: 0.1007 - sensitivity: 0.6687 - specificity: 0.6862 - precision: 0.1063
# Epoch 15: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 272s 45s/step - loss: 1.4117 - accuracy: 0.6852 - dice_coefficient: 0.1829 - jaccard_index: 0.1007 - sensitivity: 0.6687 - specificity: 0.6862 - precision: 0.1063 - val_loss: 10.2289 - val_accuracy: 0.9250 - val_dice_coefficient: 0.0076 - val_jaccard_index: 0.0038 - val_sensitivity: 0.0039 - val_specificity: 0.9982 - val_precision: 0.1496
# Epoch 16/50
# 6/6 [==============================] - ETA: 0s - loss: 1.2337 - accuracy: 0.6871 - dice_coefficient: 0.1847 - jaccard_index: 0.1018 - sensitivity: 0.6790 - specificity: 0.6900 - precision: 0.1071
# Epoch 16: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 276s 45s/step - loss: 1.2337 - accuracy: 0.6871 - dice_coefficient: 0.1847 - jaccard_index: 0.1018 - sensitivity: 0.6790 - specificity: 0.6900 - precision: 0.1071 - val_loss: 9.9601 - val_accuracy: 0.9243 - val_dice_coefficient: 0.0118 - val_jaccard_index: 0.0059 - val_sensitivity: 0.0061 - val_specificity: 0.9972 - val_precision: 0.1488
# Epoch 17/50
# 6/6 [==============================] - ETA: 0s - loss: 1.2095 - accuracy: 0.6915 - dice_coefficient: 0.1856 - jaccard_index: 0.1024 - sensitivity: 0.6722 - specificity: 0.6924 - precision: 0.1080
# Epoch 17: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 275s 45s/step - loss: 1.2095 - accuracy: 0.6915 - dice_coefficient: 0.1856 - jaccard_index: 0.1024 - sensitivity: 0.6722 - specificity: 0.6924 - precision: 0.1080 - val_loss: 9.6682 - val_accuracy: 0.9233 - val_dice_coefficient: 0.0170 - val_jaccard_index: 0.0086 - val_sensitivity: 0.0090 - val_specificity: 0.9959 - val_precision: 0.1493
# Epoch 18/50
# 6/6 [==============================] - ETA: 0s - loss: 1.1676 - accuracy: 0.6898 - dice_coefficient: 0.1772 - jaccard_index: 0.0976 - sensitivity: 0.6862 - specificity: 0.6889 - precision: 0.1028
# Epoch 18: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 272s 44s/step - loss: 1.1676 - accuracy: 0.6898 - dice_coefficient: 0.1772 - jaccard_index: 0.0976 - sensitivity: 0.6862 - specificity: 0.6889 - precision: 0.1028 - val_loss: 9.3897 - val_accuracy: 0.9225 - val_dice_coefficient: 0.0223 - val_jaccard_index: 0.0113 - val_sensitivity: 0.0120 - val_specificity: 0.9948 - val_precision: 0.1562
# Epoch 19/50
# 6/6 [==============================] - ETA: 0s - loss: 1.1014 - accuracy: 0.6851 - dice_coefficient: 0.1800 - jaccard_index: 0.0989 - sensitivity: 0.6753 - specificity: 0.6877 - precision: 0.1042
# Epoch 19: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 270s 44s/step - loss: 1.1014 - accuracy: 0.6851 - dice_coefficient: 0.1800 - jaccard_index: 0.0989 - sensitivity: 0.6753 - specificity: 0.6877 - precision: 0.1042 - val_loss: 9.0790 - val_accuracy: 0.9217 - val_dice_coefficient: 0.0279 - val_jaccard_index: 0.0142 - val_sensitivity: 0.0153 - val_specificity: 0.9937 - val_precision: 0.1619
# Epoch 20/50
# 6/6 [==============================] - ETA: 0s - loss: 1.0741 - accuracy: 0.6868 - dice_coefficient: 0.1831 - jaccard_index: 0.1009 - sensitivity: 0.6594 - specificity: 0.6928 - precision: 0.1066
# Epoch 20: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 278s 46s/step - loss: 1.0741 - accuracy: 0.6868 - dice_coefficient: 0.1831 - jaccard_index: 0.1009 - sensitivity: 0.6594 - specificity: 0.6928 - precision: 0.1066 - val_loss: 8.7013 - val_accuracy: 0.9205 - val_dice_coefficient: 0.0353 - val_jaccard_index: 0.0180 - val_sensitivity: 0.0198 - val_specificity: 0.9920 - val_precision: 0.1650
# Epoch 21/50
# 6/6 [==============================] - ETA: 0s - loss: 1.0275 - accuracy: 0.6878 - dice_coefficient: 0.1801 - jaccard_index: 0.0991 - sensitivity: 0.6652 - specificity: 0.6866 - precision: 0.1048
# Epoch 21: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 275s 45s/step - loss: 1.0275 - accuracy: 0.6878 - dice_coefficient: 0.1801 - jaccard_index: 0.0991 - sensitivity: 0.6652 - specificity: 0.6866 - precision: 0.1048 - val_loss: 8.2160 - val_accuracy: 0.9185 - val_dice_coefficient: 0.0459 - val_jaccard_index: 0.0235 - val_sensitivity: 0.0266 - val_specificity: 0.9893 - val_precision: 0.1656
# Epoch 22/50
# 6/6 [==============================] - ETA: 0s - loss: 0.9991 - accuracy: 0.6782 - dice_coefficient: 0.1774 - jaccard_index: 0.0974 - sensitivity: 0.6340 - specificity: 0.6915 - precision: 0.1047
# Epoch 22: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 274s 45s/step - loss: 0.9991 - accuracy: 0.6782 - dice_coefficient: 0.1774 - jaccard_index: 0.0974 - sensitivity: 0.6340 - specificity: 0.6915 - precision: 0.1047 - val_loss: 7.7459 - val_accuracy: 0.9167 - val_dice_coefficient: 0.0566 - val_jaccard_index: 0.0291 - val_sensitivity: 0.0339 - val_specificity: 0.9869 - val_precision: 0.1706
# Epoch 23/50
# 6/6 [==============================] - ETA: 0s - loss: 0.9491 - accuracy: 0.6855 - dice_coefficient: 0.1679 - jaccard_index: 0.0920 - sensitivity: 0.6668 - specificity: 0.6812 - precision: 0.0973 Restoring model weights from the end of the best epoch: 13.
#
# Epoch 23: val_dice_coefficient did not improve from 0.22205
# 6/6 [==============================] - 270s 44s/step - loss: 0.9491 - accuracy: 0.6855 - dice_coefficient: 0.1679 - jaccard_index: 0.0920 - sensitivity: 0.6668 - specificity: 0.6812 - precision: 0.0973 - val_loss: 7.1584 - val_accuracy: 0.9139 - val_dice_coefficient: 0.0693 - val_jaccard_index: 0.0359 - val_sensitivity: 0.0435 - val_specificity: 0.9831 - val_precision: 0.1696
# Epoch 23: early stopping
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Evaluate

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title('True Mask')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > 0.5, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title('Predicted Mask')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred):
    # Flattening the masks
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > 0.5).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    # Adding labels for each quadrant
    labels = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    # Position labels in the center of each quadrant
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix with Detailed Annotations')
    plt.show()


# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred)
plot_confusion_matrix(y_test, y_pred)
print(classification_report(y_test.flatten(), (y_pred.flatten() > 0.25).astype(int)))
# Out:
# 2/2 [==============================] - 17s 6s/step
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.97   2970502
#          1.0       0.07      0.01      0.02    175226
#
#     accuracy                           0.94   3145728
#    macro avg       0.51      0.50      0.49   3145728
# weighted avg       0.90      0.94      0.91   3145728
