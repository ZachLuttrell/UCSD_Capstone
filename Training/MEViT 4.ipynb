# %% [markdown]
# # MEViT
#
# This is the 4th iteration of MEViT. In this one I will remove early stopping altogether since this architecture seems to train relatively fast.
#
# **NOTE:** Connect to a High-RAM Environment

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# MODEL SETTINGS
model_name = 'mevit_model_4'
percentage_to_load = 50 / 100.0  # Set the % of dataset to be loaded here.
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load}')
# Out:
# Model Name: mevit_model_4
# Percentage to Load: 0.5

# %% [markdown]
# Imports

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(image_files[:number_of_files_to_load], start=1):
    img_path = os.path.join(image_directory, image_name)
    mask_name = image_to_mask[image_name]
    mask_path = os.path.join(mask_directory, mask_name)

    if os.path.exists(mask_path):
        img = tiff.imread(img_path)
        mask = tiff.imread(mask_path)

        images.append(img)
        masks.append(mask)
    else:
        print(f'\nMask not found for image: {image_name}')

    # Update the count in the same line
    print(f'\rProcessed: {count}/{number_of_files_to_load}', end='')

print("\nLoading complete.")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 50.0% of dataset: 2393 images/mask pairs...
# Processed: 2393/2393
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If there is an unnecessary singleton dimension in your dataset, remove it:
if X_train.ndim > 3:
    X_train = X_train.squeeze(axis=1)
    X_val = X_val.squeeze(axis=1)
    X_test = X_test.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (1722, 256, 256, 3), y_train: (1722, 256, 256, 1)
# X_val:   (192, 256, 256, 3), y_val: (192, 256, 256, 1)
# X_test:  (479, 256, 256, 3), y_test: (479, 256, 256, 1)

# %% [markdown]
# Model Definition

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler

# Custom Metrics
def dice_coefficient(y_true, y_pred, threshold=0.5):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

def jaccard_index(y_true, y_pred, threshold=0.5):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# Loss Function
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)
weighted_loss = weighted_binary_crossentropy(class_weights)

# Define the MEVit model
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = models.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim):
    inputs = layers.Input(shape=input_shape)
    # Flatten the input
    x = layers.Reshape((-1, input_shape[-1]))(inputs)

    # Create patches and embed
    patch_size = 16
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    patches = layers.Conv2D(filters=embed_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    patches = layers.Reshape((num_patches, embed_dim))(patches)

    # Add Transformer blocks
    for _ in range(8):
        patches = TransformerBlock(embed_dim, num_heads, ff_dim)(patches)

    # Reshape back to image
    x = layers.Reshape((input_shape[0] // patch_size, input_shape[1] // patch_size, embed_dim))(patches)
    x = Conv2DTranspose(num_classes, kernel_size=patch_size, strides=patch_size, padding="valid")(x)
    outputs = layers.Activation('sigmoid')(x)

    return Model(inputs, outputs)
# Out:
# Class weights: {0: 0.5339968946194886, 1: 7.853612816644959}

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

input_shape = (256, 256, 3)
num_classes = 1
embed_dim = 64
num_heads = 4
ff_dim = 128

model = create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim)
model._name = model_name
model.summary()

# Learning rate schedule
def lr_schedule(epoch, lr):
    if epoch >= 40 and epoch < 60:
        return lr * 0.1
    elif epoch >= 60:
        return lr * 0.1
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# Compile the model
sgd = SGD(learning_rate=0.1, momentum=0.9)
model.compile(
    optimizer=sgd,
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

# Setup callbacks
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=70,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)
# Out:
# Model: "mevit_model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 16, 16, 64)        49216
#
#  reshape_1 (Reshape)         (None, 256, 64)           0
#
#  transformer_block (Transfo  (None, 256, 64)           83200
#  rmerBlock)
#
#  transformer_block_1 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_2 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_3 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_4 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_5 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_6 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  transformer_block_7 (Trans  (None, 256, 64)           83200
#  formerBlock)
#
#  reshape_2 (Reshape)         (None, 16, 16, 64)        0
#
#  conv2d_transpose (Conv2DTr  (None, 256, 256, 1)       16385
#  anspose)
#
#  activation (Activation)     (None, 256, 256, 1)       0
#
# =================================================================
# Total params: 731201 (2.79 MB)
# Trainable params: 731201 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=16,
    epochs=70,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping, lr_scheduler]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5413 - dice_coefficient: 0.1037 - jaccard_index: 0.0554 - sensitivity: 0.4785 - specificity: 0.5450 - precision: 0.0675
# Epoch 1: val_dice_coefficient improved from -inf to 0.11926, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 106s 892ms/step - loss: 0.6935 - accuracy: 0.5413 - dice_coefficient: 0.1037 - jaccard_index: 0.0554 - sensitivity: 0.4785 - specificity: 0.5450 - precision: 0.0675 - val_loss: 0.6834 - val_accuracy: 0.0947 - val_dice_coefficient: 0.1193 - val_jaccard_index: 0.0635 - val_sensitivity: 0.9929 - val_specificity: 0.0356 - val_precision: 0.0636 - lr: 0.1000
# Epoch 2/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6755 - accuracy: 0.5128 - dice_coefficient: 0.1473 - jaccard_index: 0.0800 - sensitivity: 0.6510 - specificity: 0.5043 - precision: 0.0909
# Epoch 2: val_dice_coefficient improved from 0.11926 to 0.16543, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 95s 881ms/step - loss: 0.6755 - accuracy: 0.5128 - dice_coefficient: 0.1473 - jaccard_index: 0.0800 - sensitivity: 0.6510 - specificity: 0.5043 - precision: 0.0909 - val_loss: 0.6485 - val_accuracy: 0.6375 - val_dice_coefficient: 0.1654 - val_jaccard_index: 0.0904 - val_sensitivity: 0.5890 - val_specificity: 0.6409 - val_precision: 0.0967 - lr: 0.1000
# Epoch 3/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6514 - accuracy: 0.6315 - dice_coefficient: 0.1753 - jaccard_index: 0.0966 - sensitivity: 0.6057 - specificity: 0.6336 - precision: 0.1059
# Epoch 3: val_dice_coefficient improved from 0.16543 to 0.18205, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 95s 882ms/step - loss: 0.6514 - accuracy: 0.6315 - dice_coefficient: 0.1753 - jaccard_index: 0.0966 - sensitivity: 0.6057 - specificity: 0.6336 - precision: 0.1059 - val_loss: 0.6317 - val_accuracy: 0.7054 - val_dice_coefficient: 0.1820 - val_jaccard_index: 0.1004 - val_sensitivity: 0.5381 - val_specificity: 0.7168 - val_precision: 0.1104 - lr: 0.1000
# Epoch 4/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6325 - accuracy: 0.6336 - dice_coefficient: 0.1900 - jaccard_index: 0.1055 - sensitivity: 0.6559 - specificity: 0.6327 - precision: 0.1143
# Epoch 4: val_dice_coefficient improved from 0.18205 to 0.19028, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 99s 915ms/step - loss: 0.6325 - accuracy: 0.6336 - dice_coefficient: 0.1900 - jaccard_index: 0.1055 - sensitivity: 0.6559 - specificity: 0.6327 - precision: 0.1143 - val_loss: 0.6291 - val_accuracy: 0.7322 - val_dice_coefficient: 0.1903 - val_jaccard_index: 0.1054 - val_sensitivity: 0.5124 - val_specificity: 0.7469 - val_precision: 0.1179 - lr: 0.1000
# Epoch 5/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6352 - accuracy: 0.5975 - dice_coefficient: 0.1831 - jaccard_index: 0.1014 - sensitivity: 0.6783 - specificity: 0.5932 - precision: 0.1107
# Epoch 5: val_dice_coefficient did not improve from 0.19028
# 108/108 [==============================] - 83s 773ms/step - loss: 0.6352 - accuracy: 0.5975 - dice_coefficient: 0.1831 - jaccard_index: 0.1014 - sensitivity: 0.6783 - specificity: 0.5932 - precision: 0.1107 - val_loss: 0.6326 - val_accuracy: 0.6872 - val_dice_coefficient: 0.1868 - val_jaccard_index: 0.1033 - val_sensitivity: 0.5853 - val_specificity: 0.6944 - val_precision: 0.1121 - lr: 0.1000
# Epoch 6/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.6125 - dice_coefficient: 0.1938 - jaccard_index: 0.1079 - sensitivity: 0.7094 - specificity: 0.6054 - precision: 0.1147
# Epoch 6: val_dice_coefficient did not improve from 0.19028
# 108/108 [==============================] - 85s 789ms/step - loss: 0.6147 - accuracy: 0.6125 - dice_coefficient: 0.1938 - jaccard_index: 0.1079 - sensitivity: 0.7094 - specificity: 0.6054 - precision: 0.1147 - val_loss: 0.6034 - val_accuracy: 0.6815 - val_dice_coefficient: 0.1835 - val_jaccard_index: 0.1013 - val_sensitivity: 0.5841 - val_specificity: 0.6884 - val_precision: 0.1099 - lr: 0.1000
# Epoch 7/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.6243 - dice_coefficient: 0.1935 - jaccard_index: 0.1078 - sensitivity: 0.6853 - specificity: 0.6207 - precision: 0.1155
# Epoch 7: val_dice_coefficient did not improve from 0.19028
# 108/108 [==============================] - 83s 768ms/step - loss: 0.6181 - accuracy: 0.6243 - dice_coefficient: 0.1935 - jaccard_index: 0.1078 - sensitivity: 0.6853 - specificity: 0.6207 - precision: 0.1155 - val_loss: 0.6442 - val_accuracy: 0.7450 - val_dice_coefficient: 0.1765 - val_jaccard_index: 0.0972 - val_sensitivity: 0.4546 - val_specificity: 0.7645 - val_precision: 0.1108 - lr: 0.1000
# Epoch 8/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6293 - accuracy: 0.6110 - dice_coefficient: 0.1815 - jaccard_index: 0.1005 - sensitivity: 0.6604 - specificity: 0.6085 - precision: 0.1077
# Epoch 8: val_dice_coefficient improved from 0.19028 to 0.19759, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 93s 866ms/step - loss: 0.6293 - accuracy: 0.6110 - dice_coefficient: 0.1815 - jaccard_index: 0.1005 - sensitivity: 0.6604 - specificity: 0.6085 - precision: 0.1077 - val_loss: 0.6294 - val_accuracy: 0.7446 - val_dice_coefficient: 0.1976 - val_jaccard_index: 0.1098 - val_sensitivity: 0.5156 - val_specificity: 0.7600 - val_precision: 0.1233 - lr: 0.1000
# Epoch 9/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6101 - accuracy: 0.6179 - dice_coefficient: 0.1953 - jaccard_index: 0.1091 - sensitivity: 0.7110 - specificity: 0.6124 - precision: 0.1158
# Epoch 9: val_dice_coefficient did not improve from 0.19759
# 108/108 [==============================] - 82s 758ms/step - loss: 0.6101 - accuracy: 0.6179 - dice_coefficient: 0.1953 - jaccard_index: 0.1091 - sensitivity: 0.7110 - specificity: 0.6124 - precision: 0.1158 - val_loss: 0.6086 - val_accuracy: 0.6777 - val_dice_coefficient: 0.1906 - val_jaccard_index: 0.1056 - val_sensitivity: 0.6170 - val_specificity: 0.6821 - val_precision: 0.1135 - lr: 0.1000
# Epoch 10/70
# 108/108 [==============================] - ETA: 0s - loss: 0.6033 - accuracy: 0.6111 - dice_coefficient: 0.1963 - jaccard_index: 0.1094 - sensitivity: 0.7308 - specificity: 0.6023 - precision: 0.1153
# Epoch 10: val_dice_coefficient did not improve from 0.19759
# 108/108 [==============================] - 84s 775ms/step - loss: 0.6033 - accuracy: 0.6111 - dice_coefficient: 0.1963 - jaccard_index: 0.1094 - sensitivity: 0.7308 - specificity: 0.6023 - precision: 0.1153 - val_loss: 0.5937 - val_accuracy: 0.5496 - val_dice_coefficient: 0.1808 - val_jaccard_index: 0.0996 - val_sensitivity: 0.8075 - val_specificity: 0.5328 - val_precision: 0.1022 - lr: 0.1000
# Epoch 11/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5940 - accuracy: 0.6243 - dice_coefficient: 0.1997 - jaccard_index: 0.1115 - sensitivity: 0.7301 - specificity: 0.6165 - precision: 0.1170
# Epoch 11: val_dice_coefficient did not improve from 0.19759
# 108/108 [==============================] - 83s 767ms/step - loss: 0.5940 - accuracy: 0.6243 - dice_coefficient: 0.1997 - jaccard_index: 0.1115 - sensitivity: 0.7301 - specificity: 0.6165 - precision: 0.1170 - val_loss: 0.5818 - val_accuracy: 0.5582 - val_dice_coefficient: 0.1857 - val_jaccard_index: 0.1027 - val_sensitivity: 0.8150 - val_specificity: 0.5416 - val_precision: 0.1053 - lr: 0.1000
# Epoch 12/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5963 - accuracy: 0.6276 - dice_coefficient: 0.2017 - jaccard_index: 0.1129 - sensitivity: 0.7227 - specificity: 0.6208 - precision: 0.1199
# Epoch 12: val_dice_coefficient improved from 0.19759 to 0.20582, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 94s 874ms/step - loss: 0.5963 - accuracy: 0.6276 - dice_coefficient: 0.2017 - jaccard_index: 0.1129 - sensitivity: 0.7227 - specificity: 0.6208 - precision: 0.1199 - val_loss: 0.6085 - val_accuracy: 0.7613 - val_dice_coefficient: 0.2058 - val_jaccard_index: 0.1150 - val_sensitivity: 0.5099 - val_specificity: 0.7786 - val_precision: 0.1305 - lr: 0.1000
# Epoch 13/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5933 - accuracy: 0.6458 - dice_coefficient: 0.2053 - jaccard_index: 0.1151 - sensitivity: 0.7107 - specificity: 0.6409 - precision: 0.1219
# Epoch 13: val_dice_coefficient did not improve from 0.20582
# 108/108 [==============================] - 83s 765ms/step - loss: 0.5933 - accuracy: 0.6458 - dice_coefficient: 0.2053 - jaccard_index: 0.1151 - sensitivity: 0.7107 - specificity: 0.6409 - precision: 0.1219 - val_loss: 0.5798 - val_accuracy: 0.5561 - val_dice_coefficient: 0.1883 - val_jaccard_index: 0.1043 - val_sensitivity: 0.8336 - val_specificity: 0.5380 - val_precision: 0.1066 - lr: 0.1000
# Epoch 14/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5882 - accuracy: 0.6277 - dice_coefficient: 0.2056 - jaccard_index: 0.1153 - sensitivity: 0.7371 - specificity: 0.6206 - precision: 0.1216
# Epoch 14: val_dice_coefficient did not improve from 0.20582
# 108/108 [==============================] - 83s 770ms/step - loss: 0.5882 - accuracy: 0.6277 - dice_coefficient: 0.2056 - jaccard_index: 0.1153 - sensitivity: 0.7371 - specificity: 0.6206 - precision: 0.1216 - val_loss: 0.6166 - val_accuracy: 0.7424 - val_dice_coefficient: 0.1896 - val_jaccard_index: 0.1052 - val_sensitivity: 0.5015 - val_specificity: 0.7586 - val_precision: 0.1183 - lr: 0.1000
# Epoch 15/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5958 - accuracy: 0.6554 - dice_coefficient: 0.2053 - jaccard_index: 0.1151 - sensitivity: 0.6896 - specificity: 0.6534 - precision: 0.1231
# Epoch 15: val_dice_coefficient did not improve from 0.20582
# 108/108 [==============================] - 83s 770ms/step - loss: 0.5958 - accuracy: 0.6554 - dice_coefficient: 0.2053 - jaccard_index: 0.1151 - sensitivity: 0.6896 - specificity: 0.6534 - precision: 0.1231 - val_loss: 0.5828 - val_accuracy: 0.6653 - val_dice_coefficient: 0.1995 - val_jaccard_index: 0.1111 - val_sensitivity: 0.6795 - val_specificity: 0.6649 - val_precision: 0.1176 - lr: 0.1000
# Epoch 16/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5884 - accuracy: 0.6394 - dice_coefficient: 0.2059 - jaccard_index: 0.1153 - sensitivity: 0.7224 - specificity: 0.6332 - precision: 0.1219
# Epoch 16: val_dice_coefficient did not improve from 0.20582
# 108/108 [==============================] - 83s 770ms/step - loss: 0.5884 - accuracy: 0.6394 - dice_coefficient: 0.2059 - jaccard_index: 0.1153 - sensitivity: 0.7224 - specificity: 0.6332 - precision: 0.1219 - val_loss: 0.5763 - val_accuracy: 0.6312 - val_dice_coefficient: 0.1971 - val_jaccard_index: 0.1097 - val_sensitivity: 0.7375 - val_specificity: 0.6248 - val_precision: 0.1145 - lr: 0.1000
# Epoch 17/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.6477 - dice_coefficient: 0.2113 - jaccard_index: 0.1188 - sensitivity: 0.7277 - specificity: 0.6421 - precision: 0.1253
# Epoch 17: val_dice_coefficient improved from 0.20582 to 0.22510, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 93s 863ms/step - loss: 0.5796 - accuracy: 0.6477 - dice_coefficient: 0.2113 - jaccard_index: 0.1188 - sensitivity: 0.7277 - specificity: 0.6421 - precision: 0.1253 - val_loss: 0.5827 - val_accuracy: 0.7645 - val_dice_coefficient: 0.2251 - val_jaccard_index: 0.1271 - val_sensitivity: 0.5638 - val_specificity: 0.7782 - val_precision: 0.1417 - lr: 0.1000
# Epoch 18/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5880 - accuracy: 0.6427 - dice_coefficient: 0.2070 - jaccard_index: 0.1161 - sensitivity: 0.7191 - specificity: 0.6372 - precision: 0.1226
# Epoch 18: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 751ms/step - loss: 0.5880 - accuracy: 0.6427 - dice_coefficient: 0.2070 - jaccard_index: 0.1161 - sensitivity: 0.7191 - specificity: 0.6372 - precision: 0.1226 - val_loss: 0.5826 - val_accuracy: 0.7277 - val_dice_coefficient: 0.2109 - val_jaccard_index: 0.1181 - val_sensitivity: 0.5963 - val_specificity: 0.7367 - val_precision: 0.1294 - lr: 0.1000
# Epoch 19/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5814 - accuracy: 0.6537 - dice_coefficient: 0.2127 - jaccard_index: 0.1197 - sensitivity: 0.7262 - specificity: 0.6486 - precision: 0.1265
# Epoch 19: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 754ms/step - loss: 0.5814 - accuracy: 0.6537 - dice_coefficient: 0.2127 - jaccard_index: 0.1197 - sensitivity: 0.7262 - specificity: 0.6486 - precision: 0.1265 - val_loss: 0.5658 - val_accuracy: 0.6853 - val_dice_coefficient: 0.2130 - val_jaccard_index: 0.1196 - val_sensitivity: 0.6897 - val_specificity: 0.6852 - val_precision: 0.1268 - lr: 0.1000
# Epoch 20/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5880 - accuracy: 0.6531 - dice_coefficient: 0.2094 - jaccard_index: 0.1177 - sensitivity: 0.7061 - specificity: 0.6493 - precision: 0.1259
# Epoch 20: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 752ms/step - loss: 0.5880 - accuracy: 0.6531 - dice_coefficient: 0.2094 - jaccard_index: 0.1177 - sensitivity: 0.7061 - specificity: 0.6493 - precision: 0.1259 - val_loss: 0.5726 - val_accuracy: 0.6794 - val_dice_coefficient: 0.2111 - val_jaccard_index: 0.1183 - val_sensitivity: 0.6967 - val_specificity: 0.6786 - val_precision: 0.1251 - lr: 0.1000
# Epoch 21/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5815 - accuracy: 0.6510 - dice_coefficient: 0.2090 - jaccard_index: 0.1174 - sensitivity: 0.7167 - specificity: 0.6463 - precision: 0.1242
# Epoch 21: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 80s 745ms/step - loss: 0.5815 - accuracy: 0.6510 - dice_coefficient: 0.2090 - jaccard_index: 0.1174 - sensitivity: 0.7167 - specificity: 0.6463 - precision: 0.1242 - val_loss: 0.5776 - val_accuracy: 0.7806 - val_dice_coefficient: 0.2241 - val_jaccard_index: 0.1267 - val_sensitivity: 0.5279 - val_specificity: 0.7978 - val_precision: 0.1444 - lr: 0.1000
# Epoch 22/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5765 - accuracy: 0.6764 - dice_coefficient: 0.2203 - jaccard_index: 0.1245 - sensitivity: 0.7097 - specificity: 0.6734 - precision: 0.1328
# Epoch 22: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 751ms/step - loss: 0.5765 - accuracy: 0.6764 - dice_coefficient: 0.2203 - jaccard_index: 0.1245 - sensitivity: 0.7097 - specificity: 0.6734 - precision: 0.1328 - val_loss: 0.5797 - val_accuracy: 0.5257 - val_dice_coefficient: 0.1852 - val_jaccard_index: 0.1024 - val_sensitivity: 0.8712 - val_specificity: 0.5030 - val_precision: 0.1040 - lr: 0.1000
# Epoch 23/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.6482 - dice_coefficient: 0.2127 - jaccard_index: 0.1196 - sensitivity: 0.7452 - specificity: 0.6410 - precision: 0.1253
# Epoch 23: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 755ms/step - loss: 0.5688 - accuracy: 0.6482 - dice_coefficient: 0.2127 - jaccard_index: 0.1196 - sensitivity: 0.7452 - specificity: 0.6410 - precision: 0.1253 - val_loss: 0.5587 - val_accuracy: 0.6566 - val_dice_coefficient: 0.2093 - val_jaccard_index: 0.1173 - val_sensitivity: 0.7363 - val_specificity: 0.6515 - val_precision: 0.1226 - lr: 0.1000
# Epoch 24/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5715 - accuracy: 0.6695 - dice_coefficient: 0.2215 - jaccard_index: 0.1253 - sensitivity: 0.7140 - specificity: 0.6661 - precision: 0.1339
# Epoch 24: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 750ms/step - loss: 0.5715 - accuracy: 0.6695 - dice_coefficient: 0.2215 - jaccard_index: 0.1253 - sensitivity: 0.7140 - specificity: 0.6661 - precision: 0.1339 - val_loss: 0.5874 - val_accuracy: 0.7262 - val_dice_coefficient: 0.2126 - val_jaccard_index: 0.1191 - val_sensitivity: 0.6084 - val_specificity: 0.7343 - val_precision: 0.1296 - lr: 0.1000
# Epoch 25/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5782 - accuracy: 0.6708 - dice_coefficient: 0.2179 - jaccard_index: 0.1230 - sensitivity: 0.7057 - specificity: 0.6675 - precision: 0.1314
# Epoch 25: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 750ms/step - loss: 0.5782 - accuracy: 0.6708 - dice_coefficient: 0.2179 - jaccard_index: 0.1230 - sensitivity: 0.7057 - specificity: 0.6675 - precision: 0.1314 - val_loss: 0.5835 - val_accuracy: 0.5373 - val_dice_coefficient: 0.1857 - val_jaccard_index: 0.1026 - val_sensitivity: 0.8578 - val_specificity: 0.5161 - val_precision: 0.1045 - lr: 0.1000
# Epoch 26/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5660 - accuracy: 0.6628 - dice_coefficient: 0.2183 - jaccard_index: 0.1233 - sensitivity: 0.7280 - specificity: 0.6574 - precision: 0.1305
# Epoch 26: val_dice_coefficient did not improve from 0.22510
# 108/108 [==============================] - 81s 747ms/step - loss: 0.5660 - accuracy: 0.6628 - dice_coefficient: 0.2183 - jaccard_index: 0.1233 - sensitivity: 0.7280 - specificity: 0.6574 - precision: 0.1305 - val_loss: 0.5580 - val_accuracy: 0.5735 - val_dice_coefficient: 0.1962 - val_jaccard_index: 0.1091 - val_sensitivity: 0.8437 - val_specificity: 0.5559 - val_precision: 0.1115 - lr: 0.1000
# Epoch 27/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5597 - accuracy: 0.6691 - dice_coefficient: 0.2245 - jaccard_index: 0.1271 - sensitivity: 0.7418 - specificity: 0.6640 - precision: 0.1338
# Epoch 27: val_dice_coefficient improved from 0.22510 to 0.24778, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 93s 864ms/step - loss: 0.5597 - accuracy: 0.6691 - dice_coefficient: 0.2245 - jaccard_index: 0.1271 - sensitivity: 0.7418 - specificity: 0.6640 - precision: 0.1338 - val_loss: 0.5582 - val_accuracy: 0.7774 - val_dice_coefficient: 0.2478 - val_jaccard_index: 0.1417 - val_sensitivity: 0.6039 - val_specificity: 0.7891 - val_precision: 0.1573 - lr: 0.1000
# Epoch 28/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5585 - accuracy: 0.6841 - dice_coefficient: 0.2295 - jaccard_index: 0.1304 - sensitivity: 0.7294 - specificity: 0.6804 - precision: 0.1381
# Epoch 28: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 80s 744ms/step - loss: 0.5585 - accuracy: 0.6841 - dice_coefficient: 0.2295 - jaccard_index: 0.1304 - sensitivity: 0.7294 - specificity: 0.6804 - precision: 0.1381 - val_loss: 0.5621 - val_accuracy: 0.5671 - val_dice_coefficient: 0.1955 - val_jaccard_index: 0.1087 - val_sensitivity: 0.8510 - val_specificity: 0.5484 - val_precision: 0.1108 - lr: 0.1000
# Epoch 29/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5579 - accuracy: 0.6667 - dice_coefficient: 0.2252 - jaccard_index: 0.1275 - sensitivity: 0.7525 - specificity: 0.6597 - precision: 0.1343
# Epoch 29: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 81s 754ms/step - loss: 0.5579 - accuracy: 0.6667 - dice_coefficient: 0.2252 - jaccard_index: 0.1275 - sensitivity: 0.7525 - specificity: 0.6597 - precision: 0.1343 - val_loss: 0.5495 - val_accuracy: 0.6297 - val_dice_coefficient: 0.2100 - val_jaccard_index: 0.1177 - val_sensitivity: 0.7958 - val_specificity: 0.6188 - val_precision: 0.1215 - lr: 0.1000
# Epoch 30/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5609 - accuracy: 0.6762 - dice_coefficient: 0.2258 - jaccard_index: 0.1280 - sensitivity: 0.7373 - specificity: 0.6719 - precision: 0.1357
# Epoch 30: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 83s 768ms/step - loss: 0.5609 - accuracy: 0.6762 - dice_coefficient: 0.2258 - jaccard_index: 0.1280 - sensitivity: 0.7373 - specificity: 0.6719 - precision: 0.1357 - val_loss: 0.5609 - val_accuracy: 0.7066 - val_dice_coefficient: 0.2229 - val_jaccard_index: 0.1259 - val_sensitivity: 0.6807 - val_specificity: 0.7085 - val_precision: 0.1342 - lr: 0.1000
# Epoch 31/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5564 - accuracy: 0.6742 - dice_coefficient: 0.2290 - jaccard_index: 0.1300 - sensitivity: 0.7476 - specificity: 0.6685 - precision: 0.1373
# Epoch 31: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 82s 761ms/step - loss: 0.5564 - accuracy: 0.6742 - dice_coefficient: 0.2290 - jaccard_index: 0.1300 - sensitivity: 0.7476 - specificity: 0.6685 - precision: 0.1373 - val_loss: 0.5628 - val_accuracy: 0.5917 - val_dice_coefficient: 0.1976 - val_jaccard_index: 0.1101 - val_sensitivity: 0.8111 - val_specificity: 0.5771 - val_precision: 0.1131 - lr: 0.1000
# Epoch 32/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5460 - accuracy: 0.6902 - dice_coefficient: 0.2376 - jaccard_index: 0.1354 - sensitivity: 0.7486 - specificity: 0.6854 - precision: 0.1428
# Epoch 32: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 80s 743ms/step - loss: 0.5460 - accuracy: 0.6902 - dice_coefficient: 0.2376 - jaccard_index: 0.1354 - sensitivity: 0.7486 - specificity: 0.6854 - precision: 0.1428 - val_loss: 0.5201 - val_accuracy: 0.7072 - val_dice_coefficient: 0.2437 - val_jaccard_index: 0.1390 - val_sensitivity: 0.7695 - val_specificity: 0.7029 - val_precision: 0.1454 - lr: 0.1000
# Epoch 33/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5566 - accuracy: 0.6727 - dice_coefficient: 0.2281 - jaccard_index: 0.1294 - sensitivity: 0.7501 - specificity: 0.6671 - precision: 0.1366
# Epoch 33: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 82s 756ms/step - loss: 0.5566 - accuracy: 0.6727 - dice_coefficient: 0.2281 - jaccard_index: 0.1294 - sensitivity: 0.7501 - specificity: 0.6671 - precision: 0.1366 - val_loss: 0.5483 - val_accuracy: 0.6079 - val_dice_coefficient: 0.2112 - val_jaccard_index: 0.1185 - val_sensitivity: 0.8483 - val_specificity: 0.5922 - val_precision: 0.1212 - lr: 0.1000
# Epoch 34/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5505 - accuracy: 0.6774 - dice_coefficient: 0.2330 - jaccard_index: 0.1326 - sensitivity: 0.7584 - specificity: 0.6706 - precision: 0.1393
# Epoch 34: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 81s 749ms/step - loss: 0.5505 - accuracy: 0.6774 - dice_coefficient: 0.2330 - jaccard_index: 0.1326 - sensitivity: 0.7584 - specificity: 0.6706 - precision: 0.1393 - val_loss: 0.5555 - val_accuracy: 0.6141 - val_dice_coefficient: 0.2091 - val_jaccard_index: 0.1171 - val_sensitivity: 0.8264 - val_specificity: 0.6000 - val_precision: 0.1203 - lr: 0.1000
# Epoch 35/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5397 - accuracy: 0.6944 - dice_coefficient: 0.2425 - jaccard_index: 0.1387 - sensitivity: 0.7519 - specificity: 0.6897 - precision: 0.1466
# Epoch 35: val_dice_coefficient did not improve from 0.24778
# 108/108 [==============================] - 81s 748ms/step - loss: 0.5397 - accuracy: 0.6944 - dice_coefficient: 0.2425 - jaccard_index: 0.1387 - sensitivity: 0.7519 - specificity: 0.6897 - precision: 0.1466 - val_loss: 0.5269 - val_accuracy: 0.6755 - val_dice_coefficient: 0.2320 - val_jaccard_index: 0.1316 - val_sensitivity: 0.8007 - val_specificity: 0.6672 - val_precision: 0.1363 - lr: 0.1000
# Epoch 36/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5424 - accuracy: 0.6836 - dice_coefficient: 0.2391 - jaccard_index: 0.1365 - sensitivity: 0.7644 - specificity: 0.6773 - precision: 0.1435
# Epoch 36: val_dice_coefficient improved from 0.24778 to 0.27070, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_4
# 108/108 [==============================] - 92s 852ms/step - loss: 0.5424 - accuracy: 0.6836 - dice_coefficient: 0.2391 - jaccard_index: 0.1365 - sensitivity: 0.7644 - specificity: 0.6773 - precision: 0.1435 - val_loss: 0.5238 - val_accuracy: 0.7659 - val_dice_coefficient: 0.2707 - val_jaccard_index: 0.1569 - val_sensitivity: 0.7053 - val_specificity: 0.7694 - val_precision: 0.1681 - lr: 0.1000
# Epoch 37/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5433 - accuracy: 0.6900 - dice_coefficient: 0.2414 - jaccard_index: 0.1379 - sensitivity: 0.7639 - specificity: 0.6833 - precision: 0.1454
# Epoch 37: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 80s 744ms/step - loss: 0.5433 - accuracy: 0.6900 - dice_coefficient: 0.2414 - jaccard_index: 0.1379 - sensitivity: 0.7639 - specificity: 0.6833 - precision: 0.1454 - val_loss: 0.5239 - val_accuracy: 0.7601 - val_dice_coefficient: 0.2647 - val_jaccard_index: 0.1528 - val_sensitivity: 0.7048 - val_specificity: 0.7634 - val_precision: 0.1637 - lr: 0.1000
# Epoch 38/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5382 - accuracy: 0.6973 - dice_coefficient: 0.2464 - jaccard_index: 0.1411 - sensitivity: 0.7610 - specificity: 0.6926 - precision: 0.1491
# Epoch 38: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 764ms/step - loss: 0.5382 - accuracy: 0.6973 - dice_coefficient: 0.2464 - jaccard_index: 0.1411 - sensitivity: 0.7610 - specificity: 0.6926 - precision: 0.1491 - val_loss: 0.5112 - val_accuracy: 0.6667 - val_dice_coefficient: 0.2367 - val_jaccard_index: 0.1345 - val_sensitivity: 0.8414 - val_specificity: 0.6546 - val_precision: 0.1380 - lr: 0.1000
# Epoch 39/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5355 - accuracy: 0.6947 - dice_coefficient: 0.2457 - jaccard_index: 0.1407 - sensitivity: 0.7668 - specificity: 0.6884 - precision: 0.1484
# Epoch 39: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 747ms/step - loss: 0.5355 - accuracy: 0.6947 - dice_coefficient: 0.2457 - jaccard_index: 0.1407 - sensitivity: 0.7668 - specificity: 0.6884 - precision: 0.1484 - val_loss: 0.5128 - val_accuracy: 0.6534 - val_dice_coefficient: 0.2326 - val_jaccard_index: 0.1320 - val_sensitivity: 0.8550 - val_specificity: 0.6397 - val_precision: 0.1350 - lr: 0.1000
# Epoch 40/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5148 - accuracy: 0.7161 - dice_coefficient: 0.2602 - jaccard_index: 0.1500 - sensitivity: 0.7815 - specificity: 0.7104 - precision: 0.1570
# Epoch 40: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 83s 770ms/step - loss: 0.5148 - accuracy: 0.7161 - dice_coefficient: 0.2602 - jaccard_index: 0.1500 - sensitivity: 0.7815 - specificity: 0.7104 - precision: 0.1570 - val_loss: 0.5075 - val_accuracy: 0.6384 - val_dice_coefficient: 0.2286 - val_jaccard_index: 0.1293 - val_sensitivity: 0.8733 - val_specificity: 0.6223 - val_precision: 0.1318 - lr: 0.1000
# Epoch 41/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.6891 - dice_coefficient: 0.2495 - jaccard_index: 0.1434 - sensitivity: 0.7945 - specificity: 0.6809 - precision: 0.1493
# Epoch 41: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 755ms/step - loss: 0.5268 - accuracy: 0.6891 - dice_coefficient: 0.2495 - jaccard_index: 0.1434 - sensitivity: 0.7945 - specificity: 0.6809 - precision: 0.1493 - val_loss: 0.4942 - val_accuracy: 0.7326 - val_dice_coefficient: 0.2673 - val_jaccard_index: 0.1545 - val_sensitivity: 0.7942 - val_specificity: 0.7278 - val_precision: 0.1609 - lr: 0.0100
# Epoch 42/70
# 108/108 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.7201 - dice_coefficient: 0.2664 - jaccard_index: 0.1542 - sensitivity: 0.8014 - specificity: 0.7135 - precision: 0.1602
# Epoch 42: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 83s 773ms/step - loss: 0.5009 - accuracy: 0.7201 - dice_coefficient: 0.2664 - jaccard_index: 0.1542 - sensitivity: 0.8014 - specificity: 0.7135 - precision: 0.1602 - val_loss: 0.4932 - val_accuracy: 0.7308 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7977 - val_specificity: 0.7256 - val_precision: 0.1605 - lr: 1.0000e-03
# Epoch 43/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.7268 - dice_coefficient: 0.2701 - jaccard_index: 0.1566 - sensitivity: 0.7966 - specificity: 0.7202 - precision: 0.1630
# Epoch 43: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 747ms/step - loss: 0.4995 - accuracy: 0.7268 - dice_coefficient: 0.2701 - jaccard_index: 0.1566 - sensitivity: 0.7966 - specificity: 0.7202 - precision: 0.1630 - val_loss: 0.4931 - val_accuracy: 0.7310 - val_dice_coefficient: 0.2670 - val_jaccard_index: 0.1543 - val_sensitivity: 0.7976 - val_specificity: 0.7259 - val_precision: 0.1606 - lr: 1.0000e-04
# Epoch 44/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.7260 - dice_coefficient: 0.2701 - jaccard_index: 0.1566 - sensitivity: 0.7984 - specificity: 0.7197 - precision: 0.1630
# Epoch 44: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 83s 766ms/step - loss: 0.4995 - accuracy: 0.7260 - dice_coefficient: 0.2701 - jaccard_index: 0.1566 - sensitivity: 0.7984 - specificity: 0.7197 - precision: 0.1630 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-05
# Epoch 45/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.7253 - dice_coefficient: 0.2692 - jaccard_index: 0.1561 - sensitivity: 0.7982 - specificity: 0.7190 - precision: 0.1624
# Epoch 45: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 80s 745ms/step - loss: 0.4996 - accuracy: 0.7253 - dice_coefficient: 0.2692 - jaccard_index: 0.1561 - sensitivity: 0.7982 - specificity: 0.7190 - precision: 0.1624 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-06
# Epoch 46/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.7264 - dice_coefficient: 0.2690 - jaccard_index: 0.1559 - sensitivity: 0.7932 - specificity: 0.7198 - precision: 0.1624
# Epoch 46: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 756ms/step - loss: 0.4991 - accuracy: 0.7264 - dice_coefficient: 0.2690 - jaccard_index: 0.1559 - sensitivity: 0.7932 - specificity: 0.7198 - precision: 0.1624 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-07
# Epoch 47/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.7263 - dice_coefficient: 0.2699 - jaccard_index: 0.1565 - sensitivity: 0.7958 - specificity: 0.7202 - precision: 0.1631
# Epoch 47: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 83s 769ms/step - loss: 0.4995 - accuracy: 0.7263 - dice_coefficient: 0.2699 - jaccard_index: 0.1565 - sensitivity: 0.7958 - specificity: 0.7202 - precision: 0.1631 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-08
# Epoch 48/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.7273 - dice_coefficient: 0.2705 - jaccard_index: 0.1569 - sensitivity: 0.7954 - specificity: 0.7214 - precision: 0.1635
# Epoch 48: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 752ms/step - loss: 0.4996 - accuracy: 0.7273 - dice_coefficient: 0.2705 - jaccard_index: 0.1569 - sensitivity: 0.7954 - specificity: 0.7214 - precision: 0.1635 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-09
# Epoch 49/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4992 - accuracy: 0.7262 - dice_coefficient: 0.2688 - jaccard_index: 0.1558 - sensitivity: 0.7929 - specificity: 0.7197 - precision: 0.1622
# Epoch 49: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 756ms/step - loss: 0.4992 - accuracy: 0.7262 - dice_coefficient: 0.2688 - jaccard_index: 0.1558 - sensitivity: 0.7929 - specificity: 0.7197 - precision: 0.1622 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-10
# Epoch 50/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.7257 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7989 - specificity: 0.7198 - precision: 0.1632
# Epoch 50: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 751ms/step - loss: 0.4996 - accuracy: 0.7257 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7989 - specificity: 0.7198 - precision: 0.1632 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-11
# Epoch 51/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.7256 - dice_coefficient: 0.2689 - jaccard_index: 0.1557 - sensitivity: 0.7947 - specificity: 0.7186 - precision: 0.1623
# Epoch 51: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 760ms/step - loss: 0.4996 - accuracy: 0.7256 - dice_coefficient: 0.2689 - jaccard_index: 0.1557 - sensitivity: 0.7947 - specificity: 0.7186 - precision: 0.1623 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-12
# Epoch 52/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4993 - accuracy: 0.7267 - dice_coefficient: 0.2684 - jaccard_index: 0.1555 - sensitivity: 0.7943 - specificity: 0.7204 - precision: 0.1619
# Epoch 52: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 748ms/step - loss: 0.4993 - accuracy: 0.7267 - dice_coefficient: 0.2684 - jaccard_index: 0.1555 - sensitivity: 0.7943 - specificity: 0.7204 - precision: 0.1619 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-13
# Epoch 53/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4993 - accuracy: 0.7265 - dice_coefficient: 0.2692 - jaccard_index: 0.1561 - sensitivity: 0.7937 - specificity: 0.7205 - precision: 0.1626
# Epoch 53: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 85s 783ms/step - loss: 0.4993 - accuracy: 0.7265 - dice_coefficient: 0.2692 - jaccard_index: 0.1561 - sensitivity: 0.7937 - specificity: 0.7205 - precision: 0.1626 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-14
# Epoch 54/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7261 - dice_coefficient: 0.2694 - jaccard_index: 0.1562 - sensitivity: 0.7948 - specificity: 0.7200 - precision: 0.1627
# Epoch 54: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 84s 776ms/step - loss: 0.4994 - accuracy: 0.7261 - dice_coefficient: 0.2694 - jaccard_index: 0.1562 - sensitivity: 0.7948 - specificity: 0.7200 - precision: 0.1627 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-15
# Epoch 55/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4992 - accuracy: 0.7259 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7980 - specificity: 0.7196 - precision: 0.1634
# Epoch 55: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 751ms/step - loss: 0.4992 - accuracy: 0.7259 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7980 - specificity: 0.7196 - precision: 0.1634 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-16
# Epoch 56/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.7261 - dice_coefficient: 0.2693 - jaccard_index: 0.1560 - sensitivity: 0.7940 - specificity: 0.7187 - precision: 0.1625
# Epoch 56: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 746ms/step - loss: 0.4995 - accuracy: 0.7261 - dice_coefficient: 0.2693 - jaccard_index: 0.1560 - sensitivity: 0.7940 - specificity: 0.7187 - precision: 0.1625 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-17
# Epoch 57/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7262 - dice_coefficient: 0.2698 - jaccard_index: 0.1564 - sensitivity: 0.7956 - specificity: 0.7203 - precision: 0.1629
# Epoch 57: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 749ms/step - loss: 0.4994 - accuracy: 0.7262 - dice_coefficient: 0.2698 - jaccard_index: 0.1564 - sensitivity: 0.7956 - specificity: 0.7203 - precision: 0.1629 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-18
# Epoch 58/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4997 - accuracy: 0.7255 - dice_coefficient: 0.2694 - jaccard_index: 0.1561 - sensitivity: 0.7968 - specificity: 0.7196 - precision: 0.1626
# Epoch 58: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 756ms/step - loss: 0.4997 - accuracy: 0.7255 - dice_coefficient: 0.2694 - jaccard_index: 0.1561 - sensitivity: 0.7968 - specificity: 0.7196 - precision: 0.1626 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-19
# Epoch 59/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7261 - dice_coefficient: 0.2697 - jaccard_index: 0.1563 - sensitivity: 0.7980 - specificity: 0.7196 - precision: 0.1628
# Epoch 59: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 83s 773ms/step - loss: 0.4994 - accuracy: 0.7261 - dice_coefficient: 0.2697 - jaccard_index: 0.1563 - sensitivity: 0.7980 - specificity: 0.7196 - precision: 0.1628 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-20
# Epoch 60/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4993 - accuracy: 0.7260 - dice_coefficient: 0.2697 - jaccard_index: 0.1564 - sensitivity: 0.7952 - specificity: 0.7195 - precision: 0.1628
# Epoch 60: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 753ms/step - loss: 0.4993 - accuracy: 0.7260 - dice_coefficient: 0.2697 - jaccard_index: 0.1564 - sensitivity: 0.7952 - specificity: 0.7195 - precision: 0.1628 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-21
# Epoch 61/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7269 - dice_coefficient: 0.2700 - jaccard_index: 0.1565 - sensitivity: 0.7945 - specificity: 0.7206 - precision: 0.1630
# Epoch 61: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 84s 773ms/step - loss: 0.4994 - accuracy: 0.7269 - dice_coefficient: 0.2700 - jaccard_index: 0.1565 - sensitivity: 0.7945 - specificity: 0.7206 - precision: 0.1630 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-22
# Epoch 62/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.7258 - dice_coefficient: 0.2702 - jaccard_index: 0.1567 - sensitivity: 0.7987 - specificity: 0.7197 - precision: 0.1631
# Epoch 62: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 757ms/step - loss: 0.4989 - accuracy: 0.7258 - dice_coefficient: 0.2702 - jaccard_index: 0.1567 - sensitivity: 0.7987 - specificity: 0.7197 - precision: 0.1631 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-23
# Epoch 63/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7263 - dice_coefficient: 0.2694 - jaccard_index: 0.1561 - sensitivity: 0.7946 - specificity: 0.7197 - precision: 0.1626
# Epoch 63: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 753ms/step - loss: 0.4994 - accuracy: 0.7263 - dice_coefficient: 0.2694 - jaccard_index: 0.1561 - sensitivity: 0.7946 - specificity: 0.7197 - precision: 0.1626 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-24
# Epoch 64/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4998 - accuracy: 0.7272 - dice_coefficient: 0.2705 - jaccard_index: 0.1569 - sensitivity: 0.7972 - specificity: 0.7218 - precision: 0.1634
# Epoch 64: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 83s 772ms/step - loss: 0.4998 - accuracy: 0.7272 - dice_coefficient: 0.2705 - jaccard_index: 0.1569 - sensitivity: 0.7972 - specificity: 0.7218 - precision: 0.1634 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-25
# Epoch 65/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.7269 - dice_coefficient: 0.2711 - jaccard_index: 0.1572 - sensitivity: 0.7977 - specificity: 0.7206 - precision: 0.1637
# Epoch 65: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 84s 776ms/step - loss: 0.4991 - accuracy: 0.7269 - dice_coefficient: 0.2711 - jaccard_index: 0.1572 - sensitivity: 0.7977 - specificity: 0.7206 - precision: 0.1637 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-26
# Epoch 66/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.7264 - dice_coefficient: 0.2695 - jaccard_index: 0.1562 - sensitivity: 0.7959 - specificity: 0.7199 - precision: 0.1627
# Epoch 66: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 83s 768ms/step - loss: 0.4995 - accuracy: 0.7264 - dice_coefficient: 0.2695 - jaccard_index: 0.1562 - sensitivity: 0.7959 - specificity: 0.7199 - precision: 0.1627 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-27
# Epoch 67/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4997 - accuracy: 0.7265 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7954 - specificity: 0.7206 - precision: 0.1635
# Epoch 67: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 758ms/step - loss: 0.4997 - accuracy: 0.7265 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7954 - specificity: 0.7206 - precision: 0.1635 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-28
# Epoch 68/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4998 - accuracy: 0.7260 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7974 - specificity: 0.7196 - precision: 0.1635
# Epoch 68: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 85s 785ms/step - loss: 0.4998 - accuracy: 0.7260 - dice_coefficient: 0.2706 - jaccard_index: 0.1569 - sensitivity: 0.7974 - specificity: 0.7196 - precision: 0.1635 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-29
# Epoch 69/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7266 - dice_coefficient: 0.2688 - jaccard_index: 0.1557 - sensitivity: 0.7940 - specificity: 0.7204 - precision: 0.1622
# Epoch 69: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 81s 754ms/step - loss: 0.4994 - accuracy: 0.7266 - dice_coefficient: 0.2688 - jaccard_index: 0.1557 - sensitivity: 0.7940 - specificity: 0.7204 - precision: 0.1622 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-30
# Epoch 70/70
# 108/108 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.7272 - dice_coefficient: 0.2711 - jaccard_index: 0.1572 - sensitivity: 0.7990 - specificity: 0.7214 - precision: 0.1636
# Epoch 70: val_dice_coefficient did not improve from 0.27070
# 108/108 [==============================] - 82s 761ms/step - loss: 0.4994 - accuracy: 0.7272 - dice_coefficient: 0.2711 - jaccard_index: 0.1572 - sensitivity: 0.7990 - specificity: 0.7214 - precision: 0.1636 - val_loss: 0.4931 - val_accuracy: 0.7307 - val_dice_coefficient: 0.2669 - val_jaccard_index: 0.1542 - val_sensitivity: 0.7979 - val_specificity: 0.7255 - val_precision: 0.1605 - lr: 1.0000e-31
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > 0.5, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > 0.5).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred)
plot_confusion_matrix(y_test, y_pred)
print(classification_report(y_test.flatten(), (y_pred.flatten() > 0.5).astype(int)))
# Out:
# 15/15 [==============================] - 10s 619ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.72      0.83  29326208
#          1.0       0.17      0.80      0.27   2065536
#
#     accuracy                           0.72  31391744
#    macro avg       0.57      0.76      0.55  31391744
# weighted avg       0.93      0.72      0.79  31391744
