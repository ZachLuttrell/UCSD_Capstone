# %% [markdown]
# # MEViT
#
# This is the 8th iteration of MEViT.
#
# In this iteration I have included the following changes:
#
# Initial Settings and Imports
#
#     Added scale_factor:
#         Introduced a scale_factor parameter to control the scaling of images and masks.
#         Adjusted the code to handle the new scaling parameter.
#
# Loading and Scaling Images and Masks
#
#     Resize Function:
#         Added a function resize_images_and_masks to resize the images and masks according to the scale_factor.
#         Applied this function after loading the images and masks.
#     Normalization and Reshaping:
#         Normalized the values of images and masks after resizing.
#         Updated the reshaping of masks to match the new scaled dimensions.
#
# Custom Metrics and Loss Functions
#
#     Consistent Threshold Usage:
#         Ensured that all custom metrics consistently use the threshold parameter defined at the top.
#
# MEViT Model Definition
#
#     Input Shape Adjustment:
#         Updated the model definition to accommodate the new input shape based on the scaled images.
#     Patch Size Adjustment:
#         Ensured the patch size is appropriately set for the scaled images to balance model complexity and performance.
#
# Model Compilation and Training
#
#     Learning Rate Schedule:
#         Maintained the learning rate scheduler and other training parameters.
#     Callbacks Setup:
#         Configured EarlyStopping and ModelCheckpoint to monitor the val_dice_coefficient.
#
# Model Fitting
#
#     Model Fitting:
#         Trained the model using the .fit() method with the specified batch size, epochs, and callbacks.
#
# Model Evaluation
#
#     Evaluation Functions:
#         Updated the evaluation functions to handle the new input shape.
#         Included functions for plotting training history, showing predictions, plotting confusion matrices, and calculating classification reports and ROC-AUC scores.
#
#
#
# **NOTE:** Connect to a High-RAM Environment

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# MODEL SETTINGS
model_name = 'mevit_model_8'
percentage_to_load = 5 / 100.0  # Set the % of dataset to be loaded here.
threshold = 0.5  # Set the threshold for metrics here
scale_factor = 2.0  # Factor by which to scale images and masks
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load*100}%')
print(f'Threshold: {threshold}')
print(f'Scale Factor: {scale_factor}')
# Out:
# Model Name: mevit_model_8
# Percentage to Load: 5.0%
# Threshold: 0.5
# Scale Factor: 2.0

# %% [markdown]
# Imports

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(tqdm(image_files[:number_of_files_to_load]), start=1):
    try:
        img_path = os.path.join(image_directory, image_name)
        mask_name = image_to_mask[image_name]
        mask_path = os.path.join(mask_directory, mask_name)

        if os.path.exists(mask_path):
            img = tiff.imread(img_path)
            mask = tiff.imread(mask_path)

            images.append(img)
            masks.append(mask)
        else:
            print(f'\nMask not found for image: {image_name}')
    except Exception as e:
        print(f'\nError loading image/mask pair {image_name}: {e}')

print("\nLoading complete.")

# Check if the number of images and masks loaded are equal
if len(images) != len(masks):
    raise ValueError("The number of loaded images and masks do not match!")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 5.0% of dataset: 239 images/mask pairs...
# 100%|██████████| 239/239 [01:07<00:00,  3.54it/s]
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Function to resize and normalize images and masks
def preprocess_images_and_masks(images, masks, scale_factor):
    # Squeeze unnecessary singleton dimensions
    if images.ndim > 3 and images.shape[1] == 1:
        images = images.squeeze(axis=1)
    if masks.ndim > 3 and masks.shape[1] == 1:
        masks = masks.squeeze(axis=1)

    print(f"Original image shape: {images.shape}")
    new_size = (int(images.shape[1] * scale_factor), int(images.shape[2] * scale_factor))
    print(f"New size: {new_size}")

    if new_size[0] <= 0 or new_size[1] <= 0:
        raise ValueError("Scale factor resulted in invalid size. Check the scale factor and original dimensions.")

    resized_images = []
    resized_masks = []
    print("Resizing images and masks...")
    for img, mask in tqdm(zip(images, masks), total=len(images)):

        try:
            resized_img = cv2.resize(img, new_size)
            resized_mask = cv2.resize(mask, new_size, interpolation=cv2.INTER_NEAREST)
            resized_images.append(resized_img)
            resized_masks.append(resized_mask)
        except Exception as e:
            print(f"Error resizing image/mask pair: {e}")
            raise

    resized_images = np.array(resized_images, dtype=np.float32)
    resized_masks = np.array(resized_masks, dtype=np.float32)

    # Normalize images and masks
    resized_images /= 255.0
    resized_masks /= 255.0
    resized_masks = resized_masks.reshape((-1, new_size[0], new_size[1], 1))

    return resized_images, resized_masks

# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Resize and normalize images and masks
images, masks = preprocess_images_and_masks(images, masks, scale_factor)

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Original image shape: (239, 256, 256, 3)
# New size: (512, 512)
# Resizing images and masks...
# 100%|██████████| 239/239 [00:00<00:00, 724.18it/s]
# Dataset Shapes:
# X_train: (171, 512, 512, 3), y_train: (171, 512, 512, 1)
# X_val:   (20, 512, 512, 3), y_val: (20, 512, 512, 1)
# X_test:  (48, 512, 512, 3), y_test: (48, 512, 512, 1)

# %% [markdown]
# Metrics & Loss

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# Custom Metrics
def dice_coefficient(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

def jaccard_index(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

def sensitivity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    possible_positives = tf.reduce_sum(y_true_f)
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_negatives = tf.reduce_sum((1-y_true_f) * (1-y_pred_f))
    possible_negatives = tf.reduce_sum(1-y_true_f)
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    predicted_positives = tf.reduce_sum(y_pred_f)
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# Loss Function
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)

# Visualize class weight distribution
plt.bar(class_weights.keys(), class_weights.values())
plt.title("Class Weight Distribution")
plt.xlabel("Class")
plt.ylabel("Weight")
plt.show()

weighted_loss = weighted_binary_crossentropy(class_weights)
# Out:
# Class weights: {0: 0.5274949720047702, 1: 9.592571542048715}

# %% [markdown]
# Model Definition

# %%
# Define the MEViT model
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = models.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim):
    inputs = layers.Input(shape=input_shape)
    # Flatten the input
    x = layers.Reshape((-1, input_shape[-1]))(inputs)

    # Create patches and embed
    patch_size = 16  # Adjust as necessary based on image size and memory constraints
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    patches = layers.Conv2D(filters=embed_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    patches = layers.Reshape((num_patches, embed_dim))(patches)

    # Add Transformer blocks
    for _ in range(8):
        patches = TransformerBlock(embed_dim, num_heads, ff_dim)(patches)

    # Reshape back to image
    x = layers.Reshape((input_shape[0] // patch_size, input_shape[1] // patch_size, embed_dim))(patches)
    x = Conv2DTranspose(num_classes, kernel_size=patch_size, strides=patch_size, padding="valid")(x)
    outputs = layers.Activation('sigmoid')(x)

    return Model(inputs, outputs)

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

input_shape = (int(256 * scale_factor), int(256 * scale_factor), 3)
num_classes = 1
embed_dim = 64  # Adjust as necessary
num_heads = 4   # Adjust as necessary
ff_dim = 128    # Adjust as necessary

model = create_vit_segmentation_model(input_shape, num_classes, embed_dim, num_heads, ff_dim)
model._name = model_name
model.summary()

# Learning rate schedule
def lr_schedule(epoch, lr):
    if epoch >= 50 and epoch < 100:
        return lr * 0.99
    elif epoch >= 100 and epoch < 125:
        return lr * 0.9
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# Compile the model
initial_lr = 0.001  # Start with a lower initial learning rate
sgd = SGD(learning_rate=initial_lr, momentum=0.9)
model.compile(
    optimizer=sgd,
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)
# Out:
# Model: "mevit_model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  conv2d (Conv2D)             (None, 32, 32, 64)        49216
#
#  reshape_1 (Reshape)         (None, 1024, 64)          0
#
#  transformer_block (Transfo  (None, 1024, 64)          83200
#  rmerBlock)
#
#  transformer_block_1 (Trans  (None, 1024, 64)          83200
#  formerBlock)
#
#  transformer_block_2 (Trans  (None, 1024, 64)          83200
#  formerBlock)
#
#  transformer_block_3 (Trans  (None, 1024, 64)          83200
#  formerBlock)
#
#  transformer_block_4 (Trans  (None, 1024, 64)          83200
#  formerBlock)
#
#  transformer_block_5 (Trans  (None, 1024, 64)          83200
#  formerBlock)
#
#  transformer_block_6 (Trans  (None, 1024, 64)          83200
#  formerBlock)
#
#  transformer_block_7 (Trans  (None, 1024, 64)          83200
#  formerBlock)
#
#  reshape_2 (Reshape)         (None, 32, 32, 64)        0
#
#  conv2d_transpose (Conv2DTr  (None, 512, 512, 1)       16385
#  anspose)
#
#  activation (Activation)     (None, 512, 512, 1)       0
#
# =================================================================
# Total params: 731201 (2.79 MB)
# Trainable params: 731201 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Setup callbacks
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=30,  # Reduced patience
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=16,  # Experiment with different values
    epochs=150,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping, lr_scheduler]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4820 - dice_coefficient: 0.0941 - jaccard_index: 0.0495 - sensitivity: 0.5197 - specificity: 0.4799 - precision: 0.0520
# Epoch 1: val_dice_coefficient improved from -inf to 0.13159, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 92s 8s/step - loss: 0.6940 - accuracy: 0.4820 - dice_coefficient: 0.0941 - jaccard_index: 0.0495 - sensitivity: 0.5197 - specificity: 0.4799 - precision: 0.0520 - val_loss: 0.8285 - val_accuracy: 0.4705 - val_dice_coefficient: 0.1316 - val_jaccard_index: 0.0704 - val_sensitivity: 0.5273 - val_specificity: 0.4657 - val_precision: 0.0752 - lr: 0.0010
# Epoch 2/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4844 - dice_coefficient: 0.0941 - jaccard_index: 0.0494 - sensitivity: 0.5175 - specificity: 0.4826 - precision: 0.0519
# Epoch 2: val_dice_coefficient did not improve from 0.13159
# 11/11 [==============================] - 73s 7s/step - loss: 0.6940 - accuracy: 0.4844 - dice_coefficient: 0.0941 - jaccard_index: 0.0494 - sensitivity: 0.5175 - specificity: 0.4826 - precision: 0.0519 - val_loss: 0.8285 - val_accuracy: 0.4750 - val_dice_coefficient: 0.1315 - val_jaccard_index: 0.0704 - val_sensitivity: 0.5226 - val_specificity: 0.4708 - val_precision: 0.0753 - lr: 0.0010
# Epoch 3/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4834 - dice_coefficient: 0.0930 - jaccard_index: 0.0489 - sensitivity: 0.5191 - specificity: 0.4814 - precision: 0.0514
# Epoch 3: val_dice_coefficient improved from 0.13159 to 0.13169, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6940 - accuracy: 0.4834 - dice_coefficient: 0.0930 - jaccard_index: 0.0489 - sensitivity: 0.5191 - specificity: 0.4814 - precision: 0.0514 - val_loss: 0.8284 - val_accuracy: 0.4701 - val_dice_coefficient: 0.1317 - val_jaccard_index: 0.0705 - val_sensitivity: 0.5284 - val_specificity: 0.4648 - val_precision: 0.0752 - lr: 0.0010
# Epoch 4/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4864 - dice_coefficient: 0.0943 - jaccard_index: 0.0496 - sensitivity: 0.5163 - specificity: 0.4849 - precision: 0.0521
# Epoch 4: val_dice_coefficient did not improve from 0.13169
# 11/11 [==============================] - 73s 7s/step - loss: 0.6940 - accuracy: 0.4864 - dice_coefficient: 0.0943 - jaccard_index: 0.0496 - sensitivity: 0.5163 - specificity: 0.4849 - precision: 0.0521 - val_loss: 0.8285 - val_accuracy: 0.4783 - val_dice_coefficient: 0.1314 - val_jaccard_index: 0.0703 - val_sensitivity: 0.5191 - val_specificity: 0.4743 - val_precision: 0.0753 - lr: 0.0010
# Epoch 5/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.4928 - dice_coefficient: 0.0959 - jaccard_index: 0.0506 - sensitivity: 0.5088 - specificity: 0.4920 - precision: 0.0535
# Epoch 5: val_dice_coefficient did not improve from 0.13169
# 11/11 [==============================] - 72s 7s/step - loss: 0.6939 - accuracy: 0.4928 - dice_coefficient: 0.0959 - jaccard_index: 0.0506 - sensitivity: 0.5088 - specificity: 0.4920 - precision: 0.0535 - val_loss: 0.8286 - val_accuracy: 0.4841 - val_dice_coefficient: 0.1313 - val_jaccard_index: 0.0703 - val_sensitivity: 0.5129 - val_specificity: 0.4811 - val_precision: 0.0753 - lr: 0.0010
# Epoch 6/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.4941 - dice_coefficient: 0.0949 - jaccard_index: 0.0499 - sensitivity: 0.5082 - specificity: 0.4932 - precision: 0.0525
# Epoch 6: val_dice_coefficient did not improve from 0.13169
# 11/11 [==============================] - 74s 7s/step - loss: 0.6939 - accuracy: 0.4941 - dice_coefficient: 0.0949 - jaccard_index: 0.0499 - sensitivity: 0.5082 - specificity: 0.4932 - precision: 0.0525 - val_loss: 0.8285 - val_accuracy: 0.4816 - val_dice_coefficient: 0.1316 - val_jaccard_index: 0.0704 - val_sensitivity: 0.5167 - val_specificity: 0.4780 - val_precision: 0.0754 - lr: 0.0010
# Epoch 7/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.4913 - dice_coefficient: 0.0947 - jaccard_index: 0.0499 - sensitivity: 0.5117 - specificity: 0.4901 - precision: 0.0525
# Epoch 7: val_dice_coefficient improved from 0.13169 to 0.13185, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6939 - accuracy: 0.4913 - dice_coefficient: 0.0947 - jaccard_index: 0.0499 - sensitivity: 0.5117 - specificity: 0.4901 - precision: 0.0525 - val_loss: 0.8284 - val_accuracy: 0.4813 - val_dice_coefficient: 0.1319 - val_jaccard_index: 0.0706 - val_sensitivity: 0.5183 - val_specificity: 0.4775 - val_precision: 0.0756 - lr: 0.0010
# Epoch 8/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4880 - dice_coefficient: 0.0941 - jaccard_index: 0.0495 - sensitivity: 0.5161 - specificity: 0.4864 - precision: 0.0519
# Epoch 8: val_dice_coefficient improved from 0.13185 to 0.13230, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 85s 8s/step - loss: 0.6938 - accuracy: 0.4880 - dice_coefficient: 0.0941 - jaccard_index: 0.0495 - sensitivity: 0.5161 - specificity: 0.4864 - precision: 0.0519 - val_loss: 0.8282 - val_accuracy: 0.4781 - val_dice_coefficient: 0.1323 - val_jaccard_index: 0.0708 - val_sensitivity: 0.5235 - val_specificity: 0.4736 - val_precision: 0.0757 - lr: 0.0010
# Epoch 9/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4862 - dice_coefficient: 0.0947 - jaccard_index: 0.0498 - sensitivity: 0.5176 - specificity: 0.4844 - precision: 0.0522
# Epoch 9: val_dice_coefficient improved from 0.13230 to 0.13246, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6938 - accuracy: 0.4862 - dice_coefficient: 0.0947 - jaccard_index: 0.0498 - sensitivity: 0.5176 - specificity: 0.4844 - precision: 0.0522 - val_loss: 0.8282 - val_accuracy: 0.4792 - val_dice_coefficient: 0.1325 - val_jaccard_index: 0.0709 - val_sensitivity: 0.5231 - val_specificity: 0.4748 - val_precision: 0.0759 - lr: 0.0010
# Epoch 10/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4888 - dice_coefficient: 0.0937 - jaccard_index: 0.0493 - sensitivity: 0.5160 - specificity: 0.4874 - precision: 0.0519
# Epoch 10: val_dice_coefficient improved from 0.13246 to 0.13250, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6938 - accuracy: 0.4888 - dice_coefficient: 0.0937 - jaccard_index: 0.0493 - sensitivity: 0.5160 - specificity: 0.4874 - precision: 0.0519 - val_loss: 0.8283 - val_accuracy: 0.4847 - val_dice_coefficient: 0.1325 - val_jaccard_index: 0.0710 - val_sensitivity: 0.5178 - val_specificity: 0.4812 - val_precision: 0.0760 - lr: 0.0010
# Epoch 11/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4904 - dice_coefficient: 0.0943 - jaccard_index: 0.0496 - sensitivity: 0.5143 - specificity: 0.4891 - precision: 0.0521
# Epoch 11: val_dice_coefficient improved from 0.13250 to 0.13266, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 85s 8s/step - loss: 0.6938 - accuracy: 0.4904 - dice_coefficient: 0.0943 - jaccard_index: 0.0496 - sensitivity: 0.5143 - specificity: 0.4891 - precision: 0.0521 - val_loss: 0.8282 - val_accuracy: 0.4859 - val_dice_coefficient: 0.1327 - val_jaccard_index: 0.0711 - val_sensitivity: 0.5172 - val_specificity: 0.4827 - val_precision: 0.0761 - lr: 0.0010
# Epoch 12/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4923 - dice_coefficient: 0.0959 - jaccard_index: 0.0506 - sensitivity: 0.5126 - specificity: 0.4913 - precision: 0.0534
# Epoch 12: val_dice_coefficient improved from 0.13266 to 0.13269, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6937 - accuracy: 0.4923 - dice_coefficient: 0.0959 - jaccard_index: 0.0506 - sensitivity: 0.5126 - specificity: 0.4913 - precision: 0.0534 - val_loss: 0.8282 - val_accuracy: 0.4911 - val_dice_coefficient: 0.1327 - val_jaccard_index: 0.0711 - val_sensitivity: 0.5120 - val_specificity: 0.4889 - val_precision: 0.0763 - lr: 0.0010
# Epoch 13/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4948 - dice_coefficient: 0.0947 - jaccard_index: 0.0497 - sensitivity: 0.5100 - specificity: 0.4940 - precision: 0.0523
# Epoch 13: val_dice_coefficient improved from 0.13269 to 0.13280, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6937 - accuracy: 0.4948 - dice_coefficient: 0.0947 - jaccard_index: 0.0497 - sensitivity: 0.5100 - specificity: 0.4940 - precision: 0.0523 - val_loss: 0.8282 - val_accuracy: 0.4938 - val_dice_coefficient: 0.1328 - val_jaccard_index: 0.0711 - val_sensitivity: 0.5096 - val_specificity: 0.4921 - val_precision: 0.0764 - lr: 0.0010
# Epoch 14/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4931 - dice_coefficient: 0.0940 - jaccard_index: 0.0494 - sensitivity: 0.5123 - specificity: 0.4920 - precision: 0.0520
# Epoch 14: val_dice_coefficient improved from 0.13280 to 0.13312, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6937 - accuracy: 0.4931 - dice_coefficient: 0.0940 - jaccard_index: 0.0494 - sensitivity: 0.5123 - specificity: 0.4920 - precision: 0.0520 - val_loss: 0.8281 - val_accuracy: 0.4923 - val_dice_coefficient: 0.1331 - val_jaccard_index: 0.0713 - val_sensitivity: 0.5125 - val_specificity: 0.4904 - val_precision: 0.0765 - lr: 0.0010
# Epoch 15/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4943 - dice_coefficient: 0.0941 - jaccard_index: 0.0496 - sensitivity: 0.5112 - specificity: 0.4936 - precision: 0.0523
# Epoch 15: val_dice_coefficient improved from 0.13312 to 0.13325, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6936 - accuracy: 0.4943 - dice_coefficient: 0.0941 - jaccard_index: 0.0496 - sensitivity: 0.5112 - specificity: 0.4936 - precision: 0.0523 - val_loss: 0.8282 - val_accuracy: 0.4968 - val_dice_coefficient: 0.1332 - val_jaccard_index: 0.0714 - val_sensitivity: 0.5084 - val_specificity: 0.4957 - val_precision: 0.0767 - lr: 0.0010
# Epoch 16/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4967 - dice_coefficient: 0.0953 - jaccard_index: 0.0501 - sensitivity: 0.5091 - specificity: 0.4960 - precision: 0.0527
# Epoch 16: val_dice_coefficient improved from 0.13325 to 0.13328, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6936 - accuracy: 0.4967 - dice_coefficient: 0.0953 - jaccard_index: 0.0501 - sensitivity: 0.5091 - specificity: 0.4960 - precision: 0.0527 - val_loss: 0.8282 - val_accuracy: 0.4993 - val_dice_coefficient: 0.1333 - val_jaccard_index: 0.0714 - val_sensitivity: 0.5059 - val_specificity: 0.4987 - val_precision: 0.0768 - lr: 0.0010
# Epoch 17/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4969 - dice_coefficient: 0.0943 - jaccard_index: 0.0497 - sensitivity: 0.5088 - specificity: 0.4962 - precision: 0.0524
# Epoch 17: val_dice_coefficient improved from 0.13328 to 0.13344, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6936 - accuracy: 0.4969 - dice_coefficient: 0.0943 - jaccard_index: 0.0497 - sensitivity: 0.5088 - specificity: 0.4962 - precision: 0.0524 - val_loss: 0.8281 - val_accuracy: 0.4993 - val_dice_coefficient: 0.1334 - val_jaccard_index: 0.0715 - val_sensitivity: 0.5066 - val_specificity: 0.4986 - val_precision: 0.0769 - lr: 0.0010
# Epoch 18/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4977 - dice_coefficient: 0.0941 - jaccard_index: 0.0495 - sensitivity: 0.5093 - specificity: 0.4971 - precision: 0.0522
# Epoch 18: val_dice_coefficient did not improve from 0.13344
# 11/11 [==============================] - 74s 7s/step - loss: 0.6936 - accuracy: 0.4977 - dice_coefficient: 0.0941 - jaccard_index: 0.0495 - sensitivity: 0.5093 - specificity: 0.4971 - precision: 0.0522 - val_loss: 0.8281 - val_accuracy: 0.5012 - val_dice_coefficient: 0.1334 - val_jaccard_index: 0.0715 - val_sensitivity: 0.5046 - val_specificity: 0.5010 - val_precision: 0.0769 - lr: 0.0010
# Epoch 19/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5033 - dice_coefficient: 0.0963 - jaccard_index: 0.0508 - sensitivity: 0.5025 - specificity: 0.5036 - precision: 0.0538
# Epoch 19: val_dice_coefficient did not improve from 0.13344
# 11/11 [==============================] - 74s 7s/step - loss: 0.6936 - accuracy: 0.5033 - dice_coefficient: 0.0963 - jaccard_index: 0.0508 - sensitivity: 0.5025 - specificity: 0.5036 - precision: 0.0538 - val_loss: 0.8283 - val_accuracy: 0.5119 - val_dice_coefficient: 0.1332 - val_jaccard_index: 0.0714 - val_sensitivity: 0.4926 - val_specificity: 0.5137 - val_precision: 0.0770 - lr: 0.0010
# Epoch 20/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5025 - dice_coefficient: 0.0940 - jaccard_index: 0.0495 - sensitivity: 0.5037 - specificity: 0.5023 - precision: 0.0522
# Epoch 20: val_dice_coefficient improved from 0.13344 to 0.13367, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6936 - accuracy: 0.5025 - dice_coefficient: 0.0940 - jaccard_index: 0.0495 - sensitivity: 0.5037 - specificity: 0.5023 - precision: 0.0522 - val_loss: 0.8280 - val_accuracy: 0.5017 - val_dice_coefficient: 0.1337 - val_jaccard_index: 0.0716 - val_sensitivity: 0.5049 - val_specificity: 0.5017 - val_precision: 0.0771 - lr: 0.0010
# Epoch 21/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5018 - dice_coefficient: 0.0935 - jaccard_index: 0.0492 - sensitivity: 0.5054 - specificity: 0.5016 - precision: 0.0519
# Epoch 21: val_dice_coefficient improved from 0.13367 to 0.13369, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6935 - accuracy: 0.5018 - dice_coefficient: 0.0935 - jaccard_index: 0.0492 - sensitivity: 0.5054 - specificity: 0.5016 - precision: 0.0519 - val_loss: 0.8281 - val_accuracy: 0.5054 - val_dice_coefficient: 0.1337 - val_jaccard_index: 0.0716 - val_sensitivity: 0.5013 - val_specificity: 0.5060 - val_precision: 0.0772 - lr: 0.0010
# Epoch 22/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5066 - dice_coefficient: 0.0956 - jaccard_index: 0.0503 - sensitivity: 0.5002 - specificity: 0.5071 - precision: 0.0531
# Epoch 22: val_dice_coefficient did not improve from 0.13369
# 11/11 [==============================] - 75s 7s/step - loss: 0.6935 - accuracy: 0.5066 - dice_coefficient: 0.0956 - jaccard_index: 0.0503 - sensitivity: 0.5002 - specificity: 0.5071 - precision: 0.0531 - val_loss: 0.8282 - val_accuracy: 0.5128 - val_dice_coefficient: 0.1335 - val_jaccard_index: 0.0716 - val_sensitivity: 0.4932 - val_specificity: 0.5146 - val_precision: 0.0773 - lr: 0.0010
# Epoch 23/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5062 - dice_coefficient: 0.0945 - jaccard_index: 0.0497 - sensitivity: 0.5010 - specificity: 0.5066 - precision: 0.0523
# Epoch 23: val_dice_coefficient improved from 0.13369 to 0.13387, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6935 - accuracy: 0.5062 - dice_coefficient: 0.0945 - jaccard_index: 0.0497 - sensitivity: 0.5010 - specificity: 0.5066 - precision: 0.0523 - val_loss: 0.8281 - val_accuracy: 0.5069 - val_dice_coefficient: 0.1339 - val_jaccard_index: 0.0717 - val_sensitivity: 0.5006 - val_specificity: 0.5075 - val_precision: 0.0773 - lr: 0.0010
# Epoch 24/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5058 - dice_coefficient: 0.0952 - jaccard_index: 0.0501 - sensitivity: 0.5026 - specificity: 0.5060 - precision: 0.0529
# Epoch 24: val_dice_coefficient improved from 0.13387 to 0.13389, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6934 - accuracy: 0.5058 - dice_coefficient: 0.0952 - jaccard_index: 0.0501 - sensitivity: 0.5026 - specificity: 0.5060 - precision: 0.0529 - val_loss: 0.8281 - val_accuracy: 0.5094 - val_dice_coefficient: 0.1339 - val_jaccard_index: 0.0718 - val_sensitivity: 0.4983 - val_specificity: 0.5104 - val_precision: 0.0774 - lr: 0.0010
# Epoch 25/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5081 - dice_coefficient: 0.0950 - jaccard_index: 0.0499 - sensitivity: 0.4999 - specificity: 0.5086 - precision: 0.0527
# Epoch 25: val_dice_coefficient improved from 0.13389 to 0.13392, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 85s 8s/step - loss: 0.6934 - accuracy: 0.5081 - dice_coefficient: 0.0950 - jaccard_index: 0.0499 - sensitivity: 0.4999 - specificity: 0.5086 - precision: 0.0527 - val_loss: 0.8281 - val_accuracy: 0.5099 - val_dice_coefficient: 0.1339 - val_jaccard_index: 0.0718 - val_sensitivity: 0.4978 - val_specificity: 0.5110 - val_precision: 0.0774 - lr: 0.0010
# Epoch 26/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5086 - dice_coefficient: 0.0963 - jaccard_index: 0.0507 - sensitivity: 0.4997 - specificity: 0.5093 - precision: 0.0537
# Epoch 26: val_dice_coefficient improved from 0.13392 to 0.13394, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6934 - accuracy: 0.5086 - dice_coefficient: 0.0963 - jaccard_index: 0.0507 - sensitivity: 0.4997 - specificity: 0.5093 - precision: 0.0537 - val_loss: 0.8281 - val_accuracy: 0.5127 - val_dice_coefficient: 0.1339 - val_jaccard_index: 0.0718 - val_sensitivity: 0.4952 - val_specificity: 0.5141 - val_precision: 0.0775 - lr: 0.0010
# Epoch 27/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5070 - dice_coefficient: 0.0947 - jaccard_index: 0.0499 - sensitivity: 0.5016 - specificity: 0.5072 - precision: 0.0527
# Epoch 27: val_dice_coefficient improved from 0.13394 to 0.13429, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 86s 8s/step - loss: 0.6934 - accuracy: 0.5070 - dice_coefficient: 0.0947 - jaccard_index: 0.0499 - sensitivity: 0.5016 - specificity: 0.5072 - precision: 0.0527 - val_loss: 0.8279 - val_accuracy: 0.5045 - val_dice_coefficient: 0.1343 - val_jaccard_index: 0.0720 - val_sensitivity: 0.5050 - val_specificity: 0.5045 - val_precision: 0.0775 - lr: 0.0010
# Epoch 28/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5055 - dice_coefficient: 0.0953 - jaccard_index: 0.0501 - sensitivity: 0.5040 - specificity: 0.5057 - precision: 0.0528
# Epoch 28: val_dice_coefficient improved from 0.13429 to 0.13431, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6933 - accuracy: 0.5055 - dice_coefficient: 0.0953 - jaccard_index: 0.0501 - sensitivity: 0.5040 - specificity: 0.5057 - precision: 0.0528 - val_loss: 0.8279 - val_accuracy: 0.5065 - val_dice_coefficient: 0.1343 - val_jaccard_index: 0.0720 - val_sensitivity: 0.5031 - val_specificity: 0.5067 - val_precision: 0.0775 - lr: 0.0010
# Epoch 29/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5089 - dice_coefficient: 0.0962 - jaccard_index: 0.0506 - sensitivity: 0.5004 - specificity: 0.5094 - precision: 0.0534
# Epoch 29: val_dice_coefficient did not improve from 0.13431
# 11/11 [==============================] - 73s 7s/step - loss: 0.6933 - accuracy: 0.5089 - dice_coefficient: 0.0962 - jaccard_index: 0.0506 - sensitivity: 0.5004 - specificity: 0.5094 - precision: 0.0534 - val_loss: 0.8280 - val_accuracy: 0.5115 - val_dice_coefficient: 0.1343 - val_jaccard_index: 0.0720 - val_sensitivity: 0.4979 - val_specificity: 0.5126 - val_precision: 0.0777 - lr: 0.0010
# Epoch 30/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5117 - dice_coefficient: 0.0960 - jaccard_index: 0.0506 - sensitivity: 0.4979 - specificity: 0.5125 - precision: 0.0534
# Epoch 30: val_dice_coefficient improved from 0.13431 to 0.13431, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6933 - accuracy: 0.5117 - dice_coefficient: 0.0960 - jaccard_index: 0.0506 - sensitivity: 0.4979 - specificity: 0.5125 - precision: 0.0534 - val_loss: 0.8280 - val_accuracy: 0.5126 - val_dice_coefficient: 0.1343 - val_jaccard_index: 0.0720 - val_sensitivity: 0.4968 - val_specificity: 0.5139 - val_precision: 0.0777 - lr: 0.0010
# Epoch 31/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5097 - dice_coefficient: 0.0969 - jaccard_index: 0.0510 - sensitivity: 0.5005 - specificity: 0.5102 - precision: 0.0538
# Epoch 31: val_dice_coefficient improved from 0.13431 to 0.13451, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 84s 8s/step - loss: 0.6932 - accuracy: 0.5097 - dice_coefficient: 0.0969 - jaccard_index: 0.0510 - sensitivity: 0.5005 - specificity: 0.5102 - precision: 0.0538 - val_loss: 0.8279 - val_accuracy: 0.5094 - val_dice_coefficient: 0.1345 - val_jaccard_index: 0.0721 - val_sensitivity: 0.5009 - val_specificity: 0.5101 - val_precision: 0.0777 - lr: 0.0010
# Epoch 32/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5095 - dice_coefficient: 0.0965 - jaccard_index: 0.0508 - sensitivity: 0.5017 - specificity: 0.5099 - precision: 0.0537
# Epoch 32: val_dice_coefficient improved from 0.13451 to 0.13459, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6932 - accuracy: 0.5095 - dice_coefficient: 0.0965 - jaccard_index: 0.0508 - sensitivity: 0.5017 - specificity: 0.5099 - precision: 0.0537 - val_loss: 0.8279 - val_accuracy: 0.5100 - val_dice_coefficient: 0.1346 - val_jaccard_index: 0.0722 - val_sensitivity: 0.5007 - val_specificity: 0.5107 - val_precision: 0.0778 - lr: 0.0010
# Epoch 33/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5060 - dice_coefficient: 0.0961 - jaccard_index: 0.0506 - sensitivity: 0.5055 - specificity: 0.5060 - precision: 0.0533
# Epoch 33: val_dice_coefficient improved from 0.13459 to 0.13491, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6932 - accuracy: 0.5060 - dice_coefficient: 0.0961 - jaccard_index: 0.0506 - sensitivity: 0.5055 - specificity: 0.5060 - precision: 0.0533 - val_loss: 0.8277 - val_accuracy: 0.5057 - val_dice_coefficient: 0.1349 - val_jaccard_index: 0.0723 - val_sensitivity: 0.5064 - val_specificity: 0.5057 - val_precision: 0.0779 - lr: 0.0010
# Epoch 34/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5061 - dice_coefficient: 0.0956 - jaccard_index: 0.0503 - sensitivity: 0.5064 - specificity: 0.5060 - precision: 0.0531
# Epoch 34: val_dice_coefficient improved from 0.13491 to 0.13515, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 80s 7s/step - loss: 0.6932 - accuracy: 0.5061 - dice_coefficient: 0.0956 - jaccard_index: 0.0503 - sensitivity: 0.5064 - specificity: 0.5060 - precision: 0.0531 - val_loss: 0.8277 - val_accuracy: 0.5064 - val_dice_coefficient: 0.1351 - val_jaccard_index: 0.0725 - val_sensitivity: 0.5068 - val_specificity: 0.5063 - val_precision: 0.0780 - lr: 0.0010
# Epoch 35/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5045 - dice_coefficient: 0.0969 - jaccard_index: 0.0510 - sensitivity: 0.5082 - specificity: 0.5043 - precision: 0.0538
# Epoch 35: val_dice_coefficient improved from 0.13515 to 0.13532, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6932 - accuracy: 0.5045 - dice_coefficient: 0.0969 - jaccard_index: 0.0510 - sensitivity: 0.5082 - specificity: 0.5043 - precision: 0.0538 - val_loss: 0.8276 - val_accuracy: 0.5047 - val_dice_coefficient: 0.1353 - val_jaccard_index: 0.0726 - val_sensitivity: 0.5093 - val_specificity: 0.5042 - val_precision: 0.0781 - lr: 0.0010
# Epoch 36/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5030 - dice_coefficient: 0.0970 - jaccard_index: 0.0511 - sensitivity: 0.5098 - specificity: 0.5027 - precision: 0.0539
# Epoch 36: val_dice_coefficient improved from 0.13532 to 0.13550, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6931 - accuracy: 0.5030 - dice_coefficient: 0.0970 - jaccard_index: 0.0511 - sensitivity: 0.5098 - specificity: 0.5027 - precision: 0.0539 - val_loss: 0.8276 - val_accuracy: 0.5049 - val_dice_coefficient: 0.1355 - val_jaccard_index: 0.0727 - val_sensitivity: 0.5099 - val_specificity: 0.5044 - val_precision: 0.0782 - lr: 0.0010
# Epoch 37/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5020 - dice_coefficient: 0.0970 - jaccard_index: 0.0511 - sensitivity: 0.5125 - specificity: 0.5014 - precision: 0.0538
# Epoch 37: val_dice_coefficient improved from 0.13550 to 0.13576, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 80s 7s/step - loss: 0.6931 - accuracy: 0.5020 - dice_coefficient: 0.0970 - jaccard_index: 0.0511 - sensitivity: 0.5125 - specificity: 0.5014 - precision: 0.0538 - val_loss: 0.8275 - val_accuracy: 0.5015 - val_dice_coefficient: 0.1358 - val_jaccard_index: 0.0728 - val_sensitivity: 0.5145 - val_specificity: 0.5004 - val_precision: 0.0782 - lr: 0.0010
# Epoch 38/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5007 - dice_coefficient: 0.0965 - jaccard_index: 0.0508 - sensitivity: 0.5143 - specificity: 0.5001 - precision: 0.0534
# Epoch 38: val_dice_coefficient improved from 0.13576 to 0.13593, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6931 - accuracy: 0.5007 - dice_coefficient: 0.0965 - jaccard_index: 0.0508 - sensitivity: 0.5143 - specificity: 0.5001 - precision: 0.0534 - val_loss: 0.8274 - val_accuracy: 0.5026 - val_dice_coefficient: 0.1359 - val_jaccard_index: 0.0729 - val_sensitivity: 0.5142 - val_specificity: 0.5016 - val_precision: 0.0784 - lr: 0.0010
# Epoch 39/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5031 - dice_coefficient: 0.0966 - jaccard_index: 0.0509 - sensitivity: 0.5127 - specificity: 0.5024 - precision: 0.0536
# Epoch 39: val_dice_coefficient improved from 0.13593 to 0.13620, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 79s 7s/step - loss: 0.6930 - accuracy: 0.5031 - dice_coefficient: 0.0966 - jaccard_index: 0.0509 - sensitivity: 0.5127 - specificity: 0.5024 - precision: 0.0536 - val_loss: 0.8274 - val_accuracy: 0.5055 - val_dice_coefficient: 0.1362 - val_jaccard_index: 0.0731 - val_sensitivity: 0.5123 - val_specificity: 0.5049 - val_precision: 0.0786 - lr: 0.0010
# Epoch 40/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5031 - dice_coefficient: 0.0971 - jaccard_index: 0.0511 - sensitivity: 0.5128 - specificity: 0.5025 - precision: 0.0538
# Epoch 40: val_dice_coefficient improved from 0.13620 to 0.13651, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 78s 7s/step - loss: 0.6930 - accuracy: 0.5031 - dice_coefficient: 0.0971 - jaccard_index: 0.0511 - sensitivity: 0.5128 - specificity: 0.5025 - precision: 0.0538 - val_loss: 0.8274 - val_accuracy: 0.5054 - val_dice_coefficient: 0.1365 - val_jaccard_index: 0.0733 - val_sensitivity: 0.5136 - val_specificity: 0.5048 - val_precision: 0.0787 - lr: 0.0010
# Epoch 41/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5005 - dice_coefficient: 0.0949 - jaccard_index: 0.0501 - sensitivity: 0.5166 - specificity: 0.4994 - precision: 0.0528
# Epoch 41: val_dice_coefficient improved from 0.13651 to 0.13699, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 78s 7s/step - loss: 0.6930 - accuracy: 0.5005 - dice_coefficient: 0.0949 - jaccard_index: 0.0501 - sensitivity: 0.5166 - specificity: 0.4994 - precision: 0.0528 - val_loss: 0.8271 - val_accuracy: 0.4986 - val_dice_coefficient: 0.1370 - val_jaccard_index: 0.0735 - val_sensitivity: 0.5228 - val_specificity: 0.4967 - val_precision: 0.0789 - lr: 0.0010
# Epoch 42/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5007 - dice_coefficient: 0.0968 - jaccard_index: 0.0510 - sensitivity: 0.5170 - specificity: 0.5000 - precision: 0.0536
# Epoch 42: val_dice_coefficient improved from 0.13699 to 0.13710, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6929 - accuracy: 0.5007 - dice_coefficient: 0.0968 - jaccard_index: 0.0510 - sensitivity: 0.5170 - specificity: 0.5000 - precision: 0.0536 - val_loss: 0.8273 - val_accuracy: 0.5077 - val_dice_coefficient: 0.1371 - val_jaccard_index: 0.0736 - val_sensitivity: 0.5137 - val_specificity: 0.5074 - val_precision: 0.0791 - lr: 0.0010
# Epoch 43/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5098 - dice_coefficient: 0.0971 - jaccard_index: 0.0511 - sensitivity: 0.5078 - specificity: 0.5101 - precision: 0.0539
# Epoch 43: val_dice_coefficient improved from 0.13710 to 0.13723, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6929 - accuracy: 0.5098 - dice_coefficient: 0.0971 - jaccard_index: 0.0511 - sensitivity: 0.5078 - specificity: 0.5101 - precision: 0.0539 - val_loss: 0.8274 - val_accuracy: 0.5153 - val_dice_coefficient: 0.1372 - val_jaccard_index: 0.0737 - val_sensitivity: 0.5062 - val_specificity: 0.5164 - val_precision: 0.0794 - lr: 0.0010
# Epoch 44/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5099 - dice_coefficient: 0.0975 - jaccard_index: 0.0514 - sensitivity: 0.5078 - specificity: 0.5100 - precision: 0.0542
# Epoch 44: val_dice_coefficient improved from 0.13723 to 0.13770, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6929 - accuracy: 0.5099 - dice_coefficient: 0.0975 - jaccard_index: 0.0514 - sensitivity: 0.5078 - specificity: 0.5100 - precision: 0.0542 - val_loss: 0.8273 - val_accuracy: 0.5151 - val_dice_coefficient: 0.1377 - val_jaccard_index: 0.0740 - val_sensitivity: 0.5084 - val_specificity: 0.5160 - val_precision: 0.0797 - lr: 0.0010
# Epoch 45/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5050 - dice_coefficient: 0.0973 - jaccard_index: 0.0512 - sensitivity: 0.5146 - specificity: 0.5044 - precision: 0.0540
# Epoch 45: val_dice_coefficient improved from 0.13770 to 0.13835, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6928 - accuracy: 0.5050 - dice_coefficient: 0.0973 - jaccard_index: 0.0512 - sensitivity: 0.5146 - specificity: 0.5044 - precision: 0.0540 - val_loss: 0.8270 - val_accuracy: 0.5078 - val_dice_coefficient: 0.1383 - val_jaccard_index: 0.0743 - val_sensitivity: 0.5189 - val_specificity: 0.5073 - val_precision: 0.0798 - lr: 0.0010
# Epoch 46/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5029 - dice_coefficient: 0.0981 - jaccard_index: 0.0517 - sensitivity: 0.5176 - specificity: 0.5019 - precision: 0.0543
# Epoch 46: val_dice_coefficient improved from 0.13835 to 0.13868, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6928 - accuracy: 0.5029 - dice_coefficient: 0.0981 - jaccard_index: 0.0517 - sensitivity: 0.5176 - specificity: 0.5019 - precision: 0.0543 - val_loss: 0.8270 - val_accuracy: 0.5108 - val_dice_coefficient: 0.1387 - val_jaccard_index: 0.0745 - val_sensitivity: 0.5170 - val_specificity: 0.5108 - val_precision: 0.0801 - lr: 0.0010
# Epoch 47/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5059 - dice_coefficient: 0.0977 - jaccard_index: 0.0515 - sensitivity: 0.5159 - specificity: 0.5053 - precision: 0.0542
# Epoch 47: val_dice_coefficient improved from 0.13868 to 0.13903, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6927 - accuracy: 0.5059 - dice_coefficient: 0.0977 - jaccard_index: 0.0515 - sensitivity: 0.5159 - specificity: 0.5053 - precision: 0.0542 - val_loss: 0.8270 - val_accuracy: 0.5146 - val_dice_coefficient: 0.1390 - val_jaccard_index: 0.0747 - val_sensitivity: 0.5144 - val_specificity: 0.5153 - val_precision: 0.0804 - lr: 0.0010
# Epoch 48/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5120 - dice_coefficient: 0.0973 - jaccard_index: 0.0513 - sensitivity: 0.5093 - specificity: 0.5123 - precision: 0.0541
# Epoch 48: val_dice_coefficient improved from 0.13903 to 0.13916, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6927 - accuracy: 0.5120 - dice_coefficient: 0.0973 - jaccard_index: 0.0513 - sensitivity: 0.5093 - specificity: 0.5123 - precision: 0.0541 - val_loss: 0.8272 - val_accuracy: 0.5238 - val_dice_coefficient: 0.1392 - val_jaccard_index: 0.0748 - val_sensitivity: 0.5048 - val_specificity: 0.5264 - val_precision: 0.0807 - lr: 0.0010
# Epoch 49/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5142 - dice_coefficient: 0.0989 - jaccard_index: 0.0520 - sensitivity: 0.5086 - specificity: 0.5145 - precision: 0.0549
# Epoch 49: val_dice_coefficient improved from 0.13916 to 0.13972, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6926 - accuracy: 0.5142 - dice_coefficient: 0.0989 - jaccard_index: 0.0520 - sensitivity: 0.5086 - specificity: 0.5145 - precision: 0.0549 - val_loss: 0.8270 - val_accuracy: 0.5227 - val_dice_coefficient: 0.1397 - val_jaccard_index: 0.0751 - val_sensitivity: 0.5084 - val_specificity: 0.5248 - val_precision: 0.0810 - lr: 0.0010
# Epoch 50/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5092 - dice_coefficient: 0.0992 - jaccard_index: 0.0523 - sensitivity: 0.5157 - specificity: 0.5091 - precision: 0.0551
# Epoch 50: val_dice_coefficient improved from 0.13972 to 0.14042, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6926 - accuracy: 0.5092 - dice_coefficient: 0.0992 - jaccard_index: 0.0523 - sensitivity: 0.5157 - specificity: 0.5091 - precision: 0.0551 - val_loss: 0.8268 - val_accuracy: 0.5194 - val_dice_coefficient: 0.1404 - val_jaccard_index: 0.0755 - val_sensitivity: 0.5149 - val_specificity: 0.5207 - val_precision: 0.0813 - lr: 0.0010
# Epoch 51/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5129 - dice_coefficient: 0.0990 - jaccard_index: 0.0522 - sensitivity: 0.5116 - specificity: 0.5132 - precision: 0.0551
# Epoch 51: val_dice_coefficient improved from 0.14042 to 0.14078, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6926 - accuracy: 0.5129 - dice_coefficient: 0.0990 - jaccard_index: 0.0522 - sensitivity: 0.5116 - specificity: 0.5132 - precision: 0.0551 - val_loss: 0.8269 - val_accuracy: 0.5281 - val_dice_coefficient: 0.1408 - val_jaccard_index: 0.0757 - val_sensitivity: 0.5068 - val_specificity: 0.5311 - val_precision: 0.0818 - lr: 9.9000e-04
# Epoch 52/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5138 - dice_coefficient: 0.0979 - jaccard_index: 0.0516 - sensitivity: 0.5128 - specificity: 0.5138 - precision: 0.0544
# Epoch 52: val_dice_coefficient improved from 0.14078 to 0.14144, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6925 - accuracy: 0.5138 - dice_coefficient: 0.0979 - jaccard_index: 0.0516 - sensitivity: 0.5128 - specificity: 0.5138 - precision: 0.0544 - val_loss: 0.8266 - val_accuracy: 0.5245 - val_dice_coefficient: 0.1414 - val_jaccard_index: 0.0761 - val_sensitivity: 0.5135 - val_specificity: 0.5266 - val_precision: 0.0821 - lr: 9.8010e-04
# Epoch 53/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5102 - dice_coefficient: 0.0987 - jaccard_index: 0.0520 - sensitivity: 0.5186 - specificity: 0.5097 - precision: 0.0548
# Epoch 53: val_dice_coefficient improved from 0.14144 to 0.14203, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 80s 7s/step - loss: 0.6924 - accuracy: 0.5102 - dice_coefficient: 0.0987 - jaccard_index: 0.0520 - sensitivity: 0.5186 - specificity: 0.5097 - precision: 0.0548 - val_loss: 0.8265 - val_accuracy: 0.5266 - val_dice_coefficient: 0.1420 - val_jaccard_index: 0.0765 - val_sensitivity: 0.5135 - val_specificity: 0.5291 - val_precision: 0.0825 - lr: 9.7030e-04
# Epoch 54/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5080 - dice_coefficient: 0.0981 - jaccard_index: 0.0517 - sensitivity: 0.5216 - specificity: 0.5069 - precision: 0.0544
# Epoch 54: val_dice_coefficient improved from 0.14203 to 0.14267, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6924 - accuracy: 0.5080 - dice_coefficient: 0.0981 - jaccard_index: 0.0517 - sensitivity: 0.5216 - specificity: 0.5069 - precision: 0.0544 - val_loss: 0.8264 - val_accuracy: 0.5266 - val_dice_coefficient: 0.1427 - val_jaccard_index: 0.0768 - val_sensitivity: 0.5160 - val_specificity: 0.5291 - val_precision: 0.0828 - lr: 9.6060e-04
# Epoch 55/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5146 - dice_coefficient: 0.0996 - jaccard_index: 0.0525 - sensitivity: 0.5167 - specificity: 0.5146 - precision: 0.0553
# Epoch 55: val_dice_coefficient improved from 0.14267 to 0.14273, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6923 - accuracy: 0.5146 - dice_coefficient: 0.0996 - jaccard_index: 0.0525 - sensitivity: 0.5167 - specificity: 0.5146 - precision: 0.0553 - val_loss: 0.8267 - val_accuracy: 0.5411 - val_dice_coefficient: 0.1427 - val_jaccard_index: 0.0769 - val_sensitivity: 0.4999 - val_specificity: 0.5466 - val_precision: 0.0833 - lr: 9.5099e-04
# Epoch 56/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5231 - dice_coefficient: 0.0991 - jaccard_index: 0.0523 - sensitivity: 0.5082 - specificity: 0.5238 - precision: 0.0552
# Epoch 56: val_dice_coefficient improved from 0.14273 to 0.14340, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6922 - accuracy: 0.5231 - dice_coefficient: 0.0991 - jaccard_index: 0.0523 - sensitivity: 0.5082 - specificity: 0.5238 - precision: 0.0552 - val_loss: 0.8267 - val_accuracy: 0.5458 - val_dice_coefficient: 0.1434 - val_jaccard_index: 0.0773 - val_sensitivity: 0.4973 - val_specificity: 0.5521 - val_precision: 0.0838 - lr: 9.4148e-04
# Epoch 57/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5283 - dice_coefficient: 0.1003 - jaccard_index: 0.0529 - sensitivity: 0.5038 - specificity: 0.5297 - precision: 0.0559
# Epoch 57: val_dice_coefficient improved from 0.14340 to 0.14407, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6921 - accuracy: 0.5283 - dice_coefficient: 0.1003 - jaccard_index: 0.0529 - sensitivity: 0.5038 - specificity: 0.5297 - precision: 0.0559 - val_loss: 0.8266 - val_accuracy: 0.5489 - val_dice_coefficient: 0.1441 - val_jaccard_index: 0.0776 - val_sensitivity: 0.4964 - val_specificity: 0.5556 - val_precision: 0.0843 - lr: 9.3207e-04
# Epoch 58/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5200 - dice_coefficient: 0.1005 - jaccard_index: 0.0530 - sensitivity: 0.5148 - specificity: 0.5202 - precision: 0.0560
# Epoch 58: val_dice_coefficient improved from 0.14407 to 0.14489, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6921 - accuracy: 0.5200 - dice_coefficient: 0.1005 - jaccard_index: 0.0530 - sensitivity: 0.5148 - specificity: 0.5202 - precision: 0.0560 - val_loss: 0.8261 - val_accuracy: 0.5400 - val_dice_coefficient: 0.1449 - val_jaccard_index: 0.0781 - val_sensitivity: 0.5098 - val_specificity: 0.5448 - val_precision: 0.0845 - lr: 9.2274e-04
# Epoch 59/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5177 - dice_coefficient: 0.0999 - jaccard_index: 0.0527 - sensitivity: 0.5189 - specificity: 0.5175 - precision: 0.0555
# Epoch 59: val_dice_coefficient improved from 0.14489 to 0.14554, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6921 - accuracy: 0.5177 - dice_coefficient: 0.0999 - jaccard_index: 0.0527 - sensitivity: 0.5189 - specificity: 0.5175 - precision: 0.0555 - val_loss: 0.8260 - val_accuracy: 0.5405 - val_dice_coefficient: 0.1455 - val_jaccard_index: 0.0785 - val_sensitivity: 0.5117 - val_specificity: 0.5454 - val_precision: 0.0849 - lr: 9.1352e-04
# Epoch 60/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5310 - dice_coefficient: 0.0999 - jaccard_index: 0.0528 - sensitivity: 0.5040 - specificity: 0.5330 - precision: 0.0559
# Epoch 60: val_dice_coefficient did not improve from 0.14554
# 11/11 [==============================] - 72s 7s/step - loss: 0.6921 - accuracy: 0.5310 - dice_coefficient: 0.0999 - jaccard_index: 0.0528 - sensitivity: 0.5040 - specificity: 0.5330 - precision: 0.0559 - val_loss: 0.8265 - val_accuracy: 0.5609 - val_dice_coefficient: 0.1452 - val_jaccard_index: 0.0783 - val_sensitivity: 0.4868 - val_specificity: 0.5700 - val_precision: 0.0854 - lr: 9.0438e-04
# Epoch 61/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5373 - dice_coefficient: 0.1000 - jaccard_index: 0.0528 - sensitivity: 0.4992 - specificity: 0.5395 - precision: 0.0560
# Epoch 61: val_dice_coefficient improved from 0.14554 to 0.14613, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6919 - accuracy: 0.5373 - dice_coefficient: 0.1000 - jaccard_index: 0.0528 - sensitivity: 0.4992 - specificity: 0.5395 - precision: 0.0560 - val_loss: 0.8263 - val_accuracy: 0.5617 - val_dice_coefficient: 0.1461 - val_jaccard_index: 0.0788 - val_sensitivity: 0.4897 - val_specificity: 0.5706 - val_precision: 0.0859 - lr: 8.9534e-04
# Epoch 62/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5262 - dice_coefficient: 0.1001 - jaccard_index: 0.0528 - sensitivity: 0.5133 - specificity: 0.5265 - precision: 0.0558
# Epoch 62: val_dice_coefficient improved from 0.14613 to 0.14745, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6918 - accuracy: 0.5262 - dice_coefficient: 0.1001 - jaccard_index: 0.0528 - sensitivity: 0.5133 - specificity: 0.5265 - precision: 0.0558 - val_loss: 0.8257 - val_accuracy: 0.5488 - val_dice_coefficient: 0.1475 - val_jaccard_index: 0.0796 - val_sensitivity: 0.5098 - val_specificity: 0.5548 - val_precision: 0.0862 - lr: 8.8638e-04
# Epoch 63/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5244 - dice_coefficient: 0.1000 - jaccard_index: 0.0529 - sensitivity: 0.5175 - specificity: 0.5248 - precision: 0.0559
# Epoch 63: val_dice_coefficient improved from 0.14745 to 0.14810, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6918 - accuracy: 0.5244 - dice_coefficient: 0.1000 - jaccard_index: 0.0529 - sensitivity: 0.5175 - specificity: 0.5248 - precision: 0.0559 - val_loss: 0.8256 - val_accuracy: 0.5520 - val_dice_coefficient: 0.1481 - val_jaccard_index: 0.0800 - val_sensitivity: 0.5085 - val_specificity: 0.5587 - val_precision: 0.0867 - lr: 8.7752e-04
# Epoch 64/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5405 - dice_coefficient: 0.1007 - jaccard_index: 0.0531 - sensitivity: 0.4991 - specificity: 0.5429 - precision: 0.0563
# Epoch 64: val_dice_coefficient did not improve from 0.14810
# 11/11 [==============================] - 72s 7s/step - loss: 0.6918 - accuracy: 0.5405 - dice_coefficient: 0.1007 - jaccard_index: 0.0531 - sensitivity: 0.4991 - specificity: 0.5429 - precision: 0.0563 - val_loss: 0.8263 - val_accuracy: 0.5747 - val_dice_coefficient: 0.1475 - val_jaccard_index: 0.0797 - val_sensitivity: 0.4797 - val_specificity: 0.5862 - val_precision: 0.0872 - lr: 8.6875e-04
# Epoch 65/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.5483 - dice_coefficient: 0.1018 - jaccard_index: 0.0537 - sensitivity: 0.4927 - specificity: 0.5514 - precision: 0.0571
# Epoch 65: val_dice_coefficient improved from 0.14810 to 0.14837, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6917 - accuracy: 0.5483 - dice_coefficient: 0.1018 - jaccard_index: 0.0537 - sensitivity: 0.4927 - specificity: 0.5514 - precision: 0.0571 - val_loss: 0.8261 - val_accuracy: 0.5762 - val_dice_coefficient: 0.1484 - val_jaccard_index: 0.0801 - val_sensitivity: 0.4813 - val_specificity: 0.5876 - val_precision: 0.0878 - lr: 8.6006e-04
# Epoch 66/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5355 - dice_coefficient: 0.1012 - jaccard_index: 0.0535 - sensitivity: 0.5105 - specificity: 0.5364 - precision: 0.0566
# Epoch 66: val_dice_coefficient improved from 0.14837 to 0.15028, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6916 - accuracy: 0.5355 - dice_coefficient: 0.1012 - jaccard_index: 0.0535 - sensitivity: 0.5105 - specificity: 0.5364 - precision: 0.0566 - val_loss: 0.8251 - val_accuracy: 0.5534 - val_dice_coefficient: 0.1503 - val_jaccard_index: 0.0813 - val_sensitivity: 0.5150 - val_specificity: 0.5602 - val_precision: 0.0880 - lr: 8.5146e-04
# Epoch 67/150
# ...
# Epoch 128: val_dice_coefficient did not improve from 0.17615
# 11/11 [==============================] - 72s 7s/step - loss: 0.6871 - accuracy: 0.5845 - dice_coefficient: 0.1201 - jaccard_index: 0.0641 - sensitivity: 0.5463 - specificity: 0.5872 - precision: 0.0678 - val_loss: 0.8213 - val_accuracy: 0.6282 - val_dice_coefficient: 0.1757 - val_jaccard_index: 0.0964 - val_sensitivity: 0.5029 - val_specificity: 0.6511 - val_precision: 0.1066 - lr: 4.3433e-05
# Epoch 129/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6872 - accuracy: 0.5775 - dice_coefficient: 0.1194 - jaccard_index: 0.0637 - sensitivity: 0.5527 - specificity: 0.5791 - precision: 0.0674
# Epoch 129: val_dice_coefficient improved from 0.17615 to 0.17667, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 83s 8s/step - loss: 0.6872 - accuracy: 0.5775 - dice_coefficient: 0.1194 - jaccard_index: 0.0637 - sensitivity: 0.5527 - specificity: 0.5791 - precision: 0.0674 - val_loss: 0.8208 - val_accuracy: 0.6209 - val_dice_coefficient: 0.1767 - val_jaccard_index: 0.0970 - val_sensitivity: 0.5162 - val_specificity: 0.6424 - val_precision: 0.1068 - lr: 4.3433e-05
# Epoch 130/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.5794 - dice_coefficient: 0.1198 - jaccard_index: 0.0639 - sensitivity: 0.5516 - specificity: 0.5804 - precision: 0.0675
# Epoch 130: val_dice_coefficient did not improve from 0.17667
# 11/11 [==============================] - 73s 7s/step - loss: 0.6871 - accuracy: 0.5794 - dice_coefficient: 0.1198 - jaccard_index: 0.0639 - sensitivity: 0.5516 - specificity: 0.5804 - precision: 0.0675 - val_loss: 0.8212 - val_accuracy: 0.6271 - val_dice_coefficient: 0.1760 - val_jaccard_index: 0.0966 - val_sensitivity: 0.5056 - val_specificity: 0.6497 - val_precision: 0.1068 - lr: 4.3433e-05
# Epoch 131/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.5809 - dice_coefficient: 0.1177 - jaccard_index: 0.0629 - sensitivity: 0.5534 - specificity: 0.5817 - precision: 0.0667
# Epoch 131: val_dice_coefficient did not improve from 0.17667
# 11/11 [==============================] - 72s 7s/step - loss: 0.6871 - accuracy: 0.5809 - dice_coefficient: 0.1177 - jaccard_index: 0.0629 - sensitivity: 0.5534 - specificity: 0.5817 - precision: 0.0667 - val_loss: 0.8211 - val_accuracy: 0.6260 - val_dice_coefficient: 0.1762 - val_jaccard_index: 0.0967 - val_sensitivity: 0.5078 - val_specificity: 0.6484 - val_precision: 0.1069 - lr: 4.3433e-05
# Epoch 132/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.5841 - dice_coefficient: 0.1200 - jaccard_index: 0.0640 - sensitivity: 0.5457 - specificity: 0.5863 - precision: 0.0678
# Epoch 132: val_dice_coefficient did not improve from 0.17667
# 11/11 [==============================] - 72s 7s/step - loss: 0.6871 - accuracy: 0.5841 - dice_coefficient: 0.1200 - jaccard_index: 0.0640 - sensitivity: 0.5457 - specificity: 0.5863 - precision: 0.0678 - val_loss: 0.8214 - val_accuracy: 0.6304 - val_dice_coefficient: 0.1755 - val_jaccard_index: 0.0962 - val_sensitivity: 0.4992 - val_specificity: 0.6537 - val_precision: 0.1067 - lr: 4.3433e-05
# Epoch 133/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.5888 - dice_coefficient: 0.1210 - jaccard_index: 0.0646 - sensitivity: 0.5408 - specificity: 0.5915 - precision: 0.0685
# Epoch 133: val_dice_coefficient did not improve from 0.17667
# 11/11 [==============================] - 71s 7s/step - loss: 0.6871 - accuracy: 0.5888 - dice_coefficient: 0.1210 - jaccard_index: 0.0646 - sensitivity: 0.5408 - specificity: 0.5915 - precision: 0.0685 - val_loss: 0.8216 - val_accuracy: 0.6327 - val_dice_coefficient: 0.1752 - val_jaccard_index: 0.0961 - val_sensitivity: 0.4952 - val_specificity: 0.6564 - val_precision: 0.1067 - lr: 4.3433e-05
# Epoch 134/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.5826 - dice_coefficient: 0.1177 - jaccard_index: 0.0628 - sensitivity: 0.5450 - specificity: 0.5841 - precision: 0.0665
# Epoch 134: val_dice_coefficient improved from 0.17667 to 0.17667, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 82s 8s/step - loss: 0.6871 - accuracy: 0.5826 - dice_coefficient: 0.1177 - jaccard_index: 0.0628 - sensitivity: 0.5450 - specificity: 0.5841 - precision: 0.0665 - val_loss: 0.8209 - val_accuracy: 0.6233 - val_dice_coefficient: 0.1767 - val_jaccard_index: 0.0970 - val_sensitivity: 0.5128 - val_specificity: 0.6453 - val_precision: 0.1069 - lr: 4.3433e-05
# Epoch 135/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5789 - dice_coefficient: 0.1188 - jaccard_index: 0.0633 - sensitivity: 0.5509 - specificity: 0.5799 - precision: 0.0668
# Epoch 135: val_dice_coefficient did not improve from 0.17667
# 11/11 [==============================] - 72s 7s/step - loss: 0.6870 - accuracy: 0.5789 - dice_coefficient: 0.1188 - jaccard_index: 0.0633 - sensitivity: 0.5509 - specificity: 0.5799 - precision: 0.0668 - val_loss: 0.8210 - val_accuracy: 0.6248 - val_dice_coefficient: 0.1766 - val_jaccard_index: 0.0969 - val_sensitivity: 0.5104 - val_specificity: 0.6471 - val_precision: 0.1070 - lr: 4.3433e-05
# Epoch 136/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5804 - dice_coefficient: 0.1195 - jaccard_index: 0.0636 - sensitivity: 0.5504 - specificity: 0.5817 - precision: 0.0672
# Epoch 136: val_dice_coefficient did not improve from 0.17667
# 11/11 [==============================] - 73s 7s/step - loss: 0.6870 - accuracy: 0.5804 - dice_coefficient: 0.1195 - jaccard_index: 0.0636 - sensitivity: 0.5504 - specificity: 0.5817 - precision: 0.0672 - val_loss: 0.8211 - val_accuracy: 0.6267 - val_dice_coefficient: 0.1764 - val_jaccard_index: 0.0968 - val_sensitivity: 0.5072 - val_specificity: 0.6493 - val_precision: 0.1070 - lr: 4.3433e-05
# Epoch 137/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5853 - dice_coefficient: 0.1203 - jaccard_index: 0.0641 - sensitivity: 0.5474 - specificity: 0.5878 - precision: 0.0679
# Epoch 137: val_dice_coefficient did not improve from 0.17667
# 11/11 [==============================] - 72s 7s/step - loss: 0.6870 - accuracy: 0.5853 - dice_coefficient: 0.1203 - jaccard_index: 0.0641 - sensitivity: 0.5474 - specificity: 0.5878 - precision: 0.0679 - val_loss: 0.8214 - val_accuracy: 0.6313 - val_dice_coefficient: 0.1757 - val_jaccard_index: 0.0964 - val_sensitivity: 0.4986 - val_specificity: 0.6548 - val_precision: 0.1069 - lr: 4.3433e-05
# Epoch 138/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5824 - dice_coefficient: 0.1192 - jaccard_index: 0.0635 - sensitivity: 0.5497 - specificity: 0.5843 - precision: 0.0672
# Epoch 138: val_dice_coefficient improved from 0.17667 to 0.17679, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 8s/step - loss: 0.6870 - accuracy: 0.5824 - dice_coefficient: 0.1192 - jaccard_index: 0.0635 - sensitivity: 0.5497 - specificity: 0.5843 - precision: 0.0672 - val_loss: 0.8210 - val_accuracy: 0.6253 - val_dice_coefficient: 0.1768 - val_jaccard_index: 0.0970 - val_sensitivity: 0.5103 - val_specificity: 0.6477 - val_precision: 0.1071 - lr: 4.3433e-05
# Epoch 139/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5823 - dice_coefficient: 0.1212 - jaccard_index: 0.0647 - sensitivity: 0.5496 - specificity: 0.5842 - precision: 0.0685
# Epoch 139: val_dice_coefficient did not improve from 0.17679
# 11/11 [==============================] - 72s 7s/step - loss: 0.6870 - accuracy: 0.5823 - dice_coefficient: 0.1212 - jaccard_index: 0.0647 - sensitivity: 0.5496 - specificity: 0.5842 - precision: 0.0685 - val_loss: 0.8213 - val_accuracy: 0.6294 - val_dice_coefficient: 0.1762 - val_jaccard_index: 0.0967 - val_sensitivity: 0.5027 - val_specificity: 0.6526 - val_precision: 0.1071 - lr: 4.3433e-05
# Epoch 140/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5830 - dice_coefficient: 0.1197 - jaccard_index: 0.0638 - sensitivity: 0.5496 - specificity: 0.5853 - precision: 0.0675
# Epoch 140: val_dice_coefficient did not improve from 0.17679
# 11/11 [==============================] - 72s 7s/step - loss: 0.6869 - accuracy: 0.5830 - dice_coefficient: 0.1197 - jaccard_index: 0.0638 - sensitivity: 0.5496 - specificity: 0.5853 - precision: 0.0675 - val_loss: 0.8211 - val_accuracy: 0.6267 - val_dice_coefficient: 0.1766 - val_jaccard_index: 0.0969 - val_sensitivity: 0.5079 - val_specificity: 0.6494 - val_precision: 0.1071 - lr: 4.3433e-05
# Epoch 141/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5853 - dice_coefficient: 0.1205 - jaccard_index: 0.0644 - sensitivity: 0.5463 - specificity: 0.5875 - precision: 0.0682
# Epoch 141: val_dice_coefficient did not improve from 0.17679
# 11/11 [==============================] - 71s 7s/step - loss: 0.6870 - accuracy: 0.5853 - dice_coefficient: 0.1205 - jaccard_index: 0.0644 - sensitivity: 0.5463 - specificity: 0.5875 - precision: 0.0682 - val_loss: 0.8214 - val_accuracy: 0.6311 - val_dice_coefficient: 0.1760 - val_jaccard_index: 0.0966 - val_sensitivity: 0.4999 - val_specificity: 0.6546 - val_precision: 0.1071 - lr: 4.3433e-05
# Epoch 142/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5879 - dice_coefficient: 0.1202 - jaccard_index: 0.0641 - sensitivity: 0.5428 - specificity: 0.5905 - precision: 0.0679
# Epoch 142: val_dice_coefficient did not improve from 0.17679
# 11/11 [==============================] - 72s 7s/step - loss: 0.6869 - accuracy: 0.5879 - dice_coefficient: 0.1202 - jaccard_index: 0.0641 - sensitivity: 0.5428 - specificity: 0.5905 - precision: 0.0679 - val_loss: 0.8213 - val_accuracy: 0.6301 - val_dice_coefficient: 0.1763 - val_jaccard_index: 0.0967 - val_sensitivity: 0.5020 - val_specificity: 0.6534 - val_precision: 0.1071 - lr: 4.3433e-05
# Epoch 143/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5850 - dice_coefficient: 0.1200 - jaccard_index: 0.0640 - sensitivity: 0.5471 - specificity: 0.5874 - precision: 0.0677
# Epoch 143: val_dice_coefficient improved from 0.17679 to 0.17690, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6870 - accuracy: 0.5850 - dice_coefficient: 0.1200 - jaccard_index: 0.0640 - sensitivity: 0.5471 - specificity: 0.5874 - precision: 0.0677 - val_loss: 0.8210 - val_accuracy: 0.6268 - val_dice_coefficient: 0.1769 - val_jaccard_index: 0.0971 - val_sensitivity: 0.5086 - val_specificity: 0.6494 - val_precision: 0.1073 - lr: 4.3433e-05
# Epoch 144/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5807 - dice_coefficient: 0.1215 - jaccard_index: 0.0647 - sensitivity: 0.5535 - specificity: 0.5818 - precision: 0.0683
# Epoch 144: val_dice_coefficient improved from 0.17690 to 0.17724, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 80s 7s/step - loss: 0.6869 - accuracy: 0.5807 - dice_coefficient: 0.1215 - jaccard_index: 0.0647 - sensitivity: 0.5535 - specificity: 0.5818 - precision: 0.0683 - val_loss: 0.8208 - val_accuracy: 0.6241 - val_dice_coefficient: 0.1772 - val_jaccard_index: 0.0973 - val_sensitivity: 0.5134 - val_specificity: 0.6462 - val_precision: 0.1073 - lr: 4.3433e-05
# Epoch 145/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5758 - dice_coefficient: 0.1189 - jaccard_index: 0.0634 - sensitivity: 0.5589 - specificity: 0.5759 - precision: 0.0669
# Epoch 145: val_dice_coefficient improved from 0.17724 to 0.17760, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 8s/step - loss: 0.6870 - accuracy: 0.5758 - dice_coefficient: 0.1189 - jaccard_index: 0.0634 - sensitivity: 0.5589 - specificity: 0.5759 - precision: 0.0669 - val_loss: 0.8206 - val_accuracy: 0.6201 - val_dice_coefficient: 0.1776 - val_jaccard_index: 0.0975 - val_sensitivity: 0.5201 - val_specificity: 0.6415 - val_precision: 0.1073 - lr: 4.3433e-05
# Epoch 146/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5811 - dice_coefficient: 0.1195 - jaccard_index: 0.0638 - sensitivity: 0.5511 - specificity: 0.5833 - precision: 0.0675
# Epoch 146: val_dice_coefficient did not improve from 0.17760
# 11/11 [==============================] - 74s 7s/step - loss: 0.6869 - accuracy: 0.5811 - dice_coefficient: 0.1195 - jaccard_index: 0.0638 - sensitivity: 0.5511 - specificity: 0.5833 - precision: 0.0675 - val_loss: 0.8212 - val_accuracy: 0.6299 - val_dice_coefficient: 0.1765 - val_jaccard_index: 0.0968 - val_sensitivity: 0.5028 - val_specificity: 0.6532 - val_precision: 0.1072 - lr: 4.3433e-05
# Epoch 147/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5871 - dice_coefficient: 0.1221 - jaccard_index: 0.0652 - sensitivity: 0.5464 - specificity: 0.5894 - precision: 0.0691
# Epoch 147: val_dice_coefficient did not improve from 0.17760
# 11/11 [==============================] - 73s 7s/step - loss: 0.6869 - accuracy: 0.5871 - dice_coefficient: 0.1221 - jaccard_index: 0.0652 - sensitivity: 0.5464 - specificity: 0.5894 - precision: 0.0691 - val_loss: 0.8213 - val_accuracy: 0.6319 - val_dice_coefficient: 0.1763 - val_jaccard_index: 0.0967 - val_sensitivity: 0.4996 - val_specificity: 0.6556 - val_precision: 0.1073 - lr: 4.3433e-05
# Epoch 148/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5875 - dice_coefficient: 0.1216 - jaccard_index: 0.0648 - sensitivity: 0.5445 - specificity: 0.5894 - precision: 0.0686
# Epoch 148: val_dice_coefficient did not improve from 0.17760
# 11/11 [==============================] - 74s 7s/step - loss: 0.6869 - accuracy: 0.5875 - dice_coefficient: 0.1216 - jaccard_index: 0.0648 - sensitivity: 0.5445 - specificity: 0.5894 - precision: 0.0686 - val_loss: 0.8212 - val_accuracy: 0.6304 - val_dice_coefficient: 0.1766 - val_jaccard_index: 0.0969 - val_sensitivity: 0.5024 - val_specificity: 0.6538 - val_precision: 0.1073 - lr: 4.3433e-05
# Epoch 149/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5834 - dice_coefficient: 0.1210 - jaccard_index: 0.0645 - sensitivity: 0.5504 - specificity: 0.5854 - precision: 0.0682
# Epoch 149: val_dice_coefficient did not improve from 0.17760
# 11/11 [==============================] - 71s 6s/step - loss: 0.6869 - accuracy: 0.5834 - dice_coefficient: 0.1210 - jaccard_index: 0.0645 - sensitivity: 0.5504 - specificity: 0.5854 - precision: 0.0682 - val_loss: 0.8209 - val_accuracy: 0.6255 - val_dice_coefficient: 0.1773 - val_jaccard_index: 0.0974 - val_sensitivity: 0.5117 - val_specificity: 0.6480 - val_precision: 0.1075 - lr: 4.3433e-05
# Epoch 150/150
# 11/11 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.5785 - dice_coefficient: 0.1200 - jaccard_index: 0.0639 - sensitivity: 0.5549 - specificity: 0.5797 - precision: 0.0675
# Epoch 150: val_dice_coefficient improved from 0.17760 to 0.17769, saving model to /gdrive/My Drive/Dataset/Models/best_mevit_model_8
# 11/11 [==============================] - 81s 7s/step - loss: 0.6869 - accuracy: 0.5785 - dice_coefficient: 0.1200 - jaccard_index: 0.0639 - sensitivity: 0.5549 - specificity: 0.5797 - precision: 0.0675 - val_loss: 0.8207 - val_accuracy: 0.6227 - val_dice_coefficient: 0.1777 - val_jaccard_index: 0.0976 - val_sensitivity: 0.5166 - val_specificity: 0.6447 - val_precision: 0.1075 - lr: 4.3433e-05
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_auc_score

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred, threshold=threshold):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > threshold).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative (Correct: No Buildings)', 'False Positive (Incorrect: There Was No Building)', 'False Negative (Incorrect: There Was A Building Here)', 'True Positive (Correct: There Is A Building Here)']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred, threshold=threshold)
plot_confusion_matrix(y_test, y_pred, threshold=threshold)
print(classification_report(y_test.flatten(), (y_pred.flatten() > threshold).astype(int)))
print("ROC-AUC:", roc_auc_score(y_test.flatten(), y_pred.flatten()))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
