# %% [markdown]
# **NOTE:**
# Connect to a High-RAM environment

# %%
# HRNet Implementation: https://github.com/niecongchong/HRNet-keras-semantic-segmentation/blob/master/model/seg_hrnet.py

# %% [markdown]
# Import the libraries

# %%
from google.colab import drive
drive.mount('/gdrive')

import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
# Out:
# Mounted at /gdrive

# %% [markdown]
# Load the dataset

# %%
def count_files(directory, extension=".tif"):
    # List all files in the directory and count those with the specified extension
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")
# Out:
# Number of image files: 4787
# Number of mask files: 4787

# %%
# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
percentage_to_load = 5 / 100.0  # Set the % of dataset to be loaded here.
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(image_files[:number_of_files_to_load], start=1):
    img_path = os.path.join(image_directory, image_name)
    mask_name = image_to_mask[image_name]
    mask_path = os.path.join(mask_directory, mask_name)

    if os.path.exists(mask_path):
        img = tiff.imread(img_path)
        mask = tiff.imread(mask_path)

        images.append(img)
        masks.append(mask)
    else:
        print(f'\nMask not found for image: {image_name}')

    # Update the count in the same line
    print(f'\rProcessed: {count}/{number_of_files_to_load}', end='')

print("\nLoading complete.")

# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))
# Out:
# Attempting to load 5.0% of dataset: 239 images and masks...
# Processed: 239/239
# Loading complete.

# %% [markdown]
# Perform Train/Test/Val Split

# %%
# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If there is an unnecessary singleton dimension in dataset, remove it:
if X_train.ndim > 3:  # Assuming the desired dimension is 3 (e.g., height x width x channels)
    X_train = X_train.squeeze(axis=1)
    X_val = X_val.squeeze(axis=1)
    X_test = X_test.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (171, 256, 256, 3), y_train: (171, 256, 256, 1)
# X_val:   (20, 256, 256, 3), y_val: (20, 256, 256, 1)
# X_test:  (48, 256, 256, 3), y_test: (48, 256, 256, 1)

# %% [markdown]
# Define the model

# %%
from keras.layers import Input, Conv2D, BatchNormalization, Activation, UpSampling2D, add, concatenate
from keras.models import Model
import tensorflow as tf
from tensorflow.keras.backend import epsilon
from tensorflow.keras.losses import BinaryCrossentropy

def stem_net(input):
    # Start with a convolution with stride 1 to maintain resolution
    x = Conv2D(64, 3, strides=(1, 1), padding='same', use_bias=False, kernel_initializer='he_normal')(input)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    # Reduced stride in the next layers or adjust according to your network depth need
    x = Conv2D(64, 3, strides=(1, 1), padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    return x

def transition_layer1(x, out_filters_list=[32, 64]):
    # Branch maintaining the current resolution
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    # Branch with reduced resolution
    x1 = Conv2D(out_filters_list[1], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    return [x0, x1]

def make_branch1_0(x, out_filters=32):
    # Applying multiple basic blocks to process high-resolution features
    x = basic_Block(x, out_filters, with_conv_shortcut=True)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch1_1(x, out_filters=64):
    # Processing slightly lower resolution features
    x = basic_Block(x, out_filters, with_conv_shortcut=True)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def fuse_layer1(x):
    # x is a list of feature maps from different branches
    x0_0 = x[0]  # High-resolution feature map
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)  # Upsampling to match high-res dimensions
    x0 = add([x0_0, x0_1])  # Adding features from different resolutions

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]  # Lower resolution features
    x1 = add([x1_0, x1_1])  # Combining features with downsampling high-res features

    return [x0, x1]

def transition_layer2(x, out_filters_list=[32, 64, 128]):
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    x1 = Conv2D(out_filters_list[1], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    x2 = Conv2D(out_filters_list[2], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2 = BatchNormalization(axis=3)(x2)
    x2 = Activation('relu')(x2)

    return [x0, x1, x2]

def make_branch2_0(x, out_filters=32):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch2_1(x, out_filters=64):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def make_branch2_2(x, out_filters=128):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x

def fuse_layer2(x):
    x0_0 = x[0]
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)
    x0_2 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x0_2 = BatchNormalization(axis=3)(x0_2)
    x0_2 = UpSampling2D(size=(4, 4))(x0_2)
    x0 = add([x0_0, x0_1, x0_2])

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]
    x1_2 = Conv2D(64, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x1_2 = BatchNormalization(axis=3)(x1_2)
    x1_2 = UpSampling2D(size=(2, 2))(x1_2)
    x1 = add([x1_0, x1_1, x1_2])

    x2_0 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_0 = Activation('relu')(x2_0)
    x2_0 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x2_0)
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_1 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2_1 = BatchNormalization(axis=3)(x2_1)
    x2_2 = x[2]
    x2 = add([x2_0, x2_1, x2_2])

    return [x0, x1, x2]

def final_layer(x, classes=1):
    # Removing the sigmoid activation to use logits
    x = Conv2D(classes, 1, use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    # No activation layer here
    return x

def seg_hrnet(input_shape=(256, 256, 3), classes=1):
    inputs = Input(shape=input_shape)

    # Stem network
    x = stem_net(inputs)

    # Transition Layer 1
    x = transition_layer1(x)
    x0 = make_branch1_0(x[0])
    x1 = make_branch1_1(x[1])
    x = fuse_layer1([x0, x1])

    # Transition Layer 2
    x = transition_layer2(x)
    x0 = make_branch2_0(x[0])
    x1 = make_branch2_1(x[1])
    x2 = make_branch2_2(x[2])
    x = fuse_layer2([x0, x1, x2])

    # Final Layer
    out = final_layer(x[0], classes=classes)

    model = Model(inputs=inputs, outputs=out)
    return model

# CUSTOM METRICS
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + epsilon())

def jaccard_index(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + epsilon()) / (union + epsilon())

def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

# Assuming 10 times more weight should be given to positives
weight_for_0 = 1.0  # weight for non-building class
weight_for_1 = 10.0  # weight for building class
loss = BinaryCrossentropy(from_logits=True)

def weighted_loss(y_true, y_pred):
    weights = y_true * weight_for_1 + (1. - y_true) * weight_for_0
    return loss(y_true, y_pred, sample_weight=weights)

# MODEL FEATURES
def basic_Block(input, out_filters, strides=(1, 1), with_conv_shortcut=False):
    x = conv3x3(input, out_filters, strides)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = conv3x3(x, out_filters)
    x = BatchNormalization(axis=3)(x)

    if with_conv_shortcut:
        residual = Conv2D(out_filters, 1, strides=strides, use_bias=False, kernel_initializer='he_normal')(input)
        residual = BatchNormalization(axis=3)(residual)
        x = add([x, residual])
    else:
        x = add([x, input])

    x = Activation('relu')(x)
    return x

def conv3x3(x, out_filters, strides=(1, 1)):
    x = Conv2D(out_filters, 3, padding='same', strides=strides, use_bias=False, kernel_initializer='he_normal')(x)
    return x

# %% [markdown]
# Compile the model

# %%
from tensorflow.keras.optimizers import Adam

model = seg_hrnet()
model._name = 'HRNet_weighted_loss'
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=weighted_loss,  # Use the weighted loss function
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

model.summary()
# Out:
# Model: "HRNet_weighted_loss"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_177 (Conv2D)         (None, 256, 256, 64)         1728      ['input_4[0][0]']
#
#  batch_normalization_177 (B  (None, 256, 256, 64)         256       ['conv2d_177[0][0]']
#  atchNormalization)
#
#  activation_147 (Activation  (None, 256, 256, 64)         0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  conv2d_178 (Conv2D)         (None, 256, 256, 64)         36864     ['activation_147[0][0]']
#
#  batch_normalization_178 (B  (None, 256, 256, 64)         256       ['conv2d_178[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 256, 256, 64)         0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  conv2d_179 (Conv2D)         (None, 256, 256, 32)         18432     ['activation_148[0][0]']
#
#  batch_normalization_179 (B  (None, 256, 256, 32)         128       ['conv2d_179[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  conv2d_180 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_148[0][0]']
#
#  conv2d_181 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_149[0][0]']
#
#  batch_normalization_180 (B  (None, 128, 128, 64)         256       ['conv2d_180[0][0]']
#  atchNormalization)
#
#  batch_normalization_181 (B  (None, 256, 256, 32)         128       ['conv2d_181[0][0]']
#  atchNormalization)
#
#  activation_150 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  activation_151 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  conv2d_190 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_150[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_151[0][0]']
#
#  conv2d_183 (Conv2D)         (None, 256, 256, 32)         1024      ['activation_149[0][0]']
#
#  batch_normalization_190 (B  (None, 128, 128, 64)         256       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 256, 256, 32)         128       ['conv2d_182[0][0]']
#  atchNormalization)
#
#  batch_normalization_183 (B  (None, 256, 256, 32)         128       ['conv2d_183[0][0]']
#  atchNormalization)
#
#  activation_159 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  add_75 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_182[0][0
#                                                                     ]',
#                                                                      'batch_normalization_183[0][0
#                                                                     ]']
#
#  conv2d_191 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_159[0][0]']
#
#  conv2d_192 (Conv2D)         (None, 128, 128, 64)         4096      ['activation_150[0][0]']
#
#  activation_152 (Activation  (None, 256, 256, 32)         0         ['add_75[0][0]']
#  )
#
#  batch_normalization_191 (B  (None, 128, 128, 64)         256       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_192 (B  (None, 128, 128, 64)         256       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  conv2d_184 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_152[0][0]']
#
#  add_79 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_191[0][0
#                                                                     ]',
#                                                                      'batch_normalization_192[0][0
#                                                                     ]']
#
#  batch_normalization_184 (B  (None, 256, 256, 32)         128       ['conv2d_184[0][0]']
#  atchNormalization)
#
#  activation_160 (Activation  (None, 128, 128, 64)         0         ['add_79[0][0]']
#  )
#
#  activation_153 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_160[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_153[0][0]']
#
#  batch_normalization_193 (B  (None, 128, 128, 64)         256       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 256, 256, 32)         128       ['conv2d_185[0][0]']
#  atchNormalization)
#
#  activation_161 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  add_76 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_185[0][0
#                                                                     ]',
#                                                                      'activation_152[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_161[0][0]']
#
#  activation_154 (Activation  (None, 256, 256, 32)         0         ['add_76[0][0]']
#  )
#
#  batch_normalization_194 (B  (None, 128, 128, 64)         256       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  conv2d_186 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_154[0][0]']
#
#  add_80 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_194[0][0
#                                                                     ]',
#                                                                      'activation_160[0][0]']
#
#  batch_normalization_186 (B  (None, 256, 256, 32)         128       ['conv2d_186[0][0]']
#  atchNormalization)
#
#  activation_162 (Activation  (None, 128, 128, 64)         0         ['add_80[0][0]']
#  )
#
#  activation_155 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_162[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_155[0][0]']
#
#  batch_normalization_195 (B  (None, 128, 128, 64)         256       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_187 (B  (None, 256, 256, 32)         128       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_163 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  add_77 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_187[0][0
#                                                                     ]',
#                                                                      'activation_154[0][0]']
#
#  conv2d_196 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_163[0][0]']
#
#  activation_156 (Activation  (None, 256, 256, 32)         0         ['add_77[0][0]']
#  )
#
#  batch_normalization_196 (B  (None, 128, 128, 64)         256       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  conv2d_188 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_156[0][0]']
#
#  add_81 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_196[0][0
#                                                                     ]',
#                                                                      'activation_162[0][0]']
#
#  batch_normalization_188 (B  (None, 256, 256, 32)         128       ['conv2d_188[0][0]']
#  atchNormalization)
#
#  activation_164 (Activation  (None, 128, 128, 64)         0         ['add_81[0][0]']
#  )
#
#  activation_157 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_164[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_157[0][0]']
#
#  batch_normalization_197 (B  (None, 128, 128, 64)         256       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  batch_normalization_189 (B  (None, 256, 256, 32)         128       ['conv2d_189[0][0]']
#  atchNormalization)
#
#  activation_165 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  add_78 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_189[0][0
#                                                                     ]',
#                                                                      'activation_156[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_165[0][0]']
#
#  activation_158 (Activation  (None, 256, 256, 32)         0         ['add_78[0][0]']
#  )
#
#  batch_normalization_198 (B  (None, 128, 128, 64)         256       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  add_82 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_198[0][0
#                                                                     ]',
#                                                                      'activation_164[0][0]']
#
#  conv2d_200 (Conv2D)         (None, 128, 128, 64)         18432     ['activation_158[0][0]']
#
#  activation_166 (Activation  (None, 128, 128, 64)         0         ['add_82[0][0]']
#  )
#
#  batch_normalization_200 (B  (None, 128, 128, 64)         256       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  conv2d_199 (Conv2D)         (None, 128, 128, 32)         2048      ['activation_166[0][0]']
#
#  add_84 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_200[0][0
#                                                                     ]',
#                                                                      'activation_166[0][0]']
#
#  batch_normalization_199 (B  (None, 128, 128, 32)         128       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  conv2d_202 (Conv2D)         (None, 128, 128, 64)         36864     ['add_84[0][0]']
#
#  conv2d_203 (Conv2D)         (None, 64, 64, 128)          73728     ['add_84[0][0]']
#
#  up_sampling2d_12 (UpSampli  (None, 256, 256, 32)         0         ['batch_normalization_199[0][0
#  ng2D)                                                              ]']
#
#  batch_normalization_202 (B  (None, 128, 128, 64)         256       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  batch_normalization_203 (B  (None, 64, 64, 128)          512       ['conv2d_203[0][0]']
#  atchNormalization)
#
#  add_83 (Add)                (None, 256, 256, 32)         0         ['activation_158[0][0]',
#                                                                      'up_sampling2d_12[0][0]']
#
#  activation_168 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  activation_169 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 256, 256, 32)         9216      ['add_83[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_168[0][0]']
#
#  conv2d_220 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_169[0][0]']
#
#  batch_normalization_201 (B  (None, 256, 256, 32)         128       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  batch_normalization_212 (B  (None, 128, 128, 64)         256       ['conv2d_212[0][0]']
#  atchNormalization)
#
#  batch_normalization_220 (B  (None, 64, 64, 128)          512       ['conv2d_220[0][0]']
#  atchNormalization)
#
#  activation_167 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  activation_178 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_220[0][0
#  )                                                                  ]']
#
#  conv2d_204 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_167[0][0]']
#
#  conv2d_213 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_178[0][0]']
#
#  conv2d_221 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_186[0][0]']
#
#  batch_normalization_204 (B  (None, 256, 256, 32)         128       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  batch_normalization_213 (B  (None, 128, 128, 64)         256       ['conv2d_213[0][0]']
#  atchNormalization)
#
#  batch_normalization_221 (B  (None, 64, 64, 128)          512       ['conv2d_221[0][0]']
#  atchNormalization)
#
#  activation_170 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  add_89 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_213[0][0
#                                                                     ]',
#                                                                      'activation_168[0][0]']
#
#  add_93 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_221[0][0
#                                                                     ]',
#                                                                      'activation_169[0][0]']
#
#  conv2d_205 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_170[0][0]']
#
#  activation_179 (Activation  (None, 128, 128, 64)         0         ['add_89[0][0]']
#  )
#
#  activation_187 (Activation  (None, 64, 64, 128)          0         ['add_93[0][0]']
#  )
#
#  batch_normalization_205 (B  (None, 256, 256, 32)         128       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  conv2d_214 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_179[0][0]']
#
#  conv2d_222 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_187[0][0]']
#
#  add_85 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_205[0][0
#                                                                     ]',
#                                                                      'activation_167[0][0]']
#
#  batch_normalization_214 (B  (None, 128, 128, 64)         256       ['conv2d_214[0][0]']
#  atchNormalization)
#
#  batch_normalization_222 (B  (None, 64, 64, 128)          512       ['conv2d_222[0][0]']
#  atchNormalization)
#
#  activation_171 (Activation  (None, 256, 256, 32)         0         ['add_85[0][0]']
#  )
#
#  activation_180 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  activation_188 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  conv2d_206 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_171[0][0]']
#
#  conv2d_215 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_180[0][0]']
#
#  conv2d_223 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_188[0][0]']
#
#  batch_normalization_206 (B  (None, 256, 256, 32)         128       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  batch_normalization_215 (B  (None, 128, 128, 64)         256       ['conv2d_215[0][0]']
#  atchNormalization)
#
#  batch_normalization_223 (B  (None, 64, 64, 128)          512       ['conv2d_223[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  add_90 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_215[0][0
#                                                                     ]',
#                                                                      'activation_179[0][0]']
#
#  add_94 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_223[0][0
#                                                                     ]',
#                                                                      'activation_187[0][0]']
#
#  conv2d_207 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_172[0][0]']
#
#  activation_181 (Activation  (None, 128, 128, 64)         0         ['add_90[0][0]']
#  )
#
#  activation_189 (Activation  (None, 64, 64, 128)          0         ['add_94[0][0]']
#  )
#
#  batch_normalization_207 (B  (None, 256, 256, 32)         128       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  conv2d_216 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_181[0][0]']
#
#  conv2d_224 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_189[0][0]']
#
#  add_86 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_207[0][0
#                                                                     ]',
#                                                                      'activation_171[0][0]']
#
#  batch_normalization_216 (B  (None, 128, 128, 64)         256       ['conv2d_216[0][0]']
#  atchNormalization)
#
#  batch_normalization_224 (B  (None, 64, 64, 128)          512       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  activation_173 (Activation  (None, 256, 256, 32)         0         ['add_86[0][0]']
#  )
#
#  activation_182 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_216[0][0
#  )                                                                  ]']
#
#  activation_190 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_208 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_173[0][0]']
#
#  conv2d_217 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_182[0][0]']
#
#  conv2d_225 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_190[0][0]']
#
#  batch_normalization_208 (B  (None, 256, 256, 32)         128       ['conv2d_208[0][0]']
#  atchNormalization)
#
#  batch_normalization_217 (B  (None, 128, 128, 64)         256       ['conv2d_217[0][0]']
#  atchNormalization)
#
#  batch_normalization_225 (B  (None, 64, 64, 128)          512       ['conv2d_225[0][0]']
#  atchNormalization)
#
#  activation_174 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  add_91 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_217[0][0
#                                                                     ]',
#                                                                      'activation_181[0][0]']
#
#  add_95 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_225[0][0
#                                                                     ]',
#                                                                      'activation_189[0][0]']
#
#  conv2d_209 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_174[0][0]']
#
#  activation_183 (Activation  (None, 128, 128, 64)         0         ['add_91[0][0]']
#  )
#
#  activation_191 (Activation  (None, 64, 64, 128)          0         ['add_95[0][0]']
#  )
#
#  batch_normalization_209 (B  (None, 256, 256, 32)         128       ['conv2d_209[0][0]']
#  atchNormalization)
#
#  conv2d_218 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_183[0][0]']
#
#  conv2d_226 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_191[0][0]']
#
#  add_87 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_209[0][0
#                                                                     ]',
#                                                                      'activation_173[0][0]']
#
#  batch_normalization_218 (B  (None, 128, 128, 64)         256       ['conv2d_218[0][0]']
#  atchNormalization)
#
#  batch_normalization_226 (B  (None, 64, 64, 128)          512       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  activation_175 (Activation  (None, 256, 256, 32)         0         ['add_87[0][0]']
#  )
#
#  activation_184 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  activation_192 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  conv2d_210 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_175[0][0]']
#
#  conv2d_219 (Conv2D)         (None, 128, 128, 64)         36864     ['activation_184[0][0]']
#
#  conv2d_227 (Conv2D)         (None, 64, 64, 128)          147456    ['activation_192[0][0]']
#
#  batch_normalization_210 (B  (None, 256, 256, 32)         128       ['conv2d_210[0][0]']
#  atchNormalization)
#
#  batch_normalization_219 (B  (None, 128, 128, 64)         256       ['conv2d_219[0][0]']
#  atchNormalization)
#
#  batch_normalization_227 (B  (None, 64, 64, 128)          512       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_176 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  add_92 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_219[0][0
#                                                                     ]',
#                                                                      'activation_183[0][0]']
#
#  add_96 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_227[0][0
#                                                                     ]',
#                                                                      'activation_191[0][0]']
#
#  conv2d_211 (Conv2D)         (None, 256, 256, 32)         9216      ['activation_176[0][0]']
#
#  activation_185 (Activation  (None, 128, 128, 64)         0         ['add_92[0][0]']
#  )
#
#  activation_193 (Activation  (None, 64, 64, 128)          0         ['add_96[0][0]']
#  )
#
#  batch_normalization_211 (B  (None, 256, 256, 32)         128       ['conv2d_211[0][0]']
#  atchNormalization)
#
#  conv2d_228 (Conv2D)         (None, 128, 128, 32)         2048      ['activation_185[0][0]']
#
#  conv2d_229 (Conv2D)         (None, 64, 64, 32)           4096      ['activation_193[0][0]']
#
#  add_88 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_211[0][0
#                                                                     ]',
#                                                                      'activation_175[0][0]']
#
#  batch_normalization_228 (B  (None, 128, 128, 32)         128       ['conv2d_228[0][0]']
#  atchNormalization)
#
#  batch_normalization_229 (B  (None, 64, 64, 32)           128       ['conv2d_229[0][0]']
#  atchNormalization)
#
#  activation_177 (Activation  (None, 256, 256, 32)         0         ['add_88[0][0]']
#  )
#
#  up_sampling2d_13 (UpSampli  (None, 256, 256, 32)         0         ['batch_normalization_228[0][0
#  ng2D)                                                              ]']
#
#  up_sampling2d_14 (UpSampli  (None, 256, 256, 32)         0         ['batch_normalization_229[0][0
#  ng2D)                                                              ]']
#
#  add_97 (Add)                (None, 256, 256, 32)         0         ['activation_177[0][0]',
#                                                                      'up_sampling2d_13[0][0]',
#                                                                      'up_sampling2d_14[0][0]']
#
#  conv2d_235 (Conv2D)         (None, 256, 256, 1)          32        ['add_97[0][0]']
#
#  batch_normalization_235 (B  (None, 256, 256, 1)          4         ['conv2d_235[0][0]']
#  atchNormalization)
#
# ==================================================================================================
# Total params: 2175460 (8.30 MB)
# Trainable params: 2168930 (8.27 MB)
# Non-trainable params: 6530 (25.51 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Train

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Setup early stopping to monitor the 'val_loss' and stop training after 10 epochs of no improvements
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True  # Restores model weights from the epoch with the best value of the monitored quantity
)

# Setup model checkpointing to save the best model observed during training for later use
model_checkpoint = ModelCheckpoint(
    '/gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    epochs=50,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, model_checkpoint]
)

# Save the model
model.save('/gdrive/My Drive/Dataset/Models/hrnet_weighted_loss.h5')
# Out:
# Epoch 1/50
# 6/6 [==============================] - ETA: 0s - loss: 1.0945 - accuracy: 0.7299 - dice_coefficient: 1.0678 - jaccard_index: -5.7133 - sensitivity: 0.4689 - specificity: 0.7490 - precision: 0.0895
# Epoch 1: val_dice_coefficient improved from -inf to 0.20474, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 323s 52s/step - loss: 1.0945 - accuracy: 0.7299 - dice_coefficient: 1.0678 - jaccard_index: -5.7133 - sensitivity: 0.4689 - specificity: 0.7490 - precision: 0.0895 - val_loss: 38.7138 - val_accuracy: 0.0739 - val_dice_coefficient: 0.2047 - val_jaccard_index: 0.1140 - val_sensitivity: 1.0000 - val_specificity: 3.1378e-04 - val_precision: 0.0736
# Epoch 2/50
# 6/6 [==============================] - ETA: 0s - loss: 0.9364 - accuracy: 0.7706 - dice_coefficient: 2.1713 - jaccard_index: -8.6818 - sensitivity: 0.6126 - specificity: 0.7771 - precision: 0.1303
# Epoch 2: val_dice_coefficient improved from 0.20474 to 0.22347, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 299s 49s/step - loss: 0.9364 - accuracy: 0.7706 - dice_coefficient: 2.1713 - jaccard_index: -8.6818 - sensitivity: 0.6126 - specificity: 0.7771 - precision: 0.1303 - val_loss: 16.5762 - val_accuracy: 0.0745 - val_dice_coefficient: 0.2235 - val_jaccard_index: 0.1258 - val_sensitivity: 1.0000 - val_specificity: 9.4792e-04 - val_precision: 0.0737
# Epoch 3/50
# 6/6 [==============================] - ETA: 0s - loss: 0.9203 - accuracy: 0.7596 - dice_coefficient: 2.3886 - jaccard_index: 5.4248 - sensitivity: 0.6705 - specificity: 0.7663 - precision: 0.1371
# Epoch 3: val_dice_coefficient improved from 0.22347 to 0.23735, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 305s 51s/step - loss: 0.9203 - accuracy: 0.7596 - dice_coefficient: 2.3886 - jaccard_index: 5.4248 - sensitivity: 0.6705 - specificity: 0.7663 - precision: 0.1371 - val_loss: 4.6682 - val_accuracy: 0.1227 - val_dice_coefficient: 0.2374 - val_jaccard_index: 0.1347 - val_sensitivity: 0.9769 - val_specificity: 0.0548 - val_precision: 0.0759
# Epoch 4/50
# 6/6 [==============================] - ETA: 0s - loss: 0.9038 - accuracy: 0.7515 - dice_coefficient: 2.6248 - jaccard_index: -4.9914 - sensitivity: 0.7232 - specificity: 0.7560 - precision: 0.1387
# Epoch 4: val_dice_coefficient improved from 0.23735 to 0.23832, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 304s 50s/step - loss: 0.9038 - accuracy: 0.7515 - dice_coefficient: 2.6248 - jaccard_index: -4.9914 - sensitivity: 0.7232 - specificity: 0.7560 - precision: 0.1387 - val_loss: 1.8280 - val_accuracy: 0.4795 - val_dice_coefficient: 0.2383 - val_jaccard_index: 0.1353 - val_sensitivity: 0.7170 - val_specificity: 0.4606 - val_precision: 0.0955
# Epoch 5/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8902 - accuracy: 0.7536 - dice_coefficient: 2.8613 - jaccard_index: -3.7470 - sensitivity: 0.7665 - specificity: 0.7540 - precision: 0.1456
# Epoch 5: val_dice_coefficient improved from 0.23832 to 0.24594, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 301s 51s/step - loss: 0.8902 - accuracy: 0.7536 - dice_coefficient: 2.8613 - jaccard_index: -3.7470 - sensitivity: 0.7665 - specificity: 0.7540 - precision: 0.1456 - val_loss: 1.2587 - val_accuracy: 0.7340 - val_dice_coefficient: 0.2459 - val_jaccard_index: 0.1402 - val_sensitivity: 0.4125 - val_specificity: 0.7595 - val_precision: 0.1200
# Epoch 6/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8816 - accuracy: 0.7642 - dice_coefficient: 2.9946 - jaccard_index: -3.2310 - sensitivity: 0.7512 - specificity: 0.7643 - precision: 0.1420
# Epoch 6: val_dice_coefficient improved from 0.24594 to 0.28786, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 294s 48s/step - loss: 0.8816 - accuracy: 0.7642 - dice_coefficient: 2.9946 - jaccard_index: -3.2310 - sensitivity: 0.7512 - specificity: 0.7643 - precision: 0.1420 - val_loss: 1.1595 - val_accuracy: 0.7898 - val_dice_coefficient: 0.2879 - val_jaccard_index: 0.1681 - val_sensitivity: 0.2853 - val_specificity: 0.8298 - val_precision: 0.1176
# Epoch 7/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8670 - accuracy: 0.7697 - dice_coefficient: 3.2395 - jaccard_index: -2.6598 - sensitivity: 0.7895 - specificity: 0.7691 - precision: 0.1592
# Epoch 7: val_dice_coefficient did not improve from 0.28786
# 6/6 [==============================] - 274s 45s/step - loss: 0.8670 - accuracy: 0.7697 - dice_coefficient: 3.2395 - jaccard_index: -2.6598 - sensitivity: 0.7895 - specificity: 0.7691 - precision: 0.1592 - val_loss: 1.1225 - val_accuracy: 0.8867 - val_dice_coefficient: 0.0627 - val_jaccard_index: 0.0324 - val_sensitivity: 0.1011 - val_specificity: 0.9491 - val_precision: 0.1363
# Epoch 8/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8608 - accuracy: 0.7701 - dice_coefficient: 3.3095 - jaccard_index: -2.6403 - sensitivity: 0.8014 - specificity: 0.7701 - precision: 0.1656
# Epoch 8: val_dice_coefficient did not improve from 0.28786
# 6/6 [==============================] - 273s 44s/step - loss: 0.8608 - accuracy: 0.7701 - dice_coefficient: 3.3095 - jaccard_index: -2.6403 - sensitivity: 0.8014 - specificity: 0.7701 - precision: 0.1656 - val_loss: 1.1203 - val_accuracy: 0.7970 - val_dice_coefficient: -0.2641 - val_jaccard_index: -0.1166 - val_sensitivity: 0.2176 - val_specificity: 0.8431 - val_precision: 0.0992
# Epoch 9/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8489 - accuracy: 0.7910 - dice_coefficient: 3.5606 - jaccard_index: -2.4016 - sensitivity: 0.7927 - specificity: 0.7907 - precision: 0.1746
# Epoch 9: val_dice_coefficient improved from 0.28786 to 0.41568, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 294s 49s/step - loss: 0.8489 - accuracy: 0.7910 - dice_coefficient: 3.5606 - jaccard_index: -2.4016 - sensitivity: 0.7927 - specificity: 0.7907 - precision: 0.1746 - val_loss: 1.1283 - val_accuracy: 0.6656 - val_dice_coefficient: 0.4157 - val_jaccard_index: 0.2624 - val_sensitivity: 0.6040 - val_specificity: 0.6705 - val_precision: 0.1271
# Epoch 10/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8425 - accuracy: 0.7948 - dice_coefficient: 3.8449 - jaccard_index: -2.1415 - sensitivity: 0.8209 - specificity: 0.7915 - precision: 0.1712
# Epoch 10: val_dice_coefficient did not improve from 0.41568
# 6/6 [==============================] - 275s 45s/step - loss: 0.8425 - accuracy: 0.7948 - dice_coefficient: 3.8449 - jaccard_index: -2.1415 - sensitivity: 0.8209 - specificity: 0.7915 - precision: 0.1712 - val_loss: 1.0337 - val_accuracy: 0.8127 - val_dice_coefficient: -0.4952 - val_jaccard_index: -0.1985 - val_sensitivity: 0.4386 - val_specificity: 0.8424 - val_precision: 0.1811
# Epoch 11/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8374 - accuracy: 0.7994 - dice_coefficient: 3.8530 - jaccard_index: -2.1098 - sensitivity: 0.8148 - specificity: 0.8004 - precision: 0.1862
# Epoch 11: val_dice_coefficient improved from 0.41568 to 0.56629, saving model to /gdrive/My Drive/Dataset/Models/best_hrnet_weighted_loss
# 6/6 [==============================] - 291s 48s/step - loss: 0.8374 - accuracy: 0.7994 - dice_coefficient: 3.8530 - jaccard_index: -2.1098 - sensitivity: 0.8148 - specificity: 0.8004 - precision: 0.1862 - val_loss: 1.1595 - val_accuracy: 0.7060 - val_dice_coefficient: 0.5663 - val_jaccard_index: 0.3950 - val_sensitivity: 0.6193 - val_specificity: 0.7129 - val_precision: 0.1463
# Epoch 12/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8364 - accuracy: 0.8209 - dice_coefficient: 4.1289 - jaccard_index: -1.9748 - sensitivity: 0.7841 - specificity: 0.8229 - precision: 0.1910
# Epoch 12: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 279s 45s/step - loss: 0.8364 - accuracy: 0.8209 - dice_coefficient: 4.1289 - jaccard_index: -1.9748 - sensitivity: 0.7841 - specificity: 0.8229 - precision: 0.1910 - val_loss: 1.0345 - val_accuracy: 0.7987 - val_dice_coefficient: -8.2778 - val_jaccard_index: -0.8054 - val_sensitivity: 0.4932 - val_specificity: 0.8229 - val_precision: 0.1812
# Epoch 13/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8312 - accuracy: 0.8075 - dice_coefficient: 4.1323 - jaccard_index: -1.9575 - sensitivity: 0.8224 - specificity: 0.8106 - precision: 0.1948
# Epoch 13: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 267s 44s/step - loss: 0.8312 - accuracy: 0.8075 - dice_coefficient: 4.1323 - jaccard_index: -1.9575 - sensitivity: 0.8224 - specificity: 0.8106 - precision: 0.1948 - val_loss: 1.0244 - val_accuracy: 0.8320 - val_dice_coefficient: -0.3783 - val_jaccard_index: -0.1591 - val_sensitivity: 0.4316 - val_specificity: 0.8638 - val_precision: 0.2011
# Epoch 14/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8227 - accuracy: 0.8122 - dice_coefficient: 4.3681 - jaccard_index: -1.8681 - sensitivity: 0.8299 - specificity: 0.8122 - precision: 0.1922
# Epoch 14: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 283s 46s/step - loss: 0.8227 - accuracy: 0.8122 - dice_coefficient: 4.3681 - jaccard_index: -1.8681 - sensitivity: 0.8299 - specificity: 0.8122 - precision: 0.1922 - val_loss: 1.0472 - val_accuracy: 0.8157 - val_dice_coefficient: -0.9878 - val_jaccard_index: -0.3306 - val_sensitivity: 0.4609 - val_specificity: 0.8439 - val_precision: 0.1901
# Epoch 15/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8240 - accuracy: 0.8098 - dice_coefficient: 4.2997 - jaccard_index: -1.8954 - sensitivity: 0.8263 - specificity: 0.8082 - precision: 0.1953
# Epoch 15: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 264s 43s/step - loss: 0.8240 - accuracy: 0.8098 - dice_coefficient: 4.2997 - jaccard_index: -1.8954 - sensitivity: 0.8263 - specificity: 0.8082 - precision: 0.1953 - val_loss: 1.0153 - val_accuracy: 0.8566 - val_dice_coefficient: -0.1696 - val_jaccard_index: -0.0782 - val_sensitivity: 0.3857 - val_specificity: 0.8940 - val_precision: 0.2243
# Epoch 16/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8206 - accuracy: 0.8118 - dice_coefficient: 4.3860 - jaccard_index: -1.8665 - sensitivity: 0.8243 - specificity: 0.8118 - precision: 0.1977
# Epoch 16: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 285s 47s/step - loss: 0.8206 - accuracy: 0.8118 - dice_coefficient: 4.3860 - jaccard_index: -1.8665 - sensitivity: 0.8243 - specificity: 0.8118 - precision: 0.1977 - val_loss: 1.0200 - val_accuracy: 0.8451 - val_dice_coefficient: -0.3120 - val_jaccard_index: -0.1350 - val_sensitivity: 0.4126 - val_specificity: 0.8795 - val_precision: 0.2139
# Epoch 17/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8182 - accuracy: 0.8141 - dice_coefficient: 4.3792 - jaccard_index: -1.8912 - sensitivity: 0.8124 - specificity: 0.8104 - precision: 0.1905
# Epoch 17: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 267s 43s/step - loss: 0.8182 - accuracy: 0.8141 - dice_coefficient: 4.3792 - jaccard_index: -1.8912 - sensitivity: 0.8124 - specificity: 0.8104 - precision: 0.1905 - val_loss: 1.0199 - val_accuracy: 0.8545 - val_dice_coefficient: -0.2061 - val_jaccard_index: -0.0934 - val_sensitivity: 0.3851 - val_specificity: 0.8918 - val_precision: 0.2206
# Epoch 18/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8213 - accuracy: 0.8100 - dice_coefficient: 4.4526 - jaccard_index: -1.8911 - sensitivity: 0.8141 - specificity: 0.8094 - precision: 0.1972
# Epoch 18: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 282s 47s/step - loss: 0.8213 - accuracy: 0.8100 - dice_coefficient: 4.4526 - jaccard_index: -1.8911 - sensitivity: 0.8141 - specificity: 0.8094 - precision: 0.1972 - val_loss: 1.0264 - val_accuracy: 0.8573 - val_dice_coefficient: -0.1855 - val_jaccard_index: -0.0849 - val_sensitivity: 0.3649 - val_specificity: 0.8964 - val_precision: 0.2187
# Epoch 19/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8214 - accuracy: 0.8162 - dice_coefficient: 4.5843 - jaccard_index: -1.8655 - sensitivity: 0.8012 - specificity: 0.8169 - precision: 0.2040
# Epoch 19: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 271s 44s/step - loss: 0.8214 - accuracy: 0.8162 - dice_coefficient: 4.5843 - jaccard_index: -1.8655 - sensitivity: 0.8012 - specificity: 0.8169 - precision: 0.2040 - val_loss: 1.0235 - val_accuracy: 0.8822 - val_dice_coefficient: -0.0359 - val_jaccard_index: -0.0176 - val_sensitivity: 0.2885 - val_specificity: 0.9293 - val_precision: 0.2450
# Epoch 20/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8122 - accuracy: 0.8056 - dice_coefficient: 4.7081 - jaccard_index: -1.7507 - sensitivity: 0.8509 - specificity: 0.8028 - precision: 0.1963
# Epoch 20: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 278s 46s/step - loss: 0.8122 - accuracy: 0.8056 - dice_coefficient: 4.7081 - jaccard_index: -1.7507 - sensitivity: 0.8509 - specificity: 0.8028 - precision: 0.1963 - val_loss: 1.0159 - val_accuracy: 0.8750 - val_dice_coefficient: -0.0713 - val_jaccard_index: -0.0344 - val_sensitivity: 0.3195 - val_specificity: 0.9191 - val_precision: 0.2390
# Epoch 21/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8145 - accuracy: 0.8136 - dice_coefficient: 5.0021 - jaccard_index: -1.6972 - sensitivity: 0.8407 - specificity: 0.8120 - precision: 0.1936
# Epoch 21: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 277s 45s/step - loss: 0.8145 - accuracy: 0.8136 - dice_coefficient: 5.0021 - jaccard_index: -1.6972 - sensitivity: 0.8407 - specificity: 0.8120 - precision: 0.1936 - val_loss: 1.0202 - val_accuracy: 0.8574 - val_dice_coefficient: -0.1829 - val_jaccard_index: -0.0838 - val_sensitivity: 0.3643 - val_specificity: 0.8966 - val_precision: 0.2187
# Epoch 22/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8072 - accuracy: 0.8186 - dice_coefficient: 5.4619 - jaccard_index: -1.6320 - sensitivity: 0.8558 - specificity: 0.8168 - precision: 0.1965
# Epoch 22: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 271s 45s/step - loss: 0.8072 - accuracy: 0.8186 - dice_coefficient: 5.4619 - jaccard_index: -1.6320 - sensitivity: 0.8558 - specificity: 0.8168 - precision: 0.1965 - val_loss: 1.0268 - val_accuracy: 0.8815 - val_dice_coefficient: -0.0411 - val_jaccard_index: -0.0201 - val_sensitivity: 0.2803 - val_specificity: 0.9293 - val_precision: 0.2395
# Epoch 23/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8066 - accuracy: 0.8223 - dice_coefficient: 5.2317 - jaccard_index: -1.6507 - sensitivity: 0.8334 - specificity: 0.8220 - precision: 0.2052
# Epoch 23: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 276s 45s/step - loss: 0.8066 - accuracy: 0.8223 - dice_coefficient: 5.2317 - jaccard_index: -1.6507 - sensitivity: 0.8334 - specificity: 0.8220 - precision: 0.2052 - val_loss: 1.0250 - val_accuracy: 0.8683 - val_dice_coefficient: -0.1357 - val_jaccard_index: -0.0635 - val_sensitivity: 0.3267 - val_specificity: 0.9113 - val_precision: 0.2264
# Epoch 24/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.8225 - dice_coefficient: 5.5149 - jaccard_index: -1.6057 - sensitivity: 0.8377 - specificity: 0.8205 - precision: 0.1986
# Epoch 24: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 267s 44s/step - loss: 0.8058 - accuracy: 0.8225 - dice_coefficient: 5.5149 - jaccard_index: -1.6057 - sensitivity: 0.8377 - specificity: 0.8205 - precision: 0.1986 - val_loss: 1.0285 - val_accuracy: 0.8748 - val_dice_coefficient: -0.0895 - val_jaccard_index: -0.0428 - val_sensitivity: 0.2985 - val_specificity: 0.9206 - val_precision: 0.2299
# Epoch 25/50
# 6/6 [==============================] - ETA: 0s - loss: 0.8006 - accuracy: 0.8257 - dice_coefficient: 5.5413 - jaccard_index: -1.5849 - sensitivity: 0.8478 - specificity: 0.8248 - precision: 0.2116 Restoring model weights from the end of the best epoch: 15.
#
# Epoch 25: val_dice_coefficient did not improve from 0.56629
# 6/6 [==============================] - 279s 45s/step - loss: 0.8006 - accuracy: 0.8257 - dice_coefficient: 5.5413 - jaccard_index: -1.5849 - sensitivity: 0.8478 - specificity: 0.8248 - precision: 0.2116 - val_loss: 1.0263 - val_accuracy: 0.8757 - val_dice_coefficient: -0.1060 - val_jaccard_index: -0.0503 - val_sensitivity: 0.3023 - val_specificity: 0.9213 - val_precision: 0.2338
# Epoch 25: early stopping
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Evaluate

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title('Original Image')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title('True Mask')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > 0.5, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title('Predicted Mask')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred):
    # Flattening the masks
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > 0.5).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    # Adding labels for each quadrant
    labels = ['True Negative', 'False Positive', 'False Negative', 'True Positive']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    # Position labels in the center of each quadrant
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix with Detailed Annotations')
    plt.show()


# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred)
plot_confusion_matrix(y_test, y_pred)
print(classification_report(y_test.flatten(), (y_pred.flatten() > 0.5).astype(int)))
# Out:
# 2/2 [==============================] - 19s 5s/step
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.82      0.88   2970502
#          1.0       0.11      0.39      0.17    175226
#
#     accuracy                           0.79   3145728
#    macro avg       0.53      0.60      0.53   3145728
# weighted avg       0.91      0.79      0.84   3145728

# %%
# HRNet Implementation: https://github.com/niecongchong/HRNet-keras-semantic-segmentation/blob/master/model/seg_hrnet.py
