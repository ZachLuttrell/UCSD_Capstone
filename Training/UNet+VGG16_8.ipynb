# %% [markdown]
# # UNet+VGG16 8
# This is the 8th iteration of UNet+VGG16
#
# In this iteration I:
# - change dropout rate from 0.3 to 0.15
#
#
# **NOTE:** Connect to a High-RAM Environment with GPU enabled

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# Check for GPU availability
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# MODEL SETTINGS
model_name = 'unet_vgg_8'  # Name of the model
percentage_to_load = 50 / 100.0  # Set the % of dataset to be loaded here.
threshold = 0.75  # Set the threshold for metrics here
initial_lr = 0.01  # Learning rate at the beginning of training (NOT INCORPORATED CURRENTLY, set at 1e-4)
print(f'\nSETTINGS:')
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load*100}%')
print(f'Threshold: {threshold}')
print(f'Initial Learning Rate: {initial_lr}')
print()

# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Num GPUs Available:  1
#
# SETTINGS:
# Model Name: unet_vgg_8
# Percentage to Load: 50.0%
# Threshold: 0.75
# Initial Learning Rate: 0.01
#
# Mounted at /gdrive

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(tqdm(image_files[:number_of_files_to_load]), start=1):
    try:
        img_path = os.path.join(image_directory, image_name)
        mask_name = image_to_mask[image_name]
        mask_path = os.path.join(mask_directory, mask_name)

        if os.path.exists(mask_path):
            img = tiff.imread(img_path)
            mask = tiff.imread(mask_path)

            images.append(img)
            masks.append(mask)
        else:
            print(f'\nMask not found for image: {image_name}')
    except Exception as e:
        print(f'\nError loading image/mask pair {image_name}: {e}')

print("\nLoading complete.")

# Check if the number of images and masks loaded are equal
if len(images) != len(masks):
    raise ValueError("The number of loaded images and masks do not match!")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 50.0% of dataset: 2393 images/mask pairs...
# 100%|██████████| 2393/2393 [32:30<00:00,  1.23it/s]
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If X_train, X_test, X_val have an extra unnecessary dimension at axis=1, remove it:
X_train = X_train.squeeze(axis=1)
X_test = X_test.squeeze(axis=1)
X_val = X_val.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (1722, 256, 256, 3), y_train: (1722, 256, 256, 1)
# X_val:   (192, 256, 256, 3), y_val: (192, 256, 256, 1)
# X_test:  (479, 256, 256, 3), y_test: (479, 256, 256, 1)

# %% [markdown]
# Metrics & Loss

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# CUSTOM METRICS

# Dice Coefficient: Measures overlap between true and predicted masks.
def dice_coefficient(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

# Jaccard Index: Measures the ratio of intersection to the union of true and predicted masks.
def jaccard_index(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

# Sensitivity: Measures the proportion of actual positives correctly identified.
def sensitivity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    possible_positives = tf.reduce_sum(y_true_f)
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

# Specificity: Measures the proportion of actual negatives correctly identified.
def specificity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_negatives = tf.reduce_sum((1-y_true_f) * (1-y_pred_f))
    possible_negatives = tf.reduce_sum(1-y_true_f)
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# Precision: Measures the proportion of predicted positives that are actually true positives.
def precision(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    predicted_positives = tf.reduce_sum(y_pred_f)
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())


# LOSS FUNCTION
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)

# Visualize class weight distribution
plt.bar(class_weights.keys(), class_weights.values())
plt.title("Class Weight Distribution")
plt.xlabel("Class")
plt.ylabel("Weight")
plt.show()

weighted_loss = weighted_binary_crossentropy(class_weights)
# Out:
# Class weights: {0: 0.5339968946194886, 1: 7.853612816644959}

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16

def vgg16_unet(input_size=(256, 256, 3), freeze_vgg16=True, dropout_rate=0.15):
    inputs = Input(input_size)
    vgg16 = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_vgg16:
        # Freeze the VGG16 layers
        for layer in vgg16.layers:
            layer.trainable = False

    # Skip connections from VGG16 layers
    s1 = vgg16.get_layer("block1_conv2").output
    s2 = vgg16.get_layer("block2_conv2").output
    s3 = vgg16.get_layer("block3_conv3").output
    s4 = vgg16.get_layer("block4_conv3").output
    bridge = vgg16.get_layer("block5_conv3").output

    # Decoder with dropout
    up1 = UpSampling2D((2, 2))(bridge)
    up1 = concatenate([up1, s4])
    up1 = Conv2D(512, (3, 3), activation='relu', padding='same')(up1)
    up1 = Dropout(dropout_rate)(up1)

    up2 = UpSampling2D((2, 2))(up1)
    up2 = concatenate([up2, s3])
    up2 = Conv2D(256, (3, 3), activation='relu', padding='same')(up2)
    up2 = Dropout(dropout_rate)(up2)

    up3 = UpSampling2D((2, 2))(up2)
    up3 = concatenate([up3, s2])
    up3 = Conv2D(128, (3, 3), activation='relu', padding='same')(up3)
    up3 = Dropout(dropout_rate)(up3)

    up4 = UpSampling2D((2, 2))(up3)
    up4 = concatenate([up4, s1])
    up4 = Conv2D(64, (3, 3), activation='relu', padding='same')(up4)
    up4 = Dropout(dropout_rate)(up4)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(up4)

    model = Model(inputs, outputs)
    return model

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Define the model
model = vgg16_unet()

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)          0         ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)          2359808   ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv2[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 512)          0         ['block5_conv3[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 1024)         0         ['up_sampling2d[0][0]',
#                                                                      'block4_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 512)          4719104   ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 32, 32, 512)          0         ['conv2d[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 512)          0         ['dropout[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 768)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'block3_conv3[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 256)          1769728   ['concatenate_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64, 256)          0         ['conv2d_1[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 256)        0         ['dropout_1[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'block2_conv2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        442496    ['concatenate_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 128, 128, 128)        0         ['conv2d_2[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 128)        0         ['dropout_2[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_3[0][0]',
#  )                                                                   'block1_conv2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         110656    ['concatenate_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 256, 256, 64)         0         ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 1)          65        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 21756737 (83.00 MB)
# Trainable params: 7042049 (26.86 MB)
# Non-trainable params: 14714688 (56.13 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Early Stopping to prevent overfitting
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=15,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}.h5',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=8,
    epochs=50,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
print(f'Model saved to: /gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/50
# 216/216 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.7355 - dice_coefficient: 0.3365 - jaccard_index: 0.2048 - sensitivity: 0.4714 - specificity: 0.9053 - precision: 0.2734
# Epoch 1: val_dice_coefficient improved from -inf to 0.39156, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 216/216 [==============================] - 51s 162ms/step - loss: 0.4872 - accuracy: 0.7355 - dice_coefficient: 0.3365 - jaccard_index: 0.2048 - sensitivity: 0.4714 - specificity: 0.9053 - precision: 0.2734 - val_loss: 0.3924 - val_accuracy: 0.8180 - val_dice_coefficient: 0.3916 - val_jaccard_index: 0.2446 - val_sensitivity: 0.3817 - val_specificity: 0.9630 - val_precision: 0.4098
# Epoch 2/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3863 - accuracy: 0.7741 - dice_coefficient: 0.4099 - jaccard_index: 0.2594 - sensitivity: 0.5799 - specificity: 0.9143 - precision: 0.3242
# Epoch 2: val_dice_coefficient improved from 0.39156 to 0.43749, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 33s 154ms/step - loss: 0.3860 - accuracy: 0.7743 - dice_coefficient: 0.4097 - jaccard_index: 0.2593 - sensitivity: 0.5789 - specificity: 0.9147 - precision: 0.3244 - val_loss: 0.3557 - val_accuracy: 0.8182 - val_dice_coefficient: 0.4375 - val_jaccard_index: 0.2810 - val_sensitivity: 0.5562 - val_specificity: 0.9348 - val_precision: 0.3630
# Epoch 3/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3567 - accuracy: 0.7910 - dice_coefficient: 0.4356 - jaccard_index: 0.2800 - sensitivity: 0.6277 - specificity: 0.9138 - precision: 0.3386
# Epoch 3: val_dice_coefficient improved from 0.43749 to 0.44881, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 33s 154ms/step - loss: 0.3567 - accuracy: 0.7910 - dice_coefficient: 0.4361 - jaccard_index: 0.2804 - sensitivity: 0.6284 - specificity: 0.9138 - precision: 0.3390 - val_loss: 0.3313 - val_accuracy: 0.7999 - val_dice_coefficient: 0.4488 - val_jaccard_index: 0.2903 - val_sensitivity: 0.6540 - val_specificity: 0.9171 - val_precision: 0.3425
# Epoch 4/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3430 - accuracy: 0.7990 - dice_coefficient: 0.4488 - jaccard_index: 0.2912 - sensitivity: 0.6482 - specificity: 0.9151 - precision: 0.3511
# Epoch 4: val_dice_coefficient improved from 0.44881 to 0.44937, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 155ms/step - loss: 0.3433 - accuracy: 0.7988 - dice_coefficient: 0.4483 - jaccard_index: 0.2908 - sensitivity: 0.6477 - specificity: 0.9147 - precision: 0.3506 - val_loss: 0.3277 - val_accuracy: 0.7764 - val_dice_coefficient: 0.4494 - val_jaccard_index: 0.2906 - val_sensitivity: 0.7210 - val_specificity: 0.9017 - val_precision: 0.3272
# Epoch 5/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3310 - accuracy: 0.8056 - dice_coefficient: 0.4636 - jaccard_index: 0.3034 - sensitivity: 0.6755 - specificity: 0.9147 - precision: 0.3620
# Epoch 5: val_dice_coefficient improved from 0.44937 to 0.45940, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.3309 - accuracy: 0.8057 - dice_coefficient: 0.4635 - jaccard_index: 0.3033 - sensitivity: 0.6760 - specificity: 0.9146 - precision: 0.3618 - val_loss: 0.3145 - val_accuracy: 0.8053 - val_dice_coefficient: 0.4594 - val_jaccard_index: 0.2990 - val_sensitivity: 0.7250 - val_specificity: 0.9058 - val_precision: 0.3370
# Epoch 6/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3127 - accuracy: 0.8164 - dice_coefficient: 0.4769 - jaccard_index: 0.3148 - sensitivity: 0.7039 - specificity: 0.9145 - precision: 0.3642
# Epoch 6: val_dice_coefficient improved from 0.45940 to 0.48247, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 155ms/step - loss: 0.3127 - accuracy: 0.8164 - dice_coefficient: 0.4778 - jaccard_index: 0.3157 - sensitivity: 0.7048 - specificity: 0.9144 - precision: 0.3650 - val_loss: 0.3034 - val_accuracy: 0.8225 - val_dice_coefficient: 0.4825 - val_jaccard_index: 0.3189 - val_sensitivity: 0.6976 - val_specificity: 0.9210 - val_precision: 0.3697
# Epoch 7/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2999 - accuracy: 0.8243 - dice_coefficient: 0.4866 - jaccard_index: 0.3230 - sensitivity: 0.7236 - specificity: 0.9146 - precision: 0.3687
# Epoch 7: val_dice_coefficient improved from 0.48247 to 0.49680, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 33s 155ms/step - loss: 0.2998 - accuracy: 0.8243 - dice_coefficient: 0.4859 - jaccard_index: 0.3225 - sensitivity: 0.7232 - specificity: 0.9147 - precision: 0.3681 - val_loss: 0.2945 - val_accuracy: 0.8387 - val_dice_coefficient: 0.4968 - val_jaccard_index: 0.3316 - val_sensitivity: 0.6882 - val_specificity: 0.9279 - val_precision: 0.3899
# Epoch 8/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2929 - accuracy: 0.8290 - dice_coefficient: 0.4964 - jaccard_index: 0.3317 - sensitivity: 0.7313 - specificity: 0.9154 - precision: 0.3799
# Epoch 8: val_dice_coefficient did not improve from 0.49680
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2930 - accuracy: 0.8289 - dice_coefficient: 0.4966 - jaccard_index: 0.3320 - sensitivity: 0.7318 - specificity: 0.9150 - precision: 0.3800 - val_loss: 0.2850 - val_accuracy: 0.8173 - val_dice_coefficient: 0.4862 - val_jaccard_index: 0.3221 - val_sensitivity: 0.7749 - val_specificity: 0.9065 - val_precision: 0.3548
# Epoch 9/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2835 - accuracy: 0.8344 - dice_coefficient: 0.5031 - jaccard_index: 0.3378 - sensitivity: 0.7491 - specificity: 0.9156 - precision: 0.3816
# Epoch 9: val_dice_coefficient did not improve from 0.49680
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2834 - accuracy: 0.8345 - dice_coefficient: 0.5030 - jaccard_index: 0.3377 - sensitivity: 0.7487 - specificity: 0.9158 - precision: 0.3815 - val_loss: 0.2793 - val_accuracy: 0.8259 - val_dice_coefficient: 0.4915 - val_jaccard_index: 0.3267 - val_sensitivity: 0.7846 - val_specificity: 0.9066 - val_precision: 0.3584
# Epoch 10/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2773 - accuracy: 0.8376 - dice_coefficient: 0.5094 - jaccard_index: 0.3436 - sensitivity: 0.7584 - specificity: 0.9160 - precision: 0.3864
# Epoch 10: val_dice_coefficient improved from 0.49680 to 0.50331, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.2772 - accuracy: 0.8377 - dice_coefficient: 0.5089 - jaccard_index: 0.3431 - sensitivity: 0.7573 - specificity: 0.9162 - precision: 0.3861 - val_loss: 0.2777 - val_accuracy: 0.8239 - val_dice_coefficient: 0.5033 - val_jaccard_index: 0.3374 - val_sensitivity: 0.7582 - val_specificity: 0.9161 - val_precision: 0.3778
# Epoch 11/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2758 - accuracy: 0.8380 - dice_coefficient: 0.5102 - jaccard_index: 0.3442 - sensitivity: 0.7579 - specificity: 0.9161 - precision: 0.3897
# Epoch 11: val_dice_coefficient did not improve from 0.50331
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2760 - accuracy: 0.8379 - dice_coefficient: 0.5100 - jaccard_index: 0.3439 - sensitivity: 0.7578 - specificity: 0.9159 - precision: 0.3894 - val_loss: 0.2684 - val_accuracy: 0.8338 - val_dice_coefficient: 0.5025 - val_jaccard_index: 0.3366 - val_sensitivity: 0.7934 - val_specificity: 0.9090 - val_precision: 0.3684
# Epoch 12/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2657 - accuracy: 0.8440 - dice_coefficient: 0.5199 - jaccard_index: 0.3529 - sensitivity: 0.7759 - specificity: 0.9171 - precision: 0.3939
# Epoch 12: val_dice_coefficient improved from 0.50331 to 0.53272, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.2659 - accuracy: 0.8439 - dice_coefficient: 0.5205 - jaccard_index: 0.3535 - sensitivity: 0.7766 - specificity: 0.9165 - precision: 0.3944 - val_loss: 0.2986 - val_accuracy: 0.8826 - val_dice_coefficient: 0.5327 - val_jaccard_index: 0.3645 - val_sensitivity: 0.6466 - val_specificity: 0.9480 - val_precision: 0.4543
# Epoch 13/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2608 - accuracy: 0.8469 - dice_coefficient: 0.5235 - jaccard_index: 0.3565 - sensitivity: 0.7812 - specificity: 0.9175 - precision: 0.3967
# Epoch 13: val_dice_coefficient did not improve from 0.53272
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2609 - accuracy: 0.8467 - dice_coefficient: 0.5233 - jaccard_index: 0.3563 - sensitivity: 0.7815 - specificity: 0.9171 - precision: 0.3963 - val_loss: 0.2607 - val_accuracy: 0.8443 - val_dice_coefficient: 0.5201 - val_jaccard_index: 0.3525 - val_sensitivity: 0.7782 - val_specificity: 0.9197 - val_precision: 0.3912
# Epoch 14/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.8502 - dice_coefficient: 0.5302 - jaccard_index: 0.3625 - sensitivity: 0.7903 - specificity: 0.9179 - precision: 0.4018
# Epoch 14: val_dice_coefficient improved from 0.53272 to 0.53935, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 35s 162ms/step - loss: 0.2546 - accuracy: 0.8503 - dice_coefficient: 0.5298 - jaccard_index: 0.3621 - sensitivity: 0.7894 - specificity: 0.9182 - precision: 0.4015 - val_loss: 0.2601 - val_accuracy: 0.8721 - val_dice_coefficient: 0.5393 - val_jaccard_index: 0.3706 - val_sensitivity: 0.7334 - val_specificity: 0.9339 - val_precision: 0.4275
# Epoch 15/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2518 - accuracy: 0.8518 - dice_coefficient: 0.5331 - jaccard_index: 0.3649 - sensitivity: 0.7950 - specificity: 0.9184 - precision: 0.4036
# Epoch 15: val_dice_coefficient did not improve from 0.53935
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2520 - accuracy: 0.8516 - dice_coefficient: 0.5332 - jaccard_index: 0.3650 - sensitivity: 0.7951 - specificity: 0.9180 - precision: 0.4036 - val_loss: 0.2560 - val_accuracy: 0.8634 - val_dice_coefficient: 0.5297 - val_jaccard_index: 0.3614 - val_sensitivity: 0.7779 - val_specificity: 0.9226 - val_precision: 0.4023
# Epoch 16/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2479 - accuracy: 0.8542 - dice_coefficient: 0.5366 - jaccard_index: 0.3682 - sensitivity: 0.7986 - specificity: 0.9186 - precision: 0.4071
# Epoch 16: val_dice_coefficient did not improve from 0.53935
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2480 - accuracy: 0.8540 - dice_coefficient: 0.5361 - jaccard_index: 0.3677 - sensitivity: 0.7986 - specificity: 0.9184 - precision: 0.4065 - val_loss: 0.2520 - val_accuracy: 0.8495 - val_dice_coefficient: 0.5255 - val_jaccard_index: 0.3575 - val_sensitivity: 0.8043 - val_specificity: 0.9167 - val_precision: 0.3908
# Epoch 17/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2434 - accuracy: 0.8564 - dice_coefficient: 0.5402 - jaccard_index: 0.3719 - sensitivity: 0.8027 - specificity: 0.9193 - precision: 0.4098
# Epoch 17: val_dice_coefficient improved from 0.53935 to 0.54461, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 155ms/step - loss: 0.2435 - accuracy: 0.8562 - dice_coefficient: 0.5399 - jaccard_index: 0.3717 - sensitivity: 0.8029 - specificity: 0.9189 - precision: 0.4095 - val_loss: 0.2540 - val_accuracy: 0.8738 - val_dice_coefficient: 0.5446 - val_jaccard_index: 0.3755 - val_sensitivity: 0.7670 - val_specificity: 0.9293 - val_precision: 0.4234
# Epoch 18/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2375 - accuracy: 0.8599 - dice_coefficient: 0.5449 - jaccard_index: 0.3762 - sensitivity: 0.8122 - specificity: 0.9200 - precision: 0.4119
# Epoch 18: val_dice_coefficient did not improve from 0.54461
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2376 - accuracy: 0.8598 - dice_coefficient: 0.5445 - jaccard_index: 0.3758 - sensitivity: 0.8118 - specificity: 0.9199 - precision: 0.4116 - val_loss: 0.2436 - val_accuracy: 0.8532 - val_dice_coefficient: 0.5275 - val_jaccard_index: 0.3594 - val_sensitivity: 0.8343 - val_specificity: 0.9112 - val_precision: 0.3867
# Epoch 19/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2405 - accuracy: 0.8580 - dice_coefficient: 0.5431 - jaccard_index: 0.3746 - sensitivity: 0.8099 - specificity: 0.9196 - precision: 0.4114
# Epoch 19: val_dice_coefficient improved from 0.54461 to 0.54675, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.2404 - accuracy: 0.8581 - dice_coefficient: 0.5436 - jaccard_index: 0.3751 - sensitivity: 0.8102 - specificity: 0.9197 - precision: 0.4119 - val_loss: 0.2444 - val_accuracy: 0.8692 - val_dice_coefficient: 0.5468 - val_jaccard_index: 0.3775 - val_sensitivity: 0.7912 - val_specificity: 0.9258 - val_precision: 0.4187
# Epoch 20/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2315 - accuracy: 0.8634 - dice_coefficient: 0.5518 - jaccard_index: 0.3826 - sensitivity: 0.8216 - specificity: 0.9206 - precision: 0.4170
# Epoch 20: val_dice_coefficient did not improve from 0.54675
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2314 - accuracy: 0.8634 - dice_coefficient: 0.5522 - jaccard_index: 0.3831 - sensitivity: 0.8218 - specificity: 0.9207 - precision: 0.4175 - val_loss: 0.2430 - val_accuracy: 0.8518 - val_dice_coefficient: 0.5268 - val_jaccard_index: 0.3587 - val_sensitivity: 0.8294 - val_specificity: 0.9120 - val_precision: 0.3867
# Epoch 21/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2299 - accuracy: 0.8639 - dice_coefficient: 0.5538 - jaccard_index: 0.3848 - sensitivity: 0.8229 - specificity: 0.9207 - precision: 0.4192
# Epoch 21: val_dice_coefficient improved from 0.54675 to 0.56007, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 157ms/step - loss: 0.2297 - accuracy: 0.8641 - dice_coefficient: 0.5534 - jaccard_index: 0.3844 - sensitivity: 0.8218 - specificity: 0.9210 - precision: 0.4190 - val_loss: 0.2455 - val_accuracy: 0.8813 - val_dice_coefficient: 0.5601 - val_jaccard_index: 0.3903 - val_sensitivity: 0.7690 - val_specificity: 0.9348 - val_precision: 0.4413
# Epoch 22/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2267 - accuracy: 0.8659 - dice_coefficient: 0.5561 - jaccard_index: 0.3870 - sensitivity: 0.8277 - specificity: 0.9211 - precision: 0.4209
# Epoch 22: val_dice_coefficient did not improve from 0.56007
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2266 - accuracy: 0.8659 - dice_coefficient: 0.5569 - jaccard_index: 0.3879 - sensitivity: 0.8281 - specificity: 0.9213 - precision: 0.4217 - val_loss: 0.2389 - val_accuracy: 0.8557 - val_dice_coefficient: 0.5328 - val_jaccard_index: 0.3643 - val_sensitivity: 0.8468 - val_specificity: 0.9114 - val_precision: 0.3894
# Epoch 23/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2245 - accuracy: 0.8671 - dice_coefficient: 0.5593 - jaccard_index: 0.3898 - sensitivity: 0.8309 - specificity: 0.9215 - precision: 0.4234
# Epoch 23: val_dice_coefficient did not improve from 0.56007
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2244 - accuracy: 0.8671 - dice_coefficient: 0.5587 - jaccard_index: 0.3893 - sensitivity: 0.8310 - specificity: 0.9216 - precision: 0.4228 - val_loss: 0.2325 - val_accuracy: 0.8606 - val_dice_coefficient: 0.5388 - val_jaccard_index: 0.3700 - val_sensitivity: 0.8535 - val_specificity: 0.9117 - val_precision: 0.3947
# Epoch 24/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2230 - accuracy: 0.8678 - dice_coefficient: 0.5579 - jaccard_index: 0.3886 - sensitivity: 0.8278 - specificity: 0.9217 - precision: 0.4229
# Epoch 24: val_dice_coefficient improved from 0.56007 to 0.56581, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.2235 - accuracy: 0.8675 - dice_coefficient: 0.5581 - jaccard_index: 0.3888 - sensitivity: 0.8280 - specificity: 0.9206 - precision: 0.4231 - val_loss: 0.2458 - val_accuracy: 0.8865 - val_dice_coefficient: 0.5658 - val_jaccard_index: 0.3958 - val_sensitivity: 0.7678 - val_specificity: 0.9366 - val_precision: 0.4488
# Epoch 25/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2194 - accuracy: 0.8702 - dice_coefficient: 0.5636 - jaccard_index: 0.3940 - sensitivity: 0.8347 - specificity: 0.9224 - precision: 0.4272
# Epoch 25: val_dice_coefficient did not improve from 0.56581
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2191 - accuracy: 0.8703 - dice_coefficient: 0.5643 - jaccard_index: 0.3947 - sensitivity: 0.8350 - specificity: 0.9227 - precision: 0.4280 - val_loss: 0.2397 - val_accuracy: 0.8724 - val_dice_coefficient: 0.5440 - val_jaccard_index: 0.3748 - val_sensitivity: 0.8423 - val_specificity: 0.9156 - val_precision: 0.4029
# Epoch 26/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2159 - accuracy: 0.8719 - dice_coefficient: 0.5669 - jaccard_index: 0.3972 - sensitivity: 0.8418 - specificity: 0.9227 - precision: 0.4292
# Epoch 26: val_dice_coefficient did not improve from 0.56581
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2163 - accuracy: 0.8718 - dice_coefficient: 0.5665 - jaccard_index: 0.3968 - sensitivity: 0.8408 - specificity: 0.9224 - precision: 0.4290 - val_loss: 0.2332 - val_accuracy: 0.8543 - val_dice_coefficient: 0.5395 - val_jaccard_index: 0.3706 - val_sensitivity: 0.8548 - val_specificity: 0.9124 - val_precision: 0.3951
# Epoch 27/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2197 - accuracy: 0.8688 - dice_coefficient: 0.5620 - jaccard_index: 0.3927 - sensitivity: 0.8353 - specificity: 0.9219 - precision: 0.4257
# Epoch 27: val_dice_coefficient did not improve from 0.56581
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2195 - accuracy: 0.8690 - dice_coefficient: 0.5619 - jaccard_index: 0.3926 - sensitivity: 0.8358 - specificity: 0.9222 - precision: 0.4255 - val_loss: 0.2275 - val_accuracy: 0.8630 - val_dice_coefficient: 0.5454 - val_jaccard_index: 0.3762 - val_sensitivity: 0.8641 - val_specificity: 0.9132 - val_precision: 0.3995
# Epoch 28/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2119 - accuracy: 0.8742 - dice_coefficient: 0.5721 - jaccard_index: 0.4026 - sensitivity: 0.8465 - specificity: 0.9236 - precision: 0.4339
# Epoch 28: val_dice_coefficient did not improve from 0.56581
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2121 - accuracy: 0.8741 - dice_coefficient: 0.5723 - jaccard_index: 0.4027 - sensitivity: 0.8465 - specificity: 0.9233 - precision: 0.4340 - val_loss: 0.2250 - val_accuracy: 0.8733 - val_dice_coefficient: 0.5580 - val_jaccard_index: 0.3883 - val_sensitivity: 0.8523 - val_specificity: 0.9190 - val_precision: 0.4160
# Epoch 29/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2101 - accuracy: 0.8754 - dice_coefficient: 0.5739 - jaccard_index: 0.4042 - sensitivity: 0.8485 - specificity: 0.9236 - precision: 0.4355
# Epoch 29: val_dice_coefficient did not improve from 0.56581
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2103 - accuracy: 0.8753 - dice_coefficient: 0.5740 - jaccard_index: 0.4043 - sensitivity: 0.8485 - specificity: 0.9234 - precision: 0.4356 - val_loss: 0.2209 - val_accuracy: 0.8711 - val_dice_coefficient: 0.5587 - val_jaccard_index: 0.3889 - val_sensitivity: 0.8559 - val_specificity: 0.9195 - val_precision: 0.4155
# Epoch 30/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2126 - accuracy: 0.8742 - dice_coefficient: 0.5728 - jaccard_index: 0.4032 - sensitivity: 0.8460 - specificity: 0.9236 - precision: 0.4358
# Epoch 30: val_dice_coefficient did not improve from 0.56581
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2125 - accuracy: 0.8742 - dice_coefficient: 0.5734 - jaccard_index: 0.4038 - sensitivity: 0.8465 - specificity: 0.9237 - precision: 0.4363 - val_loss: 0.2215 - val_accuracy: 0.8730 - val_dice_coefficient: 0.5617 - val_jaccard_index: 0.3917 - val_sensitivity: 0.8473 - val_specificity: 0.9217 - val_precision: 0.4208
# Epoch 31/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2087 - accuracy: 0.8766 - dice_coefficient: 0.5766 - jaccard_index: 0.4069 - sensitivity: 0.8493 - specificity: 0.9241 - precision: 0.4394
# Epoch 31: val_dice_coefficient did not improve from 0.56581
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2086 - accuracy: 0.8767 - dice_coefficient: 0.5763 - jaccard_index: 0.4066 - sensitivity: 0.8488 - specificity: 0.9244 - precision: 0.4391 - val_loss: 0.2588 - val_accuracy: 0.8044 - val_dice_coefficient: 0.5143 - val_jaccard_index: 0.3474 - val_sensitivity: 0.8578 - val_specificity: 0.9035 - val_precision: 0.3682
# Epoch 32/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2064 - accuracy: 0.8777 - dice_coefficient: 0.5793 - jaccard_index: 0.4095 - sensitivity: 0.8519 - specificity: 0.9247 - precision: 0.4413
# Epoch 32: val_dice_coefficient improved from 0.56581 to 0.58001, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.2065 - accuracy: 0.8776 - dice_coefficient: 0.5798 - jaccard_index: 0.4100 - sensitivity: 0.8522 - specificity: 0.9245 - precision: 0.4417 - val_loss: 0.2168 - val_accuracy: 0.8833 - val_dice_coefficient: 0.5800 - val_jaccard_index: 0.4099 - val_sensitivity: 0.8314 - val_specificity: 0.9310 - val_precision: 0.4462
# Epoch 33/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2050 - accuracy: 0.8784 - dice_coefficient: 0.5798 - jaccard_index: 0.4101 - sensitivity: 0.8552 - specificity: 0.9245 - precision: 0.4410
# Epoch 33: val_dice_coefficient did not improve from 0.58001
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2048 - accuracy: 0.8785 - dice_coefficient: 0.5794 - jaccard_index: 0.4096 - sensitivity: 0.8541 - specificity: 0.9248 - precision: 0.4408 - val_loss: 0.2210 - val_accuracy: 0.8845 - val_dice_coefficient: 0.5777 - val_jaccard_index: 0.4076 - val_sensitivity: 0.8235 - val_specificity: 0.9318 - val_precision: 0.4457
# Epoch 34/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2010 - accuracy: 0.8809 - dice_coefficient: 0.5810 - jaccard_index: 0.4114 - sensitivity: 0.8590 - specificity: 0.9254 - precision: 0.4407
# Epoch 34: val_dice_coefficient did not improve from 0.58001
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2010 - accuracy: 0.8809 - dice_coefficient: 0.5807 - jaccard_index: 0.4111 - sensitivity: 0.8587 - specificity: 0.9254 - precision: 0.4405 - val_loss: 0.2163 - val_accuracy: 0.8815 - val_dice_coefficient: 0.5730 - val_jaccard_index: 0.4031 - val_sensitivity: 0.8487 - val_specificity: 0.9253 - val_precision: 0.4339
# Epoch 35/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.8794 - dice_coefficient: 0.5830 - jaccard_index: 0.4132 - sensitivity: 0.8542 - specificity: 0.9255 - precision: 0.4458
# Epoch 35: val_dice_coefficient did not improve from 0.58001
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2043 - accuracy: 0.8794 - dice_coefficient: 0.5833 - jaccard_index: 0.4136 - sensitivity: 0.8546 - specificity: 0.9253 - precision: 0.4461 - val_loss: 0.2544 - val_accuracy: 0.8538 - val_dice_coefficient: 0.5325 - val_jaccard_index: 0.3640 - val_sensitivity: 0.8438 - val_specificity: 0.9107 - val_precision: 0.3901
# Epoch 36/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2061 - accuracy: 0.8781 - dice_coefficient: 0.5780 - jaccard_index: 0.4087 - sensitivity: 0.8553 - specificity: 0.9240 - precision: 0.4396
# Epoch 36: val_dice_coefficient did not improve from 0.58001
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2060 - accuracy: 0.8781 - dice_coefficient: 0.5777 - jaccard_index: 0.4084 - sensitivity: 0.8552 - specificity: 0.9241 - precision: 0.4393 - val_loss: 0.2165 - val_accuracy: 0.8747 - val_dice_coefficient: 0.5625 - val_jaccard_index: 0.3926 - val_sensitivity: 0.8722 - val_specificity: 0.9179 - val_precision: 0.4160
# Epoch 37/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1963 - accuracy: 0.8840 - dice_coefficient: 0.5866 - jaccard_index: 0.4167 - sensitivity: 0.8639 - specificity: 0.9263 - precision: 0.4456
# Epoch 37: val_dice_coefficient did not improve from 0.58001
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1963 - accuracy: 0.8840 - dice_coefficient: 0.5866 - jaccard_index: 0.4167 - sensitivity: 0.8641 - specificity: 0.9263 - precision: 0.4456 - val_loss: 0.2113 - val_accuracy: 0.8828 - val_dice_coefficient: 0.5774 - val_jaccard_index: 0.4072 - val_sensitivity: 0.8673 - val_specificity: 0.9241 - val_precision: 0.4336
# Epoch 38/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1940 - accuracy: 0.8851 - dice_coefficient: 0.5903 - jaccard_index: 0.4204 - sensitivity: 0.8694 - specificity: 0.9265 - precision: 0.4484
# Epoch 38: val_dice_coefficient improved from 0.58001 to 0.58482, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.1938 - accuracy: 0.8852 - dice_coefficient: 0.5904 - jaccard_index: 0.4205 - sensitivity: 0.8690 - specificity: 0.9268 - precision: 0.4487 - val_loss: 0.2165 - val_accuracy: 0.8889 - val_dice_coefficient: 0.5848 - val_jaccard_index: 0.4147 - val_sensitivity: 0.8497 - val_specificity: 0.9293 - val_precision: 0.4469
# Epoch 39/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1960 - accuracy: 0.8839 - dice_coefficient: 0.5902 - jaccard_index: 0.4206 - sensitivity: 0.8664 - specificity: 0.9263 - precision: 0.4502
# Epoch 39: val_dice_coefficient did not improve from 0.58482
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1959 - accuracy: 0.8839 - dice_coefficient: 0.5899 - jaccard_index: 0.4202 - sensitivity: 0.8666 - specificity: 0.9264 - precision: 0.4498 - val_loss: 0.2100 - val_accuracy: 0.8836 - val_dice_coefficient: 0.5810 - val_jaccard_index: 0.4109 - val_sensitivity: 0.8497 - val_specificity: 0.9288 - val_precision: 0.4425
# Epoch 40/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1929 - accuracy: 0.8860 - dice_coefficient: 0.5923 - jaccard_index: 0.4223 - sensitivity: 0.8694 - specificity: 0.9269 - precision: 0.4507
# Epoch 40: val_dice_coefficient did not improve from 0.58482
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1928 - accuracy: 0.8861 - dice_coefficient: 0.5930 - jaccard_index: 0.4232 - sensitivity: 0.8697 - specificity: 0.9271 - precision: 0.4516 - val_loss: 0.2082 - val_accuracy: 0.8812 - val_dice_coefficient: 0.5812 - val_jaccard_index: 0.4111 - val_sensitivity: 0.8649 - val_specificity: 0.9262 - val_precision: 0.4385
# Epoch 41/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1959 - accuracy: 0.8844 - dice_coefficient: 0.5912 - jaccard_index: 0.4215 - sensitivity: 0.8665 - specificity: 0.9267 - precision: 0.4511
# Epoch 41: val_dice_coefficient improved from 0.58482 to 0.59912, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.1958 - accuracy: 0.8844 - dice_coefficient: 0.5920 - jaccard_index: 0.4224 - sensitivity: 0.8667 - specificity: 0.9268 - precision: 0.4520 - val_loss: 0.2200 - val_accuracy: 0.8955 - val_dice_coefficient: 0.5991 - val_jaccard_index: 0.4294 - val_sensitivity: 0.8079 - val_specificity: 0.9404 - val_precision: 0.4772
# Epoch 42/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1902 - accuracy: 0.8878 - dice_coefficient: 0.5951 - jaccard_index: 0.4252 - sensitivity: 0.8731 - specificity: 0.9277 - precision: 0.4531
# Epoch 42: val_dice_coefficient did not improve from 0.59912
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1902 - accuracy: 0.8878 - dice_coefficient: 0.5955 - jaccard_index: 0.4257 - sensitivity: 0.8733 - specificity: 0.9276 - precision: 0.4535 - val_loss: 0.2085 - val_accuracy: 0.8907 - val_dice_coefficient: 0.5949 - val_jaccard_index: 0.4250 - val_sensitivity: 0.8523 - val_specificity: 0.9324 - val_precision: 0.4580
# Epoch 43/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1881 - accuracy: 0.8889 - dice_coefficient: 0.5985 - jaccard_index: 0.4287 - sensitivity: 0.8766 - specificity: 0.9281 - precision: 0.4559
# Epoch 43: val_dice_coefficient did not improve from 0.59912
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1880 - accuracy: 0.8889 - dice_coefficient: 0.5976 - jaccard_index: 0.4279 - sensitivity: 0.8749 - specificity: 0.9283 - precision: 0.4554 - val_loss: 0.2057 - val_accuracy: 0.8830 - val_dice_coefficient: 0.5814 - val_jaccard_index: 0.4113 - val_sensitivity: 0.8816 - val_specificity: 0.9236 - val_precision: 0.4346
# Epoch 44/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1870 - accuracy: 0.8895 - dice_coefficient: 0.5983 - jaccard_index: 0.4287 - sensitivity: 0.8768 - specificity: 0.9280 - precision: 0.4558
# Epoch 44: val_dice_coefficient did not improve from 0.59912
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1870 - accuracy: 0.8895 - dice_coefficient: 0.5986 - jaccard_index: 0.4290 - sensitivity: 0.8770 - specificity: 0.9280 - precision: 0.4561 - val_loss: 0.2069 - val_accuracy: 0.8924 - val_dice_coefficient: 0.5963 - val_jaccard_index: 0.4262 - val_sensitivity: 0.8537 - val_specificity: 0.9326 - val_precision: 0.4590
# Epoch 45/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.8863 - dice_coefficient: 0.5919 - jaccard_index: 0.4226 - sensitivity: 0.8676 - specificity: 0.9275 - precision: 0.4523
# Epoch 45: val_dice_coefficient did not improve from 0.59912
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1923 - accuracy: 0.8863 - dice_coefficient: 0.5915 - jaccard_index: 0.4222 - sensitivity: 0.8669 - specificity: 0.9276 - precision: 0.4520 - val_loss: 0.2062 - val_accuracy: 0.8701 - val_dice_coefficient: 0.5651 - val_jaccard_index: 0.3953 - val_sensitivity: 0.9056 - val_specificity: 0.9138 - val_precision: 0.4118
# Epoch 46/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1853 - accuracy: 0.8905 - dice_coefficient: 0.6027 - jaccard_index: 0.4332 - sensitivity: 0.8803 - specificity: 0.9284 - precision: 0.4601
# Epoch 46: val_dice_coefficient improved from 0.59912 to 0.60948, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_8.h5
# 216/216 [==============================] - 34s 157ms/step - loss: 0.1852 - accuracy: 0.8906 - dice_coefficient: 0.6020 - jaccard_index: 0.4326 - sensitivity: 0.8797 - specificity: 0.9287 - precision: 0.4595 - val_loss: 0.2159 - val_accuracy: 0.9036 - val_dice_coefficient: 0.6095 - val_jaccard_index: 0.4400 - val_sensitivity: 0.8263 - val_specificity: 0.9410 - val_precision: 0.4836
# Epoch 47/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1866 - accuracy: 0.8901 - dice_coefficient: 0.5994 - jaccard_index: 0.4298 - sensitivity: 0.8742 - specificity: 0.9286 - precision: 0.4583
# Epoch 47: val_dice_coefficient did not improve from 0.60948
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1868 - accuracy: 0.8900 - dice_coefficient: 0.5988 - jaccard_index: 0.4292 - sensitivity: 0.8737 - specificity: 0.9283 - precision: 0.4577 - val_loss: 0.2036 - val_accuracy: 0.8913 - val_dice_coefficient: 0.5957 - val_jaccard_index: 0.4257 - val_sensitivity: 0.8739 - val_specificity: 0.9292 - val_precision: 0.4528
# Epoch 48/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1845 - accuracy: 0.8912 - dice_coefficient: 0.6018 - jaccard_index: 0.4328 - sensitivity: 0.8793 - specificity: 0.9288 - precision: 0.4599
# Epoch 48: val_dice_coefficient did not improve from 0.60948
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1846 - accuracy: 0.8912 - dice_coefficient: 0.6018 - jaccard_index: 0.4327 - sensitivity: 0.8793 - specificity: 0.9286 - precision: 0.4599 - val_loss: 0.2006 - val_accuracy: 0.8867 - val_dice_coefficient: 0.5914 - val_jaccard_index: 0.4213 - val_sensitivity: 0.8856 - val_specificity: 0.9261 - val_precision: 0.4449
# Epoch 49/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1811 - accuracy: 0.8933 - dice_coefficient: 0.6059 - jaccard_index: 0.4362 - sensitivity: 0.8843 - specificity: 0.9293 - precision: 0.4623
# Epoch 49: val_dice_coefficient did not improve from 0.60948
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1810 - accuracy: 0.8933 - dice_coefficient: 0.6057 - jaccard_index: 0.4360 - sensitivity: 0.8843 - specificity: 0.9295 - precision: 0.4620 - val_loss: 0.2034 - val_accuracy: 0.8897 - val_dice_coefficient: 0.5946 - val_jaccard_index: 0.4245 - val_sensitivity: 0.8806 - val_specificity: 0.9278 - val_precision: 0.4497
# Epoch 50/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.1812 - accuracy: 0.8933 - dice_coefficient: 0.6072 - jaccard_index: 0.4377 - sensitivity: 0.8845 - specificity: 0.9295 - precision: 0.4642
# Epoch 50: val_dice_coefficient did not improve from 0.60948
# 216/216 [==============================] - 32s 148ms/step - loss: 0.1814 - accuracy: 0.8931 - dice_coefficient: 0.6066 - jaccard_index: 0.4372 - sensitivity: 0.8841 - specificity: 0.9292 - precision: 0.4636 - val_loss: 0.2052 - val_accuracy: 0.8943 - val_dice_coefficient: 0.5967 - val_jaccard_index: 0.4268 - val_sensitivity: 0.8771 - val_specificity: 0.9291 - val_precision: 0.4533
# Model saved to: /gdrive/My Drive/Dataset/Models/unet_vgg_8.h5

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_auc_score

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred, threshold=threshold):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > threshold).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative (Correct: No Buildings)', 'False Positive (Incorrect: There Was No Building)', 'False Negative (Incorrect: There Was A Building Here)', 'True Positive (Correct: There Is A Building Here)']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred, threshold=threshold)
plot_confusion_matrix(y_test, y_pred, threshold=threshold)
print(classification_report(y_test.flatten(), (y_pred.flatten() > threshold).astype(int)))
print("ROC-AUC:", roc_auc_score(y_test.flatten(), y_pred.flatten()))
# Out:
# 15/15 [==============================] - 30s 1s/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.92      0.96  29326208
#          1.0       0.45      0.87      0.59   2065536
#
#     accuracy                           0.92  31391744
#    macro avg       0.72      0.90      0.77  31391744
# weighted avg       0.95      0.92      0.93  31391744
#
# ROC-AUC: 0.9680201288678181
