# %% [markdown]
# # UNet+VGG16 11
# This is the 11th iteration of UNet+VGG16
#
# In this iteration I:
# - built off vgg 9
# - changed the threshold for metric evalutation from .75 to .25 to see if that has any effect? does it just serve to change the metrics during training or will it impact the results at model evaluation?
#
#
# **NOTE:** Connect to a High-RAM Environment with GPU enabled

# %% [markdown]
# # Training

# %% [markdown]
# Settings

# %%
# Check for GPU availability
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# MODEL SETTINGS
model_name = 'unet_vgg_11'  # Name of the model
percentage_to_load = 50 / 100.0  # Set the % of dataset to be loaded here.
threshold = 0.25  # Set the threshold for metrics here
initial_lr = 0.01  # Learning rate at the beginning of training (NOT INCORPORATED CURRENTLY, set at 1e-4)
print(f'\nSETTINGS:')
print(f'Model Name: {model_name}')
print(f'Percentage to Load: {percentage_to_load*100}%')
print(f'Threshold: {threshold}')
print(f'Initial Learning Rate: {initial_lr}')
print()

# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')

# Imports
import os
import cv2
import numpy as np
import tifffile as tiff
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LayerNormalization, Dense, Dropout, Flatten, Conv2DTranspose
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Num GPUs Available:  1
#
# SETTINGS:
# Model Name: unet_vgg_11
# Percentage to Load: 50.0%
# Threshold: 0.25
# Initial Learning Rate: 0.01
#
# Mounted at /gdrive

# %% [markdown]
# Data Loading

# %%
# Function to count files
def count_files(directory, extension=".tif"):
    return sum(1 for file in os.listdir(directory) if file.endswith(extension))

# Paths to your image and mask directories
image_directory = '/gdrive/My Drive/Dataset/patches/train/images/'
mask_directory = '/gdrive/My Drive/Dataset/patches/train/masks/'

# Counting the TIFF files in both directories
image_count = count_files(image_directory)
mask_count = count_files(mask_directory)

print(f"Number of image files: {image_count}")
print(f"Number of mask files: {mask_count}")

# Load the images and masks into the lists below
images = []
masks = []

# Sort filenames to ensure matching pairs align
image_files = sorted([f for f in os.listdir(image_directory) if f.endswith(".tif")])
mask_files = sorted([f for f in os.listdir(mask_directory) if f.endswith(".tif")])

# Determine how many files to load based on percentage
number_of_files_to_load = int(len(image_files) * percentage_to_load)

# Create a mapping of image names to their corresponding mask names by removing '_Buildings'
image_to_mask = {f: f.replace("_patch", "_Buildings_patch") for f in image_files}

# Only iterate over the subset of files determined by the percentage
print(f'Attempting to load {percentage_to_load*100}% of dataset: {number_of_files_to_load} images/mask pairs...')
for count, image_name in enumerate(tqdm(image_files[:number_of_files_to_load]), start=1):
    try:
        img_path = os.path.join(image_directory, image_name)
        mask_name = image_to_mask[image_name]
        mask_path = os.path.join(mask_directory, mask_name)

        if os.path.exists(mask_path):
            img = tiff.imread(img_path)
            mask = tiff.imread(mask_path)

            images.append(img)
            masks.append(mask)
        else:
            print(f'\nMask not found for image: {image_name}')
    except Exception as e:
        print(f'\nError loading image/mask pair {image_name}: {e}')

print("\nLoading complete.")

# Check if the number of images and masks loaded are equal
if len(images) != len(masks):
    raise ValueError("The number of loaded images and masks do not match!")
# Out:
# Number of image files: 4787
# Number of mask files: 4787
# Attempting to load 50.0% of dataset: 2393 images/mask pairs...
# 100%|██████████| 2393/2393 [35:39<00:00,  1.12it/s]
# Loading complete.

# %% [markdown]
# Normalization & Train/Test/Val Split

# %%
# Convert the lists to numpy arrays
images = np.array(images, dtype=np.float32)
masks = np.array(masks, dtype=np.float32)

# Normalize the values
images /= 255.0
masks /= 255.0
masks = masks.reshape((-1, 256, 256, 1))

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=1995)

# Further split the training set into training and validation sets (90% train, 10% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1995)

# If X_train, X_test, X_val have an extra unnecessary dimension at axis=1, remove it:
X_train = X_train.squeeze(axis=1)
X_test = X_test.squeeze(axis=1)
X_val = X_val.squeeze(axis=1)

# Display the shapes of the datasets to confirm correct dimensions
print('Dataset Shapes:')
print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val: {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test: {y_test.shape}')
# Out:
# Dataset Shapes:
# X_train: (1722, 256, 256, 3), y_train: (1722, 256, 256, 1)
# X_val:   (192, 256, 256, 3), y_val: (192, 256, 256, 1)
# X_test:  (479, 256, 256, 3), y_test: (479, 256, 256, 1)

# %% [markdown]
# Metrics & Loss

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# CUSTOM METRICS

# Dice Coefficient: Measures overlap between true and predicted masks.
def dice_coefficient(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + tf.keras.backend.epsilon()) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + tf.keras.backend.epsilon())

# Jaccard Index: Measures the ratio of intersection to the union of true and predicted masks.
def jaccard_index(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f + y_pred_f) - intersection
    return (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())

# Sensitivity: Measures the proportion of actual positives correctly identified.
def sensitivity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    possible_positives = tf.reduce_sum(y_true_f)
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

# Specificity: Measures the proportion of actual negatives correctly identified.
def specificity(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_negatives = tf.reduce_sum((1-y_true_f) * (1-y_pred_f))
    possible_negatives = tf.reduce_sum(1-y_true_f)
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# Precision: Measures the proportion of predicted positives that are actually true positives.
def precision(y_true, y_pred, threshold=threshold):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]) > threshold, tf.float32)
    true_positives = tf.reduce_sum(y_true_f * y_pred_f)
    predicted_positives = tf.reduce_sum(y_pred_f)
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())


# LOSS FUNCTION
def calculate_class_weights(masks):
    flat_labels = masks.flatten().astype(int)
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(flat_labels), y=flat_labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    return class_weights_dict

def weighted_binary_crossentropy(weights):
    def loss(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        weighted_bce = bce * (weights[1] * y_true + weights[0] * (1 - y_true))
        return tf.keras.backend.mean(weighted_bce)
    return loss

# Calculate the class weights for the training masks
class_weights = calculate_class_weights(y_train)
print("Class weights:", class_weights)

# Visualize class weight distribution
plt.bar(class_weights.keys(), class_weights.values())
plt.title("Class Weight Distribution")
plt.xlabel("Class")
plt.ylabel("Weight")
plt.show()

weighted_loss = weighted_binary_crossentropy(class_weights)
# Out:
# Class weights: {0: 0.5339968946194886, 1: 7.853612816644959}

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16

def vgg16_unet(input_size=(256, 256, 3), freeze_vgg16=True, dropout_rate=0.45):
    inputs = Input(input_size)
    vgg16 = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_vgg16:
        # Freeze the VGG16 layers
        for layer in vgg16.layers:
            layer.trainable = False

    # Skip connections from VGG16 layers
    s1 = vgg16.get_layer("block1_conv2").output
    s2 = vgg16.get_layer("block2_conv2").output
    s3 = vgg16.get_layer("block3_conv3").output
    s4 = vgg16.get_layer("block4_conv3").output
    bridge = vgg16.get_layer("block5_conv3").output

    # Decoder with dropout
    up1 = UpSampling2D((2, 2))(bridge)
    up1 = concatenate([up1, s4])
    up1 = Conv2D(512, (3, 3), activation='relu', padding='same')(up1)
    up1 = Dropout(dropout_rate)(up1)

    up2 = UpSampling2D((2, 2))(up1)
    up2 = concatenate([up2, s3])
    up2 = Conv2D(256, (3, 3), activation='relu', padding='same')(up2)
    up2 = Dropout(dropout_rate)(up2)

    up3 = UpSampling2D((2, 2))(up2)
    up3 = concatenate([up3, s2])
    up3 = Conv2D(128, (3, 3), activation='relu', padding='same')(up3)
    up3 = Dropout(dropout_rate)(up3)

    up4 = UpSampling2D((2, 2))(up3)
    up4 = concatenate([up4, s1])
    up4 = Conv2D(64, (3, 3), activation='relu', padding='same')(up4)
    up4 = Dropout(dropout_rate)(up4)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(up4)

    model = Model(inputs, outputs)
    return model

# %% [markdown]
# Model Compilation

# %%
from keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Define the model
model = vgg16_unet()

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=weighted_loss,
    metrics=['accuracy', dice_coefficient, jaccard_index, sensitivity, specificity, precision]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)          0         ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)          2359808   ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)          2359808   ['block5_conv2[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 512)          0         ['block5_conv3[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 1024)         0         ['up_sampling2d[0][0]',
#                                                                      'block4_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 512)          4719104   ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 32, 32, 512)          0         ['conv2d[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 512)          0         ['dropout[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 768)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'block3_conv3[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 256)          1769728   ['concatenate_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64, 256)          0         ['conv2d_1[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 256)        0         ['dropout_1[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'block2_conv2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        442496    ['concatenate_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 128, 128, 128)        0         ['conv2d_2[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 128)        0         ['dropout_2[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_3[0][0]',
#  )                                                                   'block1_conv2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         110656    ['concatenate_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 256, 256, 64)         0         ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 1)          65        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 21756737 (83.00 MB)
# Trainable params: 7042049 (26.86 MB)
# Non-trainable params: 14714688 (56.13 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Early Stopping to prevent overfitting
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=15,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    f'/gdrive/My Drive/Dataset/Models/best_{model_name}.h5',  # Path where the model will be saved
    monitor='val_dice_coefficient',  # Save the model based on the maximum dice_coefficient value
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Fit the model
history = model.fit(
    X_train, y_train,
    batch_size=8,
    epochs=50,
    verbose=1,
    validation_data=(X_val, y_val),
    callbacks=[model_checkpoint, early_stopping]
)

# Save the model
model.save(f'/gdrive/My Drive/Dataset/Models/{model_name}.h5')
print(f'Model saved to: /gdrive/My Drive/Dataset/Models/{model_name}.h5')
# Out:
# Epoch 1/50
# 216/216 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.6946 - dice_coefficient: 0.1887 - jaccard_index: 0.1052 - sensitivity: 0.9040 - specificity: 0.4803 - precision: 0.1063
# Epoch 1: val_dice_coefficient improved from -inf to 0.22029, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 216/216 [==============================] - 51s 163ms/step - loss: 0.6655 - accuracy: 0.6946 - dice_coefficient: 0.1887 - jaccard_index: 0.1052 - sensitivity: 0.9040 - specificity: 0.4803 - precision: 0.1063 - val_loss: 0.4059 - val_accuracy: 0.7318 - val_dice_coefficient: 0.2203 - val_jaccard_index: 0.1245 - val_sensitivity: 0.9760 - val_specificity: 0.5531 - val_precision: 0.1249
# Epoch 2/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.4183 - accuracy: 0.7543 - dice_coefficient: 0.2376 - jaccard_index: 0.1357 - sensitivity: 0.9604 - specificity: 0.5887 - precision: 0.1365
# Epoch 2: val_dice_coefficient improved from 0.22029 to 0.25555, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 33s 155ms/step - loss: 0.4184 - accuracy: 0.7543 - dice_coefficient: 0.2384 - jaccard_index: 0.1362 - sensitivity: 0.9605 - specificity: 0.5888 - precision: 0.1370 - val_loss: 0.3664 - val_accuracy: 0.7671 - val_dice_coefficient: 0.2556 - val_jaccard_index: 0.1472 - val_sensitivity: 0.9707 - val_specificity: 0.6355 - val_precision: 0.1479
# Epoch 3/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3894 - accuracy: 0.7707 - dice_coefficient: 0.2581 - jaccard_index: 0.1491 - sensitivity: 0.9627 - specificity: 0.6291 - precision: 0.1500
# Epoch 3: val_dice_coefficient improved from 0.25555 to 0.29849, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 34s 158ms/step - loss: 0.3893 - accuracy: 0.7708 - dice_coefficient: 0.2577 - jaccard_index: 0.1489 - sensitivity: 0.9625 - specificity: 0.6295 - precision: 0.1498 - val_loss: 0.3624 - val_accuracy: 0.8269 - val_dice_coefficient: 0.2985 - val_jaccard_index: 0.1761 - val_sensitivity: 0.9482 - val_specificity: 0.7135 - val_precision: 0.1778
# Epoch 4/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3679 - accuracy: 0.7838 - dice_coefficient: 0.2724 - jaccard_index: 0.1587 - sensitivity: 0.9652 - specificity: 0.6587 - precision: 0.1596
# Epoch 4: val_dice_coefficient did not improve from 0.29849
# 216/216 [==============================] - 32s 148ms/step - loss: 0.3682 - accuracy: 0.7836 - dice_coefficient: 0.2726 - jaccard_index: 0.1589 - sensitivity: 0.9652 - specificity: 0.6580 - precision: 0.1598 - val_loss: 0.3395 - val_accuracy: 0.7775 - val_dice_coefficient: 0.2766 - val_jaccard_index: 0.1612 - val_sensitivity: 0.9732 - val_specificity: 0.6716 - val_precision: 0.1618
# Epoch 5/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3530 - accuracy: 0.7898 - dice_coefficient: 0.2836 - jaccard_index: 0.1663 - sensitivity: 0.9670 - specificity: 0.6761 - precision: 0.1672
# Epoch 5: val_dice_coefficient improved from 0.29849 to 0.30819, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 34s 156ms/step - loss: 0.3531 - accuracy: 0.7897 - dice_coefficient: 0.2841 - jaccard_index: 0.1667 - sensitivity: 0.9671 - specificity: 0.6758 - precision: 0.1676 - val_loss: 0.3287 - val_accuracy: 0.8143 - val_dice_coefficient: 0.3082 - val_jaccard_index: 0.1828 - val_sensitivity: 0.9633 - val_specificity: 0.7212 - val_precision: 0.1841
# Epoch 6/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3427 - accuracy: 0.7963 - dice_coefficient: 0.2953 - jaccard_index: 0.1741 - sensitivity: 0.9684 - specificity: 0.6897 - precision: 0.1751
# Epoch 6: val_dice_coefficient did not improve from 0.30819
# 216/216 [==============================] - 32s 148ms/step - loss: 0.3428 - accuracy: 0.7961 - dice_coefficient: 0.2949 - jaccard_index: 0.1738 - sensitivity: 0.9684 - specificity: 0.6890 - precision: 0.1749 - val_loss: 0.3173 - val_accuracy: 0.8054 - val_dice_coefficient: 0.3029 - val_jaccard_index: 0.1791 - val_sensitivity: 0.9727 - val_specificity: 0.7111 - val_precision: 0.1800
# Epoch 7/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3341 - accuracy: 0.8013 - dice_coefficient: 0.3020 - jaccard_index: 0.1788 - sensitivity: 0.9693 - specificity: 0.6996 - precision: 0.1799
# Epoch 7: val_dice_coefficient did not improve from 0.30819
# 216/216 [==============================] - 32s 148ms/step - loss: 0.3342 - accuracy: 0.8012 - dice_coefficient: 0.3020 - jaccard_index: 0.1788 - sensitivity: 0.9693 - specificity: 0.6992 - precision: 0.1799 - val_loss: 0.3123 - val_accuracy: 0.7920 - val_dice_coefficient: 0.2931 - val_jaccard_index: 0.1724 - val_sensitivity: 0.9812 - val_specificity: 0.6944 - val_precision: 0.1729
# Epoch 8/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3227 - accuracy: 0.8068 - dice_coefficient: 0.3100 - jaccard_index: 0.1844 - sensitivity: 0.9714 - specificity: 0.7125 - precision: 0.1854
# Epoch 8: val_dice_coefficient improved from 0.30819 to 0.32040, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 34s 157ms/step - loss: 0.3225 - accuracy: 0.8069 - dice_coefficient: 0.3099 - jaccard_index: 0.1843 - sensitivity: 0.9714 - specificity: 0.7131 - precision: 0.1853 - val_loss: 0.3031 - val_accuracy: 0.8203 - val_dice_coefficient: 0.3204 - val_jaccard_index: 0.1914 - val_sensitivity: 0.9722 - val_specificity: 0.7336 - val_precision: 0.1924
# Epoch 9/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3146 - accuracy: 0.8115 - dice_coefficient: 0.3159 - jaccard_index: 0.1884 - sensitivity: 0.9727 - specificity: 0.7208 - precision: 0.1894
# Epoch 9: val_dice_coefficient did not improve from 0.32040
# 216/216 [==============================] - 32s 148ms/step - loss: 0.3150 - accuracy: 0.8113 - dice_coefficient: 0.3166 - jaccard_index: 0.1889 - sensitivity: 0.9727 - specificity: 0.7198 - precision: 0.1899 - val_loss: 0.2967 - val_accuracy: 0.8147 - val_dice_coefficient: 0.3202 - val_jaccard_index: 0.1913 - val_sensitivity: 0.9760 - val_specificity: 0.7318 - val_precision: 0.1921
# Epoch 10/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.8146 - dice_coefficient: 0.3226 - jaccard_index: 0.1932 - sensitivity: 0.9727 - specificity: 0.7261 - precision: 0.1942
# Epoch 10: val_dice_coefficient improved from 0.32040 to 0.34741, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 34s 157ms/step - loss: 0.3096 - accuracy: 0.8146 - dice_coefficient: 0.3229 - jaccard_index: 0.1934 - sensitivity: 0.9728 - specificity: 0.7258 - precision: 0.1944 - val_loss: 0.2961 - val_accuracy: 0.8376 - val_dice_coefficient: 0.3474 - val_jaccard_index: 0.2108 - val_sensitivity: 0.9641 - val_specificity: 0.7658 - val_precision: 0.2124
# Epoch 11/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.3020 - accuracy: 0.8192 - dice_coefficient: 0.3293 - jaccard_index: 0.1981 - sensitivity: 0.9743 - specificity: 0.7348 - precision: 0.1991
# Epoch 11: val_dice_coefficient did not improve from 0.34741
# 216/216 [==============================] - 32s 148ms/step - loss: 0.3019 - accuracy: 0.8192 - dice_coefficient: 0.3294 - jaccard_index: 0.1982 - sensitivity: 0.9743 - specificity: 0.7348 - precision: 0.1992 - val_loss: 0.2867 - val_accuracy: 0.8301 - val_dice_coefficient: 0.3413 - val_jaccard_index: 0.2064 - val_sensitivity: 0.9722 - val_specificity: 0.7571 - val_precision: 0.2076
# Epoch 12/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2964 - accuracy: 0.8224 - dice_coefficient: 0.3337 - jaccard_index: 0.2013 - sensitivity: 0.9755 - specificity: 0.7400 - precision: 0.2023
# Epoch 12: val_dice_coefficient improved from 0.34741 to 0.36852, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 34s 160ms/step - loss: 0.2962 - accuracy: 0.8225 - dice_coefficient: 0.3334 - jaccard_index: 0.2011 - sensitivity: 0.9754 - specificity: 0.7408 - precision: 0.2021 - val_loss: 0.2980 - val_accuracy: 0.8609 - val_dice_coefficient: 0.3685 - val_jaccard_index: 0.2266 - val_sensitivity: 0.9546 - val_specificity: 0.7890 - val_precision: 0.2290
# Epoch 13/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2910 - accuracy: 0.8259 - dice_coefficient: 0.3399 - jaccard_index: 0.2058 - sensitivity: 0.9768 - specificity: 0.7462 - precision: 0.2068
# Epoch 13: val_dice_coefficient did not improve from 0.36852
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2910 - accuracy: 0.8259 - dice_coefficient: 0.3402 - jaccard_index: 0.2061 - sensitivity: 0.9768 - specificity: 0.7461 - precision: 0.2071 - val_loss: 0.2820 - val_accuracy: 0.8312 - val_dice_coefficient: 0.3391 - val_jaccard_index: 0.2048 - val_sensitivity: 0.9770 - val_specificity: 0.7534 - val_precision: 0.2058
# Epoch 14/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2878 - accuracy: 0.8279 - dice_coefficient: 0.3419 - jaccard_index: 0.2074 - sensitivity: 0.9771 - specificity: 0.7489 - precision: 0.2084
# Epoch 14: val_dice_coefficient did not improve from 0.36852
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2876 - accuracy: 0.8280 - dice_coefficient: 0.3414 - jaccard_index: 0.2070 - sensitivity: 0.9770 - specificity: 0.7494 - precision: 0.2080 - val_loss: 0.2743 - val_accuracy: 0.8242 - val_dice_coefficient: 0.3323 - val_jaccard_index: 0.2000 - val_sensitivity: 0.9840 - val_specificity: 0.7439 - val_precision: 0.2006
# Epoch 15/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2818 - accuracy: 0.8315 - dice_coefficient: 0.3480 - jaccard_index: 0.2116 - sensitivity: 0.9783 - specificity: 0.7554 - precision: 0.2126
# Epoch 15: val_dice_coefficient did not improve from 0.36852
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2816 - accuracy: 0.8316 - dice_coefficient: 0.3480 - jaccard_index: 0.2116 - sensitivity: 0.9784 - specificity: 0.7559 - precision: 0.2126 - val_loss: 0.2724 - val_accuracy: 0.8308 - val_dice_coefficient: 0.3409 - val_jaccard_index: 0.2061 - val_sensitivity: 0.9812 - val_specificity: 0.7536 - val_precision: 0.2069
# Epoch 16/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2779 - accuracy: 0.8338 - dice_coefficient: 0.3494 - jaccard_index: 0.2127 - sensitivity: 0.9779 - specificity: 0.7583 - precision: 0.2136
# Epoch 16: val_dice_coefficient improved from 0.36852 to 0.38102, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 34s 158ms/step - loss: 0.2781 - accuracy: 0.8337 - dice_coefficient: 0.3492 - jaccard_index: 0.2126 - sensitivity: 0.9779 - specificity: 0.7576 - precision: 0.2135 - val_loss: 0.2766 - val_accuracy: 0.8648 - val_dice_coefficient: 0.3810 - val_jaccard_index: 0.2360 - val_sensitivity: 0.9653 - val_specificity: 0.7968 - val_precision: 0.2380
# Epoch 17/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2765 - accuracy: 0.8351 - dice_coefficient: 0.3543 - jaccard_index: 0.2163 - sensitivity: 0.9792 - specificity: 0.7611 - precision: 0.2173
# Epoch 17: val_dice_coefficient did not improve from 0.38102
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2763 - accuracy: 0.8352 - dice_coefficient: 0.3538 - jaccard_index: 0.2159 - sensitivity: 0.9792 - specificity: 0.7613 - precision: 0.2169 - val_loss: 0.2667 - val_accuracy: 0.8302 - val_dice_coefficient: 0.3471 - val_jaccard_index: 0.2107 - val_sensitivity: 0.9824 - val_specificity: 0.7601 - val_precision: 0.2115
# Epoch 18/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2729 - accuracy: 0.8371 - dice_coefficient: 0.3577 - jaccard_index: 0.2188 - sensitivity: 0.9790 - specificity: 0.7635 - precision: 0.2199
# Epoch 18: val_dice_coefficient did not improve from 0.38102
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2729 - accuracy: 0.8372 - dice_coefficient: 0.3582 - jaccard_index: 0.2192 - sensitivity: 0.9790 - specificity: 0.7638 - precision: 0.2203 - val_loss: 0.2633 - val_accuracy: 0.8293 - val_dice_coefficient: 0.3396 - val_jaccard_index: 0.2052 - val_sensitivity: 0.9867 - val_specificity: 0.7511 - val_precision: 0.2058
# Epoch 19/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2690 - accuracy: 0.8392 - dice_coefficient: 0.3610 - jaccard_index: 0.2215 - sensitivity: 0.9798 - specificity: 0.7672 - precision: 0.2225
# Epoch 19: val_dice_coefficient improved from 0.38102 to 0.41446, saving model to /gdrive/My Drive/Dataset/Models/best_unet_vgg_11.h5
# 216/216 [==============================] - 34s 157ms/step - loss: 0.2689 - accuracy: 0.8392 - dice_coefficient: 0.3605 - jaccard_index: 0.2212 - sensitivity: 0.9798 - specificity: 0.7672 - precision: 0.2222 - val_loss: 0.2860 - val_accuracy: 0.8809 - val_dice_coefficient: 0.4145 - val_jaccard_index: 0.2621 - val_sensitivity: 0.9459 - val_specificity: 0.8277 - val_precision: 0.2660
# Epoch 20/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2659 - accuracy: 0.8421 - dice_coefficient: 0.3630 - jaccard_index: 0.2229 - sensitivity: 0.9803 - specificity: 0.7715 - precision: 0.2239
# Epoch 20: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2659 - accuracy: 0.8420 - dice_coefficient: 0.3629 - jaccard_index: 0.2228 - sensitivity: 0.9803 - specificity: 0.7714 - precision: 0.2238 - val_loss: 0.2573 - val_accuracy: 0.8333 - val_dice_coefficient: 0.3487 - val_jaccard_index: 0.2119 - val_sensitivity: 0.9859 - val_specificity: 0.7605 - val_precision: 0.2125
# Epoch 21/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2627 - accuracy: 0.8430 - dice_coefficient: 0.3667 - jaccard_index: 0.2256 - sensitivity: 0.9805 - specificity: 0.7734 - precision: 0.2266
# Epoch 21: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2626 - accuracy: 0.8431 - dice_coefficient: 0.3664 - jaccard_index: 0.2254 - sensitivity: 0.9805 - specificity: 0.7740 - precision: 0.2264 - val_loss: 0.2537 - val_accuracy: 0.8461 - val_dice_coefficient: 0.3734 - val_jaccard_index: 0.2303 - val_sensitivity: 0.9800 - val_specificity: 0.7859 - val_precision: 0.2313
# Epoch 22/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2590 - accuracy: 0.8451 - dice_coefficient: 0.3707 - jaccard_index: 0.2285 - sensitivity: 0.9816 - specificity: 0.7775 - precision: 0.2295
# Epoch 22: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2588 - accuracy: 0.8453 - dice_coefficient: 0.3704 - jaccard_index: 0.2283 - sensitivity: 0.9816 - specificity: 0.7784 - precision: 0.2292 - val_loss: 0.2554 - val_accuracy: 0.8560 - val_dice_coefficient: 0.3811 - val_jaccard_index: 0.2361 - val_sensitivity: 0.9769 - val_specificity: 0.7938 - val_precision: 0.2374
# Epoch 23/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2586 - accuracy: 0.8458 - dice_coefficient: 0.3702 - jaccard_index: 0.2282 - sensitivity: 0.9815 - specificity: 0.7779 - precision: 0.2292
# Epoch 23: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2587 - accuracy: 0.8458 - dice_coefficient: 0.3697 - jaccard_index: 0.2279 - sensitivity: 0.9814 - specificity: 0.7774 - precision: 0.2289 - val_loss: 0.2543 - val_accuracy: 0.8579 - val_dice_coefficient: 0.3732 - val_jaccard_index: 0.2302 - val_sensitivity: 0.9798 - val_specificity: 0.7868 - val_precision: 0.2313
# Epoch 24/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2577 - accuracy: 0.8461 - dice_coefficient: 0.3733 - jaccard_index: 0.2308 - sensitivity: 0.9818 - specificity: 0.7787 - precision: 0.2318
# Epoch 24: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2577 - accuracy: 0.8460 - dice_coefficient: 0.3734 - jaccard_index: 0.2308 - sensitivity: 0.9819 - specificity: 0.7784 - precision: 0.2318 - val_loss: 0.2792 - val_accuracy: 0.7832 - val_dice_coefficient: 0.2963 - val_jaccard_index: 0.1747 - val_sensitivity: 0.9953 - val_specificity: 0.6930 - val_precision: 0.1748
# Epoch 25/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2551 - accuracy: 0.8479 - dice_coefficient: 0.3752 - jaccard_index: 0.2320 - sensitivity: 0.9820 - specificity: 0.7812 - precision: 0.2330
# Epoch 25: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2551 - accuracy: 0.8479 - dice_coefficient: 0.3759 - jaccard_index: 0.2326 - sensitivity: 0.9820 - specificity: 0.7813 - precision: 0.2336 - val_loss: 0.2487 - val_accuracy: 0.8392 - val_dice_coefficient: 0.3635 - val_jaccard_index: 0.2228 - val_sensitivity: 0.9852 - val_specificity: 0.7754 - val_precision: 0.2235
# Epoch 26/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2497 - accuracy: 0.8508 - dice_coefficient: 0.3809 - jaccard_index: 0.2363 - sensitivity: 0.9834 - specificity: 0.7866 - precision: 0.2372
# Epoch 26: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2499 - accuracy: 0.8507 - dice_coefficient: 0.3806 - jaccard_index: 0.2361 - sensitivity: 0.9834 - specificity: 0.7860 - precision: 0.2371 - val_loss: 0.2454 - val_accuracy: 0.8372 - val_dice_coefficient: 0.3601 - val_jaccard_index: 0.2203 - val_sensitivity: 0.9883 - val_specificity: 0.7714 - val_precision: 0.2208
# Epoch 27/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2501 - accuracy: 0.8505 - dice_coefficient: 0.3822 - jaccard_index: 0.2374 - sensitivity: 0.9830 - specificity: 0.7862 - precision: 0.2384
# Epoch 27: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2501 - accuracy: 0.8505 - dice_coefficient: 0.3817 - jaccard_index: 0.2370 - sensitivity: 0.9829 - specificity: 0.7859 - precision: 0.2380 - val_loss: 0.2582 - val_accuracy: 0.8106 - val_dice_coefficient: 0.3284 - val_jaccard_index: 0.1972 - val_sensitivity: 0.9935 - val_specificity: 0.7359 - val_precision: 0.1974
# Epoch 28/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2479 - accuracy: 0.8517 - dice_coefficient: 0.3844 - jaccard_index: 0.2390 - sensitivity: 0.9837 - specificity: 0.7883 - precision: 0.2399
# Epoch 28: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2478 - accuracy: 0.8517 - dice_coefficient: 0.3837 - jaccard_index: 0.2385 - sensitivity: 0.9835 - specificity: 0.7885 - precision: 0.2394 - val_loss: 0.2430 - val_accuracy: 0.8559 - val_dice_coefficient: 0.3802 - val_jaccard_index: 0.2355 - val_sensitivity: 0.9840 - val_specificity: 0.7912 - val_precision: 0.2364
# Epoch 29/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2468 - accuracy: 0.8527 - dice_coefficient: 0.3833 - jaccard_index: 0.2384 - sensitivity: 0.9834 - specificity: 0.7892 - precision: 0.2394
# Epoch 29: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2468 - accuracy: 0.8527 - dice_coefficient: 0.3833 - jaccard_index: 0.2384 - sensitivity: 0.9834 - specificity: 0.7891 - precision: 0.2394 - val_loss: 0.2413 - val_accuracy: 0.8611 - val_dice_coefficient: 0.3926 - val_jaccard_index: 0.2450 - val_sensitivity: 0.9808 - val_specificity: 0.8025 - val_precision: 0.2462
# Epoch 30/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2431 - accuracy: 0.8549 - dice_coefficient: 0.3891 - jaccard_index: 0.2427 - sensitivity: 0.9839 - specificity: 0.7933 - precision: 0.2437
# Epoch 30: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2430 - accuracy: 0.8550 - dice_coefficient: 0.3891 - jaccard_index: 0.2427 - sensitivity: 0.9836 - specificity: 0.7940 - precision: 0.2437 - val_loss: 0.2527 - val_accuracy: 0.8374 - val_dice_coefficient: 0.3413 - val_jaccard_index: 0.2066 - val_sensitivity: 0.9912 - val_specificity: 0.7520 - val_precision: 0.2069
# Epoch 31/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2419 - accuracy: 0.8552 - dice_coefficient: 0.3905 - jaccard_index: 0.2436 - sensitivity: 0.9843 - specificity: 0.7941 - precision: 0.2445
# Epoch 31: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2418 - accuracy: 0.8553 - dice_coefficient: 0.3912 - jaccard_index: 0.2442 - sensitivity: 0.9843 - specificity: 0.7944 - precision: 0.2451 - val_loss: 0.2385 - val_accuracy: 0.8583 - val_dice_coefficient: 0.3922 - val_jaccard_index: 0.2447 - val_sensitivity: 0.9823 - val_specificity: 0.8014 - val_precision: 0.2457
# Epoch 32/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2394 - accuracy: 0.8569 - dice_coefficient: 0.3945 - jaccard_index: 0.2468 - sensitivity: 0.9846 - specificity: 0.7970 - precision: 0.2478
# Epoch 32: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2396 - accuracy: 0.8567 - dice_coefficient: 0.3942 - jaccard_index: 0.2467 - sensitivity: 0.9846 - specificity: 0.7961 - precision: 0.2476 - val_loss: 0.2397 - val_accuracy: 0.8415 - val_dice_coefficient: 0.3642 - val_jaccard_index: 0.2234 - val_sensitivity: 0.9898 - val_specificity: 0.7752 - val_precision: 0.2238
# Epoch 33/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.8561 - dice_coefficient: 0.3920 - jaccard_index: 0.2450 - sensitivity: 0.9841 - specificity: 0.7952 - precision: 0.2460
# Epoch 33: val_dice_coefficient did not improve from 0.41446
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2405 - accuracy: 0.8562 - dice_coefficient: 0.3922 - jaccard_index: 0.2451 - sensitivity: 0.9841 - specificity: 0.7959 - precision: 0.2461 - val_loss: 0.2384 - val_accuracy: 0.8650 - val_dice_coefficient: 0.4066 - val_jaccard_index: 0.2559 - val_sensitivity: 0.9791 - val_specificity: 0.8137 - val_precision: 0.2573
# Epoch 34/50
# 215/216 [============================>.] - ETA: 0s - loss: 0.2364 - accuracy: 0.8583 - dice_coefficient: 0.3976 - jaccard_index: 0.2492 - sensitivity: 0.9853 - specificity: 0.7992 - precision: 0.2502
# Epoch 34: val_dice_coefficient did not improve from 0.41446
# Restoring model weights from the end of the best epoch: 19.
# 216/216 [==============================] - 32s 148ms/step - loss: 0.2364 - accuracy: 0.8583 - dice_coefficient: 0.3972 - jaccard_index: 0.2489 - sensitivity: 0.9852 - specificity: 0.7992 - precision: 0.2498 - val_loss: 0.2351 - val_accuracy: 0.8580 - val_dice_coefficient: 0.3957 - val_jaccard_index: 0.2474 - val_sensitivity: 0.9829 - val_specificity: 0.8043 - val_precision: 0.2485
# Epoch 34: early stopping
# Model saved to: /gdrive/My Drive/Dataset/Models/unet_vgg_11.h5

# %% [markdown]
# # Evaluation

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_auc_score

# Evaluation functions
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_coefficient'], label='Training Dice Coefficient')
    plt.plot(history.history['val_dice_coefficient'], label='Validation Dice Coefficient')
    plt.title('Dice Coefficient Over Epochs')
    plt.legend()

    plt.show()

def show_predictions(X, y_true, y_pred, threshold=threshold, num_samples=5):
    indices = np.random.choice(range(len(X)), num_samples, replace=False)

    for i in indices:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(X[i])
        plt.title(f'Original Image [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(y_true[i].squeeze(), cmap='gray')
        plt.title(f'True Mask [{i}]')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(y_pred[i].squeeze() > threshold, cmap='gray')  # Apply a threshold to convert probabilities to binary mask
        plt.title(f'Predicted Mask [{i}]')
        plt.axis('off')

        plt.show()

def plot_confusion_matrix(y_true, y_pred, threshold=threshold):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > threshold).astype(int)  # Thresholding probabilities

    cm = confusion_matrix(y_true_f, y_pred_f)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize the confusion matrix

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')

    labels = ['True Negative (Correct: No Buildings)', 'False Positive (Incorrect: There Was No Building)', 'False Negative (Incorrect: There Was A Building Here)', 'True Positive (Correct: There Is A Building Here)']
    counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    percentages = ["{0:.2%}".format(value) for value in cm_normalized.flatten()]

    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(labels, counts, percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', cbar=False, center=0)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Perform the evaluation
plot_training_history(history)
y_pred = model.predict(X_test)
show_predictions(X_test, y_test, y_pred, threshold=threshold)
plot_confusion_matrix(y_test, y_pred, threshold=threshold)
print(classification_report(y_test.flatten(), (y_pred.flatten() > threshold).astype(int)))
print("ROC-AUC:", roc_auc_score(y_test.flatten(), y_pred.flatten()))
# Out:
# 15/15 [==============================] - 31s 1s/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.82      0.90  29326208
#          1.0       0.27      0.95      0.42   2065536
#
#     accuracy                           0.83  31391744
#    macro avg       0.63      0.88      0.66  31391744
# weighted avg       0.95      0.83      0.87  31391744
#
# ROC-AUC: 0.9473224196547947

# %%
from sklearn.metrics import precision_recall_curve, auc

# Calculate pr-aUC
precision, recall, pr_thresholds = precision_recall_curve(y_test.flatten(), y_pred.flatten())
pr_auc = auc(recall, precision)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='PR-AUC = {:.2f}'.format(pr_auc))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()
